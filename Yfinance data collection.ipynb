# %%
############################### Packages ###############################

import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib as plt
import time
from functools import reduce

# %%
############################### History of stock prices ###############################

# List of possible stocks we want to pull from yahoo finance. Found on Nasdaq: https://www.nasdaq.com/market-activity/stocks/screener

nasdaq_dataset = pd.read_csv("C:/Users/CMert/Documents/Bachelor-projekt/Projektet/Data/Stock_names.csv")
print(nasdaq_dataset["Symbol"])
# Out:
# 0          A
# 1         AA
# 2       AACG
# 3       AACT
# 4       AADI
#         ...
# 7010    ZVRA
# 7011    ZVSA
# 7012     ZWS
# 7013    ZYME
# 7014    ZYXI
# Name: Symbol, Length: 7015, dtype: object

# %%
# We create a list, where each element is the dataframe of a stock


def yf_stocks_df(list_of_stock_names):
    
    global stock_df
    stock_df = []
    
    global excluded_stocks
    excluded_stocks = []
    
    for stock in list_of_stock_names:
        try:
            # We combine the data of each stock from yf and add the variables; dividends, stock splits and sector.
            stock_ticker = yf.Ticker(stock)
            stock_data = yf.download(stock, interval = "1d")
            
            # If stock_data is empty, we will skip to the next stock on the list
            if stock_data.empty:
                excluded_stocks.append(stock)
                continue
            
            # The tickers include time in the date column, which is a problem since the stock data does not. Therefore we have to remove the time component.

            # Since "Date" is an index, we first make it a column.
            dividends = pd.DataFrame(stock_ticker.dividends).reset_index()
            splits = pd.DataFrame(stock_ticker.splits).reset_index()
            stock_data = pd.DataFrame(stock_data).reset_index()


            # Now we ensure all dataframes have the same dimension for the "Date".
            dividends['Date'] = pd.to_datetime(dividends['Date']).dt.date
            splits['Date'] = pd.to_datetime(splits['Date']).dt.date
            stock_data['Date'] = pd.to_datetime(stock_data['Date']).dt.date
            
            
            # Merge dividends and splits into the price dataframe by aligning them on the "Date" column. None available values, which can only be found in "Dividends" and "Stock Splits"
            # because we removed all stocks with empty values, is set to 0.

            column_combination = [stock_data, dividends, splits]

            indiv_stock_df = reduce(lambda  left,right: pd.merge(left, right,on=['Date'],how='outer'), column_combination).fillna(0)
            
            time.sleep(0.5)
            # Include "Sector", "Industry" and "Symbol" from nasdaq df.
            indiv_stock_df["Sector"] = nasdaq_dataset.loc[nasdaq_dataset["Symbol"] == stock, "Sector"].iloc[0] 
            
            time.sleep(0.2)
            
            indiv_stock_df["Industry"] = nasdaq_dataset.loc[nasdaq_dataset["Symbol"] == stock, "Industry"].iloc[0] 
            
            time.sleep(0.2)
            
            indiv_stock_df["Symbol"] = stock
            
            stock_df.append(indiv_stock_df)
        
        # If the stock should create an error, we will skip to the next stock.
        except Exception as e:
            excluded_stocks.append(stock)
            continue
        
        time.sleep(0.5)
    
    return excluded_stocks, stock_df

# %%
yf_stocks_df(nasdaq_dataset["Symbol"][3000:])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HNRA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HOFVW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HOLOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HOVRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HPAIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HPP^C']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HSPOR']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HTZWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HUBCW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HUBCZ']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HUMAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Failed to get ticker 'HVT/A' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HVT/A']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HWM^']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HYMCW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HYZNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ICD']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ICR^A']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ICUCW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IFIN']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IGTAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IIPR^A']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['INN^E']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['INN^F']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['INST']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['INTEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['INVO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['INVZW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IPXXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ISRLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ITI']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IVCAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IVCBW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IVCPW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IVR^B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IVR^C']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['IXAQW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JCTCF']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JPM^C']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JPM^D']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JPM^J']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JPM^K']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JPM^L']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JPM^M']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JTAIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JVSAR']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JWSM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['JXN^A']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23) (Yahoo error = "No data found, symbol may be delisted")')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KACLR']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KDLYW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KEY^I']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KEY^J']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KEY^K']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KEY^L']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KIM^L']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KIM^M']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KIM^N']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KITTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KPLTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KREF^A']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['KSM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 1926-02-17 -> 2025-01-23)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...
#   1933  2025-01-23  1.28  1.30  1.27  1.2794     1.2794    7746        0.0
#
#         Stock Splits   Sector                    Industry Symbol
#   0              0.0  Finance  Finance: Consumer Services   MOGO
#   1              0.0  Finance  Finance: Consumer Services   MOGO
#   2              0.0  Finance  Finance: Consumer Services   MOGO
#   3              0.0  Finance  Finance: Consumer Services   MOGO
#   4              0.0  Finance  Finance: Consumer Services   MOGO
#   ...            ...      ...                         ...    ...
#   1929           0.0  Finance  Finance: Consumer Services   MOGO
#   1930           0.0  Finance  Finance: Consumer Services   MOGO
#   1931           0.0  Finance  Finance: Consumer Services   MOGO
#   1932           0.0  Finance  Finance: Consumer Services   MOGO
#   1933           0.0  Finance  Finance: Consumer Services   MOGO
#
#   [1934 rows x 12 columns],
#               Date        Open        High         Low       Close   Adj Close  \
#   0     2018-12-06  144.000000  170.279999  138.960007  168.000000  168.000000
#   1     2018-12-07  166.080002  170.520004  156.000000  161.759995  161.759995
#   2     2018-12-10  160.559998  168.000000  141.600006  150.240005  150.240005
#   3     2018-12-11  151.320007  173.639999  150.839996  168.240005  168.240005
#   4     2018-12-12  160.320007  191.759995  158.759995  174.000000  174.000000
#   ...          ...         ...         ...         ...         ...         ...
#   1535  2025-01-15    2.500000    2.600000    2.295000    2.520000    2.520000
#   1536  2025-01-16    2.480000    2.640000    2.465000    2.550000    2.550000
#   1537  2025-01-17    2.500000    2.640000    2.320000    2.550000    2.550000
#   1538  2025-01-21    2.506000    2.690000    2.340000    2.540000    2.540000
#   1539  2025-01-22    2.440000    2.639000    2.420000    2.542400    2.542400
#
#         Volume  Dividends  Stock Splits                  Sector  \
#   0     283425        0.0           0.0  Consumer Discretionary
#   1      53933        0.0           0.0  Consumer Discretionary
#   2      66283        0.0           0.0  Consumer Discretionary
#   3     117233        0.0           0.0  Consumer Discretionary
#   4      48742        0.0           0.0  Consumer Discretionary
#   ...      ...        ...           ...                     ...
#   1535   26600        0.0           0.0  Consumer Discretionary
#   1536    7800        0.0           0.0  Consumer Discretionary
#   1537   14200        0.0           0.0  Consumer Discretionary
#   1538   16400        0.0           0.0  Consumer Discretionary
#   1539       3        0.0           0.0  Consumer Discretionary
#
#                  Industry Symbol
#   0     Business Services   MOGU
#   1     Business Services   MOGU
#   2     Business Services   MOGU
#   3     Business Services   MOGU
#   4     Business Services   MOGU
#   ...                 ...    ...
#   1535  Business Services   MOGU
#   1536  Business Services   MOGU
#   1537  Business Services   MOGU
#   1538  Business Services   MOGU
#   1539  Business Services   MOGU
#
#   [1540 rows x 12 columns],
#               Date        Open        High         Low       Close   Adj Close  \
#   0     2003-07-02   14.000000   14.160000   13.333333   13.333333   13.333333
#   1     2003-07-03   13.566667   13.766667   13.433333   13.733333   13.733333
#   2     2003-07-07   13.733333   14.333333   13.733333   14.333333   14.333333
#   3     2003-07-08   14.800000   15.066667   14.600000   14.633333   14.633333
#   4     2003-07-09   14.633333   15.000000   14.400000   15.000000   15.000000
#   ...          ...         ...         ...         ...         ...         ...
#   5421  2025-01-16  285.000000  288.700012  281.480011  282.600006  282.600006
#   5422  2025-01-17  283.140015  286.869995  280.000000  286.209991  286.209991
#   5423  2025-01-21  288.869995  297.559998  288.079987  297.440002  297.440002
#   5424  2025-01-22  294.399994  304.309998  291.290009  302.670013  302.670013
#   5425  2025-01-23  307.549988  314.670013  302.369995  305.089996  305.089996
#
#          Volume  Dividends  Stock Splits       Sector              Industry  \
#   0     8133000        0.0           0.0  Health Care  Medical Specialities
#   1      434400        0.0           0.0  Health Care  Medical Specialities
#   2     1237950        0.0           0.0  Health Care  Medical Specialities
#   3      955350        0.0           0.0  Health Care  Medical Specialities
#   4      454200        0.0           0.0  Health Care  Medical Specialities
#   ...       ...        ...           ...          ...                   ...
#   5421   833600        0.0           0.0  Health Care  Medical Specialities
#   5422   838500        0.0           0.0  Health Care  Medical Specialities
#   5423   714100        0.0           0.0  Health Care  Medical Specialities
#   5424   491000        0.0           0.0  Health Care  Medical Specialities
#   5425   169911        0.0           0.0  Health Care  Medical Specialities
#
#        Symbol
#   0       MOH
#   1       MOH
#   2       MOH
#   3       MOH
#   4       MOH
#   ...     ...
#   5421    MOH
#   5422    MOH
#   5423    MOH
#   5424    MOH
#   5425    MOH
#
#   [5426 rows x 12 columns],
#              Date       Open       High        Low    Close  Adj Close   Volume  \
#   0    2021-06-16  20.000000  20.480000  18.000000  19.6500    19.6500  1938800
#   1    2021-06-17  20.160000  20.698999  19.334999  19.7600    19.7600   799600
#   2    2021-06-18  19.330000  19.540001  19.010000  19.2600    19.2600   332700
#   3    2021-06-21  19.440001  19.660000  19.340000  19.6600    19.6600   150500
#   4    2021-06-22  19.200001  19.540001  18.610001  19.4000    19.4000   186800
#   ..          ...        ...        ...        ...      ...        ...      ...
#   900  2025-01-15   5.490000   5.910000   5.490000   5.7800     5.7800    13000
#   901  2025-01-16   5.440000   5.810000   5.440000   5.8100     5.8100     3800
#   902  2025-01-17   5.450000   5.555000   5.400000   5.5550     5.5550     5000
#   903  2025-01-21   5.250000   5.300000   5.250000   5.3000     5.3000     4200
#   904  2025-01-22   5.328100   5.328100   5.328100   5.3281     5.3281     1135
#
#        Dividends  Stock Splits       Sector  \
#   0          0.0           0.0  Health Care
#   1          0.0           0.0  Health Care
#   2          0.0           0.0  Health Care
#   3          0.0           0.0  Health Care
#   4          0.0           0.0  Health Care
#   ..         ...           ...          ...
#   900        0.0           0.0  Health Care
#   901        0.0           0.0  Health Care
#   902        0.0           0.0  Health Care
#   903        0.0           0.0  Health Care
#   904        0.0           0.0  Health Care
#
#                                                 Industry Symbol
#   0    Biotechnology: Biological Products (No Diagnos...   MOLN
#   1    Biotechnology: Biological Products (No Diagnos...   MOLN
#   2    Biotechnology: Biological Products (No Diagnos...   MOLN
#   3    Biotechnology: Biological Products (No Diagnos...   MOLN
#   4    Biotechnology: Biological Products (No Diagnos...   MOLN
#   ..                                                 ...    ...
#   900  Biotechnology: Biological Products (No Diagnos...   MOLN
#   901  Biotechnology: Biological Products (No Diagnos...   MOLN
#   902  Biotechnology: Biological Products (No Diagnos...   MOLN
#   903  Biotechnology: Biological Products (No Diagnos...   MOLN
#   904  Biotechnology: Biological Products (No Diagnos...   MOLN
#
#   [905 rows x 12 columns],
#               Date   Open    High    Low   Close  Adj Close    Volume  \
#   0     2014-12-11  14.25  17.500  13.80  17.020  11.426787  19850700
#   1     2014-12-12  16.50  16.500  14.89  15.150  10.171317   6046700
#   2     2014-12-15  15.21  15.400  13.60  14.460   9.708070   2894900
#   3     2014-12-16  14.46  14.460  13.81  13.920   9.345528   1442600
#   4     2014-12-17  13.80  14.000  13.20  13.290   8.922563   1944600
#   ...          ...    ...     ...    ...     ...        ...       ...
#   2539  2025-01-16   6.87   7.095   6.87   6.970   6.970000    979900
#   2540  2025-01-17   6.98   7.320   6.98   7.230   7.230000    765300
#   2541  2025-01-21   7.31   7.430   7.22   7.240   7.240000    594400
#   2542  2025-01-22   7.19   7.335   7.17   7.210   7.210000    762300
#   2543  2025-01-23   7.25   7.350   7.04   7.045   7.045000    194569
#
#         Dividends  Stock Splits      Sector  \
#   0           0.0           0.0  Technology
#   1           0.0           0.0  Technology
#   2           0.0           0.0  Technology
#   3           0.0           0.0  Technology
#   4           0.0           0.0  Technology
#   ...         ...           ...         ...
#   2539        0.0           0.0  Technology
#   2540        0.0           0.0  Technology
#   2541        0.0           0.0  Technology
#   2542        0.0           0.0  Technology
#   2543        0.0           0.0  Technology
#
#                                        Industry Symbol
#   0     Computer Software: Prepackaged Software   MOMO
#   1     Computer Software: Prepackaged Software   MOMO
#   2     Computer Software: Prepackaged Software   MOMO
#   3     Computer Software: Prepackaged Software   MOMO
#   4     Computer Software: Prepackaged Software   MOMO
#   ...                                       ...    ...
#   2539  Computer Software: Prepackaged Software   MOMO
#   2540  Computer Software: Prepackaged Software   MOMO
#   2541  Computer Software: Prepackaged Software   MOMO
#   2542  Computer Software: Prepackaged Software   MOMO
#   2543  Computer Software: Prepackaged Software   MOMO
#
#   [2544 rows x 12 columns],
#              Date   Open   High     Low   Close  Adj Close  Volume  Dividends  \
#   0    2021-03-24  9.950  9.950  9.6100  9.6400     9.6400    1400        0.0
#   1    2021-03-25  9.640  9.910  9.5100  9.9100     9.9100    3100        0.0
#   2    2021-03-26  9.910  9.910  9.9100  9.9100     9.9100       0        0.0
#   3    2021-03-29  9.680  9.680  9.6800  9.6800     9.6800  148200        0.0
#   4    2021-03-30  9.510  9.700  9.5100  9.6900     9.6900    1300        0.0
#   ..          ...    ...    ...     ...     ...        ...     ...        ...
#   958  2025-01-15  0.005  0.005  0.0050  0.0050     0.0050       0        0.0
#   959  2025-01-16  0.002  0.015  0.0020  0.0020     0.0020  543700        0.0
#   960  2025-01-17  0.002  0.070  0.0020  0.0020     0.0020    7600        0.0
#   961  2025-01-21  0.003  0.003  0.0030  0.0030     0.0030       0        0.0
#   962  2025-01-22  0.004  0.004  0.0001  0.0001     0.0001   65535        0.0
#
#        Stock Splits                  Sector                 Industry Symbol
#   0             0.0  Consumer Discretionary  Transportation Services   MOND
#   1             0.0  Consumer Discretionary  Transportation Services   MOND
#   2             0.0  Consumer Discretionary  Transportation Services   MOND
#   3             0.0  Consumer Discretionary  Transportation Services   MOND
#   4             0.0  Consumer Discretionary  Transportation Services   MOND
#   ..            ...                     ...                      ...    ...
#   958           0.0  Consumer Discretionary  Transportation Services   MOND
#   959           0.0  Consumer Discretionary  Transportation Services   MOND
#   960           0.0  Consumer Discretionary  Transportation Services   MOND
#   961           0.0  Consumer Discretionary  Transportation Services   MOND
#   962           0.0  Consumer Discretionary  Transportation Services   MOND
#
#   [963 rows x 12 columns],
#               Date        Open        High         Low       Close   Adj Close  \
#   0     2005-05-03   18.660000   20.650000   18.510000   20.049999   17.953878
#   1     2005-05-04   20.969999   22.000000   20.250000   21.600000   19.341835
#   2     2005-05-05   23.450001   23.450001   22.090000   22.639999   20.273108
#   3     2005-05-06   23.059999   23.250000   21.549999   21.600000   19.341835
#   4     2005-05-09   21.700001   21.700001   20.500000   20.770000   18.598606
#   ...          ...         ...         ...         ...         ...         ...
#   4959  2025-01-16  327.679993  329.589996  326.040009  328.470001  328.470001
#   4960  2025-01-17  330.829987  332.000000  326.029999  327.170013  327.170013
#   4961  2025-01-21  328.079987  331.049988  327.279999  330.910004  330.910004
#   4962  2025-01-22  331.239990  334.380005  329.320007  329.779999  329.779999
#   4963  2025-01-23  328.390015  330.279999  325.920013  327.589996  327.589996
#
#          Volume  Dividends  Stock Splits   Sector             Industry Symbol
#   0     3273400        0.0           0.0  Finance  Investment Managers   MORN
#   1     1263600        0.0           0.0  Finance  Investment Managers   MORN
#   2      865100        0.0           0.0  Finance  Investment Managers   MORN
#   3      460300        0.0           0.0  Finance  Investment Managers   MORN
#   4      220900        0.0           0.0  Finance  Investment Managers   MORN
#   ...       ...        ...           ...      ...                  ...    ...
#   4959   109200        0.0           0.0  Finance  Investment Managers   MORN
#   4960   134400        0.0           0.0  Finance  Investment Managers   MORN
#   4961   217300        0.0           0.0  Finance  Investment Managers   MORN
#   4962    98200        0.0           0.0  Finance  Investment Managers   MORN
#   4963    18084        0.0           0.0  Finance  Investment Managers   MORN
#
#   [4964 rows x 12 columns],
#               Date       Open       High        Low      Close  Adj Close  \
#   0     1988-01-26  11.500000  11.750000  11.250000  11.500000   6.870531
#   1     1988-01-27  11.562500  12.375000  11.437500  12.375000   7.393289
#   2     1988-01-28  12.250000  12.562500  12.125000  12.562500   7.505311
#   3     1988-01-29  12.437500  12.562500  11.875000  12.250000   7.318611
#   4     1988-02-01  12.125000  12.250000  11.937500  12.000000   7.169253
#   ...          ...        ...        ...        ...        ...        ...
#   9315  2025-01-16  26.910000  26.980000  26.559999  26.719999  26.719999
#   9316  2025-01-17  26.860001  27.309999  26.600000  27.139999  27.139999
#   9317  2025-01-21  26.950001  27.170000  26.610001  27.110001  27.110001
#   9318  2025-01-22  27.830000  28.750000  27.770000  27.799999  27.799999
#   9319  2025-01-23  27.715000  28.609400  27.639999  28.309999  28.309999
#
#          Volume  Dividends  Stock Splits       Sector                Industry  \
#   0     7244600        0.0           0.0  Industrials  Agricultural Chemicals
#   1     3652400        0.0           0.0  Industrials  Agricultural Chemicals
#   2     2180000        0.0           0.0  Industrials  Agricultural Chemicals
#   3     1335400        0.0           0.0  Industrials  Agricultural Chemicals
#   4      488800        0.0           0.0  Industrials  Agricultural Chemicals
#   ...       ...        ...           ...          ...                     ...
#   9315  4254200        0.0           0.0  Industrials  Agricultural Chemicals
#   9316  4350800        0.0           0.0  Industrials  Agricultural Chemicals
#   9317  4686400        0.0           0.0  Industrials  Agricultural Chemicals
#   9318  6783500        0.0           0.0  Industrials  Agricultural Chemicals
#   9319  1056749        0.0           0.0  Industrials  Agricultural Chemicals
#
#        Symbol
#   0       MOS
#   1       MOS
#   2       MOS
#   3       MOS
#   4       MOS
#   ...     ...
#   9315    MOS
#   9316    MOS
#   9317    MOS
#   9318    MOS
#   9319    MOS
#
#   [9320 rows x 12 columns],
#   ...])

# %%
excluded_stocks_list = pd.DataFrame(excluded_stocks, columns=["Stocks"])

excluded_stocks_list.to_csv("excluded_stocks_list.csv", index=False)

# %%
## For itreation 1-3000


# The last step is to remove the stocks on excluded_stocks_list from the Nasdaq dataset, so that we can create a stock dataset with viable data

excluded_stocks_list = pd.read_csv("C:/Users/CMert/Documents/Bachelor-projekt/Projektet/Data/excluded_stocks_list.csv")

nasdaq_true_dataset = nasdaq_dataset[~nasdaq_dataset["Symbol"].isin(excluded_stocks_list["Stocks"])]

nasdaq_true_dataset = nasdaq_true_dataset.reset_index(drop=True)



# All none available elements will be written as "Unknown" and can hence still be used as information for the stock
nasdaq_true_dataset = nasdaq_true_dataset.fillna("Unknown")

nasdaq_true_dataset.to_csv("nasdaq_true_dataset.csv", index=False)

# %%
nasdaq_true_dataset = pd.read_csv("C:/Users/CMert/Documents/Bachelor-projekt/Projektet/Data/nasdaq_true_dataset.csv")

nasdaq_true_dataset
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $140.67
# 1        AA                    Alcoa Corporation Common Stock     $34.93
# 2      AACG   ATA Creativity Global American Depositary Shares   $0.5809
# 3      AACT  Ares Acquisition Corporation II Class A Ordina...    $10.76
# 4      AADI                  Aadi Bioscience Inc. Common Stock     $1.66
# ...     ...                                                ...       ...
# 6675   ZVRA               Zevra Therapeutics Inc. Common Stock   $7.1992
# 6676   ZVSA             ZyVersa Therapeutics Inc. Common Stock     $2.91
# 6677    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $31.92
# 6678   ZYME                        Zymeworks Inc. Common Stock    $11.44
# 6679   ZYXI                            Zynex Inc. Common Stock     $8.34
#
#       Net Change % Change     Market Cap        Country IPO Year   Volume  \
# 0         0.1800   0.128%  41042001864.0  United States   1999.0    73898
# 1         0.3700   1.071%   9023821090.0  United States   2016.0   659537
# 2        -0.0291   -4.77%     18588876.0          China   2008.0    24130
# 3         0.0100   0.093%            0.0        Unknown   2023.0  1782034
# 4        -0.0900  -5.143%     40860624.0  United States  Unknown    29907
# ...          ...      ...            ...            ...      ...      ...
# 6675      0.1292   1.827%    378805987.0  United States  Unknown    56092
# 6676      0.1100   3.929%      2206903.0  United States   2022.0     8986
# 6677     -0.1700   -0.53%   5456037560.0  United States   2012.0    83391
# 6678     -0.1000  -0.867%    812782142.0  United States  Unknown    38478
# 6679     -0.0100   -0.12%    264732633.0  United States  Unknown    14352
#
#            Sector                                           Industry
# 0     Industrials   Biotechnology: Laboratory Analytical Instruments
# 1     Industrials                                           Aluminum
# 2     Real Estate                            Other Consumer Services
# 3         Finance                                       Blank Checks
# 4     Health Care         Biotechnology: Pharmaceutical Preparations
# ...           ...                                                ...
# 6675  Health Care         Biotechnology: Pharmaceutical Preparations
# 6676  Health Care         Biotechnology: Pharmaceutical Preparations
# 6677  Industrials                    Industrial Machinery/Components
# 6678  Health Care         Biotechnology: Pharmaceutical Preparations
# 6679  Health Care  Biotechnology: Electromedical & Electrotherape...
#
# [6680 rows x 11 columns]

# %%
# We save the dataframe of each stock. We can access stock_df from the function since it is defined as globally accessable.

for stock, df in enumerate(stock_df):
    stock_name = nasdaq_true_dataset["Symbol"][stock]
    time.sleep(0.2)
    
    df.to_csv(f'{stock_name}_data.csv', index=False)
    time.sleep(0.2)

# %%
## For iteration 3001 to the last

# The last step is to remove the stocks on empty_stock_list from the Nasdaq dataset, so that we can create a stock dataset with viable data

excluded_stocks_list = pd.read_csv("C:/Users/CMert/Documents/Bachelor-projekt/Projektet/Data/excluded_stocks_list.csv")

nasdaq_true_dataset = nasdaq_true_dataset[~nasdaq_true_dataset["Symbol"].isin(excluded_stocks_list["Stocks"])]

nasdaq_true_dataset = nasdaq_true_dataset.reset_index(drop=True)



# All none available elements will be written as "Unknown" and can hence still be used as information for the stock
nasdaq_true_dataset = nasdaq_true_dataset.fillna("Unknown")

nasdaq_true_dataset.to_csv("nasdaq_true_dataset.csv", index=False)

# %%
nasdaq_true_dataset = pd.read_csv("C:/Users/CMert/Documents/Bachelor-projekt/Projektet/Data/nasdaq_true_dataset.csv")

nasdaq_true_dataset
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $140.67
# 1        AA                    Alcoa Corporation Common Stock     $34.93
# 2      AACG   ATA Creativity Global American Depositary Shares   $0.5809
# 3      AACT  Ares Acquisition Corporation II Class A Ordina...    $10.76
# 4      AADI                  Aadi Bioscience Inc. Common Stock     $1.66
# ...     ...                                                ...       ...
# 6675   ZVRA               Zevra Therapeutics Inc. Common Stock   $7.1992
# 6676   ZVSA             ZyVersa Therapeutics Inc. Common Stock     $2.91
# 6677    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $31.92
# 6678   ZYME                        Zymeworks Inc. Common Stock    $11.44
# 6679   ZYXI                            Zynex Inc. Common Stock     $8.34
#
#       Net Change % Change     Market Cap        Country IPO Year   Volume  \
# 0         0.1800   0.128%  41042001864.0  United States   1999.0    73898
# 1         0.3700   1.071%   9023821090.0  United States   2016.0   659537
# 2        -0.0291   -4.77%     18588876.0          China   2008.0    24130
# 3         0.0100   0.093%            0.0        Unknown   2023.0  1782034
# 4        -0.0900  -5.143%     40860624.0  United States  Unknown    29907
# ...          ...      ...            ...            ...      ...      ...
# 6675      0.1292   1.827%    378805987.0  United States  Unknown    56092
# 6676      0.1100   3.929%      2206903.0  United States   2022.0     8986
# 6677     -0.1700   -0.53%   5456037560.0  United States   2012.0    83391
# 6678     -0.1000  -0.867%    812782142.0  United States  Unknown    38478
# 6679     -0.0100   -0.12%    264732633.0  United States  Unknown    14352
#
#            Sector                                           Industry
# 0     Industrials   Biotechnology: Laboratory Analytical Instruments
# 1     Industrials                                           Aluminum
# 2     Real Estate                            Other Consumer Services
# 3         Finance                                       Blank Checks
# 4     Health Care         Biotechnology: Pharmaceutical Preparations
# ...           ...                                                ...
# 6675  Health Care         Biotechnology: Pharmaceutical Preparations
# 6676  Health Care         Biotechnology: Pharmaceutical Preparations
# 6677  Industrials                    Industrial Machinery/Components
# 6678  Health Care         Biotechnology: Pharmaceutical Preparations
# 6679  Health Care  Biotechnology: Electromedical & Electrotherape...
#
# [6680 rows x 11 columns]

# %%
# I will only use "Sector" and "Industry" in the final dataset. Since most firms in the dataset is located in the US, "location" will be excluded.

# Notice: this is only to get an overview of the variables of the nasdaq dataset.

catog_data_overview = nasdaq_true_dataset.pivot_table(index = ["Industry"], aggfunc = "size")

# catog_data_overview.to_csv("catog_data_overview.csv")

catog_data_overview
# Out:
# Industry
#  Medicinal Chemicals and Botanical Products             31
# Accident &Health Insurance                               5
# Advertising                                             27
# Aerospace                                               29
# Agricultural Chemicals                                  13
#                                                       ...
# Trusts Except Educational Religious and Charitable     118
# Unknown                                                327
# Water Sewer Pipeline Comm & Power Line Construction      6
# Water Supply                                            14
# Wholesale Distributors                                   2
# Length: 150, dtype: int64

# %%
# We can do as we previously did, since we decided to do the data gathering in 2 steps. That's why this algorithm has follow the order of the stock_df and not of nasdaq_true_dataset.

for df in stock_df:
    stock_name = df["Symbol"].iloc[0] 
    time.sleep(0.2)
    
    df.to_csv(f'{stock_name}_data.csv', index=False)
    time.sleep(0.2)

# %%
# We combine all dataframes now. The reason we combine them here was in case the code broke midway or if I got any new ideas.

combined_stock_data_lower = pd.concat(stock_df, ignore_index=True)

combined_stock_data_lower.to_csv('combined_stock_data_lower.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       1 # We combine all dataframes now. The reason we combine them here was in case the code broke midway or if I got any new ideas.
#       3 combined_stock_data_lower = pd.concat(stock_df, ignore_index=True)
# ----> 5 combined_stock_data_lower.to_csv('combined_stock_data_lower.csv', index=False)
#
# File c:\Users\CMert\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File c:\Users\CMert\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\CMert\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\formats\csvs.py:259, in CSVFormatter.save(self)
#     240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#    (...)
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
# --> 259     self._save()
#
# File c:\Users\CMert\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\formats\csvs.py:264, in CSVFormatter._save(self)
#     262 if self._need_to_save_header:
#     263     self._save_header()
# --> 264 self._save_body()
#
# File c:\Users\CMert\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\formats\csvs.py:302, in CSVFormatter._save_body(self)
#     300 if start_i >= end_i:
#     301     break
# --> 302 self._save_chunk(start_i, end_i)
#
# File c:\Users\CMert\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_chunk(self, start_i, end_i)
#     310 data = [res.iget_values(i) for i in range(len(res.items))]
#     312 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 313 libwriters.write_csv_rows(
#     314     data,
#     315     ix,
#     316     self.nlevels,
#     317     self.cols,
#     318     self.writer,
#     319 )
#
# File c:\Users\CMert\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\writers.pyx:72, in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
# Finally we complete the dataframe.

upper_stock_df = pd.read_csv("C:/Users/CMert/Documents/Bachelor-projekt/Projektet/Data/combined_stock_data_upper.csv")

lower_stock_df = pd.read_csv("C:/Users/CMert/Documents/Bachelor-projekt/Projektet/Data/combined_stock_data_lower.csv")


complete_stock_df = pd.concat([upper_stock_df, lower_stock_df], ignore_index=True)

complete_stock_df.to_csv('complete_stock_df.csv', index=False)

complete_stock_df
# Out:
#                 Date       Open       High        Low      Close  Adj Close  \
# 0         1999-11-18  32.546494  35.765381  28.612303  31.473534  26.603025
# 1         1999-11-19  30.713518  30.758226  28.478184  28.880545  24.411301
# 2         1999-11-22  29.551144  31.473534  28.657009  31.473534  26.603025
# 3         1999-11-23  30.400572  31.205294  28.612303  28.612303  24.184568
# 4         1999-11-24  28.701717  29.998213  28.612303  29.372318  24.826971
# ...              ...        ...        ...        ...        ...        ...
# 25904227  2024-09-05   7.750000   7.890000   7.740000   7.890000   7.890000
# 25904228  2024-09-06   7.870000   7.890000   7.680000   7.840000   7.840000
# 25904229  2024-09-09   7.800000   7.850000   7.730000   7.830000   7.830000
# 25904230  2024-09-10   7.860000   8.030000   7.740000   8.020000   8.020000
# 25904231  2024-09-11   8.010000   8.010000   7.800000   7.960000   7.960000
#
#               Volume  Dividends  Stock Splits       Sector  \
# 0         62546380.0        0.0           0.0  Industrials
# 1         15234146.0        0.0           0.0  Industrials
# 2          6577870.0        0.0           0.0  Industrials
# 3          5975611.0        0.0           0.0  Industrials
# 4          4843231.0        0.0           0.0  Industrials
# ...              ...        ...           ...          ...
# 25904227     89600.0        0.0           0.0  Health Care
# 25904228     81600.0        0.0           0.0  Health Care
# 25904229     86400.0        0.0           0.0  Health Care
# 25904230     51200.0        0.0           0.0  Health Care
# 25904231     53900.0        0.0           0.0  Health Care
#
#                                                    Industry Symbol
# 0          Biotechnology: Laboratory Analytical Instruments      A
# 1          Biotechnology: Laboratory Analytical Instruments      A
# 2          Biotechnology: Laboratory Analytical Instruments      A
# 3          Biotechnology: Laboratory Analytical Instruments      A
# 4          Biotechnology: Laboratory Analytical Instruments      A
# ...                                                     ...    ...
# 25904227  Biotechnology: Electromedical & Electrotherape...   ZYXI
# 25904228  Biotechnology: Electromedical & Electrotherape...   ZYXI
# 25904229  Biotechnology: Electromedical & Electrotherape...   ZYXI
# 25904230  Biotechnology: Electromedical & Electrotherape...   ZYXI
# 25904231  Biotechnology: Electromedical & Electrotherape...   ZYXI
#
# [25904232 rows x 12 columns]

# %%
############################### GRAVEYARD ###############################

aapl = yf.download("ZYXI", interval = "1d")

aapl
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2004-02-25  2.636364  2.636364  2.554545  2.563636   1.379478   14080
# 2004-02-26  2.590909  2.636364  2.563636  2.627273   1.413721   65450
# 2004-02-27  2.627273  2.681818  2.590909  2.636364   1.418613   17930
# 2004-03-01  2.681818  2.681818  2.590909  2.627273   1.413721   15950
# 2004-03-02  2.681818  2.745455  2.545455  2.590909   1.394154   31570
# ...              ...       ...       ...       ...        ...     ...
# 2024-09-06  7.870000  7.890000  7.680000  7.840000   7.840000   81600
# 2024-09-09  7.800000  7.850000  7.730000  7.830000   7.830000   86400
# 2024-09-10  7.860000  8.030000  7.740000  8.020000   8.020000   51200
# 2024-09-11  8.010000  8.010000  7.800000  7.960000   7.960000   53900
# 2024-09-12  8.030000  8.070000  7.970000  7.980000   7.980000    5341
#
# [5173 rows x 6 columns]

# %%
kai = pd.read_csv("C:/Users/CMert/Documents/Bachelor-projekt/Projektet/combined_stock_data_lower.csv")
kai
# Out:
#                 Date  Open     High      Low    Close  Adj Close   Volume  \
# 0         1980-03-17  0.00  1.81250  1.68750  1.68750   0.731286  23200.0
# 1         1980-03-18  0.00  1.78125  1.65625  1.65625   0.717744  91200.0
# 2         1980-03-19  0.00  1.81250  1.68750  1.68750   0.731286  20000.0
# 3         1980-03-20  0.00  1.78125  1.65625  1.65625   0.717744   4000.0
# 4         1980-03-21  0.00  1.81250  1.68750  1.68750   0.731286  90400.0
# ...              ...   ...      ...      ...      ...        ...      ...
# 14976785  2024-09-05  7.75  7.89000  7.74000  7.89000   7.890000  89600.0
# 14976786  2024-09-06  7.87  7.89000  7.68000  7.84000   7.840000  81600.0
# 14976787  2024-09-09  7.80  7.85000  7.73000  7.83000   7.830000  86400.0
# 14976788  2024-09-10  7.86  8.03000  7.74000  8.02000   8.020000  51200.0
# 14976789  2024-09-11  8.01  8.01000  7.80000  7.96000   7.960000  53900.0
#
#           Dividends  Stock Splits                  Sector  \
# 0               0.0           0.0  Consumer Discretionary
# 1               0.0           0.0  Consumer Discretionary
# 2               0.0           0.0  Consumer Discretionary
# 3               0.0           0.0  Consumer Discretionary
# 4               0.0           0.0  Consumer Discretionary
# ...             ...           ...                     ...
# 14976785        0.0           0.0             Health Care
# 14976786        0.0           0.0             Health Care
# 14976787        0.0           0.0             Health Care
# 14976788        0.0           0.0             Health Care
# 14976789        0.0           0.0             Health Care
#
#                                                    Industry Symbol
# 0                        Office Equipment/Supplies/Services    HNI
# 1                        Office Equipment/Supplies/Services    HNI
# 2                        Office Equipment/Supplies/Services    HNI
# 3                        Office Equipment/Supplies/Services    HNI
# 4                        Office Equipment/Supplies/Services    HNI
# ...                                                     ...    ...
# 14976785  Biotechnology: Electromedical & Electrotherape...   ZYXI
# 14976786  Biotechnology: Electromedical & Electrotherape...   ZYXI
# 14976787  Biotechnology: Electromedical & Electrotherape...   ZYXI
# 14976788  Biotechnology: Electromedical & Electrotherape...   ZYXI
# 14976789  Biotechnology: Electromedical & Electrotherape...   ZYXI
#
# [14976790 rows x 12 columns]

# %%
nasdaq_true_dataset.loc[nasdaq_true_dataset["Symbol"] == "ZYXI", "Industry"].iloc[0]
# Out:
# 'Biotechnology: Electromedical & Electrotherapeutic Apparatus'

# %%
# We combine the data of each stock from yf and add the variables; dividends, stock splits, sector and.
aapl_ticker = yf.Ticker("AAPL")
aapl_data = yf.download("AAPL")

# The tickers include time in the date column, which is a problem since the stock data does not. Therefore we have to remove the time component.

# Since "Date" is an index, we first make it a column.
dividends = pd.DataFrame(aapl_ticker.dividends).reset_index()
splits = pd.DataFrame(aapl_ticker.splits).reset_index()
aapl_data = pd.DataFrame(aapl_data).reset_index()


# Now we ensure all dataframes have the same dimension for the "Date".
dividends['Date'] = pd.to_datetime(dividends['Date']).dt.date
splits['Date'] = pd.to_datetime(splits['Date']).dt.date
aapl_data['Date'] = pd.to_datetime(aapl_data['Date']).dt.date


# Merge dividends and splits into the price dataframe by aligning them on the "Date" column. None available values, which can only be found in "Dividends" and "Stock Splits"
# because we removed all stocks with empty values, is set to 0.

column_combination = [aapl_data, dividends, splits]

final_yf_df = reduce(lambda  left,right: pd.merge(left, right,on=['Date'],how='outer'), column_combination).fillna(0)

final_yf_df["Sector"] = nasdaq_true_dataset.loc[nasdaq_true_dataset["Symbol"] == "AAPL", "Sector"].iloc[0]

final_yf_df["Industry"] = nasdaq_true_dataset.loc[nasdaq_true_dataset["Symbol"] == "AAPL", "Industry"].iloc[0] 

final_yf_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091631
# ...           ...         ...         ...         ...         ...         ...
# 11021  2024-09-03  228.550003  229.000000  221.169998  222.770004  222.770004
# 11022  2024-09-04  221.660004  221.779999  217.479996  220.850006  220.850006
# 11023  2024-09-05  221.630005  225.479996  221.520004  222.380005  222.380005
# 11024  2024-09-06  223.949997  225.240005  219.770004  220.820007  220.820007
# 11025  2024-09-09  220.899994  221.270004  216.720001  220.910004  220.910004
#
#           Volume  Dividends  Stock Splits      Sector                Industry
# 0      469033600        0.0           0.0  Technology  Computer Manufacturing
# 1      175884800        0.0           0.0  Technology  Computer Manufacturing
# 2      105728000        0.0           0.0  Technology  Computer Manufacturing
# 3       86441600        0.0           0.0  Technology  Computer Manufacturing
# 4       73449600        0.0           0.0  Technology  Computer Manufacturing
# ...          ...        ...           ...         ...                     ...
# 11021   50190600        0.0           0.0  Technology  Computer Manufacturing
# 11022   43840200        0.0           0.0  Technology  Computer Manufacturing
# 11023   36615400        0.0           0.0  Technology  Computer Manufacturing
# 11024   48388600        0.0           0.0  Technology  Computer Manufacturing
# 11025   66246080        0.0           0.0  Technology  Computer Manufacturing
#
# [11026 rows x 11 columns]

# %%
def stocks_not_in_yf(stock_name):
    global empty_stock
    empty_stock = []
    
    global error_stock
    error_stock = []
    
    for stock in stock_name:
        try:
            yf_data_per_stock = yf.download(stock, interval = "1d")
            
            if yf_data_per_stock.empty:
                empty_stock.append(stock)
    
        except Exception as e:
            print(f"The stock, {stock}, gave error: {e}") and error_stock.append(stock)
            
        time.sleep(0.5) # This prevent false positives because the quick moventment of each iteration can create errors
            
            
    return empty_stock, error_stock

# %%
import os
import pandas as pd


folder_path = "C:/Users/CMert/Documents/Aktiepriser"
all_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]


df_list = []
for file_name in all_files:
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    
    # Optional: If you need to track which file/stock this data came from, 
    # you can add a column here:
    # df['stock_symbol'] = file_name.replace('.csv', '')
    
    df_list.append(df)

combined_df = pd.concat(df_list, ignore_index=True)


combined_df.to_csv("combined_stocks.csv", index=False)
