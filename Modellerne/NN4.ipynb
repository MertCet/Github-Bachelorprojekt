# %% [markdown]
# # Prepartions

# %%
import numpy as np
import pandas as pd
from dateutil.relativedelta import relativedelta
from sklearn.linear_model import HuberRegressor
import warnings
warnings.simplefilter(action='ignore', category=Warning)
import matplotlib.pyplot as plt
from sklearn.linear_model import ElasticNet
import matplotlib.dates as mdates
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import ParameterGrid
from datetime import datetime
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid
from joblib import Parallel, delayed
from sklearn.ensemble import RandomForestRegressor
import gc
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

# %%
df_final = pd.read_csv("C:/Users/CMert/Documents/Data bachelorprojekt/The complete dataframe/df_final_cleaned_combined_2_endofmonth.csv")

df_final['Adj Close t+1'] = df_final.groupby("Symbol")["Adj Close"].shift(-1)

df_final = df_final.dropna(subset=['Adj Close t+1']).reset_index(drop=True)

df_final = df_final[df_final['1-month momentum'] != 0]

df_final['Date'] = pd.to_datetime(df_final['Date'])

df_final = df_final.sort_values(by='Date').reset_index(drop=True)

df_final = df_final[df_final['Adj Close t+1'] <= df_final["Adj Close t+1"].quantile(0.985)]



variables = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Dividends',
       'Stock Splits', 'Market capitalization', 'Revenue', 'Earnings',
       'P/E ratio', 'P/B ratio', 'Operating Margin', 'EPS',
       'Shares Outstanding', 'Total assets', 'Total liabilities', 'Total debt',
       'Cash on Hand', 'Net assets', '1-month momentum', '6-month momentum',
       '12-month momentum', '36-month momentum', 'Book-to-market', 'Size']

df_final[variables] = df_final[variables].replace([np.inf, -np.inf], np.nan)

non_negative_variables = [
    'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Dividends',
    'Stock Splits', 'Market capitalization', 'Revenue', 'EPS',
    'Shares Outstanding', 'Total assets', 'Total liabilities', 'Total debt',
    'Cash on Hand', 'Net assets'
]

df_final[non_negative_variables] = df_final[non_negative_variables].applymap(lambda x: max(x, 0))


funda_cols = [
    'Market capitalization', 'Revenue', 'Earnings', 'P/E ratio', 'P/B ratio',
    'Operating Margin', 'EPS', 'Shares Outstanding', 'Total assets',
    'Total liabilities', 'Total debt', 'Cash on Hand', 'Net assets'
]

df_final[funda_cols] = (
    df_final.groupby('Symbol')[funda_cols]
      .shift(12))

df_final = df_final.dropna(subset=variables).reset_index(drop=True)

# %%
df_final
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# 0      1997-02-28   0.150670   0.150670   0.145089   0.145089   0.122524
# 1      1997-02-28   6.937500   6.937500   6.812500   6.812500   2.242910
# 2      1997-02-28  39.187500  39.312500  38.375000  39.312500  32.637779
# 3      1997-02-28  10.625000  10.937500  10.562500  10.875000  10.332757
# 4      1997-02-28  31.500000  31.500000  30.687500  30.687500   9.806581
# ...           ...        ...        ...        ...        ...        ...
# 700452 2024-08-30  38.150002  38.590000  37.830002  38.580002  38.580002
# 700453 2024-08-30  30.900000  31.200001  30.209999  30.440001  30.440001
# 700454 2024-08-30   6.690000   6.880000   6.670000   6.860000   6.860000
# 700455 2024-08-30  51.099998  51.250000  49.590000  50.919998  50.919998
# 700456 2024-08-30   8.060000   8.110000   7.820000   7.860000   7.860000
#
#              Volume  Dividends  Stock Splits                  Sector  ...  \
# 0       121878400.0        0.0           0.0              Technology  ...
# 1            9400.0        0.0           0.0  Consumer Discretionary  ...
# 2          494200.0        0.0           0.0                 Finance  ...
# 3          159200.0        0.0           0.0              Technology  ...
# 4           22000.0        0.0           0.0                 Finance  ...
# ...             ...        ...           ...                     ...  ...
# 700452     539900.0        0.0           0.0               Utilities  ...
# 700453    2364900.0        0.0           0.0  Consumer Discretionary  ...
# 700454    4055300.0        0.0           0.0              Technology  ...
# 700455    1494400.0        0.0           0.0              Technology  ...
# 700456     199800.0        0.0           0.0             Health Care  ...
#
#         Cash on Hand    Net assets  1-month momentum  6-month momentum  \
# 0       1.740000e+09  0.000000e+00         -0.002828          0.006597
# 1       4.700000e+06  8.849816e+07         -0.022543          0.019197
# 2       1.400000e+08  2.293864e+09          2.040556         13.065813
# 3       5.300000e+06  9.747199e+07         -1.425210          6.354053
# 4       6.967000e+07  0.000000e+00          1.078525          3.761210
# ...              ...           ...               ...               ...
# 700452  2.700000e+08  3.020000e+09         -1.464996          3.577999
# 700453  6.953566e+08  1.731511e+09          1.089708          0.321186
# 700454  3.700000e+08  5.990000e+09          0.120000          0.380000
# 700455  3.700000e+08  1.760000e+09         -1.520000         14.780001
# 700456  4.457000e+07  4.612000e+07         -1.140000          5.860001
#
#         12-month momentum  36-month momentum  Book-to-market       Size  \
# 0                0.012723           0.102261       10.516756   0.000000
# 1                0.394677           1.072677        0.668527  18.906044
# 2               25.626753           3.814121        0.645497  22.474418
# 3                6.057135           5.700832        0.062723  19.351977
# 4                6.900859           4.914822        0.355534  21.321768
# ...                   ...                ...             ...        ...
# 700452           5.195873          -2.139236        0.021338  21.436014
# 700453          15.223827          30.727109        0.105255  22.685456
# 700454          -3.950000          13.850000        0.341980  21.832332
# 700455           4.780000          -2.470000       -0.115780  20.748237
# 700456           6.630000           4.153260        0.060806  17.925572
#
#         Symbol  Adj Close t+1
# 0         AAPL       0.137604
# 1          SGC       2.140023
# 2          MTG      29.368822
# 3         NICE       9.738921
# 4          MCY       9.791734
# ...        ...            ...
# 700452     WES      38.299999
# 700453    HTHT      29.340000
# 700454    CLVT       6.550000
# 700455     CLS      43.490002
# 700456    ZYXI       7.960000
#
# [700457 rows x 32 columns]

# %% [markdown]
# # The sampling algorithm

# %%
def recursive_rolling_method(data, initial_date, date_column='Date', 
         train_period = 24, val_period = 24, test_period = 12, freq = 'months'):
    
                
    train_indices_list = []
    val_indices_list = []
    test_indices_list = []

    
    # Define initial interval
    start_train = initial_date
    end_train = start_train + relativedelta(**{freq: train_period})
    
    start_val = end_train + relativedelta(months=1)
    end_val = start_val + relativedelta(**{freq: val_period})
    
    start_test = end_val + relativedelta(months=1)
    end_test = start_test + relativedelta(**{freq: test_period})

    
    while start_test  < data[date_column].max():   
        cur_train_indices = list(data[(data[date_column] >= start_train) & 
                              (data[date_column] < end_train)].index)

        cur_val_indices = list(data[(data[date_column] >= start_val) & 
                                    (data[date_column] < end_val)].index)

        cur_test_indices = list(data[(data[date_column] >= start_test) & 
                                    (data[date_column] < end_test)].index)

        
        print("    Train period:",start_train, "-" , end_train, 
            " || Val period:",start_val, "-" , end_val, 
            " || Test period", start_test, "-", end_test,
            " || Train contains", len(cur_train_indices),
            " || Val contains", len(cur_val_indices) , 
            " || Test contains", len(cur_test_indices))

        train_indices_list.append(cur_train_indices)
        val_indices_list.append(cur_val_indices)
        test_indices_list.append(cur_test_indices)
        
        
        # Define next interval
        
        filler_unit = 1
        start_train = start_train + relativedelta(**{freq: filler_unit}) #  -  this only goes one period ahead for each interval, so they overlap
        
        # start_train = end_test
        end_train = start_train + relativedelta(**{freq: train_period})  
        
        start_val = end_train + relativedelta(months=1)
        end_val = start_val + relativedelta(**{freq: val_period})
            
        start_test = end_val + relativedelta(months=1)
        end_test = start_test + relativedelta(**{freq: test_period})

    # Ensure we have the same output as sklearn sampling packages, since we will use its regressors
    index_output = [(train,val,test) for train,val,test in zip(train_indices_list,val_indices_list,test_indices_list)]
    
    return index_output

# %%
# Create the top and bottom firms by market cap:

top_symbols = (
    df_final.groupby('Symbol')['Market capitalization'].last() 
    .nlargest(500)  
    .index 
)


df_top_500 = df_final[df_final['Symbol'].isin(top_symbols)].reset_index(drop=True)



bottom_symbols = (
    df_final.groupby('Symbol')['Market capitalization'].last() 
    .nsmallest(500)  
    .index 
)


df_bottom_500 = df_final[df_final['Symbol'].isin(bottom_symbols)].reset_index(drop=True)

# %%
df_final.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'Sector', 'Industry',
#        'Market capitalization', 'Revenue', 'Earnings', 'P/E ratio',
#        'P/B ratio', 'Operating Margin', 'EPS', 'Shares Outstanding',
#        'Total assets', 'Total liabilities', 'Total debt', 'Cash on Hand',
#        'Net assets', '1-month momentum', '6-month momentum',
#        '12-month momentum', '36-month momentum', 'Book-to-market', 'Size',
#        'Symbol', 'Adj Close t+1'],
#       dtype='object')

# %% [markdown]
# # NN4 algorithm for all stocks

# %%
X = df_final[['Date'] + variables]
y = df_final["Adj Close t+1"]

X['Date'] = pd.to_datetime(X['Date'])

initial_date = X['Date'].min()

predictions = []
y_test_list = []
dates = []


for split_num, (train_index, val_index, test_index) in enumerate(recursive_rolling_method(X,initial_date,date_column='Date',train_period=8,val_period=3,test_period=1,freq='years')):
    X_train = X.loc[train_index].drop('Date', axis=1)
    y_train = y.loc[train_index]

    X_val = X.loc[val_index].drop('Date', axis=1)
    y_val = y.loc[val_index]

    X_test = X.loc[test_index].drop('Date', axis=1)
    y_test = y.loc[test_index]

    
    input_shape = [X_train.shape[1]]
    
    
    mean_train = X_train.mean(axis=0)
    std_train  = X_train.std(axis=0)
    
    X_train = (X_train-mean_train) / std_train
    X_val = (X_val-mean_train) / std_train
    X_test = (X_test-mean_train) / std_train
    
    
    
    model = tf.keras.Sequential([
 
    tf.keras.layers.Flatten(input_shape=input_shape),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=8, activation='relu'),
    tf.keras.layers.Dense(units=4, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='linear')
    
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0, clipnorm=1.0, clipvalue=0.5), loss='mse')    
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[early_stopping])
    
    preds = model.predict(X_test)
    preds = preds.ravel()


    predictions.append(preds)
    dates.append(X.loc[y_test.index, 'Date'])
    y_test_list.append(y_test)



    del X_train, y_train, X_val, y_val, model, preds
    gc.collect()

    print(f"Completed {split_num + 1} splits")

predictions_all = np.concatenate(predictions, axis=0)
y_test_list_all = pd.concat(y_test_list, axis=0)
dates_all = pd.concat(dates, axis=0)

R2oos_NN4 = 1 - np.sum(np.power(y_test_list_all - predictions_all, 2)) / np.sum(np.power(y_test_list_all, 2))
print("R2_oos NN4:", R2oos_NN4)
# Out:
#     Train period: 1997-02-28 00:00:00 - 2005-02-28 00:00:00  || Val period: 2005-03-28 00:00:00 - 2008-03-28 00:00:00  || Test period 2008-04-28 00:00:00 - 2009-04-28 00:00:00  || Train contains 125811  || Val contains 60364  || Test contains 22228
#     Train period: 1998-02-28 00:00:00 - 2006-02-28 00:00:00  || Val period: 2006-03-28 00:00:00 - 2009-03-28 00:00:00  || Test period 2009-04-28 00:00:00 - 2010-04-28 00:00:00  || Train contains 131822  || Val contains 63246  || Test contains 22915
#     Train period: 1999-02-28 00:00:00 - 2007-02-28 00:00:00  || Val period: 2007-03-28 00:00:00 - 2010-03-28 00:00:00  || Test period 2010-04-28 00:00:00 - 2011-04-28 00:00:00  || Train contains 138129  || Val contains 66069  || Test contains 23302
#     Train period: 2000-02-28 00:00:00 - 2008-02-28 00:00:00  || Val period: 2008-03-28 00:00:00 - 2011-03-28 00:00:00  || Test period 2011-04-28 00:00:00 - 2012-04-28 00:00:00  || Train contains 145727  || Val contains 68275  || Test contains 24233
#     Train period: 2001-02-28 00:00:00 - 2009-02-28 00:00:00  || Val period: 2009-03-28 00:00:00 - 2012-03-28 00:00:00  || Test period 2012-04-28 00:00:00 - 2013-04-28 00:00:00  || Train contains 154291  || Val contains 70279  || Test contains 25026
#     Train period: 2002-02-28 00:00:00 - 2010-02-28 00:00:00  || Val period: 2010-03-28 00:00:00 - 2013-03-28 00:00:00  || Test period 2013-04-28 00:00:00 - 2014-04-28 00:00:00  || Train contains 160611  || Val contains 72378  || Test contains 25892
#     Train period: 2003-02-28 00:00:00 - 2011-02-28 00:00:00  || Val period: 2011-03-28 00:00:00 - 2014-03-28 00:00:00  || Test period 2014-04-28 00:00:00 - 2015-04-28 00:00:00  || Train contains 164593  || Val contains 74932  || Test contains 26971
#     Train period: 2004-02-28 00:00:00 - 2012-02-28 00:00:00  || Val period: 2012-03-28 00:00:00 - 2015-03-28 00:00:00  || Test period 2015-04-28 00:00:00 - 2016-04-28 00:00:00  || Train contains 169186  || Val contains 77654  || Test contains 28571
#     Train period: 2005-02-28 00:00:00 - 2013-02-28 00:00:00  || Val period: 2013-03-28 00:00:00 - 2016-03-28 00:00:00  || Test period 2016-04-28 00:00:00 - 2017-04-28 00:00:00  || Train contains 177222  || Val contains 81098  || Test contains 30144
#     Train period: 2006-02-28 00:00:00 - 2014-02-28 00:00:00  || Val period: 2014-03-28 00:00:00 - 2017-03-28 00:00:00  || Test period 2017-04-28 00:00:00 - 2018-04-28 00:00:00  || Train contains 183762  || Val contains 85324  || Test contains 31225
#     Train period: 2007-02-28 00:00:00 - 2015-02-28 00:00:00  || Val period: 2015-03-28 00:00:00 - 2018-03-28 00:00:00  || Test period 2018-04-28 00:00:00 - 2019-04-28 00:00:00  || Train contains 192835  || Val contains 89583  || Test contains 32854
#     Train period: 2008-02-28 00:00:00 - 2016-02-28 00:00:00  || Val period: 2016-03-28 00:00:00 - 2019-03-28 00:00:00  || Test period 2019-04-28 00:00:00 - 2020-04-28 00:00:00  || Train contains 197855  || Val contains 93855  || Test contains 34953
#     Train period: 2009-02-28 00:00:00 - 2017-02-28 00:00:00  || Val period: 2017-03-28 00:00:00 - 2020-03-28 00:00:00  || Test period 2020-04-28 00:00:00 - 2021-04-28 00:00:00  || Train contains 203846  || Val contains 98599  || Test contains 36696
#     Train period: 2010-02-28 00:00:00 - 2018-02-28 00:00:00  || Val period: 2018-03-28 00:00:00 - 2021-03-28 00:00:00  || Test period 2021-04-28 00:00:00 - 2022-04-28 00:00:00  || Train contains 211989  || Val contains 104036  || Test contains 38776
#     Train period: 2011-02-28 00:00:00 - 2019-02-28 00:00:00  || Val period: 2019-03-28 00:00:00 - 2022-03-28 00:00:00  || Test period 2022-04-28 00:00:00 - 2023-04-28 00:00:00  || Train contains 223231  || Val contains 109838  || Test contains 43268
#     Train period: 2012-02-28 00:00:00 - 2020-02-28 00:00:00  || Val period: 2020-03-28 00:00:00 - 2023-03-28 00:00:00  || Test period 2023-04-28 00:00:00 - 2024-04-28 00:00:00  || Train contains 233783  || Val contains 117996  || Test contains 45045
#     Train period: 2013-02-28 00:00:00 - 2021-02-28 00:00:00  || Val period: 2021-03-28 00:00:00 - 2024-03-28 00:00:00  || Test period 2024-04-28 00:00:00 - 2025-04-28 00:00:00  || Train contains 248405  || Val contains 126449  || Test contains 18811
# Epoch 1/100
# 3932/3932 [==============================] - 4s 869us/step - loss: 463.4136 - val_loss: 982.6575
# Epoch 2/100
# 3932/3932 [==============================] - 3s 888us/step - loss: 115.2224 - val_loss: 631.4695
# Epoch 3/100
# 3932/3932 [==============================] - 4s 985us/step - loss: 88.6564 - val_loss: 133.5558
# Epoch 4/100
# 3932/3932 [==============================] - 3s 859us/step - loss: 76.1466 - val_loss: 94.4529
# Epoch 5/100
# 3932/3932 [==============================] - 3s 810us/step - loss: 71.5641 - val_loss: 68.7491
# Epoch 6/100
# 3932/3932 [==============================] - 3s 808us/step - loss: 67.6024 - val_loss: 57.4843
# Epoch 7/100
# 3932/3932 [==============================] - 3s 833us/step - loss: 66.0751 - val_loss: 50.8547
# Epoch 8/100
# 3932/3932 [==============================] - 3s 837us/step - loss: 64.9519 - val_loss: 46.0627
# Epoch 9/100
# 3932/3932 [==============================] - 3s 816us/step - loss: 64.2880 - val_loss: 47.3676
# Epoch 10/100
# 3932/3932 [==============================] - 3s 807us/step - loss: 63.1639 - val_loss: 42.6503
# Epoch 11/100
# 3932/3932 [==============================] - 3s 821us/step - loss: 62.7338 - val_loss: 38.5686
# Epoch 12/100
# 3932/3932 [==============================] - 3s 810us/step - loss: 62.2052 - val_loss: 37.4997
# Epoch 13/100
# 3932/3932 [==============================] - 3s 810us/step - loss: 62.2454 - val_loss: 37.0676
# Epoch 14/100
# 3932/3932 [==============================] - 3s 815us/step - loss: 61.8713 - val_loss: 38.7381
# Epoch 15/100
# 3932/3932 [==============================] - 3s 811us/step - loss: 61.8301 - val_loss: 36.3543
# Epoch 16/100
# 3932/3932 [==============================] - 3s 817us/step - loss: 61.4221 - val_loss: 37.9419
# Epoch 17/100
# 3932/3932 [==============================] - 3s 830us/step - loss: 61.1266 - val_loss: 36.9438
# Epoch 18/100
# 3932/3932 [==============================] - 3s 817us/step - loss: 60.8939 - val_loss: 36.5547
# Epoch 19/100
# 3932/3932 [==============================] - 3s 809us/step - loss: 60.8999 - val_loss: 36.5920
# Epoch 20/100
# 3932/3932 [==============================] - 3s 808us/step - loss: 60.2636 - val_loss: 36.3183
# Epoch 21/100
# 3932/3932 [==============================] - 3s 810us/step - loss: 60.6690 - val_loss: 36.1782
# Epoch 22/100
# 3932/3932 [==============================] - 3s 815us/step - loss: 60.1212 - val_loss: 37.3096
# Epoch 23/100
# 3932/3932 [==============================] - 3s 813us/step - loss: 60.0997 - val_loss: 37.2201
# Epoch 24/100
# 3932/3932 [==============================] - 3s 826us/step - loss: 60.1244 - val_loss: 38.1903
# Epoch 25/100
# 3932/3932 [==============================] - 3s 828us/step - loss: 60.2052 - val_loss: 36.3601
# Epoch 26/100
# 3932/3932 [==============================] - 3s 826us/step - loss: 59.8169 - val_loss: 37.0736
# 695/695 [==============================] - 0s 475us/step
# Completed 1 splits
# Epoch 1/100
# 4120/4120 [==============================] - 4s 851us/step - loss: 559.4033 - val_loss: 500.5571
# Epoch 2/100
# 4120/4120 [==============================] - 3s 827us/step - loss: 118.8285 - val_loss: 351.3120
# Epoch 3/100
# 4120/4120 [==============================] - 3s 818us/step - loss: 80.2839 - val_loss: 116.4865
# Epoch 4/100
# 4120/4120 [==============================] - 4s 857us/step - loss: 67.6637 - val_loss: 54.2486
# Epoch 5/100
# 4120/4120 [==============================] - 3s 838us/step - loss: 64.1156 - val_loss: 49.6647
# Epoch 6/100
# 4120/4120 [==============================] - 4s 873us/step - loss: 63.0788 - val_loss: 47.9478
# Epoch 7/100
# 4120/4120 [==============================] - 4s 927us/step - loss: 62.3108 - val_loss: 46.3445
# Epoch 8/100
# 4120/4120 [==============================] - 4s 907us/step - loss: 61.7998 - val_loss: 46.5246
# Epoch 9/100
# 4120/4120 [==============================] - 3s 839us/step - loss: 61.5445 - val_loss: 45.2619
# Epoch 10/100
# 4120/4120 [==============================] - 3s 849us/step - loss: 61.2980 - val_loss: 44.9490
# Epoch 11/100
# 4120/4120 [==============================] - 3s 813us/step - loss: 61.0541 - val_loss: 45.5025
# Epoch 12/100
# 4120/4120 [==============================] - 3s 809us/step - loss: 60.9845 - val_loss: 43.4515
# Epoch 13/100
# 4120/4120 [==============================] - 3s 824us/step - loss: 60.6982 - val_loss: 42.9717
# Epoch 14/100
# 4120/4120 [==============================] - 3s 815us/step - loss: 60.4583 - val_loss: 42.5657
# Epoch 15/100
# 4120/4120 [==============================] - 3s 801us/step - loss: 60.6127 - val_loss: 42.5297
# Epoch 16/100
# 4120/4120 [==============================] - 3s 821us/step - loss: 60.3071 - val_loss: 42.9280
# Epoch 17/100
# 4120/4120 [==============================] - 3s 815us/step - loss: 59.9923 - val_loss: 43.0136
# Epoch 18/100
# 4120/4120 [==============================] - 3s 826us/step - loss: 59.8770 - val_loss: 42.7552
# Epoch 19/100
# 4120/4120 [==============================] - 3s 821us/step - loss: 59.8703 - val_loss: 42.8840
# Epoch 20/100
# 4120/4120 [==============================] - 3s 816us/step - loss: 59.7032 - val_loss: 42.4950
# Epoch 21/100
# 4120/4120 [==============================] - 3s 831us/step - loss: 59.7461 - val_loss: 41.5782
# Epoch 22/100
# 4120/4120 [==============================] - 3s 818us/step - loss: 59.4107 - val_loss: 41.3660
# Epoch 23/100
# 4120/4120 [==============================] - 3s 823us/step - loss: 59.7694 - val_loss: 42.5517
# Epoch 24/100
# 4120/4120 [==============================] - 3s 810us/step - loss: 59.3324 - val_loss: 41.1825
# Epoch 25/100
# 4120/4120 [==============================] - 3s 831us/step - loss: 59.4887 - val_loss: 41.0702
# Epoch 26/100
# 4120/4120 [==============================] - 3s 810us/step - loss: 59.2048 - val_loss: 41.4477
# Epoch 27/100
# 4120/4120 [==============================] - 3s 806us/step - loss: 59.3868 - val_loss: 41.6010
# Epoch 28/100
# 4120/4120 [==============================] - 3s 813us/step - loss: 59.2345 - val_loss: 40.9365
# Epoch 29/100
# 4120/4120 [==============================] - 3s 809us/step - loss: 59.0080 - val_loss: 40.9657
# Epoch 30/100
# 4120/4120 [==============================] - 3s 816us/step - loss: 59.3091 - val_loss: 42.6490
# Epoch 31/100
# 4120/4120 [==============================] - 3s 815us/step - loss: 59.3001 - val_loss: 42.1222
# Epoch 32/100
# 4120/4120 [==============================] - 3s 814us/step - loss: 59.3008 - val_loss: 43.3981
# Epoch 33/100
# 4120/4120 [==============================] - 3s 816us/step - loss: 59.0428 - val_loss: 40.8236
# Epoch 34/100
# 4120/4120 [==============================] - 3s 807us/step - loss: 58.8971 - val_loss: 40.8696
# Epoch 35/100
# 4120/4120 [==============================] - 3s 816us/step - loss: 58.8389 - val_loss: 40.9114
# Epoch 36/100
# 4120/4120 [==============================] - 3s 813us/step - loss: 59.2588 - val_loss: 40.5795
# Epoch 37/100
# 4120/4120 [==============================] - 3s 817us/step - loss: 58.6009 - val_loss: 40.7776
# Epoch 38/100
# 4120/4120 [==============================] - 3s 815us/step - loss: 58.4013 - val_loss: 41.7936
# Epoch 39/100
# 4120/4120 [==============================] - 3s 822us/step - loss: 58.5679 - val_loss: 40.7751
# Epoch 40/100
# 4120/4120 [==============================] - 3s 813us/step - loss: 58.5158 - val_loss: 40.8558
# Epoch 41/100
# 4120/4120 [==============================] - 3s 821us/step - loss: 58.6963 - val_loss: 40.2810
# Epoch 42/100
# 4120/4120 [==============================] - 3s 817us/step - loss: 58.5819 - val_loss: 40.7123
# Epoch 43/100
# 4120/4120 [==============================] - 3s 813us/step - loss: 58.3391 - val_loss: 40.4447
# Epoch 44/100
# 4120/4120 [==============================] - 3s 820us/step - loss: 58.5713 - val_loss: 40.8654
# Epoch 45/100
# 4120/4120 [==============================] - 3s 814us/step - loss: 58.4324 - val_loss: 40.4046
# Epoch 46/100
# 4120/4120 [==============================] - 3s 819us/step - loss: 58.3675 - val_loss: 40.3697
# 717/717 [==============================] - 0s 473us/step
# Completed 2 splits
# Epoch 1/100
# 4317/4317 [==============================] - 4s 846us/step - loss: 472.9464 - val_loss: 451.3892
# Epoch 2/100
# 4317/4317 [==============================] - 4s 820us/step - loss: 91.9483 - val_loss: 73.2084
# Epoch 3/100
# 4317/4317 [==============================] - 4s 826us/step - loss: 64.0879 - val_loss: 55.2336
# Epoch 4/100
# 4317/4317 [==============================] - 4s 823us/step - loss: 61.3526 - val_loss: 53.7835
# Epoch 5/100
# 4317/4317 [==============================] - 4s 826us/step - loss: 59.6607 - val_loss: 51.8780
# Epoch 6/100
# 4317/4317 [==============================] - 4s 830us/step - loss: 58.9531 - val_loss: 51.0397
# Epoch 7/100
# 4317/4317 [==============================] - 4s 822us/step - loss: 57.9499 - val_loss: 50.3023
# Epoch 8/100
# 4317/4317 [==============================] - 4s 825us/step - loss: 57.7707 - val_loss: 51.3615
# Epoch 9/100
# 4317/4317 [==============================] - 4s 820us/step - loss: 57.5117 - val_loss: 51.2451
# Epoch 10/100
# 4317/4317 [==============================] - 4s 835us/step - loss: 57.3927 - val_loss: 50.3221
# Epoch 11/100
# 4317/4317 [==============================] - 4s 826us/step - loss: 56.9865 - val_loss: 52.4204
# Epoch 12/100
# 4317/4317 [==============================] - 4s 819us/step - loss: 56.7616 - val_loss: 51.6477
# 729/729 [==============================] - 0s 497us/step
# Completed 3 splits
# Epoch 1/100
# 4554/4554 [==============================] - 4s 843us/step - loss: 464.9532 - val_loss: 197.9050
# Epoch 2/100
# 4554/4554 [==============================] - 4s 820us/step - loss: 98.5152 - val_loss: 78.8010
# Epoch 3/100
# 4554/4554 [==============================] - 4s 813us/step - loss: 68.3778 - val_loss: 66.5162
# Epoch 4/100
# 4554/4554 [==============================] - 4s 816us/step - loss: 61.4259 - val_loss: 66.1398
# Epoch 5/100
# 4554/4554 [==============================] - 4s 811us/step - loss: 59.0774 - val_loss: 67.6113
# Epoch 6/100
# 4554/4554 [==============================] - 4s 813us/step - loss: 57.6803 - val_loss: 63.0933
# Epoch 7/100
# 4554/4554 [==============================] - 4s 821us/step - loss: 56.4674 - val_loss: 56.7501
# Epoch 8/100
# 4554/4554 [==============================] - 4s 818us/step - loss: 56.2210 - val_loss: 57.0948
# Epoch 9/100
# 4554/4554 [==============================] - 4s 821us/step - loss: 55.8644 - val_loss: 54.5213
# Epoch 10/100
# 4554/4554 [==============================] - 4s 822us/step - loss: 55.6825 - val_loss: 55.1158
# Epoch 11/100
# 4554/4554 [==============================] - 4s 816us/step - loss: 55.5908 - val_loss: 51.6547
# Epoch 12/100
# 4554/4554 [==============================] - 4s 818us/step - loss: 55.4416 - val_loss: 51.3738
# Epoch 13/100
# 4554/4554 [==============================] - 4s 817us/step - loss: 55.4645 - val_loss: 51.4316
# Epoch 14/100
# 4554/4554 [==============================] - 4s 813us/step - loss: 55.2393 - val_loss: 48.1433
# Epoch 15/100
# 4554/4554 [==============================] - 4s 813us/step - loss: 54.8502 - val_loss: 49.9895
# Epoch 16/100
# 4554/4554 [==============================] - 4s 817us/step - loss: 54.8450 - val_loss: 48.3791
# Epoch 17/100
# 4554/4554 [==============================] - 4s 817us/step - loss: 54.6144 - val_loss: 48.5843
# Epoch 18/100
# 4554/4554 [==============================] - 4s 839us/step - loss: 54.7154 - val_loss: 48.1762
# Epoch 19/100
# 4554/4554 [==============================] - 4s 821us/step - loss: 54.9729 - val_loss: 47.9204
# Epoch 20/100
# 4554/4554 [==============================] - 4s 816us/step - loss: 54.7819 - val_loss: 48.9542
# Epoch 21/100
# 4554/4554 [==============================] - 4s 816us/step - loss: 54.6602 - val_loss: 47.5148
# Epoch 22/100
# 4554/4554 [==============================] - 4s 844us/step - loss: 54.6335 - val_loss: 46.9415
# Epoch 23/100
# 4554/4554 [==============================] - 4s 842us/step - loss: 54.5538 - val_loss: 47.2991
# Epoch 24/100
# 4554/4554 [==============================] - 5s 1ms/step - loss: 54.2713 - val_loss: 46.6865
# Epoch 25/100
# 4554/4554 [==============================] - 4s 918us/step - loss: 54.4689 - val_loss: 47.6620
# Epoch 26/100
# 4554/4554 [==============================] - 4s 905us/step - loss: 54.2189 - val_loss: 46.3300
# Epoch 27/100
# 4554/4554 [==============================] - 4s 906us/step - loss: 54.2526 - val_loss: 46.5159
# Epoch 28/100
# 4554/4554 [==============================] - 4s 923us/step - loss: 54.1117 - val_loss: 45.7787
# Epoch 29/100
# 4554/4554 [==============================] - 4s 968us/step - loss: 53.8958 - val_loss: 46.3998
# Epoch 30/100
# 4554/4554 [==============================] - 4s 907us/step - loss: 53.7066 - val_loss: 47.2798
# Epoch 31/100
# 4554/4554 [==============================] - 4s 939us/step - loss: 53.8920 - val_loss: 47.6044
# Epoch 32/100
# 4554/4554 [==============================] - 4s 967us/step - loss: 53.7864 - val_loss: 46.6371
# Epoch 33/100
# 4554/4554 [==============================] - 4s 986us/step - loss: 53.6588 - val_loss: 46.3236
# 758/758 [==============================] - 1s 684us/step
# Completed 4 splits
# Epoch 1/100
# 4822/4822 [==============================] - 5s 895us/step - loss: 450.3804 - val_loss: 116.7619
# Epoch 2/100
# 4822/4822 [==============================] - 4s 871us/step - loss: 124.5752 - val_loss: 63.4582
# Epoch 3/100
# 4822/4822 [==============================] - 4s 906us/step - loss: 82.2634 - val_loss: 48.0146
# Epoch 4/100
# 4822/4822 [==============================] - 4s 880us/step - loss: 64.0298 - val_loss: 42.6301
# Epoch 5/100
# 4822/4822 [==============================] - 4s 891us/step - loss: 57.7584 - val_loss: 41.3334
# Epoch 6/100
# 4822/4822 [==============================] - 4s 868us/step - loss: 55.8862 - val_loss: 40.3080
# Epoch 7/100
# 4822/4822 [==============================] - 4s 869us/step - loss: 55.4095 - val_loss: 41.2674
# Epoch 8/100
# 4822/4822 [==============================] - 4s 854us/step - loss: 54.3896 - val_loss: 40.2102
# Epoch 9/100
# 4822/4822 [==============================] - 4s 855us/step - loss: 53.9515 - val_loss: 39.4463
# Epoch 10/100
# 4822/4822 [==============================] - 4s 905us/step - loss: 53.4438 - val_loss: 40.8680
# Epoch 11/100
# 4822/4822 [==============================] - 4s 864us/step - loss: 53.4130 - val_loss: 39.3111
# Epoch 12/100
# 4822/4822 [==============================] - 4s 875us/step - loss: 53.2514 - val_loss: 39.5230
# Epoch 13/100
# 4822/4822 [==============================] - 4s 852us/step - loss: 52.9037 - val_loss: 39.1628
# Epoch 14/100
# 4822/4822 [==============================] - 4s 869us/step - loss: 52.8494 - val_loss: 39.1083
# Epoch 15/100
# 4822/4822 [==============================] - 4s 874us/step - loss: 52.2289 - val_loss: 39.3730
# Epoch 16/100
# 4822/4822 [==============================] - 4s 920us/step - loss: 52.3341 - val_loss: 38.7182
# Epoch 17/100
# 4822/4822 [==============================] - 5s 1ms/step - loss: 51.8923 - val_loss: 38.8946
# Epoch 18/100
# 4822/4822 [==============================] - 5s 945us/step - loss: 51.6026 - val_loss: 38.7123
# Epoch 19/100
# 4822/4822 [==============================] - 4s 849us/step - loss: 51.2080 - val_loss: 38.8152
# Epoch 20/100
# 4822/4822 [==============================] - 4s 864us/step - loss: 51.0776 - val_loss: 38.7051
# Epoch 21/100
# 4822/4822 [==============================] - 4s 920us/step - loss: 50.9663 - val_loss: 38.4716
# Epoch 22/100
# 4822/4822 [==============================] - 4s 877us/step - loss: 50.7915 - val_loss: 38.3272
# Epoch 23/100
# 4822/4822 [==============================] - 4s 867us/step - loss: 50.8740 - val_loss: 38.9647
# Epoch 24/100
# 4822/4822 [==============================] - 4s 861us/step - loss: 50.7582 - val_loss: 39.2453
# Epoch 25/100
# 4822/4822 [==============================] - 4s 860us/step - loss: 50.7263 - val_loss: 38.2093
# Epoch 26/100
# 4822/4822 [==============================] - 5s 1ms/step - loss: 50.6872 - val_loss: 38.2311
# Epoch 27/100
# 4822/4822 [==============================] - 4s 905us/step - loss: 50.1289 - val_loss: 38.1754
# Epoch 28/100
# 4822/4822 [==============================] - 4s 928us/step - loss: 50.2121 - val_loss: 38.8640
# Epoch 29/100
# 4822/4822 [==============================] - 5s 945us/step - loss: 50.0383 - val_loss: 38.1098
# Epoch 30/100
# 4822/4822 [==============================] - 4s 916us/step - loss: 49.9771 - val_loss: 38.1269
# Epoch 31/100
# 4822/4822 [==============================] - 4s 920us/step - loss: 50.0898 - val_loss: 39.2698
# Epoch 32/100
# 4822/4822 [==============================] - 4s 918us/step - loss: 49.7800 - val_loss: 38.0702
# Epoch 33/100
# 4822/4822 [==============================] - 4s 930us/step - loss: 49.9603 - val_loss: 37.9870
# Epoch 34/100
# 4822/4822 [==============================] - 5s 937us/step - loss: 49.7438 - val_loss: 38.3788
# Epoch 35/100
# 4822/4822 [==============================] - 4s 916us/step - loss: 49.4590 - val_loss: 38.0061
# Epoch 36/100
# 4822/4822 [==============================] - 4s 904us/step - loss: 49.5621 - val_loss: 38.1942
# Epoch 37/100
# 4822/4822 [==============================] - 4s 919us/step - loss: 49.6280 - val_loss: 38.6608
# Epoch 38/100
# 4822/4822 [==============================] - 4s 906us/step - loss: 49.6561 - val_loss: 37.6835
# Epoch 39/100
# 4822/4822 [==============================] - 4s 916us/step - loss: 49.6431 - val_loss: 37.9446
# Epoch 40/100
# 4822/4822 [==============================] - 4s 912us/step - loss: 49.2923 - val_loss: 37.7817
# Epoch 41/100
# 4822/4822 [==============================] - 4s 904us/step - loss: 49.3992 - val_loss: 37.8665
# Epoch 42/100
# 4822/4822 [==============================] - 4s 896us/step - loss: 49.4770 - val_loss: 37.7476
# Epoch 43/100
# 4822/4822 [==============================] - 4s 901us/step - loss: 49.3581 - val_loss: 37.7796
# 783/783 [==============================] - 0s 559us/step
# Completed 5 splits
# Epoch 1/100
# 5020/5020 [==============================] - 5s 930us/step - loss: 408.3033 - val_loss: 91.3316
# Epoch 2/100
# 5020/5020 [==============================] - 5s 915us/step - loss: 62.3907 - val_loss: 39.8016
# Epoch 3/100
# 5020/5020 [==============================] - 5s 919us/step - loss: 45.7269 - val_loss: 36.6015
# Epoch 4/100
# 5020/5020 [==============================] - 5s 913us/step - loss: 41.7372 - val_loss: 34.4543
# Epoch 5/100
# 5020/5020 [==============================] - 5s 912us/step - loss: 39.6576 - val_loss: 33.4598
# Epoch 6/100
# 5020/5020 [==============================] - 5s 905us/step - loss: 38.3283 - val_loss: 32.7971
# Epoch 7/100
# 5020/5020 [==============================] - 5s 911us/step - loss: 38.0561 - val_loss: 32.9377
# Epoch 8/100
# 5020/5020 [==============================] - 5s 911us/step - loss: 37.9674 - val_loss: 32.1923
# Epoch 9/100
# 5020/5020 [==============================] - 5s 917us/step - loss: 37.7511 - val_loss: 31.9611
# Epoch 10/100
# 5020/5020 [==============================] - 5s 919us/step - loss: 37.6212 - val_loss: 31.7686
# Epoch 11/100
# 5020/5020 [==============================] - 5s 907us/step - loss: 37.7389 - val_loss: 31.4576
# Epoch 12/100
# 5020/5020 [==============================] - 5s 903us/step - loss: 37.5820 - val_loss: 31.7154
# Epoch 13/100
# 5020/5020 [==============================] - 5s 908us/step - loss: 37.4797 - val_loss: 32.6898
# Epoch 14/100
# 5020/5020 [==============================] - 5s 911us/step - loss: 37.3459 - val_loss: 32.0708
# Epoch 15/100
# 5020/5020 [==============================] - 5s 923us/step - loss: 37.3189 - val_loss: 30.9723
# Epoch 16/100
# 5020/5020 [==============================] - 5s 910us/step - loss: 37.0930 - val_loss: 30.8995
# Epoch 17/100
# 5020/5020 [==============================] - 5s 920us/step - loss: 37.0669 - val_loss: 31.8530
# Epoch 18/100
# 5020/5020 [==============================] - 5s 917us/step - loss: 37.0520 - val_loss: 31.1114
# Epoch 19/100
# 5020/5020 [==============================] - 5s 949us/step - loss: 36.9774 - val_loss: 31.4517
# Epoch 20/100
# 5020/5020 [==============================] - 5s 934us/step - loss: 36.8738 - val_loss: 30.7644
# Epoch 21/100
# 5020/5020 [==============================] - 5s 943us/step - loss: 36.4320 - val_loss: 30.8825
# Epoch 22/100
# 5020/5020 [==============================] - 5s 944us/step - loss: 36.6494 - val_loss: 30.9865
# Epoch 23/100
# 5020/5020 [==============================] - 5s 955us/step - loss: 36.6586 - val_loss: 30.6276
# Epoch 24/100
# 5020/5020 [==============================] - 5s 945us/step - loss: 36.5875 - val_loss: 30.6406
# Epoch 25/100
# 5020/5020 [==============================] - 5s 931us/step - loss: 36.4668 - val_loss: 31.3698
# Epoch 26/100
# 5020/5020 [==============================] - 5s 933us/step - loss: 36.3478 - val_loss: 30.6433
# Epoch 27/100
# 5020/5020 [==============================] - 5s 940us/step - loss: 36.3379 - val_loss: 30.5617
# Epoch 28/100
# 5020/5020 [==============================] - 5s 931us/step - loss: 36.2287 - val_loss: 30.5914
# Epoch 29/100
# 5020/5020 [==============================] - 5s 934us/step - loss: 36.4199 - val_loss: 30.8941
# Epoch 30/100
# 5020/5020 [==============================] - 5s 930us/step - loss: 36.3991 - val_loss: 30.5639
# Epoch 31/100
# 5020/5020 [==============================] - 5s 925us/step - loss: 36.3147 - val_loss: 30.4617
# Epoch 32/100
# 5020/5020 [==============================] - 5s 930us/step - loss: 36.2980 - val_loss: 31.6850
# Epoch 33/100
# 5020/5020 [==============================] - 5s 945us/step - loss: 36.4432 - val_loss: 30.5359
# Epoch 34/100
# 5020/5020 [==============================] - 5s 920us/step - loss: 36.4762 - val_loss: 31.0183
# Epoch 35/100
# 5020/5020 [==============================] - 5s 925us/step - loss: 35.8840 - val_loss: 30.3535
# Epoch 36/100
# 5020/5020 [==============================] - 5s 941us/step - loss: 36.1557 - val_loss: 30.4827
# Epoch 37/100
# 5020/5020 [==============================] - 5s 936us/step - loss: 36.1524 - val_loss: 30.3349
# Epoch 38/100
# 5020/5020 [==============================] - 5s 946us/step - loss: 35.8512 - val_loss: 30.7533
# Epoch 39/100
# 5020/5020 [==============================] - 5s 939us/step - loss: 36.0265 - val_loss: 30.6798
# Epoch 40/100
# 5020/5020 [==============================] - 5s 924us/step - loss: 35.9515 - val_loss: 30.3086
# Epoch 41/100
# 5020/5020 [==============================] - 5s 929us/step - loss: 35.8983 - val_loss: 30.3556
# Epoch 42/100
# 5020/5020 [==============================] - 5s 931us/step - loss: 36.0636 - val_loss: 30.3168
# Epoch 43/100
# 5020/5020 [==============================] - 5s 939us/step - loss: 35.8600 - val_loss: 30.2526
# Epoch 44/100
# 5020/5020 [==============================] - 5s 913us/step - loss: 35.9610 - val_loss: 31.0009
# Epoch 45/100
# 5020/5020 [==============================] - 5s 918us/step - loss: 35.7393 - val_loss: 30.6805
# Epoch 46/100
# 5020/5020 [==============================] - 5s 935us/step - loss: 35.8457 - val_loss: 30.3053
# Epoch 47/100
# 5020/5020 [==============================] - 5s 922us/step - loss: 35.8004 - val_loss: 30.4193
# Epoch 48/100
# 5020/5020 [==============================] - 5s 932us/step - loss: 36.0347 - val_loss: 30.4358
# 810/810 [==============================] - 0s 548us/step
# Completed 6 splits
# Epoch 1/100
# 5144/5144 [==============================] - 5s 947us/step - loss: 465.0026 - val_loss: 143.4345
# Epoch 2/100
# 5144/5144 [==============================] - 5s 927us/step - loss: 89.7597 - val_loss: 98.9578
# Epoch 3/100
# 5144/5144 [==============================] - 5s 927us/step - loss: 61.8438 - val_loss: 76.3368
# Epoch 4/100
# 5144/5144 [==============================] - 5s 942us/step - loss: 52.4148 - val_loss: 63.1807
# Epoch 5/100
# 5144/5144 [==============================] - 5s 946us/step - loss: 48.3662 - val_loss: 55.9473
# Epoch 6/100
# 5144/5144 [==============================] - 5s 930us/step - loss: 45.7176 - val_loss: 49.3946
# Epoch 7/100
# 5144/5144 [==============================] - 5s 934us/step - loss: 42.9886 - val_loss: 43.6940
# Epoch 8/100
# 5144/5144 [==============================] - 5s 956us/step - loss: 41.5200 - val_loss: 40.9470
# Epoch 9/100
# 5144/5144 [==============================] - 5s 944us/step - loss: 40.2477 - val_loss: 38.4767
# Epoch 10/100
# 5144/5144 [==============================] - 5s 957us/step - loss: 39.4920 - val_loss: 37.5107
# Epoch 11/100
# 5144/5144 [==============================] - 5s 981us/step - loss: 38.8082 - val_loss: 36.1200
# Epoch 12/100
# 5144/5144 [==============================] - 4s 867us/step - loss: 38.4605 - val_loss: 35.1609
# Epoch 13/100
# 5144/5144 [==============================] - 5s 901us/step - loss: 38.2321 - val_loss: 35.2260
# Epoch 14/100
# 5144/5144 [==============================] - 5s 887us/step - loss: 38.3120 - val_loss: 34.6613
# Epoch 15/100
# 5144/5144 [==============================] - 4s 872us/step - loss: 37.9078 - val_loss: 34.5750
# Epoch 16/100
# 5144/5144 [==============================] - 5s 890us/step - loss: 37.9061 - val_loss: 34.0197
# Epoch 17/100
# 5144/5144 [==============================] - 5s 897us/step - loss: 37.7428 - val_loss: 34.9323
# Epoch 18/100
# 5144/5144 [==============================] - 5s 880us/step - loss: 37.8165 - val_loss: 34.6355
# Epoch 19/100
# 5144/5144 [==============================] - 5s 876us/step - loss: 37.5963 - val_loss: 34.1817
# Epoch 20/100
# 5144/5144 [==============================] - 5s 878us/step - loss: 37.3612 - val_loss: 34.1228
# Epoch 21/100
# 5144/5144 [==============================] - 5s 887us/step - loss: 37.5665 - val_loss: 34.1561
# 843/843 [==============================] - 0s 514us/step
# Completed 7 splits
# Epoch 1/100
# 5288/5288 [==============================] - 5s 878us/step - loss: 411.1386 - val_loss: 101.7953
# Epoch 2/100
# 5288/5288 [==============================] - 5s 863us/step - loss: 89.0071 - val_loss: 43.2131
# Epoch 3/100
# 5288/5288 [==============================] - 5s 865us/step - loss: 60.5028 - val_loss: 39.6397
# Epoch 4/100
# 5288/5288 [==============================] - 5s 891us/step - loss: 54.2599 - val_loss: 37.3821
# Epoch 5/100
# 5288/5288 [==============================] - 5s 888us/step - loss: 50.1694 - val_loss: 36.6799
# Epoch 6/100
# 5288/5288 [==============================] - 5s 861us/step - loss: 47.0874 - val_loss: 35.6548
# Epoch 7/100
# 5288/5288 [==============================] - 5s 861us/step - loss: 45.2824 - val_loss: 34.8499
# Epoch 8/100
# 5288/5288 [==============================] - 5s 880us/step - loss: 43.5477 - val_loss: 34.7557
# Epoch 9/100
# 5288/5288 [==============================] - 5s 889us/step - loss: 42.8047 - val_loss: 34.4615
# Epoch 10/100
# 5288/5288 [==============================] - 5s 870us/step - loss: 42.2350 - val_loss: 34.4173
# Epoch 11/100
# 5288/5288 [==============================] - 5s 870us/step - loss: 41.5619 - val_loss: 34.3003
# Epoch 12/100
# 5288/5288 [==============================] - 5s 888us/step - loss: 41.1863 - val_loss: 34.0506
# Epoch 13/100
# 5288/5288 [==============================] - 5s 889us/step - loss: 40.7636 - val_loss: 34.3967
# Epoch 14/100
# 5288/5288 [==============================] - 5s 877us/step - loss: 40.5689 - val_loss: 34.5011
# Epoch 15/100
# 5288/5288 [==============================] - 5s 861us/step - loss: 40.1262 - val_loss: 33.8377
# Epoch 16/100
# 5288/5288 [==============================] - 5s 858us/step - loss: 40.0733 - val_loss: 33.8492
# Epoch 17/100
# 5288/5288 [==============================] - 5s 861us/step - loss: 39.8172 - val_loss: 33.8764
# Epoch 18/100
# 5288/5288 [==============================] - 5s 852us/step - loss: 39.8301 - val_loss: 33.7826
# Epoch 19/100
# 5288/5288 [==============================] - 5s 853us/step - loss: 39.4502 - val_loss: 34.0278
# Epoch 20/100
# 5288/5288 [==============================] - 5s 851us/step - loss: 39.2396 - val_loss: 33.7064
# Epoch 21/100
# 5288/5288 [==============================] - 5s 853us/step - loss: 38.9867 - val_loss: 33.4107
# Epoch 22/100
# 5288/5288 [==============================] - 5s 855us/step - loss: 38.8916 - val_loss: 33.6608
# Epoch 23/100
# 5288/5288 [==============================] - 5s 857us/step - loss: 39.0624 - val_loss: 33.7321
# Epoch 24/100
# 5288/5288 [==============================] - 5s 867us/step - loss: 38.9700 - val_loss: 33.3557
# Epoch 25/100
# 5288/5288 [==============================] - 5s 860us/step - loss: 38.8276 - val_loss: 33.4815
# Epoch 26/100
# 5288/5288 [==============================] - 5s 856us/step - loss: 38.3742 - val_loss: 33.1179
# Epoch 27/100
# 5288/5288 [==============================] - 4s 840us/step - loss: 38.3190 - val_loss: 33.0426
# Epoch 28/100
# 5288/5288 [==============================] - 5s 857us/step - loss: 38.3514 - val_loss: 33.5163
# Epoch 29/100
# 5288/5288 [==============================] - 5s 857us/step - loss: 38.2792 - val_loss: 33.3878
# Epoch 30/100
# 5288/5288 [==============================] - 5s 852us/step - loss: 38.3005 - val_loss: 33.0778
# Epoch 31/100
# 5288/5288 [==============================] - 4s 849us/step - loss: 38.3807 - val_loss: 33.0768
# Epoch 32/100
# 5288/5288 [==============================] - 5s 857us/step - loss: 38.0475 - val_loss: 33.1168
# 893/893 [==============================] - 0s 498us/step
# Completed 8 splits
# Epoch 1/100
# 5539/5539 [==============================] - 5s 904us/step - loss: 400.9095 - val_loss: 84.2259
# Epoch 2/100
# 5539/5539 [==============================] - 5s 861us/step - loss: 78.9869 - val_loss: 62.2645
# Epoch 3/100
# 5539/5539 [==============================] - 5s 871us/step - loss: 58.1569 - val_loss: 54.6066
# Epoch 4/100
# 5539/5539 [==============================] - 5s 854us/step - loss: 50.5408 - val_loss: 50.6694
# Epoch 5/100
# 5539/5539 [==============================] - 5s 858us/step - loss: 46.6705 - val_loss: 46.6234
# Epoch 6/100
# 5539/5539 [==============================] - 5s 861us/step - loss: 42.4784 - val_loss: 45.3416
# Epoch 7/100
# 5539/5539 [==============================] - 5s 868us/step - loss: 40.3353 - val_loss: 44.0985
# Epoch 8/100
# 5539/5539 [==============================] - 5s 866us/step - loss: 39.7965 - val_loss: 43.0079
# Epoch 9/100
# 5539/5539 [==============================] - 5s 875us/step - loss: 38.9376 - val_loss: 43.2773
# Epoch 10/100
# 5539/5539 [==============================] - 5s 873us/step - loss: 38.3589 - val_loss: 42.3899
# Epoch 11/100
# 5539/5539 [==============================] - 5s 872us/step - loss: 38.1068 - val_loss: 43.0173
# Epoch 12/100
# 5539/5539 [==============================] - 5s 844us/step - loss: 38.3062 - val_loss: 42.7799
# Epoch 13/100
# 5539/5539 [==============================] - 5s 833us/step - loss: 37.8327 - val_loss: 42.4912
# Epoch 14/100
# 5539/5539 [==============================] - 5s 852us/step - loss: 37.6659 - val_loss: 42.7665
# Epoch 15/100
# 5539/5539 [==============================] - 6s 1ms/step - loss: 37.4807 - val_loss: 42.5728
# 942/942 [==============================] - 1s 529us/step
# Completed 9 splits
# Epoch 1/100
# 5743/5743 [==============================] - 6s 907us/step - loss: 574.2109 - val_loss: 87.5346
# Epoch 2/100
# 5743/5743 [==============================] - 5s 899us/step - loss: 94.9069 - val_loss: 50.6787
# Epoch 3/100
# 5743/5743 [==============================] - 5s 882us/step - loss: 60.6581 - val_loss: 42.9629
# Epoch 4/100
# 5743/5743 [==============================] - 5s 886us/step - loss: 50.8097 - val_loss: 41.7463
# Epoch 5/100
# 5743/5743 [==============================] - 5s 876us/step - loss: 45.9813 - val_loss: 41.5425
# Epoch 6/100
# 5743/5743 [==============================] - 5s 898us/step - loss: 43.0428 - val_loss: 41.2533
# Epoch 7/100
# 5743/5743 [==============================] - 5s 871us/step - loss: 41.3965 - val_loss: 40.4743
# Epoch 8/100
# 5743/5743 [==============================] - 5s 904us/step - loss: 40.0438 - val_loss: 40.5399
# Epoch 9/100
# 5743/5743 [==============================] - 5s 878us/step - loss: 39.0500 - val_loss: 40.7767
# Epoch 10/100
# 5743/5743 [==============================] - 5s 882us/step - loss: 38.4472 - val_loss: 40.3165
# Epoch 11/100
# 5743/5743 [==============================] - 5s 877us/step - loss: 37.8305 - val_loss: 41.3677
# Epoch 12/100
# 5743/5743 [==============================] - 5s 901us/step - loss: 37.6995 - val_loss: 40.1385
# Epoch 13/100
# 5743/5743 [==============================] - 5s 873us/step - loss: 37.6273 - val_loss: 40.4479
# Epoch 14/100
# 5743/5743 [==============================] - 5s 907us/step - loss: 37.5112 - val_loss: 39.9948
# Epoch 15/100
# 5743/5743 [==============================] - 5s 880us/step - loss: 37.4140 - val_loss: 40.0227
# Epoch 16/100
# 5743/5743 [==============================] - 5s 884us/step - loss: 37.4387 - val_loss: 39.6396
# Epoch 17/100
# 5743/5743 [==============================] - 5s 889us/step - loss: 37.3700 - val_loss: 39.8351
# Epoch 18/100
# 5743/5743 [==============================] - 5s 887us/step - loss: 37.2965 - val_loss: 39.8316
# Epoch 19/100
# 5743/5743 [==============================] - 5s 873us/step - loss: 37.1811 - val_loss: 39.7885
# Epoch 20/100
# 5743/5743 [==============================] - 5s 896us/step - loss: 37.2358 - val_loss: 40.2164
# Epoch 21/100
# 5743/5743 [==============================] - 5s 891us/step - loss: 37.0674 - val_loss: 39.4267
# Epoch 22/100
# 5743/5743 [==============================] - 5s 883us/step - loss: 37.1670 - val_loss: 39.5481
# Epoch 23/100
# 5743/5743 [==============================] - 5s 878us/step - loss: 37.1021 - val_loss: 39.8820
# Epoch 24/100
# 5743/5743 [==============================] - 5s 892us/step - loss: 37.0413 - val_loss: 39.3256
# Epoch 25/100
# 5743/5743 [==============================] - 5s 883us/step - loss: 36.9755 - val_loss: 39.4079
# Epoch 26/100
# 5743/5743 [==============================] - 5s 897us/step - loss: 36.9197 - val_loss: 39.3121
# Epoch 27/100
# 5743/5743 [==============================] - 5s 866us/step - loss: 36.9287 - val_loss: 39.9155
# Epoch 28/100
# 5743/5743 [==============================] - 5s 897us/step - loss: 36.8930 - val_loss: 39.3990
# Epoch 29/100
# 5743/5743 [==============================] - 5s 901us/step - loss: 36.7765 - val_loss: 39.2930
# Epoch 30/100
# 5743/5743 [==============================] - 5s 888us/step - loss: 36.8765 - val_loss: 39.1874
# Epoch 31/100
# 5743/5743 [==============================] - 5s 874us/step - loss: 36.8704 - val_loss: 39.7936
# Epoch 32/100
# 5743/5743 [==============================] - 5s 870us/step - loss: 36.8169 - val_loss: 39.8628
# Epoch 33/100
# 5743/5743 [==============================] - 5s 928us/step - loss: 36.8670 - val_loss: 38.9979
# Epoch 34/100
# 5743/5743 [==============================] - 5s 887us/step - loss: 36.8345 - val_loss: 39.4461
# Epoch 35/100
# 5743/5743 [==============================] - 5s 891us/step - loss: 36.8822 - val_loss: 39.2291
# Epoch 36/100
# 5743/5743 [==============================] - 5s 893us/step - loss: 36.9593 - val_loss: 39.1784
# Epoch 37/100
# 5743/5743 [==============================] - 5s 868us/step - loss: 36.7292 - val_loss: 39.9648
# Epoch 38/100
# 5743/5743 [==============================] - 5s 886us/step - loss: 36.7306 - val_loss: 39.3524
# 976/976 [==============================] - 1s 522us/step
# Completed 10 splits
# Epoch 1/100
# 6027/6027 [==============================] - 6s 913us/step - loss: 334.9547 - val_loss: 104.1918
# Epoch 2/100
# 6027/6027 [==============================] - 5s 882us/step - loss: 63.6978 - val_loss: 80.7756
# Epoch 3/100
# 6027/6027 [==============================] - 5s 877us/step - loss: 47.3441 - val_loss: 73.8461
# Epoch 4/100
# 6027/6027 [==============================] - 5s 879us/step - loss: 44.2242 - val_loss: 69.6418
# Epoch 5/100
# 6027/6027 [==============================] - 5s 892us/step - loss: 43.2368 - val_loss: 68.2006
# Epoch 6/100
# 6027/6027 [==============================] - 5s 874us/step - loss: 42.5073 - val_loss: 66.2099
# Epoch 7/100
# 6027/6027 [==============================] - 5s 891us/step - loss: 41.8869 - val_loss: 63.7025
# Epoch 8/100
# 6027/6027 [==============================] - 5s 888us/step - loss: 41.2473 - val_loss: 64.3309
# Epoch 9/100
# 6027/6027 [==============================] - 5s 908us/step - loss: 41.0377 - val_loss: 62.0030
# Epoch 10/100
# 6027/6027 [==============================] - 5s 867us/step - loss: 40.4174 - val_loss: 64.0115
# Epoch 11/100
# 6027/6027 [==============================] - 5s 898us/step - loss: 40.2619 - val_loss: 62.2387
# Epoch 12/100
# 6027/6027 [==============================] - 5s 869us/step - loss: 39.9727 - val_loss: 60.4323
# Epoch 13/100
# 6027/6027 [==============================] - 5s 856us/step - loss: 40.0252 - val_loss: 58.2717
# Epoch 14/100
# 6027/6027 [==============================] - 5s 856us/step - loss: 39.8218 - val_loss: 59.1263
# Epoch 15/100
# 6027/6027 [==============================] - 5s 858us/step - loss: 39.6548 - val_loss: 58.4491
# Epoch 16/100
# 6027/6027 [==============================] - 5s 854us/step - loss: 39.4435 - val_loss: 60.3213
# Epoch 17/100
# 6027/6027 [==============================] - 5s 865us/step - loss: 39.4899 - val_loss: 58.5223
# Epoch 18/100
# 6027/6027 [==============================] - 5s 857us/step - loss: 39.3037 - val_loss: 58.2938
# 1027/1027 [==============================] - 1s 530us/step
# Completed 11 splits
# Epoch 1/100
# 6183/6183 [==============================] - 6s 882us/step - loss: 374.2045 - val_loss: 55473.1914
# Epoch 2/100
# 6183/6183 [==============================] - 5s 873us/step - loss: 69.9978 - val_loss: 6556.1729
# Epoch 3/100
# 6183/6183 [==============================] - 5s 874us/step - loss: 50.9595 - val_loss: 13725.5918
# Epoch 4/100
# 6183/6183 [==============================] - 5s 871us/step - loss: 47.8625 - val_loss: 9882.5400
# Epoch 5/100
# 6183/6183 [==============================] - 5s 887us/step - loss: 45.8299 - val_loss: 16913.5977
# Epoch 6/100
# 6183/6183 [==============================] - 6s 895us/step - loss: 44.8227 - val_loss: 18197.5547
# Epoch 7/100
# 6183/6183 [==============================] - 5s 857us/step - loss: 43.5662 - val_loss: 8568.9707
# 1093/1093 [==============================] - 1s 495us/step
# Completed 12 splits
# Epoch 1/100
# 6371/6371 [==============================] - 6s 889us/step - loss: 429.8323 - val_loss: 303762.1250
# Epoch 2/100
# 6371/6371 [==============================] - 6s 879us/step - loss: 59.8958 - val_loss: 9139.7520
# Epoch 3/100
# 6371/6371 [==============================] - 6s 870us/step - loss: 45.3616 - val_loss: 29891.5996
# Epoch 4/100
# 6371/6371 [==============================] - 6s 885us/step - loss: 42.1048 - val_loss: 22085.3379
# Epoch 5/100
# 6371/6371 [==============================] - 6s 887us/step - loss: 40.8043 - val_loss: 30929.6035
# Epoch 6/100
# 6371/6371 [==============================] - 6s 887us/step - loss: 40.0604 - val_loss: 27286.2617
# Epoch 7/100
# 6371/6371 [==============================] - 6s 903us/step - loss: 39.4994 - val_loss: 22045.9980
# 1147/1147 [==============================] - 1s 567us/step
# Completed 13 splits
# Epoch 1/100
# 6625/6625 [==============================] - 7s 924us/step - loss: 448.2292 - val_loss: 379194.0625
# Epoch 2/100
# 6625/6625 [==============================] - 6s 907us/step - loss: 79.4434 - val_loss: 57718.9336
# Epoch 3/100
# 6625/6625 [==============================] - 6s 907us/step - loss: 57.6030 - val_loss: 43422.0898
# Epoch 4/100
# 6625/6625 [==============================] - 6s 935us/step - loss: 51.5243 - val_loss: 39021.6055
# Epoch 5/100
# 6625/6625 [==============================] - 6s 920us/step - loss: 48.4426 - val_loss: 35551.0820
# Epoch 6/100
# 6625/6625 [==============================] - 6s 923us/step - loss: 46.4821 - val_loss: 33294.4844
# Epoch 7/100
# 6625/6625 [==============================] - 6s 904us/step - loss: 45.0403 - val_loss: 34863.5547
# Epoch 8/100
# 6625/6625 [==============================] - 6s 887us/step - loss: 43.8294 - val_loss: 34406.8398
# Epoch 9/100
# 6625/6625 [==============================] - 6s 891us/step - loss: 43.1729 - val_loss: 31664.5449
# Epoch 10/100
# 6625/6625 [==============================] - 6s 902us/step - loss: 42.7417 - val_loss: 32987.6797
# Epoch 11/100
# 6625/6625 [==============================] - 6s 904us/step - loss: 42.3197 - val_loss: 28900.0137
# Epoch 12/100
# 6625/6625 [==============================] - 6s 906us/step - loss: 41.9388 - val_loss: 27857.9629
# Epoch 13/100
# 6625/6625 [==============================] - 6s 919us/step - loss: 41.5245 - val_loss: 29301.9648
# Epoch 14/100
# 6625/6625 [==============================] - 6s 905us/step - loss: 41.6331 - val_loss: 28439.3574
# Epoch 15/100
# 6625/6625 [==============================] - 6s 911us/step - loss: 41.4735 - val_loss: 28346.0352
# Epoch 16/100
# 6625/6625 [==============================] - 6s 904us/step - loss: 41.2720 - val_loss: 28003.4863
# Epoch 17/100
# 6625/6625 [==============================] - 6s 902us/step - loss: 41.2474 - val_loss: 29965.9219
# 1212/1212 [==============================] - 1s 525us/step
# Completed 14 splits
# Epoch 1/100
# 6976/6976 [==============================] - 7s 918us/step - loss: 482.5258 - val_loss: 9613.1357
# Epoch 2/100
# 6976/6976 [==============================] - 6s 889us/step - loss: 102.7143 - val_loss: 8161.5918
# Epoch 3/100
# 6976/6976 [==============================] - 6s 890us/step - loss: 83.1472 - val_loss: 8828.0303
# Epoch 4/100
# 6976/6976 [==============================] - 6s 885us/step - loss: 72.3465 - val_loss: 8735.1582
# Epoch 5/100
# 6976/6976 [==============================] - 6s 903us/step - loss: 66.5666 - val_loss: 8960.3086
# Epoch 6/100
# 6976/6976 [==============================] - 6s 879us/step - loss: 62.7891 - val_loss: 8226.4854
# Epoch 7/100
# 6976/6976 [==============================] - 6s 894us/step - loss: 60.9111 - val_loss: 7967.0742
# Epoch 8/100
# 6976/6976 [==============================] - 6s 897us/step - loss: 59.4485 - val_loss: 7663.4985
# Epoch 9/100
# 6976/6976 [==============================] - 6s 912us/step - loss: 58.0907 - val_loss: 7024.6626
# Epoch 10/100
# 6976/6976 [==============================] - 6s 901us/step - loss: 57.1864 - val_loss: 6734.6455
# Epoch 11/100
# 6976/6976 [==============================] - 6s 917us/step - loss: 55.5473 - val_loss: 6570.4517
# Epoch 12/100
# 6976/6976 [==============================] - 6s 904us/step - loss: 54.6832 - val_loss: 6431.5957
# Epoch 13/100
# 6976/6976 [==============================] - 6s 888us/step - loss: 53.9633 - val_loss: 6064.2788
# Epoch 14/100
# 6976/6976 [==============================] - 6s 913us/step - loss: 53.7960 - val_loss: 5772.4243
# Epoch 15/100
# 6976/6976 [==============================] - 6s 904us/step - loss: 53.1277 - val_loss: 5584.8564
# Epoch 16/100
# 6976/6976 [==============================] - 6s 899us/step - loss: 52.6270 - val_loss: 5320.0967
# Epoch 17/100
# 6976/6976 [==============================] - 6s 906us/step - loss: 51.7251 - val_loss: 5104.5679
# Epoch 18/100
# 6976/6976 [==============================] - 6s 887us/step - loss: 51.5173 - val_loss: 5103.8774
# Epoch 19/100
# 6976/6976 [==============================] - 6s 892us/step - loss: 51.2337 - val_loss: 4944.1709
# Epoch 20/100
# 6976/6976 [==============================] - 6s 896us/step - loss: 50.5626 - val_loss: 4738.2466
# Epoch 21/100
# 6976/6976 [==============================] - 6s 899us/step - loss: 50.8718 - val_loss: 4827.9531
# Epoch 22/100
# 6976/6976 [==============================] - 6s 902us/step - loss: 50.7666 - val_loss: 4444.2451
# Epoch 23/100
# 6976/6976 [==============================] - 6s 914us/step - loss: 50.7356 - val_loss: 4385.6597
# Epoch 24/100
# 6976/6976 [==============================] - 6s 928us/step - loss: 50.3541 - val_loss: 4317.1221
# Epoch 25/100
# 6976/6976 [==============================] - 6s 894us/step - loss: 49.7813 - val_loss: 4038.7544
# Epoch 26/100
# 6976/6976 [==============================] - 7s 947us/step - loss: 49.8588 - val_loss: 3919.9153
# Epoch 27/100
# 6976/6976 [==============================] - 6s 899us/step - loss: 49.8925 - val_loss: 3747.7070
# Epoch 28/100
# 6976/6976 [==============================] - 6s 902us/step - loss: 49.4762 - val_loss: 3842.1973
# Epoch 29/100
# 6976/6976 [==============================] - 6s 899us/step - loss: 49.2472 - val_loss: 3448.1086
# Epoch 30/100
# 6976/6976 [==============================] - 6s 899us/step - loss: 49.0565 - val_loss: 3504.4595
# Epoch 31/100
# 6976/6976 [==============================] - 6s 910us/step - loss: 48.9978 - val_loss: 3229.0239
# Epoch 32/100
# 6976/6976 [==============================] - 6s 891us/step - loss: 49.0532 - val_loss: 3303.5337
# Epoch 33/100
# 6976/6976 [==============================] - 6s 888us/step - loss: 49.1465 - val_loss: 3378.6462
# Epoch 34/100
# 6976/6976 [==============================] - 6s 881us/step - loss: 49.2253 - val_loss: 3163.7092
# Epoch 35/100
# 6976/6976 [==============================] - 6s 882us/step - loss: 48.9182 - val_loss: 2961.6943
# Epoch 36/100
# 6976/6976 [==============================] - 6s 889us/step - loss: 49.1022 - val_loss: 2909.2515
# Epoch 37/100
# 6976/6976 [==============================] - 6s 891us/step - loss: 48.9627 - val_loss: 2867.7466
# Epoch 38/100
# 6976/6976 [==============================] - 6s 883us/step - loss: 48.6474 - val_loss: 2923.5930
# Epoch 39/100
# 6976/6976 [==============================] - 6s 894us/step - loss: 48.7064 - val_loss: 2766.7026
# Epoch 40/100
# 6976/6976 [==============================] - 6s 902us/step - loss: 48.7386 - val_loss: 2701.7715
# Epoch 41/100
# 6976/6976 [==============================] - 6s 892us/step - loss: 48.7031 - val_loss: 2798.5786
# Epoch 42/100
# 6976/6976 [==============================] - 6s 888us/step - loss: 48.7280 - val_loss: 2834.3977
# Epoch 43/100
# 6976/6976 [==============================] - 6s 892us/step - loss: 48.5593 - val_loss: 2878.0977
# Epoch 44/100
# 6976/6976 [==============================] - 6s 894us/step - loss: 49.0073 - val_loss: 2899.3245
# Epoch 45/100
# 6976/6976 [==============================] - 6s 890us/step - loss: 48.7475 - val_loss: 2993.0398
# 1353/1353 [==============================] - 1s 521us/step
# Completed 15 splits
# Epoch 1/100
# 7306/7306 [==============================] - 7s 884us/step - loss: 606.7057 - val_loss: 57165.2812
# Epoch 2/100
# 7306/7306 [==============================] - 6s 877us/step - loss: 121.5517 - val_loss: 63004.4023
# Epoch 3/100
# 7306/7306 [==============================] - 6s 885us/step - loss: 113.5418 - val_loss: 78479.6328
# Epoch 4/100
# 7306/7306 [==============================] - 7s 917us/step - loss: 120.8269 - val_loss: 93624.9531
# Epoch 5/100
# 7306/7306 [==============================] - 7s 893us/step - loss: 120.8183 - val_loss: 102829.3203
# Epoch 6/100
# 7306/7306 [==============================] - 7s 896us/step - loss: 121.8095 - val_loss: 110849.5078
# 1408/1408 [==============================] - 1s 522us/step
# Completed 16 splits
# Epoch 1/100
# 7763/7763 [==============================] - 8s 924us/step - loss: 665.8265 - val_loss: 1994.3173
# Epoch 2/100
# 7763/7763 [==============================] - 7s 895us/step - loss: 120.1681 - val_loss: 1701.0376
# Epoch 3/100
# 7763/7763 [==============================] - 7s 922us/step - loss: 103.5102 - val_loss: 1421.6925
# Epoch 4/100
# 7763/7763 [==============================] - 7s 907us/step - loss: 91.4293 - val_loss: 1155.2062
# Epoch 5/100
# 7763/7763 [==============================] - 7s 871us/step - loss: 84.9358 - val_loss: 813.1098
# Epoch 6/100
# 7763/7763 [==============================] - 7s 883us/step - loss: 79.0642 - val_loss: 584.3412
# Epoch 7/100
# 7763/7763 [==============================] - 7s 906us/step - loss: 76.2545 - val_loss: 354.9182
# Epoch 8/100
# 7763/7763 [==============================] - 7s 882us/step - loss: 73.1509 - val_loss: 225.7336
# Epoch 9/100
# 7763/7763 [==============================] - 7s 896us/step - loss: 72.0874 - val_loss: 171.5178
# Epoch 10/100
# 7763/7763 [==============================] - 7s 887us/step - loss: 71.3712 - val_loss: 153.5749
# Epoch 11/100
# 7763/7763 [==============================] - 7s 889us/step - loss: 71.2425 - val_loss: 146.6987
# Epoch 12/100
# 7763/7763 [==============================] - 7s 880us/step - loss: 70.3300 - val_loss: 169.5120
# Epoch 13/100
# 7763/7763 [==============================] - 7s 884us/step - loss: 70.3181 - val_loss: 192.7388
# Epoch 14/100
# 7763/7763 [==============================] - 7s 886us/step - loss: 70.1232 - val_loss: 240.3112
# Epoch 15/100
# 7763/7763 [==============================] - 7s 938us/step - loss: 69.9784 - val_loss: 232.5987
# Epoch 16/100
# 7763/7763 [==============================] - 8s 967us/step - loss: 69.6858 - val_loss: 254.5057
# 588/588 [==============================] - 0s 478us/step
# Completed 17 splits
# R2_oos NN4: -309.07924787702

# %% [markdown]
# # NN4 algorithm for top 500 stocks

# %%
X = df_top_500[['Date'] + variables]
y = df_top_500['Adj Close t+1']

X['Date'] = pd.to_datetime(X['Date'])

initial_date = X['Date'].min()

predictions = []
y_test_list = []
dates = []


for split_num, (train_index, val_index, test_index) in enumerate(recursive_rolling_method(X,initial_date,date_column='Date',train_period=8,val_period=3,test_period=1,freq='years')):
    X_train = X.loc[train_index].drop('Date', axis=1)
    y_train = y.loc[train_index]

    X_val = X.loc[val_index].drop('Date', axis=1)
    y_val = y.loc[val_index]

    X_test = X.loc[test_index].drop('Date', axis=1)
    y_test = y.loc[test_index]

    
    input_shape = [X_train.shape[1]]
    
    
    mean_train = X_train.mean(axis=0)
    std_train  = X_train.std(axis=0)
    
    X_train = (X_train-mean_train) / std_train
    X_val = (X_val-mean_train) / std_train
    X_test = (X_test-mean_train) / std_train
    
    
    
    model = tf.keras.Sequential([
 
    tf.keras.layers.Flatten(input_shape=input_shape),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=8, activation='relu'),
    tf.keras.layers.Dense(units=4, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='linear')
    
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0, clipnorm=1.0, clipvalue=0.5), loss='mse')    
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[early_stopping])
    
    preds = model.predict(X_test)
    preds = preds.ravel()


    predictions.append(preds)
    dates.append(X.loc[y_test.index, 'Date'])
    y_test_list.append(y_test)



    del X_train, y_train, X_val, y_val, model, preds
    gc.collect()

    print(f"Completed {split_num + 1} splits")

predictions_all = np.concatenate(predictions, axis=0)
y_test_list_all = pd.concat(y_test_list, axis=0)
dates_all = pd.concat(dates, axis=0)


R2oos_NN4_top = 1 - np.sum(np.power(y_test_list_all - predictions_all, 2)) / np.sum(np.power(y_test_list_all, 2))
print("R2_oos NN4 Top 500: ", R2oos_NN4_top)
# Out:
#     Train period: 1997-02-28 00:00:00 - 2005-02-28 00:00:00  || Val period: 2005-03-28 00:00:00 - 2008-03-28 00:00:00  || Test period 2008-04-28 00:00:00 - 2009-04-28 00:00:00  || Train contains 29361  || Val contains 13204  || Test contains 4636
#     Train period: 1998-02-28 00:00:00 - 2006-02-28 00:00:00  || Val period: 2006-03-28 00:00:00 - 2009-03-28 00:00:00  || Test period 2009-04-28 00:00:00 - 2010-04-28 00:00:00  || Train contains 30401  || Val contains 13524  || Test contains 4741
#     Train period: 1999-02-28 00:00:00 - 2007-02-28 00:00:00  || Val period: 2007-03-28 00:00:00 - 2010-03-28 00:00:00  || Test period 2010-04-28 00:00:00 - 2011-04-28 00:00:00  || Train contains 31579  || Val contains 13863  || Test contains 4803
#     Train period: 2000-02-28 00:00:00 - 2008-02-28 00:00:00  || Val period: 2008-03-28 00:00:00 - 2011-03-28 00:00:00  || Test period 2011-04-28 00:00:00 - 2012-04-28 00:00:00  || Train contains 32931  || Val contains 14151  || Test contains 4951
#     Train period: 2001-02-28 00:00:00 - 2009-02-28 00:00:00  || Val period: 2009-03-28 00:00:00 - 2012-03-28 00:00:00  || Test period 2012-04-28 00:00:00 - 2013-04-28 00:00:00  || Train contains 34349  || Val contains 14468  || Test contains 5046
#     Train period: 2002-02-28 00:00:00 - 2010-02-28 00:00:00  || Val period: 2010-03-28 00:00:00 - 2013-03-28 00:00:00  || Test period 2013-04-28 00:00:00 - 2014-04-28 00:00:00  || Train contains 35303  || Val contains 14776  || Test contains 5126
#     Train period: 2003-02-28 00:00:00 - 2011-02-28 00:00:00  || Val period: 2011-03-28 00:00:00 - 2014-03-28 00:00:00  || Test period 2014-04-28 00:00:00 - 2015-04-28 00:00:00  || Train contains 35691  || Val contains 15097  || Test contains 5205
#     Train period: 2004-02-28 00:00:00 - 2012-02-28 00:00:00  || Val period: 2012-03-28 00:00:00 - 2015-03-28 00:00:00  || Test period 2015-04-28 00:00:00 - 2016-04-28 00:00:00  || Train contains 36109  || Val contains 15359  || Test contains 5271
#     Train period: 2005-02-28 00:00:00 - 2013-02-28 00:00:00  || Val period: 2013-03-28 00:00:00 - 2016-03-28 00:00:00  || Test period 2016-04-28 00:00:00 - 2017-04-28 00:00:00  || Train contains 37271  || Val contains 15579  || Test contains 5360
#     Train period: 2006-02-28 00:00:00 - 2014-02-28 00:00:00  || Val period: 2014-03-28 00:00:00 - 2017-03-28 00:00:00  || Test period 2017-04-28 00:00:00 - 2018-04-28 00:00:00  || Train contains 38082  || Val contains 15818  || Test contains 5431
#     Train period: 2007-02-28 00:00:00 - 2015-02-28 00:00:00  || Val period: 2015-03-28 00:00:00 - 2018-03-28 00:00:00  || Test period 2018-04-28 00:00:00 - 2019-04-28 00:00:00  || Train contains 39328  || Val contains 16041  || Test contains 5519
#     Train period: 2008-02-28 00:00:00 - 2016-02-28 00:00:00  || Val period: 2016-03-28 00:00:00 - 2019-03-28 00:00:00  || Test period 2019-04-28 00:00:00 - 2020-04-28 00:00:00  || Train contains 39645  || Val contains 16290  || Test contains 5580
#     Train period: 2009-02-28 00:00:00 - 2017-02-28 00:00:00  || Val period: 2017-03-28 00:00:00 - 2020-03-28 00:00:00  || Test period 2020-04-28 00:00:00 - 2021-04-28 00:00:00  || Train contains 39994  || Val contains 16516  || Test contains 5636
#     Train period: 2010-02-28 00:00:00 - 2018-02-28 00:00:00  || Val period: 2018-03-28 00:00:00 - 2021-03-28 00:00:00  || Test period 2021-04-28 00:00:00 - 2022-04-28 00:00:00  || Train contains 40679  || Val contains 16721  || Test contains 5657
#     Train period: 2011-02-28 00:00:00 - 2019-02-28 00:00:00  || Val period: 2019-03-28 00:00:00 - 2022-03-28 00:00:00  || Test period 2022-04-28 00:00:00 - 2023-04-28 00:00:00  || Train contains 41792  || Val contains 16855  || Test contains 5821
#     Train period: 2012-02-28 00:00:00 - 2020-02-28 00:00:00  || Val period: 2020-03-28 00:00:00 - 2023-03-28 00:00:00  || Test period 2023-04-28 00:00:00 - 2024-04-28 00:00:00  || Train contains 42440  || Val contains 17091  || Test contains 5757
#     Train period: 2013-02-28 00:00:00 - 2021-02-28 00:00:00  || Val period: 2021-03-28 00:00:00 - 2024-03-28 00:00:00  || Test period 2024-04-28 00:00:00 - 2025-04-28 00:00:00  || Train contains 43500  || Val contains 17229  || Test contains 2359
# Epoch 1/100
# 918/918 [==============================] - 1s 925us/step - loss: 375.8261 - val_loss: 277.4247
# Epoch 2/100
# 918/918 [==============================] - 1s 800us/step - loss: 71.3694 - val_loss: 135.1682
# Epoch 3/100
# 918/918 [==============================] - 1s 807us/step - loss: 50.7555 - val_loss: 97.8496
# Epoch 4/100
# 918/918 [==============================] - 1s 775us/step - loss: 42.0152 - val_loss: 75.7427
# Epoch 5/100
# 918/918 [==============================] - 1s 765us/step - loss: 34.7930 - val_loss: 60.6311
# Epoch 6/100
# 918/918 [==============================] - 1s 756us/step - loss: 30.1847 - val_loss: 48.4991
# Epoch 7/100
# 918/918 [==============================] - 1s 781us/step - loss: 25.8709 - val_loss: 40.7742
# Epoch 8/100
# 918/918 [==============================] - 1s 804us/step - loss: 23.2556 - val_loss: 36.9492
# Epoch 9/100
# 918/918 [==============================] - 1s 799us/step - loss: 21.3881 - val_loss: 35.8662
# Epoch 10/100
# 918/918 [==============================] - 1s 777us/step - loss: 20.2647 - val_loss: 33.5935
# Epoch 11/100
# 918/918 [==============================] - 1s 784us/step - loss: 19.2081 - val_loss: 34.6885
# Epoch 12/100
# 918/918 [==============================] - 1s 780us/step - loss: 18.9178 - val_loss: 33.7385
# Epoch 13/100
# 918/918 [==============================] - 1s 809us/step - loss: 18.4617 - val_loss: 33.6863
# Epoch 14/100
# 918/918 [==============================] - 1s 786us/step - loss: 18.3870 - val_loss: 33.0136
# Epoch 15/100
# 918/918 [==============================] - 1s 788us/step - loss: 17.9214 - val_loss: 33.8915
# Epoch 16/100
# 918/918 [==============================] - 1s 785us/step - loss: 17.5769 - val_loss: 34.0174
# Epoch 17/100
# 918/918 [==============================] - 1s 770us/step - loss: 17.3763 - val_loss: 33.3573
# Epoch 18/100
# 918/918 [==============================] - 1s 776us/step - loss: 17.2530 - val_loss: 33.5854
# Epoch 19/100
# 918/918 [==============================] - 1s 759us/step - loss: 17.1114 - val_loss: 32.5400
# Epoch 20/100
# 918/918 [==============================] - 1s 755us/step - loss: 16.9236 - val_loss: 31.6059
# Epoch 21/100
# 918/918 [==============================] - 1s 784us/step - loss: 16.7220 - val_loss: 30.7143
# Epoch 22/100
# 918/918 [==============================] - 1s 789us/step - loss: 16.7197 - val_loss: 30.3681
# Epoch 23/100
# 918/918 [==============================] - 1s 874us/step - loss: 16.6875 - val_loss: 29.7944
# Epoch 24/100
# 918/918 [==============================] - 1s 784us/step - loss: 16.7428 - val_loss: 29.4224
# Epoch 25/100
# 918/918 [==============================] - 1s 795us/step - loss: 16.5504 - val_loss: 28.8477
# Epoch 26/100
# 918/918 [==============================] - 1s 818us/step - loss: 16.3912 - val_loss: 29.5219
# Epoch 27/100
# 918/918 [==============================] - 1s 798us/step - loss: 16.2062 - val_loss: 28.2717
# Epoch 28/100
# 918/918 [==============================] - 1s 773us/step - loss: 16.1402 - val_loss: 28.6548
# Epoch 29/100
# 918/918 [==============================] - 1s 780us/step - loss: 16.1443 - val_loss: 28.2434
# Epoch 30/100
# 918/918 [==============================] - 1s 778us/step - loss: 15.9507 - val_loss: 27.2249
# Epoch 31/100
# 918/918 [==============================] - 1s 775us/step - loss: 15.9724 - val_loss: 25.6891
# Epoch 32/100
# 918/918 [==============================] - 1s 768us/step - loss: 15.7902 - val_loss: 25.1583
# Epoch 33/100
# 918/918 [==============================] - 1s 776us/step - loss: 15.9363 - val_loss: 24.9456
# Epoch 34/100
# 918/918 [==============================] - 1s 772us/step - loss: 15.9024 - val_loss: 24.3595
# Epoch 35/100
# 918/918 [==============================] - 1s 791us/step - loss: 15.7677 - val_loss: 24.2287
# Epoch 36/100
# 918/918 [==============================] - 1s 794us/step - loss: 15.6923 - val_loss: 23.4559
# Epoch 37/100
# 918/918 [==============================] - 1s 787us/step - loss: 15.8825 - val_loss: 22.5536
# Epoch 38/100
# 918/918 [==============================] - 1s 771us/step - loss: 15.6717 - val_loss: 22.3635
# Epoch 39/100
# 918/918 [==============================] - 1s 857us/step - loss: 15.6864 - val_loss: 22.4421
# Epoch 40/100
# 918/918 [==============================] - 1s 827us/step - loss: 15.5986 - val_loss: 22.2707
# Epoch 41/100
# 918/918 [==============================] - 1s 839us/step - loss: 15.5830 - val_loss: 21.7719
# Epoch 42/100
# 918/918 [==============================] - 1s 819us/step - loss: 15.5754 - val_loss: 21.2241
# Epoch 43/100
# 918/918 [==============================] - 1s 777us/step - loss: 15.6195 - val_loss: 20.2002
# Epoch 44/100
# 918/918 [==============================] - 1s 813us/step - loss: 15.3558 - val_loss: 19.9772
# Epoch 45/100
# 918/918 [==============================] - 1s 773us/step - loss: 15.4199 - val_loss: 20.0776
# Epoch 46/100
# 918/918 [==============================] - 1s 760us/step - loss: 15.4515 - val_loss: 20.5945
# Epoch 47/100
# 918/918 [==============================] - 1s 790us/step - loss: 15.4445 - val_loss: 19.0378
# Epoch 48/100
# 918/918 [==============================] - 1s 831us/step - loss: 15.1461 - val_loss: 19.3165
# Epoch 49/100
# 918/918 [==============================] - 1s 789us/step - loss: 15.2850 - val_loss: 19.4270
# Epoch 50/100
# 918/918 [==============================] - 1s 768us/step - loss: 15.1078 - val_loss: 19.1852
# Epoch 51/100
# 918/918 [==============================] - 1s 760us/step - loss: 15.3330 - val_loss: 17.9678
# Epoch 52/100
# 918/918 [==============================] - 1s 762us/step - loss: 15.3646 - val_loss: 17.6223
# Epoch 53/100
# 918/918 [==============================] - 1s 763us/step - loss: 15.1310 - val_loss: 17.3958
# Epoch 54/100
# 918/918 [==============================] - 1s 768us/step - loss: 14.9937 - val_loss: 18.0856
# Epoch 55/100
# 918/918 [==============================] - 1s 772us/step - loss: 15.3896 - val_loss: 17.3502
# Epoch 56/100
# 918/918 [==============================] - 1s 784us/step - loss: 15.1926 - val_loss: 17.0147
# Epoch 57/100
# 918/918 [==============================] - 1s 780us/step - loss: 15.0827 - val_loss: 16.7186
# Epoch 58/100
# 918/918 [==============================] - 1s 775us/step - loss: 15.0207 - val_loss: 16.6753
# Epoch 59/100
# 918/918 [==============================] - 1s 768us/step - loss: 14.8565 - val_loss: 16.4237
# Epoch 60/100
# 918/918 [==============================] - 1s 772us/step - loss: 14.9591 - val_loss: 15.9088
# Epoch 61/100
# 918/918 [==============================] - 1s 800us/step - loss: 14.9479 - val_loss: 15.7737
# Epoch 62/100
# 918/918 [==============================] - 1s 784us/step - loss: 14.9333 - val_loss: 15.2204
# Epoch 63/100
# 918/918 [==============================] - 1s 773us/step - loss: 14.8392 - val_loss: 15.6002
# Epoch 64/100
# 918/918 [==============================] - 1s 795us/step - loss: 15.0067 - val_loss: 15.2504
# Epoch 65/100
# 918/918 [==============================] - 1s 801us/step - loss: 14.9412 - val_loss: 15.0928
# Epoch 66/100
# 918/918 [==============================] - 1s 775us/step - loss: 15.0055 - val_loss: 14.8483
# Epoch 67/100
# 918/918 [==============================] - 1s 794us/step - loss: 14.8367 - val_loss: 14.6139
# Epoch 68/100
# 918/918 [==============================] - 1s 777us/step - loss: 14.7279 - val_loss: 14.3582
# Epoch 69/100
# 918/918 [==============================] - 1s 811us/step - loss: 14.7902 - val_loss: 14.6721
# Epoch 70/100
# 918/918 [==============================] - 1s 856us/step - loss: 14.8374 - val_loss: 14.5498
# Epoch 71/100
# 918/918 [==============================] - 1s 773us/step - loss: 14.8608 - val_loss: 14.4476
# Epoch 72/100
# 918/918 [==============================] - 1s 795us/step - loss: 14.7204 - val_loss: 14.0846
# Epoch 73/100
# 918/918 [==============================] - 1s 772us/step - loss: 14.8436 - val_loss: 14.1597
# Epoch 74/100
# 918/918 [==============================] - 1s 797us/step - loss: 14.7379 - val_loss: 14.0818
# Epoch 75/100
# 918/918 [==============================] - 1s 794us/step - loss: 14.6055 - val_loss: 13.9627
# Epoch 76/100
# 918/918 [==============================] - 1s 776us/step - loss: 14.5893 - val_loss: 14.0150
# Epoch 77/100
# 918/918 [==============================] - 1s 783us/step - loss: 14.5929 - val_loss: 13.3648
# Epoch 78/100
# 918/918 [==============================] - 1s 771us/step - loss: 14.7290 - val_loss: 13.4616
# Epoch 79/100
# 918/918 [==============================] - 1s 786us/step - loss: 14.5554 - val_loss: 13.2488
# Epoch 80/100
# 918/918 [==============================] - 1s 802us/step - loss: 14.7419 - val_loss: 13.2604
# Epoch 81/100
# 918/918 [==============================] - 1s 771us/step - loss: 14.7405 - val_loss: 13.7575
# Epoch 82/100
# 918/918 [==============================] - 1s 775us/step - loss: 14.7822 - val_loss: 13.2577
# Epoch 83/100
# 918/918 [==============================] - 1s 792us/step - loss: 14.6115 - val_loss: 13.2749
# Epoch 84/100
# 918/918 [==============================] - 1s 789us/step - loss: 14.6649 - val_loss: 13.5498
# 145/145 [==============================] - 0s 475us/step
# Completed 1 splits
# Epoch 1/100
# 951/951 [==============================] - 1s 849us/step - loss: 554.1101 - val_loss: 1002.3853
# Epoch 2/100
# 951/951 [==============================] - 1s 768us/step - loss: 107.2823 - val_loss: 893.4370
# Epoch 3/100
# 951/951 [==============================] - 1s 768us/step - loss: 51.6452 - val_loss: 571.2701
# Epoch 4/100
# 951/951 [==============================] - 1s 777us/step - loss: 39.7924 - val_loss: 355.4724
# Epoch 5/100
# 951/951 [==============================] - 1s 782us/step - loss: 32.6044 - val_loss: 206.9401
# Epoch 6/100
# 951/951 [==============================] - 1s 770us/step - loss: 26.9500 - val_loss: 118.3073
# Epoch 7/100
# 951/951 [==============================] - 1s 772us/step - loss: 22.8276 - val_loss: 75.4763
# Epoch 8/100
# 951/951 [==============================] - 1s 768us/step - loss: 20.4226 - val_loss: 51.9745
# Epoch 9/100
# 951/951 [==============================] - 1s 786us/step - loss: 18.1931 - val_loss: 43.0375
# Epoch 10/100
# 951/951 [==============================] - 1s 770us/step - loss: 17.4448 - val_loss: 38.7669
# Epoch 11/100
# 951/951 [==============================] - 1s 791us/step - loss: 16.7227 - val_loss: 35.2374
# Epoch 12/100
# 951/951 [==============================] - 1s 768us/step - loss: 16.2881 - val_loss: 32.4108
# Epoch 13/100
# 951/951 [==============================] - 1s 768us/step - loss: 15.8984 - val_loss: 33.0571
# Epoch 14/100
# 951/951 [==============================] - 1s 765us/step - loss: 15.6893 - val_loss: 31.1005
# Epoch 15/100
# 951/951 [==============================] - 1s 766us/step - loss: 15.4991 - val_loss: 29.5815
# Epoch 16/100
# 951/951 [==============================] - 1s 763us/step - loss: 15.4385 - val_loss: 29.0732
# Epoch 17/100
# 951/951 [==============================] - 1s 765us/step - loss: 15.0534 - val_loss: 27.8891
# Epoch 18/100
# 951/951 [==============================] - 1s 763us/step - loss: 15.3012 - val_loss: 28.8703
# Epoch 19/100
# 951/951 [==============================] - 1s 795us/step - loss: 14.9950 - val_loss: 26.5735
# Epoch 20/100
# 951/951 [==============================] - 1s 776us/step - loss: 14.9819 - val_loss: 27.4870
# Epoch 21/100
# 951/951 [==============================] - 1s 762us/step - loss: 15.0579 - val_loss: 27.6443
# Epoch 22/100
# 951/951 [==============================] - 1s 764us/step - loss: 14.7018 - val_loss: 26.4486
# Epoch 23/100
# 951/951 [==============================] - 1s 765us/step - loss: 14.8242 - val_loss: 25.1917
# Epoch 24/100
# 951/951 [==============================] - 1s 788us/step - loss: 14.7518 - val_loss: 25.1476
# Epoch 25/100
# 951/951 [==============================] - 1s 783us/step - loss: 14.5649 - val_loss: 27.3825
# Epoch 26/100
# 951/951 [==============================] - 1s 765us/step - loss: 14.6088 - val_loss: 26.7902
# Epoch 27/100
# 951/951 [==============================] - 1s 762us/step - loss: 14.5272 - val_loss: 26.0425
# Epoch 28/100
# 951/951 [==============================] - 1s 788us/step - loss: 14.4439 - val_loss: 26.8708
# Epoch 29/100
# 951/951 [==============================] - 1s 764us/step - loss: 14.3609 - val_loss: 25.6370
# 149/149 [==============================] - 0s 459us/step
# Completed 2 splits
# Epoch 1/100
# 987/987 [==============================] - 1s 832us/step - loss: 483.5031 - val_loss: 2578.8733
# Epoch 2/100
# 987/987 [==============================] - 1s 760us/step - loss: 62.9334 - val_loss: 597.3682
# Epoch 3/100
# 987/987 [==============================] - 1s 780us/step - loss: 37.3458 - val_loss: 290.5089
# Epoch 4/100
# 987/987 [==============================] - 1s 755us/step - loss: 28.2895 - val_loss: 224.4386
# Epoch 5/100
# 987/987 [==============================] - 1s 757us/step - loss: 22.8566 - val_loss: 234.7325
# Epoch 6/100
# 987/987 [==============================] - 1s 755us/step - loss: 19.2814 - val_loss: 264.4138
# Epoch 7/100
# 987/987 [==============================] - 1s 771us/step - loss: 17.1442 - val_loss: 313.7866
# Epoch 8/100
# 987/987 [==============================] - 1s 756us/step - loss: 15.6361 - val_loss: 358.4147
# Epoch 9/100
# 987/987 [==============================] - 1s 757us/step - loss: 14.3531 - val_loss: 357.3368
# 151/151 [==============================] - 0s 469us/step
# Completed 3 splits
# Epoch 1/100
# 1030/1030 [==============================] - 1s 826us/step - loss: 917.9609 - val_loss: 957.0743
# Epoch 2/100
# 1030/1030 [==============================] - 1s 760us/step - loss: 878.1646 - val_loss: 912.2303
# Epoch 3/100
# 1030/1030 [==============================] - 1s 769us/step - loss: 841.0551 - val_loss: 869.5290
# Epoch 4/100
# 1030/1030 [==============================] - 1s 758us/step - loss: 806.1058 - val_loss: 828.9504
# Epoch 5/100
# 1030/1030 [==============================] - 1s 773us/step - loss: 772.9543 - val_loss: 790.4950
# Epoch 6/100
# 1030/1030 [==============================] - 1s 759us/step - loss: 742.0632 - val_loss: 754.1616
# Epoch 7/100
# 1030/1030 [==============================] - 1s 759us/step - loss: 713.5082 - val_loss: 719.9835
# Epoch 8/100
# 1030/1030 [==============================] - 1s 761us/step - loss: 687.0372 - val_loss: 687.8900
# Epoch 9/100
# 1030/1030 [==============================] - 1s 753us/step - loss: 662.4831 - val_loss: 657.9213
# Epoch 10/100
# 1030/1030 [==============================] - 1s 757us/step - loss: 640.0741 - val_loss: 630.0616
# Epoch 11/100
# 1030/1030 [==============================] - 1s 757us/step - loss: 619.9568 - val_loss: 604.3261
# Epoch 12/100
# 1030/1030 [==============================] - 1s 781us/step - loss: 601.7437 - val_loss: 580.8190
# Epoch 13/100
# 1030/1030 [==============================] - 1s 754us/step - loss: 586.0585 - val_loss: 559.8030
# Epoch 14/100
# 1030/1030 [==============================] - 1s 753us/step - loss: 572.6121 - val_loss: 541.1699
# Epoch 15/100
# 1030/1030 [==============================] - 1s 754us/step - loss: 561.5062 - val_loss: 525.2040
# Epoch 16/100
# 1030/1030 [==============================] - 1s 757us/step - loss: 552.8572 - val_loss: 512.6941
# Epoch 17/100
# 1030/1030 [==============================] - 1s 754us/step - loss: 546.6821 - val_loss: 503.2180
# Epoch 18/100
# 1030/1030 [==============================] - 1s 757us/step - loss: 542.4622 - val_loss: 496.0370
# Epoch 19/100
# 1030/1030 [==============================] - 1s 765us/step - loss: 539.6750 - val_loss: 490.8673
# Epoch 20/100
# 1030/1030 [==============================] - 1s 761us/step - loss: 537.8553 - val_loss: 487.4470
# Epoch 21/100
# 1030/1030 [==============================] - 1s 760us/step - loss: 536.6993 - val_loss: 487.8000
# Epoch 22/100
# 1030/1030 [==============================] - 1s 756us/step - loss: 495.4545 - val_loss: 7055.4194
# Epoch 23/100
# 1030/1030 [==============================] - 1s 754us/step - loss: 461.0126 - val_loss: 4206.1772
# Epoch 24/100
# 1030/1030 [==============================] - 1s 771us/step - loss: 446.8046 - val_loss: 5719.7173
# Epoch 25/100
# 1030/1030 [==============================] - 1s 757us/step - loss: 434.1354 - val_loss: 7338.1353
# 155/155 [==============================] - 0s 465us/step
# Completed 4 splits
# Epoch 1/100
# 1074/1074 [==============================] - 1s 824us/step - loss: 520.9929 - val_loss: 423.0571
# Epoch 2/100
# 1074/1074 [==============================] - 1s 747us/step - loss: 58.9157 - val_loss: 315.4573
# Epoch 3/100
# 1074/1074 [==============================] - 1s 744us/step - loss: 42.2407 - val_loss: 275.7213
# Epoch 4/100
# 1074/1074 [==============================] - 1s 754us/step - loss: 34.6932 - val_loss: 257.4143
# Epoch 5/100
# 1074/1074 [==============================] - 1s 752us/step - loss: 28.9521 - val_loss: 249.3721
# Epoch 6/100
# 1074/1074 [==============================] - 1s 752us/step - loss: 25.4070 - val_loss: 253.0872
# Epoch 7/100
# 1074/1074 [==============================] - 1s 763us/step - loss: 22.2135 - val_loss: 114.7310
# Epoch 8/100
# 1074/1074 [==============================] - 1s 750us/step - loss: 19.4111 - val_loss: 34.5956
# Epoch 9/100
# 1074/1074 [==============================] - 1s 750us/step - loss: 17.5560 - val_loss: 20.9922
# Epoch 10/100
# 1074/1074 [==============================] - 1s 747us/step - loss: 15.7045 - val_loss: 24.8797
# Epoch 11/100
# 1074/1074 [==============================] - 1s 749us/step - loss: 14.9057 - val_loss: 37.1244
# Epoch 12/100
# 1074/1074 [==============================] - 1s 766us/step - loss: 14.0010 - val_loss: 45.1290
# Epoch 13/100
# 1074/1074 [==============================] - 1s 760us/step - loss: 13.1789 - val_loss: 47.7966
# Epoch 14/100
# 1074/1074 [==============================] - 1s 748us/step - loss: 12.3476 - val_loss: 81.7300
# 158/158 [==============================] - 0s 464us/step
# Completed 5 splits
# Epoch 1/100
# 1104/1104 [==============================] - 1s 836us/step - loss: 791.2193 - val_loss: 1122.4760
# Epoch 2/100
# 1104/1104 [==============================] - 1s 765us/step - loss: 122.0619 - val_loss: 1456.6055
# Epoch 3/100
# 1104/1104 [==============================] - 1s 766us/step - loss: 49.8328 - val_loss: 1055.8795
# Epoch 4/100
# 1104/1104 [==============================] - 1s 764us/step - loss: 37.3518 - val_loss: 758.9570
# Epoch 5/100
# 1104/1104 [==============================] - 1s 768us/step - loss: 29.3571 - val_loss: 560.6379
# Epoch 6/100
# 1104/1104 [==============================] - 1s 757us/step - loss: 23.4246 - val_loss: 407.4684
# Epoch 7/100
# 1104/1104 [==============================] - 1s 759us/step - loss: 18.2519 - val_loss: 268.6545
# Epoch 8/100
# 1104/1104 [==============================] - 1s 760us/step - loss: 14.5785 - val_loss: 166.1388
# Epoch 9/100
# 1104/1104 [==============================] - 1s 764us/step - loss: 12.1778 - val_loss: 99.1171
# Epoch 10/100
# 1104/1104 [==============================] - 1s 766us/step - loss: 10.9765 - val_loss: 66.9895
# Epoch 11/100
# 1104/1104 [==============================] - 1s 789us/step - loss: 10.1078 - val_loss: 49.5810
# Epoch 12/100
# 1104/1104 [==============================] - 1s 759us/step - loss: 9.7185 - val_loss: 37.3929
# Epoch 13/100
# 1104/1104 [==============================] - 1s 760us/step - loss: 9.1427 - val_loss: 32.8607
# Epoch 14/100
# 1104/1104 [==============================] - 1s 758us/step - loss: 8.8379 - val_loss: 27.1209
# Epoch 15/100
# 1104/1104 [==============================] - 1s 765us/step - loss: 8.6402 - val_loss: 23.0434
# Epoch 16/100
# 1104/1104 [==============================] - 1s 768us/step - loss: 8.4005 - val_loss: 23.0474
# Epoch 17/100
# 1104/1104 [==============================] - 1s 769us/step - loss: 8.3051 - val_loss: 22.9786
# Epoch 18/100
# 1104/1104 [==============================] - 1s 761us/step - loss: 8.1259 - val_loss: 20.8110
# Epoch 19/100
# 1104/1104 [==============================] - 1s 775us/step - loss: 8.1042 - val_loss: 22.1897
# Epoch 20/100
# 1104/1104 [==============================] - 1s 759us/step - loss: 7.9166 - val_loss: 20.4871
# Epoch 21/100
# 1104/1104 [==============================] - 1s 761us/step - loss: 7.8662 - val_loss: 20.9868
# Epoch 22/100
# 1104/1104 [==============================] - 1s 758us/step - loss: 7.7208 - val_loss: 20.9954
# Epoch 23/100
# 1104/1104 [==============================] - 1s 769us/step - loss: 7.6310 - val_loss: 21.1867
# Epoch 24/100
# 1104/1104 [==============================] - 1s 762us/step - loss: 7.6531 - val_loss: 20.5167
# Epoch 25/100
# 1104/1104 [==============================] - 1s 777us/step - loss: 7.4750 - val_loss: 20.1852
# Epoch 26/100
# 1104/1104 [==============================] - 1s 764us/step - loss: 7.4111 - val_loss: 21.4518
# Epoch 27/100
# 1104/1104 [==============================] - 1s 760us/step - loss: 7.4422 - val_loss: 20.1628
# Epoch 28/100
# 1104/1104 [==============================] - 1s 764us/step - loss: 7.2873 - val_loss: 19.9047
# Epoch 29/100
# 1104/1104 [==============================] - 1s 772us/step - loss: 7.3072 - val_loss: 18.1891
# Epoch 30/100
# 1104/1104 [==============================] - 1s 761us/step - loss: 7.2734 - val_loss: 18.7950
# Epoch 31/100
# 1104/1104 [==============================] - 1s 762us/step - loss: 7.2332 - val_loss: 17.3098
# Epoch 32/100
# 1104/1104 [==============================] - 1s 757us/step - loss: 7.3428 - val_loss: 18.4484
# Epoch 33/100
# 1104/1104 [==============================] - 1s 761us/step - loss: 7.1799 - val_loss: 16.8249
# Epoch 34/100
# 1104/1104 [==============================] - 1s 770us/step - loss: 7.0999 - val_loss: 15.9895
# Epoch 35/100
# 1104/1104 [==============================] - 1s 774us/step - loss: 7.1714 - val_loss: 16.0748
# Epoch 36/100
# 1104/1104 [==============================] - 1s 762us/step - loss: 7.1619 - val_loss: 16.4297
# Epoch 37/100
# 1104/1104 [==============================] - 1s 767us/step - loss: 7.1572 - val_loss: 14.5540
# Epoch 38/100
# 1104/1104 [==============================] - 1s 778us/step - loss: 7.0606 - val_loss: 15.3890
# Epoch 39/100
# 1104/1104 [==============================] - 1s 765us/step - loss: 7.0867 - val_loss: 14.9405
# Epoch 40/100
# 1104/1104 [==============================] - 1s 773us/step - loss: 7.0180 - val_loss: 14.0172
# Epoch 41/100
# 1104/1104 [==============================] - 1s 765us/step - loss: 7.0191 - val_loss: 14.8462
# Epoch 42/100
# 1104/1104 [==============================] - 1s 762us/step - loss: 6.9351 - val_loss: 14.0419
# Epoch 43/100
# 1104/1104 [==============================] - 1s 764us/step - loss: 6.9754 - val_loss: 13.1296
# Epoch 44/100
# 1104/1104 [==============================] - 1s 776us/step - loss: 6.9687 - val_loss: 12.1233
# Epoch 45/100
# 1104/1104 [==============================] - 1s 773us/step - loss: 6.9297 - val_loss: 12.8842
# Epoch 46/100
# 1104/1104 [==============================] - 1s 764us/step - loss: 6.9600 - val_loss: 13.2081
# Epoch 47/100
# 1104/1104 [==============================] - 1s 763us/step - loss: 6.9091 - val_loss: 12.6432
# Epoch 48/100
# 1104/1104 [==============================] - 1s 763us/step - loss: 6.9187 - val_loss: 12.9214
# Epoch 49/100
# 1104/1104 [==============================] - 1s 763us/step - loss: 6.8145 - val_loss: 12.8578
# 161/161 [==============================] - 0s 546us/step
# Completed 6 splits
# Epoch 1/100
# 1116/1116 [==============================] - 1s 826us/step - loss: 518.1948 - val_loss: 6663.4019
# Epoch 2/100
# 1116/1116 [==============================] - 1s 774us/step - loss: 51.8348 - val_loss: 946.5035
# Epoch 3/100
# 1116/1116 [==============================] - 1s 765us/step - loss: 29.1496 - val_loss: 388.5746
# Epoch 4/100
# 1116/1116 [==============================] - 1s 768us/step - loss: 21.0678 - val_loss: 224.3307
# Epoch 5/100
# 1116/1116 [==============================] - 1s 773us/step - loss: 16.4926 - val_loss: 142.1675
# Epoch 6/100
# 1116/1116 [==============================] - 1s 761us/step - loss: 14.0483 - val_loss: 117.6035
# Epoch 7/100
# 1116/1116 [==============================] - 1s 763us/step - loss: 12.3057 - val_loss: 97.8562
# Epoch 8/100
# 1116/1116 [==============================] - 1s 762us/step - loss: 11.4128 - val_loss: 101.6208
# Epoch 9/100
# 1116/1116 [==============================] - 1s 775us/step - loss: 10.8039 - val_loss: 92.4019
# Epoch 10/100
# 1116/1116 [==============================] - 1s 761us/step - loss: 10.2823 - val_loss: 94.4264
# Epoch 11/100
# 1116/1116 [==============================] - 1s 762us/step - loss: 9.8540 - val_loss: 81.8787
# Epoch 12/100
# 1116/1116 [==============================] - 1s 761us/step - loss: 9.4282 - val_loss: 87.5764
# Epoch 13/100
# 1116/1116 [==============================] - 1s 758us/step - loss: 9.0793 - val_loss: 81.6552
# Epoch 14/100
# 1116/1116 [==============================] - 1s 775us/step - loss: 8.9646 - val_loss: 73.2279
# Epoch 15/100
# 1116/1116 [==============================] - 1s 771us/step - loss: 8.6624 - val_loss: 72.0071
# Epoch 16/100
# 1116/1116 [==============================] - 1s 762us/step - loss: 8.4641 - val_loss: 72.2102
# Epoch 17/100
# 1116/1116 [==============================] - 1s 763us/step - loss: 8.3190 - val_loss: 66.9333
# Epoch 18/100
# 1116/1116 [==============================] - 1s 768us/step - loss: 8.2998 - val_loss: 69.8044
# Epoch 19/100
# 1116/1116 [==============================] - 1s 757us/step - loss: 8.1812 - val_loss: 59.7746
# Epoch 20/100
# 1116/1116 [==============================] - 1s 760us/step - loss: 8.1308 - val_loss: 66.7417
# Epoch 21/100
# 1116/1116 [==============================] - 1s 768us/step - loss: 8.0431 - val_loss: 65.1613
# Epoch 22/100
# 1116/1116 [==============================] - 1s 783us/step - loss: 7.9868 - val_loss: 68.4502
# Epoch 23/100
# 1116/1116 [==============================] - 1s 763us/step - loss: 8.0302 - val_loss: 59.0421
# Epoch 24/100
# 1116/1116 [==============================] - 1s 762us/step - loss: 7.9451 - val_loss: 60.8509
# Epoch 25/100
# 1116/1116 [==============================] - 1s 765us/step - loss: 7.8104 - val_loss: 60.0051
# Epoch 26/100
# 1116/1116 [==============================] - 1s 781us/step - loss: 7.8723 - val_loss: 65.7675
# Epoch 27/100
# 1116/1116 [==============================] - 1s 759us/step - loss: 7.8359 - val_loss: 63.2291
# Epoch 28/100
# 1116/1116 [==============================] - 1s 777us/step - loss: 7.9500 - val_loss: 57.6896
# Epoch 29/100
# 1116/1116 [==============================] - 1s 759us/step - loss: 7.8237 - val_loss: 54.4959
# Epoch 30/100
# 1116/1116 [==============================] - 1s 764us/step - loss: 7.7010 - val_loss: 54.0845
# Epoch 31/100
# 1116/1116 [==============================] - 1s 770us/step - loss: 7.6693 - val_loss: 53.4206
# Epoch 32/100
# 1116/1116 [==============================] - 1s 755us/step - loss: 7.7810 - val_loss: 52.3332
# Epoch 33/100
# 1116/1116 [==============================] - 1s 757us/step - loss: 7.6695 - val_loss: 52.0470
# Epoch 34/100
# 1116/1116 [==============================] - 1s 758us/step - loss: 7.6389 - val_loss: 57.4700
# Epoch 35/100
# 1116/1116 [==============================] - 1s 775us/step - loss: 7.7024 - val_loss: 55.2060
# Epoch 36/100
# 1116/1116 [==============================] - 1s 763us/step - loss: 7.6139 - val_loss: 49.6956
# Epoch 37/100
# 1116/1116 [==============================] - 1s 776us/step - loss: 7.5887 - val_loss: 50.7163
# Epoch 38/100
# 1116/1116 [==============================] - 1s 779us/step - loss: 7.6757 - val_loss: 47.9905
# Epoch 39/100
# 1116/1116 [==============================] - 1s 784us/step - loss: 7.5452 - val_loss: 45.2053
# Epoch 40/100
# 1116/1116 [==============================] - 1s 762us/step - loss: 7.5840 - val_loss: 46.1443
# Epoch 41/100
# 1116/1116 [==============================] - 1s 769us/step - loss: 7.4715 - val_loss: 47.6070
# Epoch 42/100
# 1116/1116 [==============================] - 1s 758us/step - loss: 7.4680 - val_loss: 46.2136
# Epoch 43/100
# 1116/1116 [==============================] - 1s 771us/step - loss: 7.4164 - val_loss: 46.3877
# Epoch 44/100
# 1116/1116 [==============================] - 1s 761us/step - loss: 7.4386 - val_loss: 45.5376
# 163/163 [==============================] - 0s 469us/step
# Completed 7 splits
# Epoch 1/100
# 1129/1129 [==============================] - 1s 818us/step - loss: 711.5027 - val_loss: 567.2183
# Epoch 2/100
# 1129/1129 [==============================] - 1s 766us/step - loss: 74.4903 - val_loss: 261.9959
# Epoch 3/100
# 1129/1129 [==============================] - 1s 758us/step - loss: 43.4817 - val_loss: 190.1743
# Epoch 4/100
# 1129/1129 [==============================] - 1s 757us/step - loss: 34.0249 - val_loss: 143.4087
# Epoch 5/100
# 1129/1129 [==============================] - 1s 760us/step - loss: 27.8247 - val_loss: 116.9039
# Epoch 6/100
# 1129/1129 [==============================] - 1s 776us/step - loss: 23.5415 - val_loss: 100.1978
# Epoch 7/100
# 1129/1129 [==============================] - 1s 765us/step - loss: 20.1217 - val_loss: 80.6386
# Epoch 8/100
# 1129/1129 [==============================] - 1s 776us/step - loss: 17.3667 - val_loss: 69.8380
# Epoch 9/100
# 1129/1129 [==============================] - 1s 763us/step - loss: 15.5421 - val_loss: 63.6551
# Epoch 10/100
# 1129/1129 [==============================] - 1s 774us/step - loss: 14.4970 - val_loss: 58.4133
# Epoch 11/100
# 1129/1129 [==============================] - 1s 763us/step - loss: 13.5677 - val_loss: 58.2312
# Epoch 12/100
# 1129/1129 [==============================] - 1s 765us/step - loss: 12.9894 - val_loss: 56.2922
# Epoch 13/100
# 1129/1129 [==============================] - 1s 762us/step - loss: 12.7226 - val_loss: 54.5068
# Epoch 14/100
# 1129/1129 [==============================] - 1s 776us/step - loss: 12.4904 - val_loss: 56.3192
# Epoch 15/100
# 1129/1129 [==============================] - 1s 760us/step - loss: 12.0881 - val_loss: 53.5332
# Epoch 16/100
# 1129/1129 [==============================] - 1s 759us/step - loss: 11.8856 - val_loss: 54.3196
# Epoch 17/100
# 1129/1129 [==============================] - 1s 769us/step - loss: 11.8410 - val_loss: 53.6574
# Epoch 18/100
# 1129/1129 [==============================] - 1s 758us/step - loss: 11.9454 - val_loss: 51.9230
# Epoch 19/100
# 1129/1129 [==============================] - 1s 761us/step - loss: 11.5211 - val_loss: 53.9025
# Epoch 20/100
# 1129/1129 [==============================] - 1s 777us/step - loss: 11.6644 - val_loss: 53.4584
# Epoch 21/100
# 1129/1129 [==============================] - 1s 773us/step - loss: 11.5226 - val_loss: 53.5756
# Epoch 22/100
# 1129/1129 [==============================] - 1s 762us/step - loss: 11.6392 - val_loss: 52.9579
# Epoch 23/100
# 1129/1129 [==============================] - 1s 765us/step - loss: 11.4482 - val_loss: 52.8879
# 165/165 [==============================] - 0s 467us/step
# Completed 8 splits
# Epoch 1/100
# 1165/1165 [==============================] - 1s 880us/step - loss: 692.3853 - val_loss: 226.3208
# Epoch 2/100
# 1165/1165 [==============================] - 1s 770us/step - loss: 94.8736 - val_loss: 117.2504
# Epoch 3/100
# 1165/1165 [==============================] - 1s 745us/step - loss: 64.5621 - val_loss: 102.0052
# Epoch 4/100
# 1165/1165 [==============================] - 1s 763us/step - loss: 49.5291 - val_loss: 71.1860
# Epoch 5/100
# 1165/1165 [==============================] - 1s 755us/step - loss: 38.9170 - val_loss: 48.1632
# Epoch 6/100
# 1165/1165 [==============================] - 1s 751us/step - loss: 30.5584 - val_loss: 38.6110
# Epoch 7/100
# 1165/1165 [==============================] - 1s 743us/step - loss: 24.6882 - val_loss: 27.5912
# Epoch 8/100
# 1165/1165 [==============================] - 1s 760us/step - loss: 19.7569 - val_loss: 23.4590
# Epoch 9/100
# 1165/1165 [==============================] - 1s 763us/step - loss: 17.7178 - val_loss: 20.0895
# Epoch 10/100
# 1165/1165 [==============================] - 1s 745us/step - loss: 15.8517 - val_loss: 19.2865
# Epoch 11/100
# 1165/1165 [==============================] - 1s 758us/step - loss: 15.1882 - val_loss: 19.5141
# Epoch 12/100
# 1165/1165 [==============================] - 1s 751us/step - loss: 14.6070 - val_loss: 18.5739
# Epoch 13/100
# 1165/1165 [==============================] - 1s 749us/step - loss: 14.2841 - val_loss: 18.1684
# Epoch 14/100
# 1165/1165 [==============================] - 1s 755us/step - loss: 13.8881 - val_loss: 17.9272
# Epoch 15/100
# 1165/1165 [==============================] - 1s 767us/step - loss: 13.5071 - val_loss: 17.8301
# Epoch 16/100
# 1165/1165 [==============================] - 1s 748us/step - loss: 13.2798 - val_loss: 18.1470
# Epoch 17/100
# 1165/1165 [==============================] - 1s 749us/step - loss: 13.0509 - val_loss: 18.3983
# Epoch 18/100
# 1165/1165 [==============================] - 1s 761us/step - loss: 12.9725 - val_loss: 17.1399
# Epoch 19/100
# 1165/1165 [==============================] - 1s 749us/step - loss: 12.5478 - val_loss: 17.1758
# Epoch 20/100
# 1165/1165 [==============================] - 1s 749us/step - loss: 12.6044 - val_loss: 17.1156
# Epoch 21/100
# 1165/1165 [==============================] - 1s 783us/step - loss: 12.4192 - val_loss: 16.9817
# Epoch 22/100
# 1165/1165 [==============================] - 1s 772us/step - loss: 12.2678 - val_loss: 16.9985
# Epoch 23/100
# 1165/1165 [==============================] - 1s 756us/step - loss: 12.0663 - val_loss: 17.2341
# Epoch 24/100
# 1165/1165 [==============================] - 1s 752us/step - loss: 11.9499 - val_loss: 17.0712
# Epoch 25/100
# 1165/1165 [==============================] - 1s 765us/step - loss: 11.8385 - val_loss: 16.7933
# Epoch 26/100
# 1165/1165 [==============================] - 1s 750us/step - loss: 11.6625 - val_loss: 16.8076
# Epoch 27/100
# 1165/1165 [==============================] - 1s 749us/step - loss: 11.6125 - val_loss: 17.5195
# Epoch 28/100
# 1165/1165 [==============================] - 1s 756us/step - loss: 11.5019 - val_loss: 16.7811
# Epoch 29/100
# 1165/1165 [==============================] - 1s 757us/step - loss: 11.3128 - val_loss: 16.9416
# Epoch 30/100
# 1165/1165 [==============================] - 1s 751us/step - loss: 11.1503 - val_loss: 17.2692
# Epoch 31/100
# 1165/1165 [==============================] - 1s 762us/step - loss: 10.9878 - val_loss: 16.9922
# Epoch 32/100
# 1165/1165 [==============================] - 1s 768us/step - loss: 11.1023 - val_loss: 16.6635
# Epoch 33/100
# 1165/1165 [==============================] - 1s 744us/step - loss: 11.0001 - val_loss: 16.7046
# Epoch 34/100
# 1165/1165 [==============================] - 1s 759us/step - loss: 10.9261 - val_loss: 17.2149
# Epoch 35/100
# 1165/1165 [==============================] - 1s 748us/step - loss: 10.8738 - val_loss: 16.3803
# Epoch 36/100
# 1165/1165 [==============================] - 1s 752us/step - loss: 10.7261 - val_loss: 16.8096
# Epoch 37/100
# 1165/1165 [==============================] - 1s 751us/step - loss: 10.7012 - val_loss: 17.5748
# Epoch 38/100
# 1165/1165 [==============================] - 1s 765us/step - loss: 10.5155 - val_loss: 16.6694
# Epoch 39/100
# 1165/1165 [==============================] - 1s 762us/step - loss: 10.6138 - val_loss: 16.5425
# Epoch 40/100
# 1165/1165 [==============================] - 1s 757us/step - loss: 10.5679 - val_loss: 16.3870
# 168/168 [==============================] - 0s 489us/step
# Completed 9 splits
# Epoch 1/100
# 1191/1191 [==============================] - 1s 811us/step - loss: 810.1581 - val_loss: 138.4145
# Epoch 2/100
# 1191/1191 [==============================] - 1s 751us/step - loss: 95.5763 - val_loss: 76.2450
# Epoch 3/100
# 1191/1191 [==============================] - 1s 774us/step - loss: 66.2689 - val_loss: 68.7736
# Epoch 4/100
# 1191/1191 [==============================] - 1s 752us/step - loss: 52.8138 - val_loss: 54.7801
# Epoch 5/100
# 1191/1191 [==============================] - 1s 749us/step - loss: 43.8135 - val_loss: 49.0969
# Epoch 6/100
# 1191/1191 [==============================] - 1s 754us/step - loss: 37.0124 - val_loss: 42.9618
# Epoch 7/100
# 1191/1191 [==============================] - 1s 749us/step - loss: 32.2478 - val_loss: 30.2033
# Epoch 8/100
# 1191/1191 [==============================] - 1s 748us/step - loss: 28.1777 - val_loss: 26.8890
# Epoch 9/100
# 1191/1191 [==============================] - 1s 765us/step - loss: 25.2882 - val_loss: 23.0498
# Epoch 10/100
# 1191/1191 [==============================] - 1s 749us/step - loss: 23.1194 - val_loss: 23.6631
# Epoch 11/100
# 1191/1191 [==============================] - 1s 750us/step - loss: 21.0060 - val_loss: 22.1518
# Epoch 12/100
# 1191/1191 [==============================] - 1s 758us/step - loss: 19.6250 - val_loss: 22.8253
# Epoch 13/100
# 1191/1191 [==============================] - 1s 750us/step - loss: 17.8621 - val_loss: 21.4020
# Epoch 14/100
# 1191/1191 [==============================] - 1s 764us/step - loss: 16.8747 - val_loss: 21.2716
# Epoch 15/100
# 1191/1191 [==============================] - 1s 762us/step - loss: 16.0306 - val_loss: 21.3945
# Epoch 16/100
# 1191/1191 [==============================] - 1s 758us/step - loss: 15.2791 - val_loss: 21.4374
# Epoch 17/100
# 1191/1191 [==============================] - 1s 747us/step - loss: 14.5596 - val_loss: 20.7669
# Epoch 18/100
# 1191/1191 [==============================] - 1s 760us/step - loss: 14.0376 - val_loss: 20.7153
# Epoch 19/100
# 1191/1191 [==============================] - 1s 751us/step - loss: 13.5357 - val_loss: 20.6183
# Epoch 20/100
# 1191/1191 [==============================] - 1s 746us/step - loss: 13.1472 - val_loss: 20.5706
# Epoch 21/100
# 1191/1191 [==============================] - 1s 760us/step - loss: 12.7489 - val_loss: 20.4770
# Epoch 22/100
# 1191/1191 [==============================] - 1s 747us/step - loss: 12.3682 - val_loss: 21.1543
# Epoch 23/100
# 1191/1191 [==============================] - 1s 748us/step - loss: 12.1957 - val_loss: 20.3645
# Epoch 24/100
# 1191/1191 [==============================] - 1s 760us/step - loss: 12.1295 - val_loss: 20.6065
# Epoch 25/100
# 1191/1191 [==============================] - 1s 761us/step - loss: 11.8800 - val_loss: 20.4953
# Epoch 26/100
# 1191/1191 [==============================] - 1s 747us/step - loss: 11.8187 - val_loss: 20.2391
# Epoch 27/100
# 1191/1191 [==============================] - 1s 811us/step - loss: 11.6857 - val_loss: 20.0771
# Epoch 28/100
# 1191/1191 [==============================] - 1s 747us/step - loss: 11.7419 - val_loss: 20.2731
# Epoch 29/100
# 1191/1191 [==============================] - 1s 792us/step - loss: 11.6350 - val_loss: 20.1799
# Epoch 30/100
# 1191/1191 [==============================] - 1s 749us/step - loss: 11.5824 - val_loss: 21.0534
# Epoch 31/100
# 1191/1191 [==============================] - 1s 758us/step - loss: 11.6578 - val_loss: 20.4799
# Epoch 32/100
# 1191/1191 [==============================] - 1s 762us/step - loss: 11.6194 - val_loss: 20.3126
# 170/170 [==============================] - 0s 461us/step
# Completed 10 splits
# Epoch 1/100
# 1229/1229 [==============================] - 1s 785us/step - loss: 1174.4539 - val_loss: 351.1790
# Epoch 2/100
# 1229/1229 [==============================] - 1s 741us/step - loss: 111.3214 - val_loss: 104.4131
# Epoch 3/100
# 1229/1229 [==============================] - 1s 742us/step - loss: 62.5750 - val_loss: 82.7568
# Epoch 4/100
# 1229/1229 [==============================] - 1s 729us/step - loss: 45.8535 - val_loss: 64.5397
# Epoch 5/100
# 1229/1229 [==============================] - 1s 740us/step - loss: 35.4712 - val_loss: 54.4275
# Epoch 6/100
# 1229/1229 [==============================] - 1s 732us/step - loss: 28.1453 - val_loss: 34.5646
# Epoch 7/100
# 1229/1229 [==============================] - 1s 745us/step - loss: 23.9377 - val_loss: 31.9881
# Epoch 8/100
# 1229/1229 [==============================] - 1s 740us/step - loss: 21.5599 - val_loss: 28.4460
# Epoch 9/100
# 1229/1229 [==============================] - 1s 729us/step - loss: 20.3093 - val_loss: 27.6974
# Epoch 10/100
# 1229/1229 [==============================] - 1s 727us/step - loss: 19.5751 - val_loss: 27.0508
# Epoch 11/100
# 1229/1229 [==============================] - 1s 754us/step - loss: 19.0111 - val_loss: 26.9649
# Epoch 12/100
# 1229/1229 [==============================] - 1s 775us/step - loss: 18.7146 - val_loss: 26.9776
# Epoch 13/100
# 1229/1229 [==============================] - 2s 1ms/step - loss: 18.3138 - val_loss: 26.7133
# Epoch 14/100
# 1229/1229 [==============================] - 1s 776us/step - loss: 18.0870 - val_loss: 26.9944
# Epoch 15/100
# 1229/1229 [==============================] - 1s 943us/step - loss: 17.5809 - val_loss: 26.8365
# Epoch 16/100
# 1229/1229 [==============================] - 1s 938us/step - loss: 17.5547 - val_loss: 26.8392
# Epoch 17/100
# 1229/1229 [==============================] - 1s 863us/step - loss: 17.3790 - val_loss: 26.6511
# Epoch 18/100
# 1229/1229 [==============================] - 1s 840us/step - loss: 16.8577 - val_loss: 26.3058
# Epoch 19/100
# 1229/1229 [==============================] - 1s 755us/step - loss: 16.6540 - val_loss: 26.1882
# Epoch 20/100
# 1229/1229 [==============================] - 1s 734us/step - loss: 16.2986 - val_loss: 26.0473
# Epoch 21/100
# 1229/1229 [==============================] - 1s 740us/step - loss: 16.2422 - val_loss: 26.2715
# Epoch 22/100
# 1229/1229 [==============================] - 1s 762us/step - loss: 15.8253 - val_loss: 26.0095
# Epoch 23/100
# 1229/1229 [==============================] - 1s 726us/step - loss: 15.5993 - val_loss: 26.1120
# Epoch 24/100
# 1229/1229 [==============================] - 1s 734us/step - loss: 15.3779 - val_loss: 26.1827
# Epoch 25/100
# 1229/1229 [==============================] - 1s 762us/step - loss: 15.2719 - val_loss: 26.2759
# Epoch 26/100
# 1229/1229 [==============================] - 1s 749us/step - loss: 15.1152 - val_loss: 25.8766
# Epoch 27/100
# 1229/1229 [==============================] - 1s 777us/step - loss: 14.8878 - val_loss: 25.8686
# Epoch 28/100
# 1229/1229 [==============================] - 1s 821us/step - loss: 14.7510 - val_loss: 25.7902
# Epoch 29/100
# 1229/1229 [==============================] - 1s 821us/step - loss: 14.6431 - val_loss: 25.8696
# Epoch 30/100
# 1229/1229 [==============================] - 1s 788us/step - loss: 14.3583 - val_loss: 25.6821
# Epoch 31/100
# 1229/1229 [==============================] - 1s 783us/step - loss: 14.2934 - val_loss: 25.7995
# Epoch 32/100
# 1229/1229 [==============================] - 1s 823us/step - loss: 14.2433 - val_loss: 27.4642
# Epoch 33/100
# 1229/1229 [==============================] - 1s 778us/step - loss: 14.2227 - val_loss: 26.1208
# Epoch 34/100
# 1229/1229 [==============================] - 1s 797us/step - loss: 14.0351 - val_loss: 25.6223
# Epoch 35/100
# 1229/1229 [==============================] - 1s 792us/step - loss: 14.0907 - val_loss: 25.4243
# Epoch 36/100
# 1229/1229 [==============================] - 1s 777us/step - loss: 14.0105 - val_loss: 25.5645
# Epoch 37/100
# 1229/1229 [==============================] - 1s 785us/step - loss: 14.0360 - val_loss: 26.0345
# Epoch 38/100
# 1229/1229 [==============================] - 1s 786us/step - loss: 13.8151 - val_loss: 25.7580
# Epoch 39/100
# 1229/1229 [==============================] - 1s 788us/step - loss: 13.8748 - val_loss: 25.2347
# Epoch 40/100
# 1229/1229 [==============================] - 1s 776us/step - loss: 13.6766 - val_loss: 25.2911
# Epoch 41/100
# 1229/1229 [==============================] - 1s 817us/step - loss: 13.6617 - val_loss: 26.3393
# Epoch 42/100
# 1229/1229 [==============================] - 1s 778us/step - loss: 13.5197 - val_loss: 25.7098
# Epoch 43/100
# 1229/1229 [==============================] - 1s 775us/step - loss: 13.6315 - val_loss: 25.2370
# Epoch 44/100
# 1229/1229 [==============================] - 1s 795us/step - loss: 13.6356 - val_loss: 25.2103
# Epoch 45/100
# 1229/1229 [==============================] - 1s 788us/step - loss: 13.7202 - val_loss: 25.5647
# Epoch 46/100
# 1229/1229 [==============================] - 1s 805us/step - loss: 13.6285 - val_loss: 25.1594
# Epoch 47/100
# 1229/1229 [==============================] - 1s 789us/step - loss: 13.4564 - val_loss: 25.0904
# Epoch 48/100
# 1229/1229 [==============================] - 1s 794us/step - loss: 13.4801 - val_loss: 25.4211
# Epoch 49/100
# 1229/1229 [==============================] - 1s 788us/step - loss: 13.3902 - val_loss: 25.2586
# Epoch 50/100
# 1229/1229 [==============================] - 1s 781us/step - loss: 13.2745 - val_loss: 25.0890
# Epoch 51/100
# 1229/1229 [==============================] - 1s 814us/step - loss: 13.3864 - val_loss: 25.1856
# Epoch 52/100
# 1229/1229 [==============================] - 1s 790us/step - loss: 13.2723 - val_loss: 25.1831
# Epoch 53/100
# ...
# Epoch 8/100
# 1306/1306 [==============================] - 1s 751us/step - loss: 54.7486 - val_loss: 10237.0518
# Epoch 9/100
# 1306/1306 [==============================] - 1s 750us/step - loss: 49.0517 - val_loss: 8651.2080
# Epoch 10/100
# 1306/1306 [==============================] - 1s 739us/step - loss: 44.3093 - val_loss: 7595.4248
# Epoch 11/100
# 1306/1306 [==============================] - 1s 823us/step - loss: 40.0351 - val_loss: 6397.5420
# Epoch 12/100
# 1306/1306 [==============================] - 1s 773us/step - loss: 37.0603 - val_loss: 5897.2446
# Epoch 13/100
# 1306/1306 [==============================] - 1s 751us/step - loss: 34.7662 - val_loss: 5206.0552
# Epoch 14/100
# 1306/1306 [==============================] - 1s 743us/step - loss: 32.8852 - val_loss: 5146.4077
# Epoch 15/100
# 1306/1306 [==============================] - 1s 758us/step - loss: 31.1426 - val_loss: 4688.0732
# Epoch 16/100
# 1306/1306 [==============================] - 1s 749us/step - loss: 30.0431 - val_loss: 4575.4824
# Epoch 17/100
# 1306/1306 [==============================] - 1s 739us/step - loss: 29.4077 - val_loss: 4593.4307
# Epoch 18/100
# 1306/1306 [==============================] - 1s 748us/step - loss: 28.5715 - val_loss: 3880.2656
# Epoch 19/100
# 1306/1306 [==============================] - 1s 761us/step - loss: 27.8753 - val_loss: 3397.3672
# Epoch 20/100
# 1306/1306 [==============================] - 1s 772us/step - loss: 27.3403 - val_loss: 4010.1064
# Epoch 21/100
# 1306/1306 [==============================] - 1s 765us/step - loss: 27.0802 - val_loss: 3245.0806
# Epoch 22/100
# 1306/1306 [==============================] - 1s 748us/step - loss: 26.7035 - val_loss: 3460.7883
# Epoch 23/100
# 1306/1306 [==============================] - 1s 845us/step - loss: 26.2408 - val_loss: 2749.2893
# Epoch 24/100
# 1306/1306 [==============================] - 1s 897us/step - loss: 26.2105 - val_loss: 2812.8093
# Epoch 25/100
# 1306/1306 [==============================] - 1s 907us/step - loss: 25.7209 - val_loss: 2423.9958
# Epoch 26/100
# 1306/1306 [==============================] - 1s 853us/step - loss: 25.4312 - val_loss: 2468.2686
# Epoch 27/100
# 1306/1306 [==============================] - 1s 810us/step - loss: 25.1849 - val_loss: 2031.1393
# Epoch 28/100
# 1306/1306 [==============================] - 1s 817us/step - loss: 25.2492 - val_loss: 2054.1990
# Epoch 29/100
# 1306/1306 [==============================] - 1s 816us/step - loss: 25.2085 - val_loss: 2100.6582
# Epoch 30/100
# 1306/1306 [==============================] - 1s 824us/step - loss: 24.8561 - val_loss: 2173.1440
# Epoch 31/100
# 1306/1306 [==============================] - 1s 819us/step - loss: 24.7026 - val_loss: 1722.8895
# Epoch 32/100
# 1306/1306 [==============================] - 1s 813us/step - loss: 24.5332 - val_loss: 1438.9373
# Epoch 33/100
# 1306/1306 [==============================] - 1s 827us/step - loss: 24.3263 - val_loss: 1740.6370
# Epoch 34/100
# 1306/1306 [==============================] - 1s 837us/step - loss: 23.9888 - val_loss: 1349.9639
# Epoch 35/100
# 1306/1306 [==============================] - 1s 807us/step - loss: 24.0726 - val_loss: 1413.7019
# Epoch 36/100
# 1306/1306 [==============================] - 1s 828us/step - loss: 23.9616 - val_loss: 1236.6901
# Epoch 37/100
# 1306/1306 [==============================] - 1s 826us/step - loss: 23.8164 - val_loss: 1366.8568
# Epoch 38/100
# 1306/1306 [==============================] - 1s 810us/step - loss: 23.7403 - val_loss: 1245.2174
# Epoch 39/100
# 1306/1306 [==============================] - 1s 803us/step - loss: 23.8691 - val_loss: 1179.9679
# Epoch 40/100
# 1306/1306 [==============================] - 1s 808us/step - loss: 23.7447 - val_loss: 1210.5687
# Epoch 41/100
# 1306/1306 [==============================] - 1s 808us/step - loss: 23.8586 - val_loss: 1122.8387
# Epoch 42/100
# 1306/1306 [==============================] - 1s 803us/step - loss: 23.6701 - val_loss: 1148.3352
# Epoch 43/100
# 1306/1306 [==============================] - 1s 817us/step - loss: 23.5906 - val_loss: 1010.1902
# Epoch 44/100
# 1306/1306 [==============================] - 1s 817us/step - loss: 23.2915 - val_loss: 936.4736
# Epoch 45/100
# 1306/1306 [==============================] - 1s 797us/step - loss: 23.4285 - val_loss: 947.8821
# Epoch 46/100
# 1306/1306 [==============================] - 1s 805us/step - loss: 23.3694 - val_loss: 1007.8143
# Epoch 47/100
# 1306/1306 [==============================] - 1s 816us/step - loss: 23.3364 - val_loss: 993.5212
# Epoch 48/100
# 1306/1306 [==============================] - 1s 806us/step - loss: 23.4289 - val_loss: 1044.4183
# Epoch 49/100
# 1306/1306 [==============================] - 1s 813us/step - loss: 23.1696 - val_loss: 966.6630
# 182/182 [==============================] - 0s 493us/step
# Completed 15 splits
# Epoch 1/100
# 1327/1327 [==============================] - 2s 887us/step - loss: 6335.1904 - val_loss: 23232.6426
# Epoch 2/100
# 1327/1327 [==============================] - 1s 832us/step - loss: 1271.3741 - val_loss: 84089.3906
# Epoch 3/100
# 1327/1327 [==============================] - 1s 815us/step - loss: 173.9193 - val_loss: 27578.8770
# Epoch 4/100
# 1327/1327 [==============================] - 1s 822us/step - loss: 125.5284 - val_loss: 14711.3047
# Epoch 5/100
# 1327/1327 [==============================] - 1s 823us/step - loss: 101.2970 - val_loss: 10408.6787
# Epoch 6/100
# 1327/1327 [==============================] - 1s 815us/step - loss: 85.5591 - val_loss: 8514.9336
# Epoch 7/100
# 1327/1327 [==============================] - 1s 831us/step - loss: 74.2113 - val_loss: 6754.0068
# Epoch 8/100
# 1327/1327 [==============================] - 1s 825us/step - loss: 65.8831 - val_loss: 5958.0767
# Epoch 9/100
# 1327/1327 [==============================] - 1s 839us/step - loss: 60.2570 - val_loss: 5987.4121
# Epoch 10/100
# 1327/1327 [==============================] - 1s 819us/step - loss: 55.6220 - val_loss: 5615.6343
# Epoch 11/100
# 1327/1327 [==============================] - 1s 827us/step - loss: 52.1355 - val_loss: 5630.2915
# Epoch 12/100
# 1327/1327 [==============================] - 1s 839us/step - loss: 49.4184 - val_loss: 5604.7354
# Epoch 13/100
# 1327/1327 [==============================] - 1s 817us/step - loss: 46.8191 - val_loss: 5276.1797
# Epoch 14/100
# 1327/1327 [==============================] - 1s 822us/step - loss: 44.5907 - val_loss: 5081.0132
# Epoch 15/100
# 1327/1327 [==============================] - 1s 822us/step - loss: 42.3996 - val_loss: 5330.0400
# Epoch 16/100
# 1327/1327 [==============================] - 1s 841us/step - loss: 40.7235 - val_loss: 4944.7983
# Epoch 17/100
# 1327/1327 [==============================] - 1s 822us/step - loss: 39.3338 - val_loss: 4913.3218
# Epoch 18/100
# 1327/1327 [==============================] - 1s 857us/step - loss: 38.1587 - val_loss: 4578.0762
# Epoch 19/100
# 1327/1327 [==============================] - 1s 842us/step - loss: 37.2137 - val_loss: 4652.8989
# Epoch 20/100
# 1327/1327 [==============================] - 1s 824us/step - loss: 36.2346 - val_loss: 4462.6475
# Epoch 21/100
# 1327/1327 [==============================] - 1s 826us/step - loss: 35.5149 - val_loss: 4480.3721
# Epoch 22/100
# 1327/1327 [==============================] - 1s 826us/step - loss: 34.9375 - val_loss: 4158.8882
# Epoch 23/100
# 1327/1327 [==============================] - 1s 830us/step - loss: 34.5126 - val_loss: 3842.0510
# Epoch 24/100
# 1327/1327 [==============================] - 1s 821us/step - loss: 34.2287 - val_loss: 3420.3928
# Epoch 25/100
# 1327/1327 [==============================] - 1s 818us/step - loss: 33.8593 - val_loss: 2878.9932
# Epoch 26/100
# 1327/1327 [==============================] - 1s 825us/step - loss: 33.5089 - val_loss: 3075.4580
# Epoch 27/100
# 1327/1327 [==============================] - 1s 826us/step - loss: 33.3309 - val_loss: 2450.1023
# Epoch 28/100
# 1327/1327 [==============================] - 1s 816us/step - loss: 32.9350 - val_loss: 2751.7407
# Epoch 29/100
# 1327/1327 [==============================] - 1s 836us/step - loss: 32.8600 - val_loss: 2195.0459
# Epoch 30/100
# 1327/1327 [==============================] - 1s 826us/step - loss: 32.6601 - val_loss: 2481.8135
# Epoch 31/100
# 1327/1327 [==============================] - 1s 825us/step - loss: 32.3591 - val_loss: 2245.1062
# Epoch 32/100
# 1327/1327 [==============================] - 1s 821us/step - loss: 32.1405 - val_loss: 2233.4429
# Epoch 33/100
# 1327/1327 [==============================] - 1s 830us/step - loss: 32.1943 - val_loss: 1800.9746
# Epoch 34/100
# 1327/1327 [==============================] - 1s 833us/step - loss: 31.8708 - val_loss: 1744.8595
# Epoch 35/100
# 1327/1327 [==============================] - 1s 831us/step - loss: 31.6858 - val_loss: 1510.2484
# Epoch 36/100
# 1327/1327 [==============================] - 1s 826us/step - loss: 31.7164 - val_loss: 1421.2554
# Epoch 37/100
# 1327/1327 [==============================] - 1s 817us/step - loss: 31.4849 - val_loss: 1401.7957
# Epoch 38/100
# 1327/1327 [==============================] - 1s 824us/step - loss: 31.4946 - val_loss: 1360.4382
# Epoch 39/100
# 1327/1327 [==============================] - 1s 837us/step - loss: 31.3528 - val_loss: 1348.9321
# Epoch 40/100
# 1327/1327 [==============================] - 1s 814us/step - loss: 31.1100 - val_loss: 1268.0344
# Epoch 41/100
# 1327/1327 [==============================] - 1s 829us/step - loss: 31.1774 - val_loss: 1290.7234
# Epoch 42/100
# 1327/1327 [==============================] - 1s 823us/step - loss: 31.0487 - val_loss: 905.7080
# Epoch 43/100
# 1327/1327 [==============================] - 1s 831us/step - loss: 30.9167 - val_loss: 1088.2498
# Epoch 44/100
# 1327/1327 [==============================] - 1s 811us/step - loss: 30.7739 - val_loss: 1119.8790
# Epoch 45/100
# 1327/1327 [==============================] - 1s 829us/step - loss: 30.6741 - val_loss: 892.2476
# Epoch 46/100
# 1327/1327 [==============================] - 1s 823us/step - loss: 30.6429 - val_loss: 1008.8489
# Epoch 47/100
# 1327/1327 [==============================] - 1s 821us/step - loss: 30.6669 - val_loss: 1019.4771
# Epoch 48/100
# 1327/1327 [==============================] - 1s 820us/step - loss: 30.7536 - val_loss: 788.7424
# Epoch 49/100
# 1327/1327 [==============================] - 1s 825us/step - loss: 30.3607 - val_loss: 815.5756
# Epoch 50/100
# 1327/1327 [==============================] - 1s 831us/step - loss: 30.3616 - val_loss: 896.9703
# Epoch 51/100
# 1327/1327 [==============================] - 1s 815us/step - loss: 30.4152 - val_loss: 701.4967
# Epoch 52/100
# 1327/1327 [==============================] - 1s 827us/step - loss: 30.3021 - val_loss: 692.3599
# Epoch 53/100
# 1327/1327 [==============================] - 1s 826us/step - loss: 30.3206 - val_loss: 670.5762
# Epoch 54/100
# 1327/1327 [==============================] - 1s 829us/step - loss: 30.2292 - val_loss: 685.7275
# Epoch 55/100
# 1327/1327 [==============================] - 1s 818us/step - loss: 30.2449 - val_loss: 651.3370
# Epoch 56/100
# 1327/1327 [==============================] - 1s 830us/step - loss: 30.1591 - val_loss: 492.1043
# Epoch 57/100
# 1327/1327 [==============================] - 1s 831us/step - loss: 30.1283 - val_loss: 640.0447
# Epoch 58/100
# 1327/1327 [==============================] - 1s 824us/step - loss: 30.0979 - val_loss: 581.0323
# Epoch 59/100
# 1327/1327 [==============================] - 1s 820us/step - loss: 30.0408 - val_loss: 646.4894
# Epoch 60/100
# 1327/1327 [==============================] - 1s 829us/step - loss: 30.0335 - val_loss: 563.2109
# Epoch 61/100
# 1327/1327 [==============================] - 1s 827us/step - loss: 29.8658 - val_loss: 548.1255
# 180/180 [==============================] - 0s 501us/step
# Completed 16 splits
# Epoch 1/100
# 1360/1360 [==============================] - 2s 902us/step - loss: 7588.4741 - val_loss: 10720.1631
# Epoch 2/100
# 1360/1360 [==============================] - 1s 830us/step - loss: 808.7208 - val_loss: 602.0399
# Epoch 3/100
# 1360/1360 [==============================] - 1s 823us/step - loss: 198.3189 - val_loss: 415.3647
# Epoch 4/100
# 1360/1360 [==============================] - 1s 809us/step - loss: 142.8876 - val_loss: 365.1204
# Epoch 5/100
# 1360/1360 [==============================] - 1s 824us/step - loss: 123.7182 - val_loss: 318.1229
# Epoch 6/100
# 1360/1360 [==============================] - 1s 820us/step - loss: 111.4424 - val_loss: 296.4810
# Epoch 7/100
# 1360/1360 [==============================] - 1s 829us/step - loss: 102.3876 - val_loss: 291.1425
# Epoch 8/100
# 1360/1360 [==============================] - 1s 827us/step - loss: 95.8803 - val_loss: 277.6226
# Epoch 9/100
# 1360/1360 [==============================] - 1s 836us/step - loss: 91.1054 - val_loss: 287.1349
# Epoch 10/100
# 1360/1360 [==============================] - 1s 866us/step - loss: 87.0090 - val_loss: 265.1845
# Epoch 11/100
# 1360/1360 [==============================] - 1s 852us/step - loss: 84.1119 - val_loss: 274.2681
# Epoch 12/100
# 1360/1360 [==============================] - 1s 822us/step - loss: 80.5743 - val_loss: 251.3654
# Epoch 13/100
# 1360/1360 [==============================] - 1s 818us/step - loss: 77.8884 - val_loss: 243.5374
# Epoch 14/100
# 1360/1360 [==============================] - 1s 822us/step - loss: 75.9881 - val_loss: 240.7533
# Epoch 15/100
# 1360/1360 [==============================] - 1s 832us/step - loss: 73.9409 - val_loss: 234.4372
# Epoch 16/100
# 1360/1360 [==============================] - 1s 822us/step - loss: 71.9153 - val_loss: 226.6887
# Epoch 17/100
# 1360/1360 [==============================] - 1s 833us/step - loss: 70.3230 - val_loss: 227.9164
# Epoch 18/100
# 1360/1360 [==============================] - 1s 813us/step - loss: 69.0328 - val_loss: 222.2110
# Epoch 19/100
# 1360/1360 [==============================] - 1s 852us/step - loss: 67.5358 - val_loss: 219.1899
# Epoch 20/100
# 1360/1360 [==============================] - 1s 833us/step - loss: 65.9002 - val_loss: 214.9719
# Epoch 21/100
# 1360/1360 [==============================] - 1s 829us/step - loss: 64.5861 - val_loss: 210.6096
# Epoch 22/100
# 1360/1360 [==============================] - 1s 809us/step - loss: 63.7702 - val_loss: 209.9889
# Epoch 23/100
# 1360/1360 [==============================] - 1s 822us/step - loss: 62.8645 - val_loss: 207.3831
# Epoch 24/100
# 1360/1360 [==============================] - 1s 816us/step - loss: 62.2517 - val_loss: 202.3287
# Epoch 25/100
# 1360/1360 [==============================] - 1s 821us/step - loss: 61.4374 - val_loss: 203.8734
# Epoch 26/100
# 1360/1360 [==============================] - 1s 835us/step - loss: 60.1053 - val_loss: 197.0930
# Epoch 27/100
# 1360/1360 [==============================] - 1s 831us/step - loss: 59.1269 - val_loss: 196.6920
# Epoch 28/100
# 1360/1360 [==============================] - 1s 827us/step - loss: 58.4162 - val_loss: 195.6833
# Epoch 29/100
# 1360/1360 [==============================] - 1s 815us/step - loss: 58.0927 - val_loss: 194.1255
# Epoch 30/100
# 1360/1360 [==============================] - 1s 831us/step - loss: 57.2578 - val_loss: 193.7624
# Epoch 31/100
# 1360/1360 [==============================] - 1s 819us/step - loss: 56.7388 - val_loss: 191.6036
# Epoch 32/100
# 1360/1360 [==============================] - 1s 825us/step - loss: 56.4083 - val_loss: 190.9337
# Epoch 33/100
# 1360/1360 [==============================] - 1s 836us/step - loss: 55.7744 - val_loss: 189.9746
# Epoch 34/100
# 1360/1360 [==============================] - 1s 844us/step - loss: 55.4080 - val_loss: 195.8138
# Epoch 35/100
# 1360/1360 [==============================] - 1s 877us/step - loss: 55.1288 - val_loss: 189.2138
# Epoch 36/100
# 1360/1360 [==============================] - 1s 863us/step - loss: 54.7162 - val_loss: 189.6441
# Epoch 37/100
# 1360/1360 [==============================] - 1s 826us/step - loss: 54.2854 - val_loss: 189.3141
# Epoch 38/100
# 1360/1360 [==============================] - 1s 860us/step - loss: 54.1052 - val_loss: 189.6916
# Epoch 39/100
# 1360/1360 [==============================] - 1s 868us/step - loss: 53.9355 - val_loss: 190.3655
# Epoch 40/100
# 1360/1360 [==============================] - 1s 910us/step - loss: 53.4846 - val_loss: 189.2628
# 74/74 [==============================] - 0s 535us/step
# Completed 17 splits
# R2_oos NN4 Top 500:  0.9316162587132466

# %% [markdown]
# # NN4 algorithm for bottom 500 stocks

# %%
X = df_bottom_500[['Date'] + variables]
y = df_bottom_500['Adj Close t+1']

X['Date'] = pd.to_datetime(X['Date'])

initial_date = X['Date'].min()

predictions = []
y_test_list = []
dates = []


for split_num, (train_index, val_index, test_index) in enumerate(recursive_rolling_method(X,initial_date,date_column='Date',train_period=8,val_period=3,test_period=1,freq='years')):
    X_train = X.loc[train_index].drop('Date', axis=1)
    y_train = y.loc[train_index]

    X_val = X.loc[val_index].drop('Date', axis=1)
    y_val = y.loc[val_index]

    X_test = X.loc[test_index].drop('Date', axis=1)
    y_test = y.loc[test_index]

    
    input_shape = [X_train.shape[1]]
    
    
    mean_train = X_train.mean(axis=0)
    std_train  = X_train.std(axis=0)
    
    X_train = (X_train-mean_train) / std_train
    X_val = (X_val-mean_train) / std_train
    X_test = (X_test-mean_train) / std_train
    
    
    
    model = tf.keras.Sequential([
 
    tf.keras.layers.Flatten(input_shape=input_shape),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=8, activation='relu'),
    tf.keras.layers.Dense(units=4, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='linear')
    
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0, clipnorm=1.0, clipvalue=0.5), loss='mse')    
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[early_stopping])
    
    preds = model.predict(X_test)
    preds = preds.ravel()


    predictions.append(preds)
    dates.append(X.loc[y_test.index, 'Date'])
    y_test_list.append(y_test)



    del X_train, y_train, X_val, y_val, model, preds
    gc.collect()

    print(f"Completed {split_num + 1} splits")

predictions_all = np.concatenate(predictions, axis=0)
y_test_list_all = pd.concat(y_test_list, axis=0)
dates_all = pd.concat(dates, axis=0)

R2oos_NN4_bottom = 1 - np.sum(np.power(y_test_list_all - predictions_all, 2)) / np.sum(np.power(y_test_list_all, 2))
print("R2_oos NN4 bottom 500: ", R2oos_NN4_bottom)
# Out:
#     Train period: 1997-02-28 00:00:00 - 2005-02-28 00:00:00  || Val period: 2005-03-28 00:00:00 - 2008-03-28 00:00:00  || Test period 2008-04-28 00:00:00 - 2009-04-28 00:00:00  || Train contains 6974  || Val contains 3935  || Test contains 1557
#     Train period: 1998-02-28 00:00:00 - 2006-02-28 00:00:00  || Val period: 2006-03-28 00:00:00 - 2009-03-28 00:00:00  || Test period 2009-04-28 00:00:00 - 2010-04-28 00:00:00  || Train contains 7561  || Val contains 4256  || Test contains 1633
#     Train period: 1999-02-28 00:00:00 - 2007-02-28 00:00:00  || Val period: 2007-03-28 00:00:00 - 2010-03-28 00:00:00  || Test period 2010-04-28 00:00:00 - 2011-04-28 00:00:00  || Train contains 8150  || Val contains 4597  || Test contains 1704
#     Train period: 2000-02-28 00:00:00 - 2008-02-28 00:00:00  || Val period: 2008-03-28 00:00:00 - 2011-03-28 00:00:00  || Test period 2011-04-28 00:00:00 - 2012-04-28 00:00:00  || Train contains 8887  || Val contains 4876  || Test contains 1778
#     Train period: 2001-02-28 00:00:00 - 2009-02-28 00:00:00  || Val period: 2009-03-28 00:00:00 - 2012-03-28 00:00:00  || Test period 2012-04-28 00:00:00 - 2013-04-28 00:00:00  || Train contains 9767  || Val contains 5094  || Test contains 1888
#     Train period: 2002-02-28 00:00:00 - 2010-02-28 00:00:00  || Val period: 2010-03-28 00:00:00 - 2013-03-28 00:00:00  || Test period 2013-04-28 00:00:00 - 2014-04-28 00:00:00  || Train contains 10466  || Val contains 5349  || Test contains 1973
#     Train period: 2003-02-28 00:00:00 - 2011-02-28 00:00:00  || Val period: 2011-03-28 00:00:00 - 2014-03-28 00:00:00  || Test period 2014-04-28 00:00:00 - 2015-04-28 00:00:00  || Train contains 11013  || Val contains 5617  || Test contains 2064
#     Train period: 2004-02-28 00:00:00 - 2012-02-28 00:00:00  || Val period: 2012-03-28 00:00:00 - 2015-03-28 00:00:00  || Test period 2015-04-28 00:00:00 - 2016-04-28 00:00:00  || Train contains 11578  || Val contains 5905  || Test contains 2278
#     Train period: 2005-02-28 00:00:00 - 2013-02-28 00:00:00  || Val period: 2013-03-28 00:00:00 - 2016-03-28 00:00:00  || Test period 2016-04-28 00:00:00 - 2017-04-28 00:00:00  || Train contains 12396  || Val contains 6278  || Test contains 2551
#     Train period: 2006-02-28 00:00:00 - 2014-02-28 00:00:00  || Val period: 2014-03-28 00:00:00 - 2017-03-28 00:00:00  || Test period 2017-04-28 00:00:00 - 2018-04-28 00:00:00  || Train contains 13142  || Val contains 6837  || Test contains 2743
#     Train period: 2007-02-28 00:00:00 - 2015-02-28 00:00:00  || Val period: 2015-03-28 00:00:00 - 2018-03-28 00:00:00  || Test period 2018-04-28 00:00:00 - 2019-04-28 00:00:00  || Train contains 14080  || Val contains 7509  || Test contains 3057
#     Train period: 2008-02-28 00:00:00 - 2016-02-28 00:00:00  || Val period: 2016-03-28 00:00:00 - 2019-03-28 00:00:00  || Test period 2019-04-28 00:00:00 - 2020-04-28 00:00:00  || Train contains 14727  || Val contains 8276  || Test contains 3551
#     Train period: 2009-02-28 00:00:00 - 2017-02-28 00:00:00  || Val period: 2017-03-28 00:00:00 - 2020-03-28 00:00:00  || Test period 2020-04-28 00:00:00 - 2021-04-28 00:00:00  || Train contains 15564  || Val contains 9256  || Test contains 3902
#     Train period: 2010-02-28 00:00:00 - 2018-02-28 00:00:00  || Val period: 2018-03-28 00:00:00 - 2021-03-28 00:00:00  || Test period 2021-04-28 00:00:00 - 2022-04-28 00:00:00  || Train contains 16638  || Val contains 10412  || Test contains 4286
#     Train period: 2011-02-28 00:00:00 - 2019-02-28 00:00:00  || Val period: 2019-03-28 00:00:00 - 2022-03-28 00:00:00  || Test period 2022-04-28 00:00:00 - 2023-04-28 00:00:00  || Train contains 18073  || Val contains 11621  || Test contains 5119
#     Train period: 2012-02-28 00:00:00 - 2020-02-28 00:00:00  || Val period: 2020-03-28 00:00:00 - 2023-03-28 00:00:00  || Test period 2023-04-28 00:00:00 - 2024-04-28 00:00:00  || Train contains 19789  || Val contains 13164  || Test contains 5673
#     Train period: 2013-02-28 00:00:00 - 2021-02-28 00:00:00  || Val period: 2021-03-28 00:00:00 - 2024-03-28 00:00:00  || Test period 2024-04-28 00:00:00 - 2025-04-28 00:00:00  || Train contains 22102  || Val contains 14938  || Test contains 2398
# Epoch 1/100
# 218/218 [==============================] - 1s 1ms/step - loss: 5611.6455 - val_loss: 9505.7354
# Epoch 2/100
# 218/218 [==============================] - 0s 1ms/step - loss: 5415.6328 - val_loss: 8981.8418
# Epoch 3/100
# 218/218 [==============================] - 0s 976us/step - loss: 4972.3027 - val_loss: 7942.7183
# Epoch 4/100
# 218/218 [==============================] - 0s 974us/step - loss: 4185.1509 - val_loss: 6246.9053
# Epoch 5/100
# 218/218 [==============================] - 0s 950us/step - loss: 3033.5481 - val_loss: 4219.2944
# Epoch 6/100
# 218/218 [==============================] - 0s 934us/step - loss: 1864.6327 - val_loss: 2638.0396
# Epoch 7/100
# 218/218 [==============================] - 0s 949us/step - loss: 1114.1870 - val_loss: 1945.9689
# Epoch 8/100
# 218/218 [==============================] - 0s 911us/step - loss: 770.2673 - val_loss: 1669.0439
# Epoch 9/100
# 218/218 [==============================] - 0s 931us/step - loss: 618.3712 - val_loss: 1565.6620
# Epoch 10/100
# 218/218 [==============================] - 0s 913us/step - loss: 535.7687 - val_loss: 1405.7865
# Epoch 11/100
# 218/218 [==============================] - 0s 926us/step - loss: 484.0896 - val_loss: 1404.2151
# Epoch 12/100
# 218/218 [==============================] - 0s 919us/step - loss: 451.7636 - val_loss: 1332.3082
# Epoch 13/100
# 218/218 [==============================] - 0s 1ms/step - loss: 427.9101 - val_loss: 1331.0511
# Epoch 14/100
# 218/218 [==============================] - 0s 921us/step - loss: 413.9454 - val_loss: 1309.7173
# Epoch 15/100
# 218/218 [==============================] - 0s 919us/step - loss: 398.9099 - val_loss: 1370.0275
# Epoch 16/100
# 218/218 [==============================] - 0s 915us/step - loss: 387.2144 - val_loss: 1380.7551
# Epoch 17/100
# 218/218 [==============================] - 0s 912us/step - loss: 383.2079 - val_loss: 1391.1476
# Epoch 18/100
# 218/218 [==============================] - 0s 909us/step - loss: 378.0246 - val_loss: 1465.4314
# Epoch 19/100
# 218/218 [==============================] - 0s 925us/step - loss: 369.6275 - val_loss: 1564.4352
# 49/49 [==============================] - 0s 516us/step
# Completed 1 splits
# Epoch 1/100
# 237/237 [==============================] - 1s 1ms/step - loss: 6441.8735 - val_loss: 8129.9331
# Epoch 2/100
# 237/237 [==============================] - 0s 918us/step - loss: 6413.1670 - val_loss: 8081.6963
# Epoch 3/100
# 237/237 [==============================] - 0s 895us/step - loss: 6321.4766 - val_loss: 7874.7969
# Epoch 4/100
# 237/237 [==============================] - 0s 988us/step - loss: 6017.9858 - val_loss: 7314.4536
# Epoch 5/100
# 237/237 [==============================] - 0s 905us/step - loss: 5342.2939 - val_loss: 6188.3062
# Epoch 6/100
# 237/237 [==============================] - 0s 898us/step - loss: 4112.1216 - val_loss: 4418.4312
# Epoch 7/100
# 237/237 [==============================] - 0s 900us/step - loss: 2556.5334 - val_loss: 2648.4507
# Epoch 8/100
# 237/237 [==============================] - 0s 896us/step - loss: 1424.6392 - val_loss: 1754.5533
# Epoch 9/100
# 237/237 [==============================] - 0s 896us/step - loss: 971.1282 - val_loss: 1381.7402
# Epoch 10/100
# 237/237 [==============================] - 0s 940us/step - loss: 777.9274 - val_loss: 1165.9451
# Epoch 11/100
# 237/237 [==============================] - 0s 1ms/step - loss: 675.7259 - val_loss: 1015.0883
# Epoch 12/100
# 237/237 [==============================] - 0s 1ms/step - loss: 614.8564 - val_loss: 922.9923
# Epoch 13/100
# 237/237 [==============================] - 0s 913us/step - loss: 586.6292 - val_loss: 853.8027
# Epoch 14/100
# 237/237 [==============================] - 0s 995us/step - loss: 559.8851 - val_loss: 794.9852
# Epoch 15/100
# 237/237 [==============================] - 0s 977us/step - loss: 540.9764 - val_loss: 755.3940
# Epoch 16/100
# 237/237 [==============================] - 0s 1ms/step - loss: 528.8666 - val_loss: 721.0811
# Epoch 17/100
# 237/237 [==============================] - 0s 1ms/step - loss: 514.9428 - val_loss: 711.8766
# Epoch 18/100
# 237/237 [==============================] - 0s 987us/step - loss: 510.8061 - val_loss: 687.4829
# Epoch 19/100
# 237/237 [==============================] - 0s 1ms/step - loss: 501.3200 - val_loss: 675.4587
# Epoch 20/100
# 237/237 [==============================] - 0s 1ms/step - loss: 492.5221 - val_loss: 675.9470
# Epoch 21/100
# 237/237 [==============================] - 0s 1ms/step - loss: 498.1605 - val_loss: 674.7856
# Epoch 22/100
# 237/237 [==============================] - 0s 984us/step - loss: 491.7924 - val_loss: 646.2802
# Epoch 23/100
# 237/237 [==============================] - 0s 1ms/step - loss: 487.4450 - val_loss: 629.7693
# Epoch 24/100
# 237/237 [==============================] - 0s 1ms/step - loss: 476.3797 - val_loss: 627.2512
# Epoch 25/100
# 237/237 [==============================] - 0s 1ms/step - loss: 471.9311 - val_loss: 616.4788
# Epoch 26/100
# 237/237 [==============================] - 0s 941us/step - loss: 470.8940 - val_loss: 613.5176
# Epoch 27/100
# 237/237 [==============================] - 0s 910us/step - loss: 467.1300 - val_loss: 609.7747
# Epoch 28/100
# 237/237 [==============================] - 0s 926us/step - loss: 467.6814 - val_loss: 604.2170
# Epoch 29/100
# 237/237 [==============================] - 0s 938us/step - loss: 467.5734 - val_loss: 605.0703
# Epoch 30/100
# 237/237 [==============================] - 0s 905us/step - loss: 474.6859 - val_loss: 590.2099
# Epoch 31/100
# 237/237 [==============================] - 0s 934us/step - loss: 462.0786 - val_loss: 590.9175
# Epoch 32/100
# 237/237 [==============================] - 0s 961us/step - loss: 461.7469 - val_loss: 584.6620
# Epoch 33/100
# 237/237 [==============================] - 0s 980us/step - loss: 453.9578 - val_loss: 575.2230
# Epoch 34/100
# 237/237 [==============================] - 0s 968us/step - loss: 450.9787 - val_loss: 569.9073
# Epoch 35/100
# 237/237 [==============================] - 0s 964us/step - loss: 448.6603 - val_loss: 565.8690
# Epoch 36/100
# 237/237 [==============================] - 0s 982us/step - loss: 443.0477 - val_loss: 581.8011
# Epoch 37/100
# 237/237 [==============================] - 0s 968us/step - loss: 446.6499 - val_loss: 560.8314
# Epoch 38/100
# 237/237 [==============================] - 0s 941us/step - loss: 447.4921 - val_loss: 544.1918
# Epoch 39/100
# 237/237 [==============================] - 0s 962us/step - loss: 435.5693 - val_loss: 558.6390
# Epoch 40/100
# 237/237 [==============================] - 0s 953us/step - loss: 435.4224 - val_loss: 538.8823
# Epoch 41/100
# 237/237 [==============================] - 0s 954us/step - loss: 437.0897 - val_loss: 541.4388
# Epoch 42/100
# 237/237 [==============================] - 0s 953us/step - loss: 437.0659 - val_loss: 539.6768
# Epoch 43/100
# 237/237 [==============================] - 0s 954us/step - loss: 435.4997 - val_loss: 536.1763
# Epoch 44/100
# 237/237 [==============================] - 0s 953us/step - loss: 429.5481 - val_loss: 530.7952
# Epoch 45/100
# 237/237 [==============================] - 0s 959us/step - loss: 433.2372 - val_loss: 534.2499
# Epoch 46/100
# 237/237 [==============================] - 0s 961us/step - loss: 428.6097 - val_loss: 521.5276
# Epoch 47/100
# 237/237 [==============================] - 0s 998us/step - loss: 425.6874 - val_loss: 532.3262
# Epoch 48/100
# 237/237 [==============================] - 0s 984us/step - loss: 425.7943 - val_loss: 519.2974
# Epoch 49/100
# 237/237 [==============================] - 0s 996us/step - loss: 426.8796 - val_loss: 513.8972
# Epoch 50/100
# 237/237 [==============================] - 0s 1ms/step - loss: 428.4815 - val_loss: 517.7083
# Epoch 51/100
# 237/237 [==============================] - 0s 1ms/step - loss: 419.6549 - val_loss: 504.7726
# Epoch 52/100
# 237/237 [==============================] - 0s 994us/step - loss: 419.6817 - val_loss: 513.2767
# Epoch 53/100
# 237/237 [==============================] - 0s 1ms/step - loss: 419.3291 - val_loss: 499.0855
# Epoch 54/100
# 237/237 [==============================] - 0s 1ms/step - loss: 418.0482 - val_loss: 493.0995
# Epoch 55/100
# 237/237 [==============================] - 0s 979us/step - loss: 408.5189 - val_loss: 500.9250
# Epoch 56/100
# 237/237 [==============================] - 0s 993us/step - loss: 414.7572 - val_loss: 488.2327
# Epoch 57/100
# 237/237 [==============================] - 0s 973us/step - loss: 406.0358 - val_loss: 488.3043
# Epoch 58/100
# 237/237 [==============================] - 0s 962us/step - loss: 400.9750 - val_loss: 491.5895
# Epoch 59/100
# 237/237 [==============================] - 0s 974us/step - loss: 405.9073 - val_loss: 482.6692
# Epoch 60/100
# 237/237 [==============================] - 0s 1ms/step - loss: 405.1823 - val_loss: 488.8744
# Epoch 61/100
# 237/237 [==============================] - 0s 1ms/step - loss: 401.8099 - val_loss: 484.5910
# Epoch 62/100
# 237/237 [==============================] - 0s 1ms/step - loss: 399.0272 - val_loss: 479.6837
# Epoch 63/100
# 237/237 [==============================] - 0s 1ms/step - loss: 397.3216 - val_loss: 477.5060
# Epoch 64/100
# 237/237 [==============================] - 0s 1ms/step - loss: 400.0229 - val_loss: 472.6993
# Epoch 65/100
# 237/237 [==============================] - 0s 1ms/step - loss: 400.6498 - val_loss: 472.4798
# Epoch 66/100
# 237/237 [==============================] - 0s 1ms/step - loss: 393.3162 - val_loss: 463.2987
# Epoch 67/100
# 237/237 [==============================] - 0s 1ms/step - loss: 390.8963 - val_loss: 463.7633
# Epoch 68/100
# 237/237 [==============================] - 0s 1ms/step - loss: 391.5116 - val_loss: 461.1424
# Epoch 69/100
# 237/237 [==============================] - 0s 1ms/step - loss: 393.2754 - val_loss: 468.2646
# Epoch 70/100
# 237/237 [==============================] - 0s 1ms/step - loss: 386.9898 - val_loss: 452.1803
# Epoch 71/100
# 237/237 [==============================] - 0s 1ms/step - loss: 383.5818 - val_loss: 462.1306
# Epoch 72/100
# 237/237 [==============================] - 0s 1ms/step - loss: 388.1161 - val_loss: 454.8189
# Epoch 73/100
# 237/237 [==============================] - 0s 1ms/step - loss: 381.9723 - val_loss: 453.3551
# Epoch 74/100
# 237/237 [==============================] - 0s 1ms/step - loss: 384.0849 - val_loss: 453.9850
# Epoch 75/100
# 237/237 [==============================] - 0s 1ms/step - loss: 379.4654 - val_loss: 447.9203
# Epoch 76/100
# 237/237 [==============================] - 0s 1ms/step - loss: 376.4962 - val_loss: 448.5198
# Epoch 77/100
# 237/237 [==============================] - 0s 1ms/step - loss: 377.5334 - val_loss: 438.4219
# Epoch 78/100
# 237/237 [==============================] - 0s 1ms/step - loss: 374.3526 - val_loss: 440.7494
# Epoch 79/100
# 237/237 [==============================] - 0s 1ms/step - loss: 376.1841 - val_loss: 445.8259
# Epoch 80/100
# 237/237 [==============================] - 0s 1ms/step - loss: 376.3778 - val_loss: 435.3029
# Epoch 81/100
# 237/237 [==============================] - 0s 1ms/step - loss: 375.9715 - val_loss: 437.2279
# Epoch 82/100
# 237/237 [==============================] - 0s 1ms/step - loss: 374.2988 - val_loss: 429.2266
# Epoch 83/100
# 237/237 [==============================] - 0s 1ms/step - loss: 374.2733 - val_loss: 424.9760
# Epoch 84/100
# 237/237 [==============================] - 0s 1ms/step - loss: 368.5735 - val_loss: 430.1341
# Epoch 85/100
# 237/237 [==============================] - 0s 1ms/step - loss: 368.7050 - val_loss: 426.0430
# Epoch 86/100
# 237/237 [==============================] - 0s 1ms/step - loss: 370.8544 - val_loss: 420.9647
# Epoch 87/100
# 237/237 [==============================] - 0s 1ms/step - loss: 361.4623 - val_loss: 416.4333
# Epoch 88/100
# 237/237 [==============================] - 0s 1ms/step - loss: 367.6181 - val_loss: 413.2433
# Epoch 89/100
# 237/237 [==============================] - 0s 1ms/step - loss: 363.9721 - val_loss: 412.2055
# Epoch 90/100
# 237/237 [==============================] - 0s 1ms/step - loss: 357.6443 - val_loss: 409.9684
# Epoch 91/100
# 237/237 [==============================] - 0s 1ms/step - loss: 358.2842 - val_loss: 409.1832
# Epoch 92/100
# 237/237 [==============================] - 0s 1ms/step - loss: 357.4973 - val_loss: 408.8473
# Epoch 93/100
# 237/237 [==============================] - 0s 1ms/step - loss: 356.0844 - val_loss: 403.2051
# Epoch 94/100
# 237/237 [==============================] - 0s 1ms/step - loss: 353.2485 - val_loss: 405.2379
# Epoch 95/100
# 237/237 [==============================] - 0s 1ms/step - loss: 352.7290 - val_loss: 398.8340
# Epoch 96/100
# 237/237 [==============================] - 0s 1ms/step - loss: 348.8590 - val_loss: 401.6370
# Epoch 97/100
# 237/237 [==============================] - 0s 1ms/step - loss: 348.6014 - val_loss: 398.8980
# Epoch 98/100
# 237/237 [==============================] - 0s 1ms/step - loss: 348.1566 - val_loss: 395.0791
# Epoch 99/100
# 237/237 [==============================] - 0s 1ms/step - loss: 347.1783 - val_loss: 398.8387
# Epoch 100/100
# 237/237 [==============================] - 0s 1ms/step - loss: 345.6901 - val_loss: 390.1137
# 52/52 [==============================] - 0s 675us/step
# Completed 2 splits
# Epoch 1/100
# 255/255 [==============================] - 1s 2ms/step - loss: 7161.1455 - val_loss: 7620.4771
# Epoch 2/100
# 255/255 [==============================] - 0s 1ms/step - loss: 7015.1445 - val_loss: 7367.5659
# Epoch 3/100
# 255/255 [==============================] - 0s 1ms/step - loss: 6593.5396 - val_loss: 6726.4600
# Epoch 4/100
# 255/255 [==============================] - 0s 1ms/step - loss: 5623.5674 - val_loss: 5492.1816
# Epoch 5/100
# 255/255 [==============================] - 0s 1ms/step - loss: 4057.4739 - val_loss: 3729.2517
# Epoch 6/100
# 255/255 [==============================] - 0s 1ms/step - loss: 2195.3257 - val_loss: 2382.5859
# Epoch 7/100
# 255/255 [==============================] - 0s 1ms/step - loss: 1079.5234 - val_loss: 1866.6790
# Epoch 8/100
# 255/255 [==============================] - 0s 1ms/step - loss: 778.6760 - val_loss: 1549.1302
# Epoch 9/100
# 255/255 [==============================] - 0s 1ms/step - loss: 662.2119 - val_loss: 1327.9741
# Epoch 10/100
# 255/255 [==============================] - 0s 1ms/step - loss: 609.1223 - val_loss: 1160.3049
# Epoch 11/100
# 255/255 [==============================] - 0s 1ms/step - loss: 578.9290 - val_loss: 1030.0322
# Epoch 12/100
# 255/255 [==============================] - 0s 1ms/step - loss: 551.5432 - val_loss: 936.8427
# Epoch 13/100
# 255/255 [==============================] - 0s 1ms/step - loss: 536.7731 - val_loss: 848.9370
# Epoch 14/100
# 255/255 [==============================] - 0s 1ms/step - loss: 523.4031 - val_loss: 784.4150
# Epoch 15/100
# 255/255 [==============================] - 0s 1ms/step - loss: 507.4663 - val_loss: 727.4459
# Epoch 16/100
# 255/255 [==============================] - 0s 1ms/step - loss: 493.9700 - val_loss: 683.2065
# Epoch 17/100
# 255/255 [==============================] - 0s 1ms/step - loss: 485.4322 - val_loss: 645.4234
# Epoch 18/100
# 255/255 [==============================] - 0s 1ms/step - loss: 478.7054 - val_loss: 614.4608
# Epoch 19/100
# 255/255 [==============================] - 0s 1ms/step - loss: 476.8524 - val_loss: 592.2987
# Epoch 20/100
# 255/255 [==============================] - 0s 1ms/step - loss: 470.5493 - val_loss: 571.9922
# Epoch 21/100
# 255/255 [==============================] - 0s 999us/step - loss: 467.5751 - val_loss: 557.5082
# Epoch 22/100
# 255/255 [==============================] - 0s 1ms/step - loss: 457.1073 - val_loss: 537.9991
# Epoch 23/100
# 255/255 [==============================] - 0s 1ms/step - loss: 457.1481 - val_loss: 529.9628
# Epoch 24/100
# 255/255 [==============================] - 0s 1ms/step - loss: 449.0218 - val_loss: 524.2811
# Epoch 25/100
# 255/255 [==============================] - 0s 1ms/step - loss: 442.1732 - val_loss: 509.5448
# Epoch 26/100
# 255/255 [==============================] - 0s 1ms/step - loss: 442.6540 - val_loss: 503.6582
# Epoch 27/100
# 255/255 [==============================] - 0s 1ms/step - loss: 442.4597 - val_loss: 496.7076
# Epoch 28/100
# 255/255 [==============================] - 0s 1ms/step - loss: 437.0484 - val_loss: 491.2474
# Epoch 29/100
# 255/255 [==============================] - 0s 1ms/step - loss: 431.0379 - val_loss: 483.5327
# Epoch 30/100
# 255/255 [==============================] - 0s 1ms/step - loss: 436.1602 - val_loss: 481.8354
# Epoch 31/100
# 255/255 [==============================] - 0s 1ms/step - loss: 425.6689 - val_loss: 475.8245
# Epoch 32/100
# 255/255 [==============================] - 0s 1ms/step - loss: 422.2820 - val_loss: 475.8019
# Epoch 33/100
# 255/255 [==============================] - 0s 999us/step - loss: 422.4706 - val_loss: 464.7544
# Epoch 34/100
# 255/255 [==============================] - 0s 990us/step - loss: 418.1240 - val_loss: 464.7769
# Epoch 35/100
# 255/255 [==============================] - 0s 1ms/step - loss: 412.1616 - val_loss: 465.8914
# Epoch 36/100
# 255/255 [==============================] - 0s 1ms/step - loss: 407.9866 - val_loss: 460.2506
# Epoch 37/100
# 255/255 [==============================] - 0s 1ms/step - loss: 404.7495 - val_loss: 451.8749
# Epoch 38/100
# 255/255 [==============================] - 0s 1ms/step - loss: 403.6227 - val_loss: 450.0775
# Epoch 39/100
# 255/255 [==============================] - 0s 1ms/step - loss: 402.3600 - val_loss: 449.0506
# Epoch 40/100
# 255/255 [==============================] - 0s 1ms/step - loss: 400.3501 - val_loss: 441.5249
# Epoch 41/100
# 255/255 [==============================] - 0s 1ms/step - loss: 396.2505 - val_loss: 446.3429
# Epoch 42/100
# 255/255 [==============================] - 0s 1ms/step - loss: 389.9488 - val_loss: 440.1443
# Epoch 43/100
# 255/255 [==============================] - 0s 1ms/step - loss: 387.5014 - val_loss: 435.1479
# Epoch 44/100
# 255/255 [==============================] - 0s 2ms/step - loss: 386.9172 - val_loss: 438.0267
# Epoch 45/100
# 255/255 [==============================] - 1s 2ms/step - loss: 382.8273 - val_loss: 429.2990
# Epoch 46/100
# 255/255 [==============================] - 0s 1ms/step - loss: 378.3117 - val_loss: 438.0563
# Epoch 47/100
# 255/255 [==============================] - 0s 1ms/step - loss: 378.8881 - val_loss: 431.1642
# Epoch 48/100
# 255/255 [==============================] - 0s 1ms/step - loss: 374.3807 - val_loss: 429.8434
# Epoch 49/100
# 255/255 [==============================] - 0s 1ms/step - loss: 376.2511 - val_loss: 422.1306
# Epoch 50/100
# 255/255 [==============================] - 0s 1ms/step - loss: 369.6202 - val_loss: 422.2944
# Epoch 51/100
# 255/255 [==============================] - 0s 1ms/step - loss: 367.2834 - val_loss: 416.6985
# Epoch 52/100
# 255/255 [==============================] - 0s 1ms/step - loss: 366.6096 - val_loss: 414.9393
# Epoch 53/100
# 255/255 [==============================] - 0s 1ms/step - loss: 365.5886 - val_loss: 418.4883
# Epoch 54/100
# 255/255 [==============================] - 0s 1ms/step - loss: 360.0772 - val_loss: 416.2029
# Epoch 55/100
# 255/255 [==============================] - 0s 1ms/step - loss: 356.0859 - val_loss: 410.9747
# Epoch 56/100
# 255/255 [==============================] - 0s 1ms/step - loss: 357.5376 - val_loss: 407.5839
# Epoch 57/100
# 255/255 [==============================] - 0s 1ms/step - loss: 352.5233 - val_loss: 404.7901
# Epoch 58/100
# 255/255 [==============================] - 0s 1ms/step - loss: 355.1285 - val_loss: 406.5927
# Epoch 59/100
# 255/255 [==============================] - 0s 1ms/step - loss: 351.8280 - val_loss: 399.3787
# Epoch 60/100
# 255/255 [==============================] - 0s 1ms/step - loss: 354.1649 - val_loss: 399.1976
# Epoch 61/100
# 255/255 [==============================] - 0s 1ms/step - loss: 343.8931 - val_loss: 397.9342
# Epoch 62/100
# 255/255 [==============================] - 0s 1ms/step - loss: 344.0114 - val_loss: 402.5520
# Epoch 63/100
# 255/255 [==============================] - 0s 1ms/step - loss: 345.3193 - val_loss: 399.9536
# Epoch 64/100
# 255/255 [==============================] - 0s 1ms/step - loss: 339.3207 - val_loss: 395.0698
# Epoch 65/100
# 255/255 [==============================] - 0s 1ms/step - loss: 332.1838 - val_loss: 396.3101
# Epoch 66/100
# 255/255 [==============================] - 0s 1ms/step - loss: 332.9200 - val_loss: 393.2181
# Epoch 67/100
# 255/255 [==============================] - 0s 1ms/step - loss: 334.0993 - val_loss: 390.1213
# Epoch 68/100
# 255/255 [==============================] - 0s 1ms/step - loss: 329.7985 - val_loss: 392.7398
# Epoch 69/100
# 255/255 [==============================] - 0s 1ms/step - loss: 327.7477 - val_loss: 382.7040
# Epoch 70/100
# 255/255 [==============================] - 0s 1ms/step - loss: 327.4410 - val_loss: 392.8605
# Epoch 71/100
# 255/255 [==============================] - 0s 1ms/step - loss: 321.5486 - val_loss: 381.1461
# Epoch 72/100
# 255/255 [==============================] - 0s 1ms/step - loss: 321.3740 - val_loss: 381.5086
# Epoch 73/100
# 255/255 [==============================] - 0s 1ms/step - loss: 320.1500 - val_loss: 379.1133
# Epoch 74/100
# 255/255 [==============================] - 0s 1ms/step - loss: 317.1030 - val_loss: 378.5278
# Epoch 75/100
# 255/255 [==============================] - 0s 1ms/step - loss: 314.2840 - val_loss: 373.1326
# Epoch 76/100
# 255/255 [==============================] - 0s 1ms/step - loss: 313.2537 - val_loss: 376.9052
# Epoch 77/100
# 255/255 [==============================] - 0s 1ms/step - loss: 309.3056 - val_loss: 376.8065
# Epoch 78/100
# 255/255 [==============================] - 0s 1ms/step - loss: 308.6470 - val_loss: 372.4856
# Epoch 79/100
# 255/255 [==============================] - 0s 1ms/step - loss: 305.8088 - val_loss: 369.7552
# Epoch 80/100
# 255/255 [==============================] - 0s 1ms/step - loss: 304.1156 - val_loss: 369.1524
# Epoch 81/100
# 255/255 [==============================] - 0s 1ms/step - loss: 302.0384 - val_loss: 366.4804
# Epoch 82/100
# 255/255 [==============================] - 0s 1ms/step - loss: 299.1024 - val_loss: 362.0950
# Epoch 83/100
# 255/255 [==============================] - 0s 1ms/step - loss: 299.6531 - val_loss: 362.4325
# Epoch 84/100
# 255/255 [==============================] - 0s 1ms/step - loss: 299.8399 - val_loss: 361.2320
# Epoch 85/100
# 255/255 [==============================] - 0s 1ms/step - loss: 295.7061 - val_loss: 360.8596
# Epoch 86/100
# 255/255 [==============================] - 0s 1ms/step - loss: 292.2985 - val_loss: 357.5132
# Epoch 87/100
# 255/255 [==============================] - 0s 2ms/step - loss: 291.4097 - val_loss: 362.2132
# Epoch 88/100
# 255/255 [==============================] - 0s 2ms/step - loss: 290.0331 - val_loss: 354.3772
# Epoch 89/100
# 255/255 [==============================] - 0s 1ms/step - loss: 285.3899 - val_loss: 359.1131
# Epoch 90/100
# 255/255 [==============================] - 0s 1ms/step - loss: 283.9353 - val_loss: 353.9667
# Epoch 91/100
# 255/255 [==============================] - 0s 1ms/step - loss: 284.9167 - val_loss: 349.6711
# Epoch 92/100
# 255/255 [==============================] - 0s 1ms/step - loss: 281.6356 - val_loss: 349.6023
# Epoch 93/100
# 255/255 [==============================] - 0s 1ms/step - loss: 281.2253 - val_loss: 348.5550
# Epoch 94/100
# 255/255 [==============================] - 0s 1ms/step - loss: 278.8182 - val_loss: 350.7473
# Epoch 95/100
# 255/255 [==============================] - 0s 1ms/step - loss: 276.9548 - val_loss: 346.7511
# Epoch 96/100
# 255/255 [==============================] - 0s 1ms/step - loss: 278.2134 - val_loss: 346.7711
# Epoch 97/100
# 255/255 [==============================] - 0s 1ms/step - loss: 275.0694 - val_loss: 345.3724
# Epoch 98/100
# 255/255 [==============================] - 0s 1ms/step - loss: 274.1754 - val_loss: 345.0428
# Epoch 99/100
# 255/255 [==============================] - 0s 1ms/step - loss: 272.5221 - val_loss: 342.5195
# Epoch 100/100
# 255/255 [==============================] - 0s 1ms/step - loss: 271.6320 - val_loss: 342.4893
# 54/54 [==============================] - 0s 568us/step
# Completed 3 splits
# Epoch 1/100
# 278/278 [==============================] - 1s 1ms/step - loss: 7863.8496 - val_loss: 8092.4585
# Epoch 2/100
# 278/278 [==============================] - 0s 1ms/step - loss: 7682.1201 - val_loss: 8026.9600
# Epoch 3/100
# 278/278 [==============================] - 0s 1ms/step - loss: 7138.1147 - val_loss: 9040.7383
# Epoch 4/100
# 278/278 [==============================] - 0s 990us/step - loss: 5921.8237 - val_loss: 16475.3848
# Epoch 5/100
# 278/278 [==============================] - 0s 1ms/step - loss: 3960.0247 - val_loss: 41345.0117
# Epoch 6/100
# 278/278 [==============================] - 0s 1ms/step - loss: 2099.3816 - val_loss: 75905.0625
# Epoch 7/100
# 278/278 [==============================] - 0s 1ms/step - loss: 1337.4099 - val_loss: 89697.1094
# 56/56 [==============================] - 0s 580us/step
# Completed 4 splits
# Epoch 1/100
# 306/306 [==============================] - 1s 1ms/step - loss: 7391.6021 - val_loss: 9624.9385
# Epoch 2/100
# 306/306 [==============================] - 0s 980us/step - loss: 6656.6392 - val_loss: 18406.4844
# Epoch 3/100
# 306/306 [==============================] - 0s 990us/step - loss: 5064.6094 - val_loss: 58105.0352
# Epoch 4/100
# 306/306 [==============================] - 0s 1ms/step - loss: 2852.8452 - val_loss: 145291.0156
# Epoch 5/100
# 306/306 [==============================] - 0s 981us/step - loss: 1425.5745 - val_loss: 208476.3125
# Epoch 6/100
# 306/306 [==============================] - 0s 992us/step - loss: 960.6913 - val_loss: 187005.6406
# 59/59 [==============================] - 0s 558us/step
# Completed 5 splits
# Epoch 1/100
# 328/328 [==============================] - 1s 1ms/step - loss: 7822.7861 - val_loss: 11815.7197
# Epoch 2/100
# 328/328 [==============================] - 0s 984us/step - loss: 7170.8486 - val_loss: 42281.1992
# Epoch 3/100
# 328/328 [==============================] - 0s 1ms/step - loss: 5527.2847 - val_loss: 181208.9062
# Epoch 4/100
# 328/328 [==============================] - 0s 986us/step - loss: 3123.8213 - val_loss: 522254.6562
# Epoch 5/100
# 328/328 [==============================] - 0s 972us/step - loss: 1457.5394 - val_loss: 690014.9375
# Epoch 6/100
# 328/328 [==============================] - 0s 979us/step - loss: 931.7043 - val_loss: 635783.7500
# 62/62 [==============================] - 0s 521us/step
# Completed 6 splits
# Epoch 1/100
# 345/345 [==============================] - 1s 1ms/step - loss: 8329.9072 - val_loss: 6721.6113
# Epoch 2/100
# 345/345 [==============================] - 0s 972us/step - loss: 6910.7725 - val_loss: 5060.1069
# Epoch 3/100
# 345/345 [==============================] - 0s 965us/step - loss: 4156.6528 - val_loss: 2820.0017
# Epoch 4/100
# 345/345 [==============================] - 0s 967us/step - loss: 1405.1451 - val_loss: 2053.2778
# Epoch 5/100
# 345/345 [==============================] - 0s 947us/step - loss: 758.7625 - val_loss: 1780.8098
# Epoch 6/100
# 345/345 [==============================] - 0s 1ms/step - loss: 664.6460 - val_loss: 1473.8986
# Epoch 7/100
# 345/345 [==============================] - 0s 1ms/step - loss: 619.9283 - val_loss: 1247.2708
# Epoch 8/100
# 345/345 [==============================] - 0s 1ms/step - loss: 590.7261 - val_loss: 1081.7598
# Epoch 9/100
# 345/345 [==============================] - 0s 1ms/step - loss: 569.7311 - val_loss: 946.2352
# Epoch 10/100
# 345/345 [==============================] - 0s 1ms/step - loss: 548.8895 - val_loss: 831.6425
# Epoch 11/100
# 345/345 [==============================] - 0s 1ms/step - loss: 535.6926 - val_loss: 731.1211
# Epoch 12/100
# 345/345 [==============================] - 0s 1ms/step - loss: 521.0969 - val_loss: 660.1185
# Epoch 13/100
# 345/345 [==============================] - 0s 996us/step - loss: 516.4520 - val_loss: 604.0016
# Epoch 14/100
# 345/345 [==============================] - 0s 1ms/step - loss: 506.6602 - val_loss: 558.8505
# Epoch 15/100
# 345/345 [==============================] - 0s 1ms/step - loss: 499.2520 - val_loss: 524.2454
# Epoch 16/100
# 345/345 [==============================] - 0s 1ms/step - loss: 494.1183 - val_loss: 510.5808
# Epoch 17/100
# 345/345 [==============================] - 0s 1ms/step - loss: 485.1871 - val_loss: 495.7755
# Epoch 18/100
# 345/345 [==============================] - 0s 1ms/step - loss: 479.6347 - val_loss: 481.9189
# Epoch 19/100
# 345/345 [==============================] - 0s 1ms/step - loss: 480.8552 - val_loss: 473.5032
# Epoch 20/100
# 345/345 [==============================] - 0s 988us/step - loss: 464.3377 - val_loss: 461.2239
# Epoch 21/100
# 345/345 [==============================] - 0s 1ms/step - loss: 459.0208 - val_loss: 450.3510
# Epoch 22/100
# 345/345 [==============================] - 0s 1ms/step - loss: 450.4669 - val_loss: 440.6219
# Epoch 23/100
# 345/345 [==============================] - 0s 1ms/step - loss: 446.5989 - val_loss: 434.9921
# Epoch 24/100
# 345/345 [==============================] - 0s 994us/step - loss: 446.3673 - val_loss: 433.0407
# Epoch 25/100
# 345/345 [==============================] - 0s 983us/step - loss: 436.8571 - val_loss: 428.7398
# Epoch 26/100
# 345/345 [==============================] - 0s 1ms/step - loss: 435.6043 - val_loss: 424.5713
# Epoch 27/100
# 345/345 [==============================] - 0s 960us/step - loss: 431.8658 - val_loss: 423.8462
# Epoch 28/100
# 345/345 [==============================] - 0s 972us/step - loss: 427.9038 - val_loss: 422.6220
# Epoch 29/100
# 345/345 [==============================] - 0s 972us/step - loss: 420.0032 - val_loss: 418.9624
# Epoch 30/100
# 345/345 [==============================] - 0s 960us/step - loss: 418.3468 - val_loss: 416.2295
# Epoch 31/100
# 345/345 [==============================] - 0s 1ms/step - loss: 407.6434 - val_loss: 412.6360
# Epoch 32/100
# 345/345 [==============================] - 0s 972us/step - loss: 402.3802 - val_loss: 410.6843
# Epoch 33/100
# 345/345 [==============================] - 0s 975us/step - loss: 401.7177 - val_loss: 408.3305
# Epoch 34/100
# 345/345 [==============================] - 0s 1ms/step - loss: 399.0657 - val_loss: 409.9960
# Epoch 35/100
# 345/345 [==============================] - 0s 1ms/step - loss: 392.8415 - val_loss: 407.9645
# Epoch 36/100
# 345/345 [==============================] - 0s 1ms/step - loss: 386.3640 - val_loss: 399.9525
# Epoch 37/100
# 345/345 [==============================] - 0s 1ms/step - loss: 385.4313 - val_loss: 397.9093
# Epoch 38/100
# 345/345 [==============================] - 0s 1ms/step - loss: 381.2499 - val_loss: 399.4237
# Epoch 39/100
# 345/345 [==============================] - 0s 1ms/step - loss: 373.9825 - val_loss: 396.7905
# Epoch 40/100
# 345/345 [==============================] - 0s 1ms/step - loss: 376.7939 - val_loss: 397.9373
# Epoch 41/100
# 345/345 [==============================] - 0s 1ms/step - loss: 370.1967 - val_loss: 392.1117
# Epoch 42/100
# 345/345 [==============================] - 0s 1ms/step - loss: 363.1975 - val_loss: 392.6758
# Epoch 43/100
# 345/345 [==============================] - 0s 1ms/step - loss: 360.6016 - val_loss: 391.2793
# Epoch 44/100
# 345/345 [==============================] - 0s 1ms/step - loss: 358.7877 - val_loss: 391.1308
# Epoch 45/100
# 345/345 [==============================] - 0s 1ms/step - loss: 353.2234 - val_loss: 392.9075
# Epoch 46/100
# 345/345 [==============================] - 0s 1ms/step - loss: 348.6807 - val_loss: 387.1907
# Epoch 47/100
# 345/345 [==============================] - 0s 998us/step - loss: 344.8946 - val_loss: 387.9246
# Epoch 48/100
# 345/345 [==============================] - 0s 1ms/step - loss: 341.5114 - val_loss: 385.8165
# Epoch 49/100
# 345/345 [==============================] - 0s 974us/step - loss: 336.8957 - val_loss: 382.8242
# Epoch 50/100
# 345/345 [==============================] - 0s 959us/step - loss: 334.2228 - val_loss: 384.4139
# Epoch 51/100
# 345/345 [==============================] - 0s 973us/step - loss: 331.5487 - val_loss: 382.2380
# Epoch 52/100
# 345/345 [==============================] - 0s 1ms/step - loss: 326.0618 - val_loss: 381.6417
# Epoch 53/100
# 345/345 [==============================] - 0s 957us/step - loss: 325.1704 - val_loss: 381.4968
# Epoch 54/100
# 345/345 [==============================] - 0s 965us/step - loss: 324.1956 - val_loss: 379.1143
# Epoch 55/100
# 345/345 [==============================] - 0s 964us/step - loss: 318.9510 - val_loss: 380.3737
# Epoch 56/100
# 345/345 [==============================] - 0s 960us/step - loss: 313.9856 - val_loss: 383.3512
# Epoch 57/100
# 345/345 [==============================] - 0s 963us/step - loss: 312.1222 - val_loss: 378.5627
# Epoch 58/100
# 345/345 [==============================] - 0s 976us/step - loss: 310.1069 - val_loss: 378.1886
# Epoch 59/100
# 345/345 [==============================] - 0s 968us/step - loss: 307.2503 - val_loss: 379.5645
# Epoch 60/100
# 345/345 [==============================] - 0s 1ms/step - loss: 302.7210 - val_loss: 378.3763
# Epoch 61/100
# 345/345 [==============================] - 1s 2ms/step - loss: 300.3987 - val_loss: 374.4817
# Epoch 62/100
# 345/345 [==============================] - 0s 1ms/step - loss: 299.7716 - val_loss: 373.0450
# Epoch 63/100
# 345/345 [==============================] - 0s 1ms/step - loss: 296.5296 - val_loss: 371.7954
# Epoch 64/100
# 345/345 [==============================] - 0s 1ms/step - loss: 293.9944 - val_loss: 371.1808
# Epoch 65/100
# 345/345 [==============================] - 0s 1ms/step - loss: 292.8188 - val_loss: 378.6316
# Epoch 66/100
# 345/345 [==============================] - 0s 991us/step - loss: 289.6432 - val_loss: 372.2824
# Epoch 67/100
# 345/345 [==============================] - 0s 992us/step - loss: 287.3840 - val_loss: 370.0424
# Epoch 68/100
# 345/345 [==============================] - 0s 1ms/step - loss: 284.7636 - val_loss: 368.6953
# Epoch 69/100
# 345/345 [==============================] - 0s 1ms/step - loss: 283.5470 - val_loss: 369.0535
# Epoch 70/100
# 345/345 [==============================] - 0s 1ms/step - loss: 281.3871 - val_loss: 368.3628
# Epoch 71/100
# 345/345 [==============================] - 0s 1ms/step - loss: 279.8725 - val_loss: 367.6132
# Epoch 72/100
# 345/345 [==============================] - 0s 1ms/step - loss: 277.8591 - val_loss: 367.9927
# Epoch 73/100
# 345/345 [==============================] - 0s 982us/step - loss: 275.4337 - val_loss: 370.1083
# Epoch 74/100
# 345/345 [==============================] - 0s 959us/step - loss: 272.2871 - val_loss: 368.8419
# Epoch 75/100
# 345/345 [==============================] - 0s 953us/step - loss: 268.9987 - val_loss: 371.3676
# Epoch 76/100
# 345/345 [==============================] - 0s 1ms/step - loss: 269.1760 - val_loss: 371.1909
# 65/65 [==============================] - 0s 549us/step
# Completed 7 splits
# Epoch 1/100
# 362/362 [==============================] - 1s 1ms/step - loss: 8611.0225 - val_loss: 8094.2383
# Epoch 2/100
# 362/362 [==============================] - 0s 971us/step - loss: 8081.2222 - val_loss: 7250.1914
# Epoch 3/100
# 362/362 [==============================] - 0s 983us/step - loss: 6475.7490 - val_loss: 5310.5244
# Epoch 4/100
# 362/362 [==============================] - 0s 957us/step - loss: 3612.0222 - val_loss: 3261.8198
# Epoch 5/100
# 362/362 [==============================] - 0s 985us/step - loss: 1536.0828 - val_loss: 2714.6648
# Epoch 6/100
# 362/362 [==============================] - 0s 970us/step - loss: 970.8042 - val_loss: 2406.9443
# Epoch 7/100
# 362/362 [==============================] - 0s 1ms/step - loss: 779.9116 - val_loss: 2261.2651
# Epoch 8/100
# 362/362 [==============================] - 0s 1ms/step - loss: 706.3619 - val_loss: 2053.1326
# Epoch 9/100
# 362/362 [==============================] - 0s 1ms/step - loss: 660.5428 - val_loss: 1916.2085
# Epoch 10/100
# 362/362 [==============================] - 0s 961us/step - loss: 639.8458 - val_loss: 1777.8500
# Epoch 11/100
# 362/362 [==============================] - 0s 974us/step - loss: 628.6619 - val_loss: 1605.0696
# Epoch 12/100
# 362/362 [==============================] - 0s 955us/step - loss: 596.6721 - val_loss: 1469.3354
# Epoch 13/100
# 362/362 [==============================] - 0s 952us/step - loss: 588.7642 - val_loss: 1339.2449
# Epoch 14/100
# 362/362 [==============================] - 0s 958us/step - loss: 562.4531 - val_loss: 1218.1342
# Epoch 15/100
# 362/362 [==============================] - 0s 959us/step - loss: 552.8008 - val_loss: 1118.7794
# Epoch 16/100
# 362/362 [==============================] - 0s 1ms/step - loss: 538.2241 - val_loss: 1025.0082
# Epoch 17/100
# 362/362 [==============================] - 0s 950us/step - loss: 527.7145 - val_loss: 947.0178
# Epoch 18/100
# 362/362 [==============================] - 0s 953us/step - loss: 514.6966 - val_loss: 900.9161
# Epoch 19/100
# 362/362 [==============================] - 0s 957us/step - loss: 509.4542 - val_loss: 839.2320
# Epoch 20/100
# 362/362 [==============================] - 0s 956us/step - loss: 500.6005 - val_loss: 790.5881
# Epoch 21/100
# 362/362 [==============================] - 0s 959us/step - loss: 489.7872 - val_loss: 759.2435
# Epoch 22/100
# 362/362 [==============================] - 0s 966us/step - loss: 480.4319 - val_loss: 722.2385
# Epoch 23/100
# 362/362 [==============================] - 0s 963us/step - loss: 476.9355 - val_loss: 689.6025
# Epoch 24/100
# 362/362 [==============================] - 0s 1ms/step - loss: 463.6499 - val_loss: 655.4198
# Epoch 25/100
# 362/362 [==============================] - 0s 956us/step - loss: 459.6472 - val_loss: 621.7299
# Epoch 26/100
# 362/362 [==============================] - 0s 1000us/step - loss: 454.6927 - val_loss: 597.6473
# Epoch 27/100
# 362/362 [==============================] - 0s 1ms/step - loss: 449.8486 - val_loss: 571.2556
# Epoch 28/100
# 362/362 [==============================] - 0s 1ms/step - loss: 440.3889 - val_loss: 554.4221
# Epoch 29/100
# 362/362 [==============================] - 0s 1ms/step - loss: 431.3647 - val_loss: 537.0084
# Epoch 30/100
# 362/362 [==============================] - 0s 1ms/step - loss: 431.9845 - val_loss: 524.8226
# Epoch 31/100
# 362/362 [==============================] - 0s 1ms/step - loss: 421.6479 - val_loss: 508.3615
# Epoch 32/100
# 362/362 [==============================] - 0s 953us/step - loss: 417.0131 - val_loss: 491.8879
# Epoch 33/100
# 362/362 [==============================] - 0s 960us/step - loss: 412.8166 - val_loss: 483.9074
# Epoch 34/100
# 362/362 [==============================] - 0s 965us/step - loss: 409.2692 - val_loss: 476.0771
# Epoch 35/100
# 362/362 [==============================] - 0s 1ms/step - loss: 403.5460 - val_loss: 462.6467
# Epoch 36/100
# 362/362 [==============================] - 0s 952us/step - loss: 403.5433 - val_loss: 455.7661
# Epoch 37/100
# 362/362 [==============================] - 0s 968us/step - loss: 396.9327 - val_loss: 447.8232
# Epoch 38/100
# 362/362 [==============================] - 0s 1ms/step - loss: 391.3481 - val_loss: 439.5640
# Epoch 39/100
# 362/362 [==============================] - 0s 1ms/step - loss: 390.6709 - val_loss: 433.5614
# Epoch 40/100
# 362/362 [==============================] - 0s 963us/step - loss: 385.1316 - val_loss: 429.5490
# Epoch 41/100
# 362/362 [==============================] - 0s 953us/step - loss: 380.2331 - val_loss: 420.9530
# Epoch 42/100
# 362/362 [==============================] - 0s 959us/step - loss: 377.1627 - val_loss: 417.3840
# Epoch 43/100
# 362/362 [==============================] - 0s 954us/step - loss: 367.6666 - val_loss: 408.6018
# Epoch 44/100
# 362/362 [==============================] - 0s 964us/step - loss: 368.8546 - val_loss: 400.4438
# Epoch 45/100
# 362/362 [==============================] - 0s 1ms/step - loss: 368.1974 - val_loss: 400.3797
# Epoch 46/100
# 362/362 [==============================] - 0s 1ms/step - loss: 358.5977 - val_loss: 393.8931
# Epoch 47/100
# 362/362 [==============================] - 0s 1ms/step - loss: 359.7018 - val_loss: 393.4055
# Epoch 48/100
# 362/362 [==============================] - 0s 1ms/step - loss: 352.3856 - val_loss: 388.9981
# Epoch 49/100
# 362/362 [==============================] - 0s 1ms/step - loss: 354.5050 - val_loss: 385.2960
# Epoch 50/100
# 362/362 [==============================] - 0s 1ms/step - loss: 350.0974 - val_loss: 383.6988
# Epoch 51/100
# 362/362 [==============================] - 0s 990us/step - loss: 347.4500 - val_loss: 384.5976
# Epoch 52/100
# 362/362 [==============================] - 0s 1ms/step - loss: 341.5364 - val_loss: 376.9771
# Epoch 53/100
# 362/362 [==============================] - 0s 1ms/step - loss: 339.9016 - val_loss: 372.8976
# Epoch 54/100
# 362/362 [==============================] - 0s 1ms/step - loss: 334.7867 - val_loss: 365.7466
# Epoch 55/100
# 362/362 [==============================] - 0s 981us/step - loss: 331.6247 - val_loss: 361.7402
# Epoch 56/100
# 362/362 [==============================] - 0s 992us/step - loss: 332.5674 - val_loss: 358.2766
# Epoch 57/100
# 362/362 [==============================] - 0s 1000us/step - loss: 324.3940 - val_loss: 355.1177
# Epoch 58/100
# 362/362 [==============================] - 0s 1ms/step - loss: 323.4655 - val_loss: 354.0118
# Epoch 59/100
# 362/362 [==============================] - 0s 1ms/step - loss: 319.6693 - val_loss: 353.3311
# Epoch 60/100
# 362/362 [==============================] - 0s 997us/step - loss: 317.5977 - val_loss: 355.2264
# Epoch 61/100
# 362/362 [==============================] - 0s 1ms/step - loss: 316.0547 - val_loss: 357.8208
# Epoch 62/100
# 362/362 [==============================] - 0s 997us/step - loss: 313.1181 - val_loss: 349.8699
# Epoch 63/100
# 362/362 [==============================] - 0s 1ms/step - loss: 308.7736 - val_loss: 346.8017
# Epoch 64/100
# 362/362 [==============================] - 0s 1ms/step - loss: 307.2331 - val_loss: 343.9287
# Epoch 65/100
# 362/362 [==============================] - 0s 1ms/step - loss: 305.6196 - val_loss: 340.0189
# Epoch 66/100
# 362/362 [==============================] - 0s 1ms/step - loss: 304.7857 - val_loss: 337.7602
# Epoch 67/100
# 362/362 [==============================] - 0s 1ms/step - loss: 302.9950 - val_loss: 333.7734
# Epoch 68/100
# 362/362 [==============================] - 0s 1ms/step - loss: 297.6967 - val_loss: 334.7873
# Epoch 69/100
# 362/362 [==============================] - 0s 1ms/step - loss: 297.5770 - val_loss: 334.0158
# Epoch 70/100
# 362/362 [==============================] - 0s 1ms/step - loss: 295.4202 - val_loss: 328.2628
# Epoch 71/100
# 362/362 [==============================] - 0s 1ms/step - loss: 292.5454 - val_loss: 324.8086
# Epoch 72/100
# 362/362 [==============================] - 0s 1ms/step - loss: 292.5256 - val_loss: 324.7930
# Epoch 73/100
# 362/362 [==============================] - 0s 1ms/step - loss: 290.1364 - val_loss: 323.9874
# Epoch 74/100
# 362/362 [==============================] - 0s 1ms/step - loss: 288.0874 - val_loss: 321.3593
# Epoch 75/100
# 362/362 [==============================] - 0s 974us/step - loss: 285.8615 - val_loss: 319.2999
# Epoch 76/100
# 362/362 [==============================] - 0s 965us/step - loss: 283.6636 - val_loss: 318.0511
# Epoch 77/100
# 362/362 [==============================] - 0s 951us/step - loss: 284.3410 - val_loss: 316.5006
# Epoch 78/100
# 362/362 [==============================] - 0s 1ms/step - loss: 282.7038 - val_loss: 314.8032
# Epoch 79/100
# 362/362 [==============================] - 0s 990us/step - loss: 280.8295 - val_loss: 314.8701
# Epoch 80/100
# 362/362 [==============================] - 0s 955us/step - loss: 282.6397 - val_loss: 310.6413
# Epoch 81/100
# 362/362 [==============================] - 0s 972us/step - loss: 281.7109 - val_loss: 308.6941
# Epoch 82/100
# 362/362 [==============================] - 0s 1ms/step - loss: 277.2961 - val_loss: 308.5829
# Epoch 83/100
# 362/362 [==============================] - 0s 967us/step - loss: 277.5901 - val_loss: 307.1232
# Epoch 84/100
# 362/362 [==============================] - 0s 1ms/step - loss: 273.0820 - val_loss: 304.5303
# Epoch 85/100
# 362/362 [==============================] - 0s 961us/step - loss: 274.0271 - val_loss: 306.5750
# Epoch 86/100
# 362/362 [==============================] - 0s 948us/step - loss: 273.3098 - val_loss: 307.0934
# Epoch 87/100
# 362/362 [==============================] - 0s 972us/step - loss: 272.6979 - val_loss: 301.9439
# Epoch 88/100
# 362/362 [==============================] - 0s 969us/step - loss: 271.5366 - val_loss: 297.6595
# Epoch 89/100
# 362/362 [==============================] - 0s 962us/step - loss: 269.6718 - val_loss: 296.4760
# Epoch 90/100
# 362/362 [==============================] - 0s 958us/step - loss: 270.6440 - val_loss: 297.1090
# Epoch 91/100
# ...
# Epoch 77/100
# 411/411 [==============================] - 0s 992us/step - loss: 287.8406 - val_loss: 482.1447
# Epoch 78/100
# 411/411 [==============================] - 0s 997us/step - loss: 286.0215 - val_loss: 471.6343
# Epoch 79/100
# 411/411 [==============================] - 0s 1ms/step - loss: 283.7552 - val_loss: 466.5344
# Epoch 80/100
# 411/411 [==============================] - 0s 997us/step - loss: 285.9665 - val_loss: 466.3644
# Epoch 81/100
# 411/411 [==============================] - 0s 991us/step - loss: 284.4419 - val_loss: 463.4607
# Epoch 82/100
# 411/411 [==============================] - 0s 995us/step - loss: 283.0144 - val_loss: 459.3780
# Epoch 83/100
# 411/411 [==============================] - 0s 999us/step - loss: 280.5936 - val_loss: 458.2707
# Epoch 84/100
# 411/411 [==============================] - 0s 1ms/step - loss: 281.0035 - val_loss: 452.5976
# Epoch 85/100
# 411/411 [==============================] - 0s 989us/step - loss: 279.5793 - val_loss: 452.1604
# Epoch 86/100
# 411/411 [==============================] - 0s 1ms/step - loss: 279.6985 - val_loss: 446.4554
# Epoch 87/100
# 411/411 [==============================] - 0s 993us/step - loss: 279.3706 - val_loss: 441.6851
# Epoch 88/100
# 411/411 [==============================] - 0s 1ms/step - loss: 278.0572 - val_loss: 433.2018
# Epoch 89/100
# 411/411 [==============================] - 0s 963us/step - loss: 276.2312 - val_loss: 444.2356
# Epoch 90/100
# 411/411 [==============================] - 0s 978us/step - loss: 278.8822 - val_loss: 431.2365
# Epoch 91/100
# 411/411 [==============================] - 0s 970us/step - loss: 278.3262 - val_loss: 428.4582
# Epoch 92/100
# 411/411 [==============================] - 0s 1ms/step - loss: 277.1209 - val_loss: 424.8592
# Epoch 93/100
# 411/411 [==============================] - 0s 1ms/step - loss: 275.6459 - val_loss: 426.8505
# Epoch 94/100
# 411/411 [==============================] - 0s 972us/step - loss: 276.2094 - val_loss: 418.5323
# Epoch 95/100
# 411/411 [==============================] - 0s 1ms/step - loss: 275.5367 - val_loss: 421.4279
# Epoch 96/100
# 411/411 [==============================] - 0s 1ms/step - loss: 274.7098 - val_loss: 419.8767
# Epoch 97/100
# 411/411 [==============================] - 0s 944us/step - loss: 274.0447 - val_loss: 410.7469
# Epoch 98/100
# 411/411 [==============================] - 0s 950us/step - loss: 272.9016 - val_loss: 409.0905
# Epoch 99/100
# 411/411 [==============================] - 0s 928us/step - loss: 272.6725 - val_loss: 406.9761
# Epoch 100/100
# 411/411 [==============================] - 0s 959us/step - loss: 271.8828 - val_loss: 405.9488
# 86/86 [==============================] - 0s 539us/step
# Completed 10 splits
# Epoch 1/100
# 440/440 [==============================] - 1s 1ms/step - loss: 7870.1250 - val_loss: 7729.2275
# Epoch 2/100
# 440/440 [==============================] - 0s 924us/step - loss: 5873.4585 - val_loss: 4593.5537
# Epoch 3/100
# 440/440 [==============================] - 0s 927us/step - loss: 2462.0327 - val_loss: 1495.3611
# Epoch 4/100
# 440/440 [==============================] - 0s 951us/step - loss: 897.8895 - val_loss: 854.1589
# Epoch 5/100
# 440/440 [==============================] - 0s 904us/step - loss: 653.3056 - val_loss: 699.4072
# Epoch 6/100
# 440/440 [==============================] - 0s 919us/step - loss: 585.9613 - val_loss: 620.6937
# Epoch 7/100
# 440/440 [==============================] - 0s 931us/step - loss: 531.6065 - val_loss: 578.1074
# Epoch 8/100
# 440/440 [==============================] - 0s 951us/step - loss: 494.9355 - val_loss: 533.3868
# Epoch 9/100
# 440/440 [==============================] - 0s 985us/step - loss: 465.2483 - val_loss: 506.0443
# Epoch 10/100
# 440/440 [==============================] - 0s 1ms/step - loss: 446.3568 - val_loss: 488.9890
# Epoch 11/100
# 440/440 [==============================] - 0s 1ms/step - loss: 427.9756 - val_loss: 472.0417
# Epoch 12/100
# 440/440 [==============================] - 0s 1ms/step - loss: 411.8783 - val_loss: 462.2841
# Epoch 13/100
# 440/440 [==============================] - 0s 979us/step - loss: 401.9543 - val_loss: 453.1302
# Epoch 14/100
# 440/440 [==============================] - 0s 980us/step - loss: 395.0300 - val_loss: 447.4938
# Epoch 15/100
# 440/440 [==============================] - 0s 973us/step - loss: 387.4703 - val_loss: 440.1449
# Epoch 16/100
# 440/440 [==============================] - 0s 1ms/step - loss: 379.3967 - val_loss: 437.2256
# Epoch 17/100
# 440/440 [==============================] - 0s 980us/step - loss: 372.7961 - val_loss: 439.6202
# Epoch 18/100
# 440/440 [==============================] - 0s 978us/step - loss: 369.2248 - val_loss: 432.0760
# Epoch 19/100
# 440/440 [==============================] - 0s 1ms/step - loss: 363.6797 - val_loss: 430.9944
# Epoch 20/100
# 440/440 [==============================] - 0s 1ms/step - loss: 359.3166 - val_loss: 428.9901
# Epoch 21/100
# 440/440 [==============================] - 0s 1ms/step - loss: 355.9027 - val_loss: 428.6407
# Epoch 22/100
# 440/440 [==============================] - 0s 985us/step - loss: 353.2063 - val_loss: 429.7957
# Epoch 23/100
# 440/440 [==============================] - 0s 1ms/step - loss: 347.7653 - val_loss: 427.9535
# Epoch 24/100
# 440/440 [==============================] - 0s 1ms/step - loss: 346.9853 - val_loss: 425.6696
# Epoch 25/100
# 440/440 [==============================] - 0s 974us/step - loss: 344.1981 - val_loss: 426.6557
# Epoch 26/100
# 440/440 [==============================] - 0s 1ms/step - loss: 342.5710 - val_loss: 424.2466
# Epoch 27/100
# 440/440 [==============================] - 0s 1ms/step - loss: 338.4565 - val_loss: 426.9165
# Epoch 28/100
# 440/440 [==============================] - 0s 982us/step - loss: 337.9464 - val_loss: 426.8373
# Epoch 29/100
# 440/440 [==============================] - 0s 976us/step - loss: 336.6776 - val_loss: 428.3879
# Epoch 30/100
# 440/440 [==============================] - 0s 983us/step - loss: 332.6783 - val_loss: 439.9324
# Epoch 31/100
# 440/440 [==============================] - 0s 1ms/step - loss: 332.0099 - val_loss: 429.1328
# 96/96 [==============================] - 0s 579us/step
# Completed 11 splits
# Epoch 1/100
# 461/461 [==============================] - 1s 1ms/step - loss: 8060.9214 - val_loss: 170698.9219
# Epoch 2/100
# 461/461 [==============================] - 0s 1ms/step - loss: 6883.2046 - val_loss: 4380873.5000
# Epoch 3/100
# 461/461 [==============================] - 1s 1ms/step - loss: 3753.6948 - val_loss: 30551966.0000
# Epoch 4/100
# 461/461 [==============================] - 0s 1ms/step - loss: 1359.5735 - val_loss: 40953276.0000
# Epoch 5/100
# 461/461 [==============================] - 0s 1ms/step - loss: 879.1111 - val_loss: 33004512.0000
# Epoch 6/100
# 461/461 [==============================] - 1s 1ms/step - loss: 686.3661 - val_loss: 24984542.0000
# 111/111 [==============================] - 0s 550us/step
# Completed 12 splits
# Epoch 1/100
# 487/487 [==============================] - 1s 1ms/step - loss: 8635.5439 - val_loss: 9274.9268
# Epoch 2/100
# 487/487 [==============================] - 1s 1ms/step - loss: 8211.0342 - val_loss: 1244343.7500
# Epoch 3/100
# 487/487 [==============================] - 1s 1ms/step - loss: 6305.4580 - val_loss: 21665626.0000
# Epoch 4/100
# 487/487 [==============================] - 1s 1ms/step - loss: 2742.5850 - val_loss: 99868648.0000
# Epoch 5/100
# 487/487 [==============================] - 1s 1ms/step - loss: 1050.0408 - val_loss: 109070304.0000
# Epoch 6/100
# 487/487 [==============================] - 1s 1ms/step - loss: 665.3582 - val_loss: 86798456.0000
# 122/122 [==============================] - 0s 614us/step
# Completed 13 splits
# Epoch 1/100
# 520/520 [==============================] - 1s 1ms/step - loss: 8419.2607 - val_loss: 445029.3125
# Epoch 2/100
# 520/520 [==============================] - 1s 1ms/step - loss: 6333.7354 - val_loss: 9474123.0000
# Epoch 3/100
# 520/520 [==============================] - 1s 1ms/step - loss: 2134.0820 - val_loss: 41897244.0000
# Epoch 4/100
# 520/520 [==============================] - 1s 1ms/step - loss: 746.8909 - val_loss: 37225828.0000
# Epoch 5/100
# 520/520 [==============================] - 1s 986us/step - loss: 598.6705 - val_loss: 28695188.0000
# Epoch 6/100
# 520/520 [==============================] - 1s 969us/step - loss: 544.7066 - val_loss: 24028770.0000
# 134/134 [==============================] - 0s 519us/step
# Completed 14 splits
# Epoch 1/100
# 565/565 [==============================] - 1s 1ms/step - loss: 7766.1050 - val_loss: 3892.2454
# Epoch 2/100
# 565/565 [==============================] - 1s 1ms/step - loss: 4568.2627 - val_loss: 3896.9666
# Epoch 3/100
# 565/565 [==============================] - 1s 1ms/step - loss: 1052.4763 - val_loss: 4877.7881
# Epoch 4/100
# 565/565 [==============================] - 1s 1ms/step - loss: 601.8951 - val_loss: 2949.4443
# Epoch 5/100
# 565/565 [==============================] - 1s 996us/step - loss: 519.9786 - val_loss: 1903.4303
# Epoch 6/100
# 565/565 [==============================] - 1s 990us/step - loss: 475.8986 - val_loss: 1345.1531
# Epoch 7/100
# 565/565 [==============================] - 1s 994us/step - loss: 448.3576 - val_loss: 1165.4160
# Epoch 8/100
# 565/565 [==============================] - 1s 967us/step - loss: 438.7831 - val_loss: 921.5241
# Epoch 9/100
# 565/565 [==============================] - 1s 966us/step - loss: 425.2946 - val_loss: 831.6111
# Epoch 10/100
# 565/565 [==============================] - 1s 989us/step - loss: 418.9903 - val_loss: 784.6779
# Epoch 11/100
# 565/565 [==============================] - 1s 991us/step - loss: 410.0792 - val_loss: 763.4390
# Epoch 12/100
# 565/565 [==============================] - 1s 990us/step - loss: 406.2441 - val_loss: 722.1331
# Epoch 13/100
# 565/565 [==============================] - 1s 993us/step - loss: 403.1987 - val_loss: 694.7530
# Epoch 14/100
# 565/565 [==============================] - 1s 965us/step - loss: 393.7847 - val_loss: 686.8047
# Epoch 15/100
# 565/565 [==============================] - 1s 970us/step - loss: 392.2610 - val_loss: 645.1705
# Epoch 16/100
# 565/565 [==============================] - 1s 989us/step - loss: 389.9834 - val_loss: 672.2007
# Epoch 17/100
# 565/565 [==============================] - 1s 977us/step - loss: 386.4556 - val_loss: 654.9641
# Epoch 18/100
# 565/565 [==============================] - 1s 965us/step - loss: 386.7809 - val_loss: 632.5091
# Epoch 19/100
# 565/565 [==============================] - 1s 983us/step - loss: 383.7047 - val_loss: 638.5152
# Epoch 20/100
# 565/565 [==============================] - 1s 985us/step - loss: 379.7256 - val_loss: 662.3269
# Epoch 21/100
# 565/565 [==============================] - 1s 967us/step - loss: 375.0454 - val_loss: 648.7703
# Epoch 22/100
# 565/565 [==============================] - 1s 1ms/step - loss: 376.9200 - val_loss: 673.2662
# Epoch 23/100
# 565/565 [==============================] - 1s 971us/step - loss: 374.7817 - val_loss: 633.5969
# 160/160 [==============================] - 0s 496us/step
# Completed 15 splits
# Epoch 1/100
# 619/619 [==============================] - 1s 1ms/step - loss: 7309.2866 - val_loss: 5992.5723
# Epoch 2/100
# 619/619 [==============================] - 1s 981us/step - loss: 4170.8135 - val_loss: 55301.9219
# Epoch 3/100
# 619/619 [==============================] - 1s 1ms/step - loss: 945.7405 - val_loss: 89414.2422
# Epoch 4/100
# 619/619 [==============================] - 1s 1ms/step - loss: 600.4404 - val_loss: 75811.2422
# Epoch 5/100
# 619/619 [==============================] - 1s 1ms/step - loss: 527.5589 - val_loss: 63732.7734
# Epoch 6/100
# 619/619 [==============================] - 1s 1ms/step - loss: 496.2240 - val_loss: 59225.5039
# 178/178 [==============================] - 0s 583us/step
# Completed 16 splits
# Epoch 1/100
# 691/691 [==============================] - 1s 1ms/step - loss: 6992.8525 - val_loss: 1714.0338
# Epoch 2/100
# 691/691 [==============================] - 1s 1ms/step - loss: 3375.7031 - val_loss: 10096.5195
# Epoch 3/100
# 691/691 [==============================] - 1s 1ms/step - loss: 591.3206 - val_loss: 5108.3262
# Epoch 4/100
# 691/691 [==============================] - 1s 1ms/step - loss: 477.5102 - val_loss: 2727.9802
# Epoch 5/100
# 691/691 [==============================] - 1s 983us/step - loss: 448.6195 - val_loss: 1516.5081
# Epoch 6/100
# 691/691 [==============================] - 1s 987us/step - loss: 432.3736 - val_loss: 936.1339
# Epoch 7/100
# 691/691 [==============================] - 1s 966us/step - loss: 421.3952 - val_loss: 618.8582
# Epoch 8/100
# 691/691 [==============================] - 1s 974us/step - loss: 415.7787 - val_loss: 482.8832
# Epoch 9/100
# 691/691 [==============================] - 1s 1ms/step - loss: 408.9770 - val_loss: 433.9015
# Epoch 10/100
# 691/691 [==============================] - 1s 968us/step - loss: 413.0892 - val_loss: 362.3488
# Epoch 11/100
# 691/691 [==============================] - 1s 989us/step - loss: 406.7591 - val_loss: 351.4374
# Epoch 12/100
# 691/691 [==============================] - 1s 970us/step - loss: 405.9987 - val_loss: 328.3761
# Epoch 13/100
# 691/691 [==============================] - 1s 997us/step - loss: 400.0568 - val_loss: 302.6635
# Epoch 14/100
# 691/691 [==============================] - 1s 1ms/step - loss: 403.3907 - val_loss: 295.1028
# Epoch 15/100
# 691/691 [==============================] - 1s 990us/step - loss: 400.1798 - val_loss: 299.4632
# Epoch 16/100
# 691/691 [==============================] - 1s 969us/step - loss: 397.2690 - val_loss: 282.4391
# Epoch 17/100
# 691/691 [==============================] - 1s 974us/step - loss: 400.2621 - val_loss: 283.8730
# Epoch 18/100
# 691/691 [==============================] - 1s 993us/step - loss: 394.7140 - val_loss: 284.2697
# Epoch 19/100
# 691/691 [==============================] - 1s 1ms/step - loss: 395.7426 - val_loss: 274.5960
# Epoch 20/100
# 691/691 [==============================] - 1s 1ms/step - loss: 394.7589 - val_loss: 278.5013
# Epoch 21/100
# 691/691 [==============================] - 1s 1ms/step - loss: 392.2306 - val_loss: 272.3955
# Epoch 22/100
# 691/691 [==============================] - 1s 1ms/step - loss: 393.6139 - val_loss: 279.6908
# Epoch 23/100
# 691/691 [==============================] - 1s 1000us/step - loss: 393.1216 - val_loss: 279.4675
# Epoch 24/100
# 691/691 [==============================] - 1s 1ms/step - loss: 392.0378 - val_loss: 283.2322
# Epoch 25/100
# 691/691 [==============================] - 1s 990us/step - loss: 391.6709 - val_loss: 271.3189
# Epoch 26/100
# 691/691 [==============================] - 1s 1ms/step - loss: 392.4745 - val_loss: 269.6518
# Epoch 27/100
# 691/691 [==============================] - 1s 1ms/step - loss: 389.3189 - val_loss: 271.5862
# Epoch 28/100
# 691/691 [==============================] - 1s 999us/step - loss: 389.9113 - val_loss: 268.0246
# Epoch 29/100
# 691/691 [==============================] - 1s 1ms/step - loss: 386.1085 - val_loss: 285.3225
# Epoch 30/100
# 691/691 [==============================] - 1s 1ms/step - loss: 387.9117 - val_loss: 284.1577
# Epoch 31/100
# 691/691 [==============================] - 1s 1ms/step - loss: 384.5986 - val_loss: 256.8682
# Epoch 32/100
# 691/691 [==============================] - 1s 1ms/step - loss: 384.6612 - val_loss: 274.5916
# Epoch 33/100
# 691/691 [==============================] - 1s 1ms/step - loss: 384.5974 - val_loss: 283.9031
# Epoch 34/100
# 691/691 [==============================] - 1s 1ms/step - loss: 380.5867 - val_loss: 273.5158
# Epoch 35/100
# 691/691 [==============================] - 1s 1ms/step - loss: 382.3789 - val_loss: 255.6268
# Epoch 36/100
# 691/691 [==============================] - 1s 994us/step - loss: 381.2285 - val_loss: 260.4570
# Epoch 37/100
# 691/691 [==============================] - 1s 998us/step - loss: 380.8985 - val_loss: 270.1648
# Epoch 38/100
# 691/691 [==============================] - 1s 974us/step - loss: 381.1291 - val_loss: 269.4759
# Epoch 39/100
# 691/691 [==============================] - 1s 1ms/step - loss: 378.8840 - val_loss: 273.2697
# Epoch 40/100
# 691/691 [==============================] - 1s 974us/step - loss: 379.9598 - val_loss: 265.3504
# 75/75 [==============================] - 0s 508us/step
# Completed 17 splits
# R2_oos NN4 bottom 500:  -5310.36588745191

# %%
R2oos_OLS_df = pd.DataFrame({
    "NN4" : [R2oos_NN4,
                R2oos_NN4_top,
                R2oos_NN4_bottom
                ]
})

R2oos_OLS_df.index = ['Alle', "Øverste 500", "Nederste 500"]

# %%
R2oos_OLS_df
# Out:
#                       NN4
# Alle          -309.079248
# Øverste 500      0.931616
# Nederste 500 -5310.365887

# %%
R2oos_OLS_df.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/R2-værdier/R2oos_NN4.csv", index=False)

# %% [markdown]
# # Variable importance

# %%
X_train = df_final[variables].loc[(df_final["Date"] >= '2013-02-28') & (df_final["Date"] < '2021-02-28')]
y_train = df_final["Adj Close t+1"].loc[(df_final["Date"]>='2013-02-28') & (df_final["Date"] < '2021-02-28')]

X_val = df_final[variables].loc[(df_final["Date"] >= '2021-02-28') & (df_final["Date"] < '2024-02-28')]
y_val = df_final["Adj Close t+1"].loc[(df_final["Date"] >= '2021-02-28') & (df_final["Date"] < '2024-02-28')]

X_test = df_final[variables].loc[(df_final["Date"] >= '2024-02-28') & (df_final["Date"] < '2025-02-28')]
y_test = df_final["Adj Close t+1"].loc[(df_final["Date"] >= '2024-02-28') & (df_final["Date"] < '2025-02-28')]


input_shape = [X_train.shape[1]]
    

mean_train = X_train.mean(axis=0)
std_train  = X_train.std(axis=0)

X_train = (X_train-mean_train) / std_train
X_val = (X_val-mean_train) / std_train
X_test = (X_test-mean_train) / std_train



model = tf.keras.Sequential([

tf.keras.layers.Flatten(input_shape=input_shape),
tf.keras.layers.Dense(units=32, activation='relu'),
tf.keras.layers.Dense(units=16, activation='relu'),
tf.keras.layers.Dense(units=8, activation='relu'),
tf.keras.layers.Dense(units=4, activation='relu'),
tf.keras.layers.Dense(units=1, activation='linear')

])

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0, clipnorm=1.0, clipvalue=0.5), loss='mse')    

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[early_stopping])

preds = model.predict(X_test)
preds = preds.ravel()


R2oos_varimp = 1 - np.sum((y_test - preds) ** 2) / np.sum((y_test - y_test.mean()) ** 2)
R2oos_varimp
# Out:
# Epoch 1/100
# 7763/7763 [==============================] - 7s 855us/step - loss: 803.0314 - val_loss: 25593.6875
# Epoch 2/100
# 7763/7763 [==============================] - 7s 949us/step - loss: 131.3824 - val_loss: 22228.3438
# Epoch 3/100
# 7763/7763 [==============================] - 8s 997us/step - loss: 110.4619 - val_loss: 21889.3730
# Epoch 4/100
# 7763/7763 [==============================] - 7s 964us/step - loss: 100.6764 - val_loss: 21162.0137
# Epoch 5/100
# 7763/7763 [==============================] - 8s 989us/step - loss: 92.1029 - val_loss: 19423.0488
# Epoch 6/100
# 7763/7763 [==============================] - 7s 922us/step - loss: 87.2892 - val_loss: 17513.2559
# Epoch 7/100
# 7763/7763 [==============================] - 7s 870us/step - loss: 83.1270 - val_loss: 16046.6689
# Epoch 8/100
# 7763/7763 [==============================] - 7s 864us/step - loss: 81.0015 - val_loss: 14930.2100
# Epoch 9/100
# 7763/7763 [==============================] - 7s 863us/step - loss: 79.5566 - val_loss: 14252.1748
# Epoch 10/100
# 7763/7763 [==============================] - 7s 864us/step - loss: 78.7417 - val_loss: 13971.1914
# Epoch 11/100
# 7763/7763 [==============================] - 7s 866us/step - loss: 76.9065 - val_loss: 12593.8877
# Epoch 12/100
# 7763/7763 [==============================] - 7s 925us/step - loss: 75.5259 - val_loss: 11657.1426
# Epoch 13/100
# 7763/7763 [==============================] - 7s 948us/step - loss: 74.4858 - val_loss: 9983.7441
# Epoch 14/100
# 7763/7763 [==============================] - 7s 953us/step - loss: 73.0896 - val_loss: 9080.6230
# Epoch 15/100
# 7763/7763 [==============================] - 7s 927us/step - loss: 72.3971 - val_loss: 8928.4580
# Epoch 16/100
# 7763/7763 [==============================] - 7s 962us/step - loss: 72.1941 - val_loss: 7970.9409
# Epoch 17/100
# 7763/7763 [==============================] - 7s 953us/step - loss: 71.3709 - val_loss: 7338.2065
# Epoch 18/100
# 7763/7763 [==============================] - 8s 968us/step - loss: 70.4222 - val_loss: 6689.7178
# Epoch 19/100
# 7763/7763 [==============================] - 7s 942us/step - loss: 70.2110 - val_loss: 5764.3813
# Epoch 20/100
# 7763/7763 [==============================] - 8s 975us/step - loss: 69.8839 - val_loss: 4946.1089
# Epoch 21/100
# 7763/7763 [==============================] - 7s 942us/step - loss: 69.1524 - val_loss: 4616.8198
# Epoch 22/100
# 7763/7763 [==============================] - 7s 922us/step - loss: 68.7443 - val_loss: 4201.0840
# Epoch 23/100
# 7763/7763 [==============================] - 7s 867us/step - loss: 68.5039 - val_loss: 3312.8066
# Epoch 24/100
# 7763/7763 [==============================] - 7s 875us/step - loss: 68.3190 - val_loss: 2750.8564
# Epoch 25/100
# 7763/7763 [==============================] - 7s 871us/step - loss: 67.8235 - val_loss: 2113.9341
# Epoch 26/100
# 7763/7763 [==============================] - 7s 876us/step - loss: 67.5815 - val_loss: 1709.4406
# Epoch 27/100
# 7763/7763 [==============================] - 7s 902us/step - loss: 67.1761 - val_loss: 1450.2676
# Epoch 28/100
# 7763/7763 [==============================] - 7s 917us/step - loss: 67.0080 - val_loss: 1363.3748
# Epoch 29/100
# 7763/7763 [==============================] - 7s 928us/step - loss: 67.2051 - val_loss: 1015.4346
# Epoch 30/100
# 7763/7763 [==============================] - 8s 988us/step - loss: 66.7586 - val_loss: 725.2942
# Epoch 31/100
# 7763/7763 [==============================] - 7s 962us/step - loss: 66.5701 - val_loss: 479.1333
# Epoch 32/100
# 7763/7763 [==============================] - 7s 910us/step - loss: 66.5401 - val_loss: 351.5742
# Epoch 33/100
# 7763/7763 [==============================] - 7s 864us/step - loss: 66.2728 - val_loss: 311.0498
# Epoch 34/100
# 7763/7763 [==============================] - 7s 865us/step - loss: 66.2542 - val_loss: 294.2007
# Epoch 35/100
# 7763/7763 [==============================] - 7s 868us/step - loss: 66.4999 - val_loss: 268.8752
# Epoch 36/100
# 7763/7763 [==============================] - 7s 867us/step - loss: 66.2174 - val_loss: 260.4223
# Epoch 37/100
# 7763/7763 [==============================] - 7s 930us/step - loss: 66.4507 - val_loss: 290.6123
# Epoch 38/100
# 7763/7763 [==============================] - 7s 880us/step - loss: 66.2040 - val_loss: 315.2449
# Epoch 39/100
# 7763/7763 [==============================] - 7s 917us/step - loss: 66.2214 - val_loss: 274.5823
# Epoch 40/100
# 7763/7763 [==============================] - 7s 906us/step - loss: 66.1265 - val_loss: 242.6312
# Epoch 41/100
# 7763/7763 [==============================] - 7s 908us/step - loss: 66.2778 - val_loss: 348.0626
# Epoch 42/100
# 7763/7763 [==============================] - 7s 949us/step - loss: 66.3220 - val_loss: 243.2733
# Epoch 43/100
# 7763/7763 [==============================] - 7s 949us/step - loss: 66.1046 - val_loss: 312.2130
# Epoch 44/100
# 7763/7763 [==============================] - 7s 964us/step - loss: 66.0912 - val_loss: 253.5042
# Epoch 45/100
# 7763/7763 [==============================] - 7s 948us/step - loss: 65.7844 - val_loss: 236.1832
# Epoch 46/100
# 7763/7763 [==============================] - 7s 921us/step - loss: 65.8836 - val_loss: 354.5623
# Epoch 47/100
# 7763/7763 [==============================] - 7s 926us/step - loss: 65.5883 - val_loss: 334.2083
# Epoch 48/100
# 7763/7763 [==============================] - 7s 919us/step - loss: 65.7545 - val_loss: 242.7131
# Epoch 49/100
# 7763/7763 [==============================] - 7s 943us/step - loss: 65.7694 - val_loss: 333.2039
# Epoch 50/100
# 7763/7763 [==============================] - 7s 919us/step - loss: 65.8358 - val_loss: 335.8461
# 823/823 [==============================] - 0s 483us/step
# 0.9834088336057925

# %%
R2_dic = {}

for variable in variables:
    X_test_copy = X_test.copy()
    
    X_test_copy[variable] = 0
    
    preds = model.predict(X_test_copy)
    preds = preds.ravel()

    
    R2oos_varimp_each_var = 1 - np.sum(np.power(y_test - preds, 2)) / np.sum(np.power(y_test, 2))
    
    R2_dic[variable] = R2oos_varimp_each_var
# Out:
# 823/823 [==============================] - 0s 529us/step
# 823/823 [==============================] - 0s 535us/step
# 823/823 [==============================] - 0s 519us/step
# 823/823 [==============================] - 0s 488us/step
# 823/823 [==============================] - 0s 501us/step
# 823/823 [==============================] - 0s 514us/step
# 823/823 [==============================] - 0s 533us/step
# 823/823 [==============================] - 0s 537us/step
# 823/823 [==============================] - 0s 526us/step
# 823/823 [==============================] - 0s 588us/step
# 823/823 [==============================] - 0s 533us/step
# 823/823 [==============================] - 0s 528us/step
# 823/823 [==============================] - 0s 531us/step
# 823/823 [==============================] - 0s 525us/step
# 823/823 [==============================] - 0s 522us/step
# 823/823 [==============================] - 0s 516us/step
# 823/823 [==============================] - 0s 507us/step
# 823/823 [==============================] - 0s 508us/step
# 823/823 [==============================] - 0s 515us/step
# 823/823 [==============================] - 0s 513us/step
# 823/823 [==============================] - 0s 506us/step
# 823/823 [==============================] - 0s 512us/step
# 823/823 [==============================] - 0s 505us/step
# 823/823 [==============================] - 0s 508us/step
# 823/823 [==============================] - 0s 507us/step
# 823/823 [==============================] - 0s 510us/step
# 823/823 [==============================] - 0s 563us/step

# %%
R2_dic
# Out:
# {'Open': 0.9820734111904185,
#  'High': 0.9878516114245713,
#  'Low': 0.9836618515188511,
#  'Close': 0.9796447520767954,
#  'Adj Close': 0.326178480613856,
#  'Volume': 0.9885422162101222,
#  'Dividends': 0.9885392692467514,
#  'Stock Splits': 0.9886781452618938,
#  'Market capitalization': 0.9881148370466718,
#  'Revenue': 0.9884832295214296,
#  'Earnings': 0.9886318653218569,
#  'P/E ratio': 0.9885489824082291,
#  'P/B ratio': 0.9885393796664765,
#  'Operating Margin': 0.9886785705000125,
#  'EPS': 0.9885415388044485,
#  'Shares Outstanding': 0.9884527066152451,
#  'Total assets': 0.9885136638972402,
#  'Total liabilities': 0.9883970210977718,
#  'Total debt': 0.9885517167612059,
#  'Cash on Hand': 0.9885385261644978,
#  'Net assets': 0.9884894734009962,
#  '1-month momentum': 0.9887902069176537,
#  '6-month momentum': 0.9892122465805822,
#  '12-month momentum': 0.9898834715589956,
#  '36-month momentum': 0.9897508385046597,
#  'Book-to-market': 0.9886724941032586,
#  'Size': 0.9884234973329119}

# %%
varimp = pd.DataFrame.from_dict(R2_dic, orient='index', columns=['R2oos']).reset_index()
varimp.rename(columns={'index': 'Variable'}, inplace=True)

varimp['reduc_R2oos'] = R2oos_varimp - varimp['R2oos']

varimp['reduc_R2oos'] = varimp['reduc_R2oos'].clip(lower=0)

total_reduction = varimp['reduc_R2oos'].sum()
varimp['var_imp'] = varimp['reduc_R2oos'] / total_reduction

varimp = varimp.sort_values(by='var_imp', ascending=False).reset_index(drop=True)

imp = varimp.sort_values('var_imp', ascending=False).head(20)

# %%
varimp
# Out:
#                  Variable     R2oos  reduc_R2oos   var_imp
# 0               Adj Close  0.326178     0.657230  0.992301
# 1                   Close  0.979645     0.003764  0.005683
# 2                    Open  0.982073     0.001335  0.002016
# 3      Shares Outstanding  0.988453     0.000000  0.000000
# 4          Book-to-market  0.988672     0.000000  0.000000
# 5       36-month momentum  0.989751     0.000000  0.000000
# 6       12-month momentum  0.989883     0.000000  0.000000
# 7        6-month momentum  0.989212     0.000000  0.000000
# 8        1-month momentum  0.988790     0.000000  0.000000
# 9              Net assets  0.988489     0.000000  0.000000
# 10           Cash on Hand  0.988539     0.000000  0.000000
# 11             Total debt  0.988552     0.000000  0.000000
# 12      Total liabilities  0.988397     0.000000  0.000000
# 13           Total assets  0.988514     0.000000  0.000000
# 14       Operating Margin  0.988679     0.000000  0.000000
# 15                    EPS  0.988542     0.000000  0.000000
# 16                   High  0.987852     0.000000  0.000000
# 17              P/B ratio  0.988539     0.000000  0.000000
# 18              P/E ratio  0.988549     0.000000  0.000000
# 19               Earnings  0.988632     0.000000  0.000000
# 20                Revenue  0.988483     0.000000  0.000000
# 21  Market capitalization  0.988115     0.000000  0.000000
# 22           Stock Splits  0.988678     0.000000  0.000000
# 23              Dividends  0.988539     0.000000  0.000000
# 24                 Volume  0.988542     0.000000  0.000000
# 25                    Low  0.983662     0.000000  0.000000
# 26                   Size  0.988423     0.000000  0.000000

# %%
imp = varimp.sort_values('var_imp', ascending=False).head(20)

df_plot = pd.DataFrame({
    'Variable': imp['Variable'],
    'Importance': imp['var_imp']
})

plt.figure(figsize=(12, 8))
plt.barh(df_plot['Variable'], df_plot['Importance'], color='steelblue')
plt.gca().invert_yaxis()



plt.axvline(0.2, color='black', linestyle='--', linewidth=0.5)
plt.axvline(0.4, color='black', linestyle='--', linewidth=0.5)
plt.axvline(0.6, color='black', linestyle='--', linewidth=0.5)
plt.axvline(0.8, color='black', linestyle='--', linewidth=0.5)



plt.xlabel('Variable Importance')
plt.ylabel('Variables')
plt.title('NN4')

plt.show()

# %%
varimp=varimp[["Variable", "var_imp"]]
varimp.to_csv(r'C:/Users/CMert/Documents/Data bachelorprojekt/variable-comparison/varimp NN4.csv', index = False)

# %% [markdown]
# # Preparations for machine learning portfolios

# %%
# The following is a table comparing the estimiates to the true values of each stock for every day in the test set.

# Remember to rerun df_final for all stock!

symbols = df_final.loc[dates_all.index, 'Symbol']  


comparison = pd.DataFrame({
    'Date': dates_all,  
    'y_hat': predictions_all.tolist(),
    'y_true': y_test_list_all.tolist(),
    'Symbol': symbols  
})


comparison['MonthYear'] = comparison['Date'].dt.to_period('M')

comparison = comparison.sort_values(by=['Date', 'Symbol'], ascending=True)
comparison = comparison.set_index(['MonthYear', 'Symbol'])

comparison
# Out:
#                        Date      y_hat     y_true
# MonthYear Symbol
# 2008-04   A      2008-04-30  19.352745  23.992857
#           AAL    2008-04-30   7.902241   3.733256
#           AAON   2008-04-30   3.223413   3.544210
#           AAP    2008-04-30  30.723236  35.527317
#           AAPL   2008-04-30   0.448046   5.692668
# ...                     ...        ...        ...
# 2024-08   ZVIA   2024-08-30   1.204806   1.020000
#           ZVRA   2024-08-30   7.558702   7.390000
#           ZWS    2024-08-30  33.233730  32.099998
#           ZYME   2024-08-30  12.001637  12.100000
#           ZYXI   2024-08-30   8.876501   7.960000
#
# [510910 rows x 3 columns]

# %%
# Save the df for the Diebold-Mariano test

ols= comparison.reset_index()
ols.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/Estimater/NN4 Estimates", index = False)

# %%
ols = pd.read_csv("C:/Users/CMert/Documents/Data bachelorprojekt/Estimater/NN4 Estimates")

# %% [markdown]
# Lad Adj Close være betegnet som P. Afkastraten udregnes ved:
#
# $$ r_{t+1} = \frac{P_{t+1}}{P_t} -1 $$
# Og
#
# $$ \hat{r}_{t+1} = \frac{\hat{P}_{t+1}}{P_t} -1 $$

# %% [markdown]
# Merafkastsraten udregnes ved:
#
# $$ er_{t+1} = r_{t+1} - r_{f,t+1}  $$
# Og
#
# $$ \hat{er}_{t+1} = \hat{r}_{t+1} - r_{f,t+1}  $$
#
#
# Her er $R_{f,t}$ notation for den risikofrie rate i periode t. Fordi vi arbejder med amerikanske aktier, har vi fundet data for obligationsraten i USA, og benytter dette som den risikofrie rate.
# Dataen er fundet her: https://fred.stlouisfed.org/series/DGS20

# %%
#Calculate estimiated future return, where distance between each period is one month. Notice that for the return estimate, then for P_t we use the actual adj close price, since at time t it is known: 

comparison = ols

comparison['Date'] = pd.to_datetime(comparison['Date'])


comparison = comparison.sort_values(by=['Symbol', 'Date']).reset_index(drop=True)


comparison["ret_t+1_hat"] = comparison["y_hat"] / comparison.groupby("Symbol")["y_true"].shift(1) - 1
comparison["ret_t+1_true"] = comparison["y_true"] / comparison.groupby("Symbol")["y_true"].shift(1) - 1


comparison_ret_1m = comparison.sort_values(by=['Date', 'Symbol'], ascending=True)


comparison_ret_1m
# Out:
#        MonthYear Symbol       Date      y_hat     y_true  ret_t+1_hat  \
# 0        2008-04      A 2008-04-30  19.352745  23.992857          NaN
# 549      2008-04    AAL 2008-04-30   7.902241   3.733256          NaN
# 898      2008-04   AAON 2008-04-30   3.223413   3.544210          NaN
# 1095     2008-04    AAP 2008-04-30  30.723236  35.527317          NaN
# 1292     2008-04   AAPL 2008-04-30   0.448046   5.692668          NaN
# ...          ...    ...        ...        ...        ...          ...
# 510411   2024-08   ZVIA 2024-08-30   1.204806   1.020000     0.192877
# 510510   2024-08   ZVRA 2024-08-30   7.558702   7.390000    -0.011934
# 510647   2024-08    ZWS 2024-08-30  33.233730  32.099998     0.024784
# 510723   2024-08   ZYME 2024-08-30  12.001637  12.100000     0.023157
# 510909   2024-08   ZYXI 2024-08-30   8.876501   7.960000     0.129326
#
#         ret_t+1_true
# 0                NaN
# 549              NaN
# 898              NaN
# 1095             NaN
# 1292             NaN
# ...              ...
# 510411      0.009901
# 510510     -0.033987
# 510647     -0.010176
# 510723      0.031543
# 510909      0.012723
#
# [510910 rows x 7 columns]

# %%
# Drop rows where either 'ret_t-(y_hat)	' or 'ret_t-(y_true)' is NaN
comparison_ret_1m = comparison_ret_1m.dropna(subset=['ret_t+1_hat', 'ret_t+1_true']).reset_index(drop=False)

# %%
treasury_securities = pd.read_excel("C:/Users/CMert/Documents/Data bachelorprojekt/Treasury securities.xlsx")

# %%
treasury_securities['Date'] = pd.to_datetime(treasury_securities['Date'])
comparison_ret_1m['Date'] = pd.to_datetime(comparison_ret_1m['Date'])

new_comparison = pd.merge(comparison_ret_1m, treasury_securities, on='Date', how='inner')

new_comparison = new_comparison[new_comparison['Treasury Securities'] != 0]

new_comparison['Treasury Securities'] = new_comparison['Treasury Securities'] / (12*100)

new_comparison['exc_ret_t+1_hat'] = new_comparison['ret_t+1_hat']-new_comparison['Treasury Securities']

new_comparison['exc_ret_t+1_true'] = new_comparison['ret_t+1_true']-new_comparison['Treasury Securities']

new_comparison = new_comparison.sort_values(by=['Date', 'Symbol'], ascending=True)

new_comparison = new_comparison.drop("index", axis = 1)

new_comparison
# Out:
#        MonthYear Symbol       Date      y_hat     y_true  ret_t+1_hat  \
# 0        2008-05      A 2008-05-30  23.300346  22.805721    -0.028863
# 1        2008-05    AAL 2008-05-30   4.382995   2.356854     0.174041
# 2        2008-05   AAON 2008-05-30   3.647266   3.271587     0.029077
# 3        2008-05    AAP 2008-05-30  35.146969  34.281311    -0.010706
# 4        2008-05   AAPL 2008-05-30   0.468119   5.049963    -0.917768
# ...          ...    ...        ...        ...        ...          ...
# 507062   2024-08   ZVIA 2024-08-30   1.204806   1.020000     0.192877
# 507063   2024-08   ZVRA 2024-08-30   7.558702   7.390000    -0.011934
# 507064   2024-08    ZWS 2024-08-30  33.233730  32.099998     0.024784
# 507065   2024-08   ZYME 2024-08-30  12.001637  12.100000     0.023157
# 507066   2024-08   ZYXI 2024-08-30   8.876501   7.960000     0.129326
#
#         ret_t+1_true  Treasury Securities  exc_ret_t+1_hat  exc_ret_t+1_true
# 0          -0.049479             0.003950        -0.032813         -0.053429
# 1          -0.368687             0.003950         0.170091         -0.372637
# 2          -0.076921             0.003950         0.025127         -0.080871
# 3          -0.035072             0.003950        -0.014656         -0.039022
# 4          -0.112901             0.003950        -0.921718         -0.116851
# ...              ...                  ...              ...               ...
# 507062      0.009901             0.003567         0.189311          0.006334
# 507063     -0.033987             0.003567        -0.015501         -0.037554
# 507064     -0.010176             0.003567         0.021217         -0.013742
# 507065      0.031543             0.003567         0.019591          0.027976
# 507066      0.012723             0.003567         0.125759          0.009156
#
# [507067 rows x 10 columns]

# %%
# Remember to rerun df_final, when adding 'Market cap' since it is standardized:

new_comparison['Date'] = pd.to_datetime(new_comparison['Date'])
df_final['Date'] = pd.to_datetime(df_final['Date'])

final_comparison = pd.merge(new_comparison, df_final[["Date", "Symbol", "Market capitalization"]], on=["Date", "Symbol"], how="inner")


final_comparison = final_comparison.sort_values(by=['Date', 'Symbol'], ascending=True)

# %%
final_comparison = final_comparison.rename(columns={'Treasury Securities' : 'Risk free rate'})

# %%
# We now limit the df to the following decade 2014-01 and 2023-12
final_comparison = final_comparison[
    (final_comparison["MonthYear"] >= "2014-01") &
    (final_comparison["MonthYear"] <= "2023-12")
]

# %%
final_comparison
# Out:
#        MonthYear Symbol       Date       y_hat      y_true  ret_t+1_hat  \
# 134848   2014-01      A 2014-01-31   38.525986   37.276997     0.011823
# 134849   2014-01   AACG 2014-01-31    0.694024    0.375884     0.984856
# 134850   2014-01    AAL 2014-01-31   33.127846   34.815441     0.047389
# 134851   2014-01   AAON 2014-01-31   12.907468   12.327587     0.054806
# 134852   2014-01    AAP 2014-01-31  106.649124  115.128609     0.027608
# ...          ...    ...        ...         ...         ...          ...
# 477000   2023-12   ZVIA 2023-12-29    2.475625    1.700000     0.231654
# 477001   2023-12   ZVRA 2023-12-29    5.424884    5.790000    -0.171773
# 477002   2023-12    ZWS 2023-12-29   26.137281   29.427322    -0.104554
# 477003   2023-12   ZYME 2023-12-29    9.186041   10.840000    -0.115877
# 477004   2023-12   ZYXI 2023-12-29   10.501640   11.840000    -0.035662
#
#         ret_t+1_true  Risk free rate  exc_ret_t+1_hat  exc_ret_t+1_true  \
# 134848     -0.020980        0.002792         0.009031         -0.023772
# 134849      0.075000        0.002792         0.982064          0.072208
# 134850      0.100745        0.002792         0.044598          0.097953
# 134851      0.007418        0.002792         0.052014          0.004626
# 134852      0.109311        0.002792         0.024816          0.106519
# ...              ...             ...              ...               ...
# 477000     -0.154229        0.003500         0.228154         -0.157729
# 477001     -0.116031        0.003500        -0.175273         -0.119531
# 477002      0.008160        0.003500        -0.108054          0.004660
# 477003      0.043311        0.003500        -0.119377          0.039811
# 477004      0.087236        0.003500        -0.039162          0.083736
#
#         Market capitalization
# 134848           1.904000e+10
# 134849           9.062000e+07
# 134850           6.590000e+09
# 134851           1.170000e+09
# 134852           8.060000e+09
# ...                       ...
# 477000           2.600000e+08
# 477001           1.583091e+08
# 477002           3.760000e+09
# 477003           4.900000e+08
# 477004           5.300000e+08
#
# [342157 rows x 11 columns]

# %%
# Index every month in order

unique_months = final_comparison['MonthYear'].unique()
unique_months.sort()

month_indices = list(range(1, len(unique_months) + 1))

df_month_merge = pd.DataFrame({
    'MonthYear': unique_months,
    'MonthIndex': month_indices
})

final_comparison = final_comparison.merge(df_month_merge, on='MonthYear', how='left')

# %%
final_comparison
# Out:
#        MonthYear Symbol       Date       y_hat      y_true  ret_t+1_hat  \
# 0        2014-01      A 2014-01-31   38.525986   37.276997     0.011823
# 1        2014-01   AACG 2014-01-31    0.694024    0.375884     0.984856
# 2        2014-01    AAL 2014-01-31   33.127846   34.815441     0.047389
# 3        2014-01   AAON 2014-01-31   12.907468   12.327587     0.054806
# 4        2014-01    AAP 2014-01-31  106.649124  115.128609     0.027608
# ...          ...    ...        ...         ...         ...          ...
# 342152   2023-12   ZVIA 2023-12-29    2.475625    1.700000     0.231654
# 342153   2023-12   ZVRA 2023-12-29    5.424884    5.790000    -0.171773
# 342154   2023-12    ZWS 2023-12-29   26.137281   29.427322    -0.104554
# 342155   2023-12   ZYME 2023-12-29    9.186041   10.840000    -0.115877
# 342156   2023-12   ZYXI 2023-12-29   10.501640   11.840000    -0.035662
#
#         ret_t+1_true  Risk free rate  exc_ret_t+1_hat  exc_ret_t+1_true  \
# 0          -0.020980        0.002792         0.009031         -0.023772
# 1           0.075000        0.002792         0.982064          0.072208
# 2           0.100745        0.002792         0.044598          0.097953
# 3           0.007418        0.002792         0.052014          0.004626
# 4           0.109311        0.002792         0.024816          0.106519
# ...              ...             ...              ...               ...
# 342152     -0.154229        0.003500         0.228154         -0.157729
# 342153     -0.116031        0.003500        -0.175273         -0.119531
# 342154      0.008160        0.003500        -0.108054          0.004660
# 342155      0.043311        0.003500        -0.119377          0.039811
# 342156      0.087236        0.003500        -0.039162          0.083736
#
#         Market capitalization  MonthIndex
# 0                1.904000e+10           1
# 1                9.062000e+07           1
# 2                6.590000e+09           1
# 3                1.170000e+09           1
# 4                8.060000e+09           1
# ...                       ...         ...
# 342152           2.600000e+08         120
# 342153           1.583091e+08         120
# 342154           3.760000e+09         120
# 342155           4.900000e+08         120
# 342156           5.300000e+08         120
#
# [342157 rows x 12 columns]

# %%
# Function to add the decile rank of each stock in each month

def decile_ranks(df):
    df = df.sort_values(by='exc_ret_t+1_hat', ascending=True)
    
    df['Decile rank'] = pd.qcut(df['exc_ret_t+1_hat'], 10, labels=False, duplicates='drop')
    return df


final_comparison = final_comparison.groupby('MonthYear', group_keys=False).apply(decile_ranks)

# %%
# A dictionray of the stock history of each decile:

decile_dataframes = {}

# Loop through each decile rank
for decile in range(10):
    
    decile_df = final_comparison[final_comparison['Decile rank'] == decile].copy()
    
    decile_df.reset_index(drop=True, inplace=True)
    
    decile_dataframes[f'decile_rank_{decile}'] = decile_df

# %%
decile_dataframes['decile_rank_9']
# Out:
#       MonthYear Symbol       Date        y_hat     y_true  ret_t+1_hat  \
# 0       2014-01   GRMN 2014-01-31    34.063148  38.340729     0.058231
# 1       2014-01   CASH 2014-01-31    13.180257  13.150163     0.058288
# 2       2014-01     CW 2014-01-31    61.184540  64.155563     0.058345
# 3       2014-01   PKOH 2014-01-31    42.256283  43.954945     0.058697
# 4       2014-01    WLK 2014-01-31    55.989780  58.125114     0.058747
# ...         ...    ...        ...          ...        ...          ...
# 34253   2023-12   JAGX 2023-12-29  1216.706787   6.240000   133.294341
# 34254   2023-12   NUWE 2023-12-29  2997.955811  16.100000   146.682558
# 34255   2023-12   ONFO 2023-12-29   139.175308   0.540000   271.892766
# 34256   2023-12   ASNS 2023-12-29   351.409088   1.130000   312.758113
# 34257   2023-12   VERB 2023-12-29   100.521332   0.158000   583.426328
#
#        ret_t+1_true  Risk free rate  exc_ret_t+1_hat  exc_ret_t+1_true  \
# 0          0.191121        0.002792         0.055439          0.188329
# 1          0.055872        0.002792         0.055496          0.053080
# 2          0.109736        0.002792         0.055553          0.106944
# 3          0.101255        0.002792         0.055905          0.098463
# 4          0.099125        0.002792         0.055955          0.096334
# ...             ...             ...              ...               ...
# 34253     -0.311258        0.003500       133.290841         -0.314758
# 34254     -0.206897        0.003500       146.679058         -0.210397
# 34255      0.058824        0.003500       271.889266          0.055324
# 34256      0.008929        0.003500       312.754613          0.005429
# 34257     -0.081395        0.003500       583.422828         -0.084895
#
#        Market capitalization  MonthIndex  Decile rank
# 0               9.010000e+09           1            9
# 1               2.400000e+08           1            9
# 2               2.960000e+09           1            9
# 3               6.500000e+08           1            9
# 4               8.130000e+09           1            9
# ...                      ...         ...          ...
# 34253           1.314000e+07         120            9
# 34254           3.380000e+06         120            9
# 34255           7.760000e+06         120            9
# 34256           8.260000e+06         120            9
# 34257           1.906000e+07         120            9
#
# [34258 rows x 13 columns]

# %% [markdown]
# # Machine learning portfolios

# %% [markdown]
# For hvert decildatasæt og derfra for hver måned tilføjer vi to vægte for hver aktie. Vægtene er henholdsvis 'equal weights' og 'market capitalization weights' som udregnes ved:
#
# $$w^{eq} = \frac{1}{N}, $$
# hvor N er antallet af aktier for den respektive måned. Vægten baseret på aktiens markedsværdi udregnes ved:
#
# $$w^{mc}_{i} = \frac{mc_i}{\sum_{j = 1}^N mc_j}, $$
# hvor $i$ og $j$ er en indexering af aktierne for den respektive måned.

# %%
for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Calculate eq weights:
    decile_dfs_value['eq_weights'] = 1 / decile_dfs_value.groupby('MonthYear')['Symbol'].transform('count')
    
    # Calculate mc weights
    decile_dfs_value['mc_weights'] = decile_dfs_value['Market capitalization'] / decile_dfs_value.groupby('MonthYear')['Market capitalization'].transform('sum')
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %% [markdown]
# I artiklen S. 2261 (PDF S. 39) er porteføljens merafkastsrate givet ved:
#
# $$\hat{er}^P_{t+1} = \sum_{i = 1}^N w^P_{i,t} \cdot \hat{er}_{i,t+1} , $$
# hvor P angiver den enkelte portefølje, specificeret ved variablerne Decile rank og MonthYear.

# %%
# Weighted true excess return at t+1 for each stock:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    # Calculate the product of equal weights and excess return, to find the equal weighted excess return of each stock:
    decile_dfs_value['exc_ret_t+1_true_eq'] = decile_dfs_value['exc_ret_t+1_true'] * decile_dfs_value['eq_weights']
    
    
    # Calculate the product of mc weights and excess return, to find the mc weighted excess return of each stock:
    decile_dfs_value['exc_ret_t+1_true_mc'] = decile_dfs_value['exc_ret_t+1_true'] * decile_dfs_value['mc_weights']
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted true portfolio excess return at t+1:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Calculate true eq portfolio excess return:
    decile_dfs_value['portfolio_true_exc_ret_eq'] = decile_dfs_value.groupby('MonthYear')['exc_ret_t+1_true_eq'].transform('sum')
    
    # Calculate true mc portfolio excess return:
    decile_dfs_value['portfolio_true_exc_ret_mc'] = decile_dfs_value.groupby('MonthYear')['exc_ret_t+1_true_mc'].transform('sum')
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted predicted excess return at t+1 for each stock:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    # Calculate the product of equal weights and excess return, to find the equal weighted excess return of each stock:
    decile_dfs_value['exc_ret_t+1_hat_eq'] = decile_dfs_value['exc_ret_t+1_hat'] * decile_dfs_value['eq_weights']
    
    
    # Calculate the product of mc weights and excess return, to find the mc weighted excess return of each stock:
    decile_dfs_value['exc_ret_t+1_hat_mc'] = decile_dfs_value['exc_ret_t+1_hat'] * decile_dfs_value['mc_weights']
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted predicted portfolio excess return at t+1:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Calculate true eq portfolio excess return:
    decile_dfs_value['portfolio_hat_exc_ret_eq'] = decile_dfs_value.groupby('MonthYear')['exc_ret_t+1_hat_eq'].transform('sum')
    
    # Calculate true mc portfolio excess return:
    decile_dfs_value['portfolio_hat_exc_ret_mc'] = decile_dfs_value.groupby('MonthYear')['exc_ret_t+1_hat_mc'].transform('sum')
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted true return at t+1 for each stock:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    # Calculate the product of equal weights and return, to find the equal weighted return of each stock:
    decile_dfs_value['ret_t+1_true_eq'] = decile_dfs_value['ret_t+1_true'] * decile_dfs_value['eq_weights']
    
    
    # Calculate the product of mc weights and return, to find the mc weighted return of each stock:
    decile_dfs_value['ret_t+1_true_mc'] = decile_dfs_value['ret_t+1_true'] * decile_dfs_value['mc_weights']
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted true portfolio return at t+1:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Calculate true eq portfolio return:
    decile_dfs_value['portfolio_true_ret_eq'] = decile_dfs_value.groupby('MonthYear')['ret_t+1_true_eq'].transform('sum')
    
    # Calculate true mc portfolio return:
    decile_dfs_value['portfolio_true_ret_mc'] = decile_dfs_value.groupby('MonthYear')['ret_t+1_true_mc'].transform('sum')
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
decile_dataframes['decile_rank_5'].columns
# Out:
# Index(['MonthYear', 'Symbol', 'Date', 'y_hat', 'y_true', 'ret_t+1_hat',
#        'ret_t+1_true', 'Risk free rate', 'exc_ret_t+1_hat', 'exc_ret_t+1_true',
#        'Market capitalization', 'MonthIndex', 'Decile rank', 'eq_weights',
#        'mc_weights', 'exc_ret_t+1_true_eq', 'exc_ret_t+1_true_mc',
#        'portfolio_true_exc_ret_eq', 'portfolio_true_exc_ret_mc',
#        'exc_ret_t+1_hat_eq', 'exc_ret_t+1_hat_mc', 'portfolio_hat_exc_ret_eq',
#        'portfolio_hat_exc_ret_mc', 'ret_t+1_true_eq', 'ret_t+1_true_mc',
#        'portfolio_true_ret_eq', 'portfolio_true_ret_mc'],
#       dtype='object')

# %%
portfolio_returns2 = {}

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():

    portfolio_variables = decile_dfs_value[['MonthYear',
                                   
                                   'portfolio_true_exc_ret_eq',
                                   'portfolio_true_exc_ret_mc',
                                   
                                   'portfolio_hat_exc_ret_eq',
                                   'portfolio_hat_exc_ret_mc',
                                   
                                   'portfolio_true_ret_eq',
                                   'portfolio_true_ret_mc',
                                   
                                   'Decile rank',
                                   'MonthIndex',
                                   
                                   ]].copy()
    
    portfolio_variables = portfolio_variables.drop_duplicates()
    
    portfolio_variables.reset_index(drop=True, inplace=True)
    
    portfolio_returns2[decile_dfs_key] = portfolio_variables

# %%
portfolio_returns2['decile_rank_9']
# Out:
#     MonthYear  portfolio_true_exc_ret_eq  portfolio_true_exc_ret_mc  \
# 0     2014-01                   0.111444                   0.027160
# 1     2014-02                   0.080336                   0.034084
# 2     2014-03                   0.034653                   0.011943
# 3     2014-04                   0.047298                   0.020860
# 4     2014-05                   0.082768                   0.038185
# ..        ...                        ...                        ...
# 115   2023-08                  -0.034912                  -0.001867
# 116   2023-09                  -0.114007                  -0.063248
# 117   2023-10                   0.171111                   0.103980
# 118   2023-11                   0.167891                   0.094640
# 119   2023-12                  -0.021779                  -0.027638
#
#      portfolio_hat_exc_ret_eq  portfolio_hat_exc_ret_mc  \
# 0                    0.290515                  0.250763
# 1                    0.236632                  0.221984
# 2                    0.215482                  0.211284
# 3                    0.186883                  0.280444
# 4                    0.192973                  0.259731
# ..                        ...                       ...
# 115                  4.523595                  1.204419
# 116                  5.250590                  1.459821
# 117                  7.338184                  1.810694
# 118                  7.761237                  1.722291
# 119                  9.142448                  1.518102
#
#      portfolio_true_ret_eq  portfolio_true_ret_mc  Decile rank  MonthIndex
# 0                 0.114236               0.029952            9           1
# 1                 0.083094               0.036842            9           2
# 2                 0.037411               0.014702            9           3
# 3                 0.049981               0.023544            9           4
# 4                 0.085310               0.040727            9           5
# ..                     ...                    ...          ...         ...
# 115              -0.031253               0.001791            9         116
# 116              -0.109907              -0.059148            9         117
# 117               0.175453               0.108322            9         118
# 118               0.171824               0.098573            9         119
# 119              -0.018279              -0.024138            9         120
#
# [120 rows x 9 columns]

# %% [markdown]
# Pr. vores finansieringsbog, så gælder: "For any portfolio, P, we define the Sharpe-ratio as excess return relative to standard deviation", jf. S. 57, "Finance 1 and Beyond":
#
# $$Sharpe-ratio^P = \frac{er^P_{t+1}}{\sigma_R^P}$$

# %%
#Find Sharpe-ratio of each decile rank dataframe:

for decile_key, portfolio_df in portfolio_returns2.items():
    
    # Calculate average of the true portfolio excess return
    mean_ER_true_eq = portfolio_df['portfolio_true_exc_ret_eq'].mean()
    mean_ER_true_mc = portfolio_df['portfolio_true_exc_ret_mc'].mean()
    
    # Calculate average of the predicted portfolio excess return
    mean_ER_pred_eq = portfolio_df['portfolio_hat_exc_ret_eq'].mean()
    mean_ER_pred_mc = portfolio_df['portfolio_hat_exc_ret_mc'].mean()
    
    # Calculate standard deviation of the true portfolio excess returns
    std_R_true_eq = portfolio_df['portfolio_true_ret_eq'].std()
    std_R_true_mc = portfolio_df['portfolio_true_ret_mc'].std()
    
    # Calculate annualized Sharpe ratio of the true excess returns
    sharpe_ratio_eq = (mean_ER_true_eq / std_R_true_eq) * np.sqrt(12)
    sharpe_ratio_mc = (mean_ER_true_mc / std_R_true_mc) * np.sqrt(12)
    
   
    portfolio_df['Mean_true_ER_eq'] = mean_ER_true_eq
    portfolio_df['Mean_true_ER_mc'] = mean_ER_true_mc
    portfolio_df['Mean_pred_ER_eq'] = mean_ER_pred_eq
    portfolio_df['Mean_pred_ER_mc'] = mean_ER_pred_mc
    portfolio_df['Std_true_ER_eq'] = std_R_true_eq
    portfolio_df['Std_true_ER_mc'] = std_R_true_mc
    portfolio_df['Sharpe_ratio_eq'] = sharpe_ratio_eq
    portfolio_df['Sharpe_ratio_mc'] = sharpe_ratio_mc
    

    portfolio_returns2[decile_key] = portfolio_df

# %% [markdown]
# # Zero-net-investment long-short portfolios

# %% [markdown]
# At shorte en aktie betyder at du låner aktier, som du vælger at sælge, fordi du forudsiger at de vil falde i pris og dermed kan du købe dem billiger og tjene differencen. At longe en aktie betyder at du køber en aktie, fordi du forventer den stiger i pris og dermed kan tjene differencen. Derfor vil man ifølge zero-net-investment teorien bruge alle ens penge på long-investment, hvor pengene kommer af de aktier man lige har shortet. Dvs. til tid 0 skal ens portefølje have følgende værdi:
#
# $$\sum_{i = 1}^N w_i \cdot P^{long}_{i,0} - \sum_{j = 1}^M w_j \cdot P^{short}_{j,0} = 0$$
# Her vælges vægtene for både short- og long-aktierne som før, hvor summen af alle vægte skal være 1. Afkastet for zero-net-investment er dermed til tid t givet ved:
#
# $$\sum_{i = 1}^N w_i \cdot P^{long}_{i,t} - \sum_{j = 1}^M w_j \cdot P^{short}_{j,t} = profit$$

# %%
# Create the tables that show the performance of the machine learning portfolios

long_df = portfolio_returns2['decile_rank_9'].copy()
short_df = portfolio_returns2['decile_rank_0'].copy()

long_df['Investment type'] = 'long'
short_df['Investment type'] = 'short'


calc_df = pd.merge(long_df, short_df, on='MonthIndex', suffixes=('_long', '_short'))

# %%
# Calculate zero-net investment excess returns
calc_df['true_ER_zni_eq'] = calc_df['portfolio_true_exc_ret_eq_long'] - calc_df['portfolio_true_exc_ret_eq_short']
calc_df['true_ER_zni_mc'] = calc_df['portfolio_true_exc_ret_mc_long'] - calc_df['portfolio_true_exc_ret_mc_short']
calc_df['pred_ER_zni_eq'] = calc_df['portfolio_hat_exc_ret_eq_long'] - calc_df['portfolio_hat_exc_ret_eq_short']
calc_df['pred_ER_zni_mc'] = calc_df['portfolio_hat_exc_ret_mc_long'] - calc_df['portfolio_hat_exc_ret_mc_short']

# Calculate the means
mean_true_ER_zni_eq = calc_df['true_ER_zni_eq'].mean()
mean_true_ER_zni_mc = calc_df['true_ER_zni_mc'].mean()

mean_pred_ER_zni_eq = calc_df['pred_ER_zni_eq'].mean()
mean_pred_ER_zni_mc = calc_df['pred_ER_zni_mc'].mean()

# # Calculate zero-net investment returns that we need for Sharpe ratio
calc_df['true_R_zni_eq'] = calc_df['portfolio_true_ret_eq_long'] - calc_df['portfolio_true_ret_eq_short']
calc_df['true_R_zni_mc'] = calc_df['portfolio_true_ret_mc_long'] - calc_df['portfolio_true_ret_mc_short']


std_true_R_zni_eq = calc_df['true_R_zni_eq'].std()
std_true_R_zni_mc = calc_df['true_R_zni_mc'].std()

# Sharpe ratio
sharpe_ratio_eq_zni = (mean_true_ER_zni_eq / std_true_R_zni_eq) * np.sqrt(12)
sharpe_ratio_mc_zni = (mean_true_ER_zni_mc / std_true_R_zni_mc) * np.sqrt(12)

# %%
calc_df
# Out:
#     MonthYear_long  portfolio_true_exc_ret_eq_long  \
# 0          2014-01                        0.111444
# 1          2014-02                        0.080336
# 2          2014-03                        0.034653
# 3          2014-04                        0.047298
# 4          2014-05                        0.082768
# ..             ...                             ...
# 115        2023-08                       -0.034912
# 116        2023-09                       -0.114007
# 117        2023-10                        0.171111
# 118        2023-11                        0.167891
# 119        2023-12                       -0.021779
#
#      portfolio_true_exc_ret_mc_long  portfolio_hat_exc_ret_eq_long  \
# 0                          0.027160                       0.290515
# 1                          0.034084                       0.236632
# 2                          0.011943                       0.215482
# 3                          0.020860                       0.186883
# 4                          0.038185                       0.192973
# ..                              ...                            ...
# 115                       -0.001867                       4.523595
# 116                       -0.063248                       5.250590
# 117                        0.103980                       7.338184
# 118                        0.094640                       7.761237
# 119                       -0.027638                       9.142448
#
#      portfolio_hat_exc_ret_mc_long  portfolio_true_ret_eq_long  \
# 0                         0.250763                    0.114236
# 1                         0.221984                    0.083094
# 2                         0.211284                    0.037411
# 3                         0.280444                    0.049981
# 4                         0.259731                    0.085310
# ..                             ...                         ...
# 115                       1.204419                   -0.031253
# 116                       1.459821                   -0.109907
# 117                       1.810694                    0.175453
# 118                       1.722291                    0.171824
# 119                       1.518102                   -0.018279
#
#      portfolio_true_ret_mc_long  Decile rank_long  MonthIndex  \
# 0                      0.029952                 9           1
# 1                      0.036842                 9           2
# 2                      0.014702                 9           3
# 3                      0.023544                 9           4
# 4                      0.040727                 9           5
# ..                          ...               ...         ...
# 115                    0.001791                 9         116
# 116                   -0.059148                 9         117
# 117                    0.108322                 9         118
# 118                    0.098573                 9         119
# 119                   -0.024138                 9         120
#
#      Mean_true_ER_eq_long  ...  Std_true_ER_mc_short  Sharpe_ratio_eq_short  \
# 0                0.143775  ...              0.059524              -1.854026
# 1                0.143775  ...              0.059524              -1.854026
# 2                0.143775  ...              0.059524              -1.854026
# 3                0.143775  ...              0.059524              -1.854026
# 4                0.143775  ...              0.059524              -1.854026
# ..                    ...  ...                   ...                    ...
# 115              0.143775  ...              0.059524              -1.854026
# 116              0.143775  ...              0.059524              -1.854026
# 117              0.143775  ...              0.059524              -1.854026
# 118              0.143775  ...              0.059524              -1.854026
# 119              0.143775  ...              0.059524              -1.854026
#
#      Sharpe_ratio_mc_short  Investment type_short  true_ER_zni_eq  \
# 0                -0.836018                  short        0.068514
# 1                -0.836018                  short        0.149049
# 2                -0.836018                  short        0.129249
# 3                -0.836018                  short        0.080610
# 4                -0.836018                  short        0.060913
# ..                     ...                    ...             ...
# 115              -0.836018                  short        0.046201
# 116              -0.836018                  short       -0.014615
# 117              -0.836018                  short        0.106973
# 118              -0.836018                  short        0.083580
# 119              -0.836018                  short        0.026310
#
#      true_ER_zni_mc  pred_ER_zni_eq pred_ER_zni_mc true_R_zni_eq  \
# 0         -0.009581        0.364723       0.345645      0.068514
# 1          0.036560        0.328794       0.342109      0.149049
# 2          0.019608        0.301580       0.337109      0.129249
# 3          0.019950        0.277656       0.359629      0.080610
# 4          0.027862        0.298491       0.346257      0.060913
# ..              ...             ...            ...           ...
# 115        0.014806        4.769094       1.468497      0.046201
# 116       -0.005810        5.495667       1.722154     -0.014615
# 117        0.034468        7.582577       2.072693      0.106973
# 118        0.042561        8.008835       1.988329      0.083580
# 119       -0.007716        9.381841       1.778119      0.026310
#
#      true_R_zni_mc
# 0        -0.009581
# 1         0.036560
# 2         0.019608
# 3         0.019950
# 4         0.027862
# ..             ...
# 115       0.014806
# 116      -0.005810
# 117       0.034468
# 118       0.042561
# 119      -0.007716
#
# [120 rows x 41 columns]

# %%
performance_data = []

for i in range(10):
    decile_key = f'decile_rank_{i}'
    decile_df = portfolio_returns2[decile_key]
    
    mean_pred_ER_eq = decile_df['Mean_pred_ER_eq'].iloc[0]
    mean_true_ER_eq = decile_df['Mean_true_ER_eq'].iloc[0]
    std_true_ER_eq = decile_df['Std_true_ER_eq'].iloc[0]
    sharpe_ratio_eq = decile_df['Sharpe_ratio_eq'].iloc[0]
    
    performance_data.append([mean_pred_ER_eq, mean_true_ER_eq, std_true_ER_eq, sharpe_ratio_eq])

# The zero-net-investments caluclations will be used as H-L row
performance_data.append([mean_pred_ER_zni_eq, mean_true_ER_zni_eq, std_true_R_zni_eq, sharpe_ratio_eq_zni])


columns = ['Pred Avg', 'True Avg', 'SD', 'SR']
index = ['Low(L)', '1', '2', '3', '4', '5', '6', '7', '8', 'High(H)', 'H-L']

ML_performance_eq_table = pd.DataFrame(performance_data, columns=columns, index=index)

# %%
ML_performance_eq_table
# Out:
#          Pred Avg  True Avg        SD        SR
# Low(L)  -0.151312 -0.039728  0.074228 -1.854026
# 1       -0.066743 -0.026542  0.063424 -1.449672
# 2       -0.043950 -0.015060  0.057937 -0.900432
# 3       -0.028577 -0.006407  0.054188 -0.409578
# 4       -0.016131  0.000634  0.050897  0.043168
# 5       -0.004580  0.008581  0.050969  0.583216
# 6        0.007520  0.015907  0.052330  1.053009
# 7        0.023605  0.027946  0.056971  1.699263
# 8        0.063712  0.039731  0.066852  2.058726
# High(H)  8.189952  0.143775  0.421309  1.182153
# H-L      8.341264  0.183503  0.408375  1.556588

# %%
performance_data = []

for i in range(10):
    decile_key = f'decile_rank_{i}'
    decile_df = portfolio_returns2[decile_key]
    
    mean_pred_ER_mc = decile_df['Mean_pred_ER_mc'].iloc[0]
    mean_true_ER_mc = decile_df['Mean_true_ER_mc'].iloc[0]
    std_true_ER_mc = decile_df['Std_true_ER_mc'].iloc[0]
    sharpe_ratio_mc = decile_df['Sharpe_ratio_mc'].iloc[0]
    
    performance_data.append([mean_pred_ER_mc, mean_true_ER_mc, std_true_ER_mc, sharpe_ratio_mc])

# The zero-net-investments caluclations will be used as H-L row
performance_data.append([mean_pred_ER_zni_mc, mean_true_ER_zni_mc, std_true_R_zni_mc, sharpe_ratio_mc_zni])

columns = ['Pred Avg', 'True Avg', 'SD', 'SR']
index = ['Low(L)', '1', '2', '3', '4', '5', '6', '7', '8', 'High(H)', 'H-L']

ML_performance_mc_table = pd.DataFrame(performance_data, columns=columns, index=index)

# %%
ML_performance_mc_table
# Out:
#          Pred Avg      True Avg        SD        SR
# Low(L)  -0.168000 -1.436536e-02  0.059524 -0.836018
# 1       -0.066585 -9.415753e-03  0.055202 -0.590870
# 2       -0.044027 -6.947219e-03  0.050618 -0.475445
# 3       -0.028476 -8.249941e-07  0.046333 -0.000062
# 4       -0.016092  4.156774e-03  0.044600  0.322855
# 5       -0.004646  1.062561e-02  0.044366  0.829644
# 6        0.007480  1.689265e-02  0.046078  1.269984
# 7        0.023238  2.737744e-02  0.048855  1.941234
# 8        0.061673  3.296614e-02  0.052772  2.163975
# High(H)  0.490182  3.006154e-02  0.065626  1.586819
# H-L      0.658182  4.442690e-02  0.042982  3.580537

# %%
ML_performance_eq_table.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/ML_Sharpe_results/NN4_eq.csv")
ML_performance_mc_table.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/ML_Sharpe_results/NN4_mc.csv")

# %% [markdown]
# # The second table of the machine learning portfolios performance

# %% [markdown]
# Maximum drawdown er i artiklen defineret ved:
#
# $$MaxDD = \max _{0 \leq t_{1} \leq t_{2} \leq T}\left(Y_{t_{1}}-Y_{t_{2}}\right),  $$
# hvor $Y_t$ er den akkumulerede log afkast givet ved:
#
# $$ r = \log\left(\prod_{i = 1}^{n}(1+r_i) \right)$$
#
# $$ = \sum_{i = 1}^{n} \log \left( 1+r_i \right), $$
# hvor n er antallet af porteføljer

# %%
# Calculate the maximum drawdown
def max_dd(returns):
    
    draw_downs = []
    exc_ret = returns.copy()
    
    # Calculate cumulative log excess returns
    exc_ret = np.log(1 + exc_ret).cumsum()
    
    
    peak = exc_ret.iloc[0]
    
    for i in range(1, len(exc_ret)):
        current = exc_ret.iloc[i]
        
        if current > peak:
            peak = current  
        else:
            drawdown = peak - current  
            draw_downs.append(drawdown)
    
    if draw_downs:
        max_drawdown = max(draw_downs)
    else:
        max_drawdown = 0  # In the off chance the stock is ever increasing
    
    return max_drawdown

maxdd_eq = max_dd(calc_df['true_ER_zni_eq'])
maxdd_mc = max_dd(calc_df['true_ER_zni_mc'])


maxdd_eq_pct = maxdd_eq * 100
maxdd_mc_pct = maxdd_mc * 100

print("MaxDD EQ: ", maxdd_eq_pct)
print("MaxDD MC: ", maxdd_mc_pct)
# Out:
# MaxDD EQ:  1.4723034519629863
# MaxDD MC:  4.973295691979551

# %% [markdown]
# # Max 1M loss
# I artiklen defineret som den mest extreme, negative månedlige afkast.

# %%
max_1m_loss_eq_pct = calc_df['true_ER_zni_eq'].min()*(-100)
max_1m_loss_mc_pct = calc_df['true_ER_zni_mc'].min()*(-100)

print("Max 1M EQ: ", max_1m_loss_eq_pct)
print("Max 1M MC: ", max_1m_loss_mc_pct)
# Out:
# Max 1M EQ:  1.461518060797172
# Max 1M MC:  4.8516522343727235

# %% [markdown]
# # Turnover
#
# I artiklen er turnover defineret ved:
#
# $$ \frac{1}{T} \sum_{t = 1}^T \left(\sum_{i = 1}^n   \bigg| w_{i,t+1} - \frac{w_{i,t}(1+r_{i,t+1})}{1+ \sum_{j = 1}^n  w_{j,t} \cdot r_{j,t+1}}  \bigg|  \right)  $$

# %%
# Get the t+1 weights for both eq and mc weights:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['Symbol', 'MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Create next month's weights for eq_weights and mc_weights, and if they dont exist set to 0
    decile_dfs_value['eq_weights_t+1'] = decile_dfs_value.groupby('Symbol')['eq_weights'].shift(-1).fillna(0)
    decile_dfs_value['mc_weights_t+1'] = decile_dfs_value.groupby('Symbol')['mc_weights'].shift(-1).fillna(0)

    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
def turnover(long_df, short_df, weight_t0, weight_t1, exc_ret_t1):
    turnover_each_month = []
    
    # Combine long and short portfolios into one portfolio
    zero_net = pd.concat([long_df, short_df], ignore_index=True)
    
    zero_net.sort_values(['MonthYear'], inplace=True)
    zero_net.reset_index(drop=True, inplace=True)
    
    months = zero_net['MonthYear'].unique()
    
    for t in months[:-1]:  # Exclude the last month since it has no t+1 weights
        
        current_month = zero_net[zero_net['MonthYear'] == t]
        
        # Calculate the denominator for month t
        denominator = 1 + (current_month[weight_t0] * current_month[exc_ret_t1]).sum()
        
        # Calculate the turnover for each stock
        current_month['fraction'] = (
            current_month[weight_t0] * (1 + current_month[exc_ret_t1]) / denominator
        )
        current_month['abs_diff'] = abs(
            current_month[weight_t1] - current_month['fraction']
        )
        
        # Sum the absolute differences for month t
        turnover_each_month.append(current_month['abs_diff'].sum())
    
    # Calculate the average turnover across all months
    turnover = sum(turnover_each_month) / len(turnover_each_month)
    return turnover

# %%
long_df = decile_dataframes['decile_rank_9']
short_df = decile_dataframes['decile_rank_0']


weight_eq = 'eq_weights'
weight_t1_eq = 'eq_weights_t+1'
exc_ret_t1 = 'exc_ret_t+1_true'

turnover_eq = turnover(long_df, short_df, weight_eq, weight_t1_eq, exc_ret_t1)


weight_mc = 'mc_weights'
weight_t1_mc = 'mc_weights_t+1'
exc_ret_t1 = 'exc_ret_t+1_true'

turnover_mc = turnover(long_df, short_df, weight_mc, weight_t1_mc, exc_ret_t1)


turnover_eq_pct = turnover_eq*100
turnover_mc_pct = turnover_mc*100

print("Turnover EQ: ", turnover_eq_pct)
print("Turnover MC: ", turnover_mc_pct)
# Out:
# Turnover EQ:  47.3164000361802
# Turnover MC:  57.46354945329457

# %%
eq_table_OLS = pd.DataFrame({
    "NN4" : [maxdd_eq_pct,
                max_1m_loss_eq_pct,
                turnover_eq_pct
                ]
})


eq_table_OLS.index = ['Max DD(%)', "Max 1M loss(%)", "Turnover(%)"]

# %%
eq_table_OLS
# Out:
#                       NN4
# Max DD(%)        1.472303
# Max 1M loss(%)   1.461518
# Turnover(%)     47.316400

# %%
mc_table_OLS = pd.DataFrame({
    "NN4" : [maxdd_mc_pct,
                max_1m_loss_mc_pct,
                turnover_mc_pct
                ]
})


mc_table_OLS.index = ['Max DD(%)', "Max 1M loss(%)", "Turnover(%)"]

# %%
mc_table_OLS
# Out:
#                       NN4
# Max DD(%)        4.973296
# Max 1M loss(%)   4.851652
# Turnover(%)     57.463549

# %%
eq_table_OLS.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/ML Performance tables/NN4_eq.csv")
mc_table_OLS.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/ML Performance tables/NN4_mc.csv")

# %% [markdown]
# # Cumulative log returns of portfolio rank 0 and 9

# %%
calc_df
# Out:
#     MonthYear_long  portfolio_true_exc_ret_eq_long  \
# 0          2014-01                        0.111444
# 1          2014-02                        0.080336
# 2          2014-03                        0.034653
# 3          2014-04                        0.047298
# 4          2014-05                        0.082768
# ..             ...                             ...
# 115        2023-08                       -0.034912
# 116        2023-09                       -0.114007
# 117        2023-10                        0.171111
# 118        2023-11                        0.167891
# 119        2023-12                       -0.021779
#
#      portfolio_true_exc_ret_mc_long  portfolio_hat_exc_ret_eq_long  \
# 0                          0.027160                       0.290515
# 1                          0.034084                       0.236632
# 2                          0.011943                       0.215482
# 3                          0.020860                       0.186883
# 4                          0.038185                       0.192973
# ..                              ...                            ...
# 115                       -0.001867                       4.523595
# 116                       -0.063248                       5.250590
# 117                        0.103980                       7.338184
# 118                        0.094640                       7.761237
# 119                       -0.027638                       9.142448
#
#      portfolio_hat_exc_ret_mc_long  portfolio_true_ret_eq_long  \
# 0                         0.250763                    0.114236
# 1                         0.221984                    0.083094
# 2                         0.211284                    0.037411
# 3                         0.280444                    0.049981
# 4                         0.259731                    0.085310
# ..                             ...                         ...
# 115                       1.204419                   -0.031253
# 116                       1.459821                   -0.109907
# 117                       1.810694                    0.175453
# 118                       1.722291                    0.171824
# 119                       1.518102                   -0.018279
#
#      portfolio_true_ret_mc_long  Decile rank_long  MonthIndex  \
# 0                      0.029952                 9           1
# 1                      0.036842                 9           2
# 2                      0.014702                 9           3
# 3                      0.023544                 9           4
# 4                      0.040727                 9           5
# ..                          ...               ...         ...
# 115                    0.001791                 9         116
# 116                   -0.059148                 9         117
# 117                    0.108322                 9         118
# 118                    0.098573                 9         119
# 119                   -0.024138                 9         120
#
#      Mean_true_ER_eq_long  ...  Std_true_ER_mc_short  Sharpe_ratio_eq_short  \
# 0                0.143775  ...              0.059524              -1.854026
# 1                0.143775  ...              0.059524              -1.854026
# 2                0.143775  ...              0.059524              -1.854026
# 3                0.143775  ...              0.059524              -1.854026
# 4                0.143775  ...              0.059524              -1.854026
# ..                    ...  ...                   ...                    ...
# 115              0.143775  ...              0.059524              -1.854026
# 116              0.143775  ...              0.059524              -1.854026
# 117              0.143775  ...              0.059524              -1.854026
# 118              0.143775  ...              0.059524              -1.854026
# 119              0.143775  ...              0.059524              -1.854026
#
#      Sharpe_ratio_mc_short  Investment type_short  true_ER_zni_eq  \
# 0                -0.836018                  short        0.068514
# 1                -0.836018                  short        0.149049
# 2                -0.836018                  short        0.129249
# 3                -0.836018                  short        0.080610
# 4                -0.836018                  short        0.060913
# ..                     ...                    ...             ...
# 115              -0.836018                  short        0.046201
# 116              -0.836018                  short       -0.014615
# 117              -0.836018                  short        0.106973
# 118              -0.836018                  short        0.083580
# 119              -0.836018                  short        0.026310
#
#      true_ER_zni_mc  pred_ER_zni_eq pred_ER_zni_mc true_R_zni_eq  \
# 0         -0.009581        0.364723       0.345645      0.068514
# 1          0.036560        0.328794       0.342109      0.149049
# 2          0.019608        0.301580       0.337109      0.129249
# 3          0.019950        0.277656       0.359629      0.080610
# 4          0.027862        0.298491       0.346257      0.060913
# ..              ...             ...            ...           ...
# 115        0.014806        4.769094       1.468497      0.046201
# 116       -0.005810        5.495667       1.722154     -0.014615
# 117        0.034468        7.582577       2.072693      0.106973
# 118        0.042561        8.008835       1.988329      0.083580
# 119       -0.007716        9.381841       1.778119      0.026310
#
#      true_R_zni_mc
# 0        -0.009581
# 1         0.036560
# 2         0.019608
# 3         0.019950
# 4         0.027862
# ..             ...
# 115       0.014806
# 116      -0.005810
# 117       0.034468
# 118       0.042561
# 119      -0.007716
#
# [120 rows x 41 columns]

# %%
long_df = calc_df.copy()


long_df = long_df.set_index("MonthYear_long")
long_df.sort_values(['MonthYear_long'], inplace = True)


long_df['true_exc_ret_eq_t'] = long_df['portfolio_true_exc_ret_eq_long'].shift(1)


long_df['cum_log_exc_ret_eq_long'] =(np.log(1 + long_df['true_exc_ret_eq_t'])).cumsum()

long_df['cum_log_exc_ret_eq_long'].iloc[0] = 0


long_df[['cum_log_exc_ret_eq_long']].plot(grid=True, figsize=(12, 7))
# Out:
# <Axes: xlabel='MonthYear_long'>

# %%
long_df = calc_df.copy()


long_df = long_df.set_index("MonthYear_long")
long_df.sort_values(['MonthYear_long'], inplace = True)


long_df['true_exc_ret_mc_t'] = long_df['portfolio_true_exc_ret_mc_long'].shift(1)


long_df['cum_log_exc_ret_mc_long'] =(np.log(1 + long_df['true_exc_ret_mc_t'])).cumsum()

long_df['cum_log_exc_ret_mc_long'].iloc[0] = 0

long_df[['cum_log_exc_ret_mc_long']].plot(grid=True, figsize=(12, 7))
# Out:
# <Axes: xlabel='MonthYear_long'>

# %%
short_df = calc_df.copy()


short_df = long_df.set_index("MonthYear_short")
short_df.sort_values(['MonthYear_short'], inplace = True)


short_df['true_exc_ret_eq_t'] = short_df['portfolio_true_exc_ret_eq_short'].shift(1)


short_df['cum_log_exc_ret_eq_short'] = (np.log(1 + short_df['true_exc_ret_eq_t'])).cumsum()

short_df['cum_log_exc_ret_eq_short'].iloc[0] = 0


short_df[['cum_log_exc_ret_eq_short']].plot(grid=True, figsize=(12, 7))
# Out:
# <Axes: xlabel='MonthYear_short'>

# %%
short_df = calc_df.copy()


short_df = long_df.set_index("MonthYear_short")
short_df.sort_values(['MonthYear_short'], inplace = True)


short_df['true_exc_ret_mc_t'] = short_df['portfolio_true_exc_ret_mc_short'].shift(1)


short_df['cum_log_exc_ret_mc_short'] = (np.log(1 + short_df['true_exc_ret_mc_t'])).cumsum()

short_df['cum_log_exc_ret_mc_short'].iloc[0] = 0


short_df[['cum_log_exc_ret_mc_short']].plot(grid=True, figsize=(12, 7))
# Out:
# <Axes: xlabel='MonthYear_short'>

# %%
long_short_OLS_eq = pd.merge(long_df[['cum_log_exc_ret_eq_long']], short_df[['cum_log_exc_ret_eq_short']],left_index=True, right_index=True)


long_short_OLS_eq[["cum_log_exc_ret_eq_long", "cum_log_exc_ret_eq_short"]].plot(grid=True,figsize=(12, 5))
# Out:
# <Axes: xlabel='MonthYear_long'>

# %%
long_short_OLS_eq.to_csv(r'C:/Users/CMert/Documents/Data bachelorprojekt/ML grafer/NN4 eq.csv')

# %%
long_short_OLS_mc = pd.merge(long_df[['cum_log_exc_ret_mc_long']], short_df[['cum_log_exc_ret_mc_short']],left_index=True, right_index=True)


long_short_OLS_mc[["cum_log_exc_ret_mc_long", "cum_log_exc_ret_mc_short"]].plot(grid=True,figsize=(12, 5))
# Out:
# <Axes: xlabel='MonthYear_long'>

# %%
long_short_OLS_mc.to_csv(r'C:/Users/CMert/Documents/Data bachelorprojekt/ML grafer/NN4 mc.csv')

# %% [markdown]
# # Graveyard
