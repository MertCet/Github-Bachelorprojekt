# %% [markdown]
# # Prepartions

# %%
import numpy as np
import pandas as pd
from dateutil.relativedelta import relativedelta
from sklearn.linear_model import HuberRegressor
import warnings
warnings.simplefilter(action='ignore', category=Warning)
import matplotlib.pyplot as plt
from sklearn.linear_model import ElasticNet
import matplotlib.dates as mdates
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import ParameterGrid
from datetime import datetime
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid
from joblib import Parallel, delayed
from sklearn.ensemble import RandomForestRegressor
import gc
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

# %%
df_final = pd.read_csv("C:/Users/CMert/Documents/Data bachelorprojekt/The complete dataframe/df_final_cleaned_combined_2_endofmonth.csv")

df_final['Adj Close t+1'] = df_final.groupby("Symbol")["Adj Close"].shift(-1)

df_final = df_final.dropna(subset=['Adj Close t+1']).reset_index(drop=True)

df_final = df_final[df_final['1-month momentum'] != 0]

df_final['Date'] = pd.to_datetime(df_final['Date'])

df_final = df_final.sort_values(by='Date').reset_index(drop=True)

df_final = df_final[df_final['Adj Close t+1'] <= df_final["Adj Close t+1"].quantile(0.985)]



variables = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Dividends',
       'Stock Splits', 'Market capitalization', 'Revenue', 'Earnings',
       'P/E ratio', 'P/B ratio', 'Operating Margin', 'EPS',
       'Shares Outstanding', 'Total assets', 'Total liabilities', 'Total debt',
       'Cash on Hand', 'Net assets', '1-month momentum', '6-month momentum',
       '12-month momentum', '36-month momentum', 'Book-to-market', 'Size']

df_final[variables] = df_final[variables].replace([np.inf, -np.inf], np.nan)

non_negative_variables = [
    'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Dividends',
    'Stock Splits', 'Market capitalization', 'Revenue', 'EPS',
    'Shares Outstanding', 'Total assets', 'Total liabilities', 'Total debt',
    'Cash on Hand', 'Net assets'
]

df_final[non_negative_variables] = df_final[non_negative_variables].applymap(lambda x: max(x, 0))


funda_cols = [
    'Market capitalization', 'Revenue', 'Earnings', 'P/E ratio', 'P/B ratio',
    'Operating Margin', 'EPS', 'Shares Outstanding', 'Total assets',
    'Total liabilities', 'Total debt', 'Cash on Hand', 'Net assets'
]

df_final[funda_cols] = (
    df_final.groupby('Symbol')[funda_cols]
      .shift(12))

df_final = df_final.dropna(subset=variables).reset_index(drop=True)

# %%
df_final
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# 0      1997-02-28   0.150670   0.150670   0.145089   0.145089   0.122524
# 1      1997-02-28   6.937500   6.937500   6.812500   6.812500   2.242910
# 2      1997-02-28  39.187500  39.312500  38.375000  39.312500  32.637779
# 3      1997-02-28  10.625000  10.937500  10.562500  10.875000  10.332757
# 4      1997-02-28  31.500000  31.500000  30.687500  30.687500   9.806581
# ...           ...        ...        ...        ...        ...        ...
# 711296 2024-08-30  38.150002  38.590000  37.830002  38.580002  38.580002
# 711297 2024-08-30  30.900000  31.200001  30.209999  30.440001  30.440001
# 711298 2024-08-30   6.690000   6.880000   6.670000   6.860000   6.860000
# 711299 2024-08-30  51.099998  51.250000  49.590000  50.919998  50.919998
# 711300 2024-08-30   8.060000   8.110000   7.820000   7.860000   7.860000
#
#              Volume  Dividends  Stock Splits                  Sector  ...  \
# 0       121878400.0        0.0           0.0              Technology  ...
# 1            9400.0        0.0           0.0  Consumer Discretionary  ...
# 2          494200.0        0.0           0.0                 Finance  ...
# 3          159200.0        0.0           0.0              Technology  ...
# 4           22000.0        0.0           0.0                 Finance  ...
# ...             ...        ...           ...                     ...  ...
# 711296     539900.0        0.0           0.0               Utilities  ...
# 711297    2364900.0        0.0           0.0  Consumer Discretionary  ...
# 711298    4055300.0        0.0           0.0              Technology  ...
# 711299    1494400.0        0.0           0.0              Technology  ...
# 711300     199800.0        0.0           0.0             Health Care  ...
#
#         Cash on Hand    Net assets  1-month momentum  6-month momentum  \
# 0       1.740000e+09  0.000000e+00         -0.002828          0.006597
# 1       4.700000e+06  8.849816e+07         -0.022543          0.019197
# 2       1.400000e+08  2.293864e+09          2.040556         13.065813
# 3       5.300000e+06  9.747199e+07         -1.425210          6.354053
# 4       6.967000e+07  0.000000e+00          1.078525          3.761210
# ...              ...           ...               ...               ...
# 711296  2.700000e+08  3.020000e+09         -1.464996          3.577999
# 711297  6.953566e+08  1.731511e+09          1.089708          0.321186
# 711298  3.700000e+08  5.990000e+09          0.120000          0.380000
# 711299  3.700000e+08  1.760000e+09         -1.520000         14.780001
# 711300  4.457000e+07  4.612000e+07         -1.140000          5.860001
#
#         12-month momentum  36-month momentum  Book-to-market       Size  \
# 0                0.012723           0.102261       10.516756   0.000000
# 1                0.394677           1.072677        0.668527  18.906044
# 2               25.626753           3.814121        0.645497  22.474418
# 3                6.057135           5.700832        0.062723  19.351977
# 4                6.900859           4.914822        0.355534  21.321768
# ...                   ...                ...             ...        ...
# 711296           5.195873          -2.139236        0.021338  21.436014
# 711297          15.223827          30.727109        0.105255  22.685456
# 711298          -3.950000          13.850000        0.341980  21.832332
# 711299           4.780000          -2.470000       -0.115780  20.748237
# 711300           6.630000           4.153260        0.060806  17.925572
#
#         Symbol  Adj Close t+1
# 0         AAPL       0.137604
# 1          SGC       2.140023
# 2          MTG      29.368822
# 3         NICE       9.738921
# 4          MCY       9.791734
# ...        ...            ...
# 711296     WES      38.299999
# 711297    HTHT      29.340000
# 711298    CLVT       6.550000
# 711299     CLS      43.490002
# 711300    ZYXI       7.960000
#
# [711301 rows x 32 columns]

# %% [markdown]
# # The sampling algorithm

# %%
def recursive_rolling_method(data, initial_date, date_column='Date', 
         train_period = 24, val_period = 24, test_period = 12, freq = 'months'):
    
                
    train_indices_list = []
    val_indices_list = []
    test_indices_list = []

    
    # Define initial interval
    start_train = initial_date
    end_train = start_train + relativedelta(**{freq: train_period})
    
    start_val = end_train + relativedelta(months=1)
    end_val = start_val + relativedelta(**{freq: val_period})
    
    start_test = end_val + relativedelta(months=1)
    end_test = start_test + relativedelta(**{freq: test_period})

    
    while start_test  < data[date_column].max():   
        cur_train_indices = list(data[(data[date_column] >= start_train) & 
                              (data[date_column] < end_train)].index)

        cur_val_indices = list(data[(data[date_column] >= start_val) & 
                                    (data[date_column] < end_val)].index)

        cur_test_indices = list(data[(data[date_column] >= start_test) & 
                                    (data[date_column] < end_test)].index)

        
        print("    Train period:",start_train, "-" , end_train, 
            " || Val period:",start_val, "-" , end_val, 
            " || Test period", start_test, "-", end_test,
            " || Train contains", len(cur_train_indices),
            " || Val contains", len(cur_val_indices) , 
            " || Test contains", len(cur_test_indices))

        train_indices_list.append(cur_train_indices)
        val_indices_list.append(cur_val_indices)
        test_indices_list.append(cur_test_indices)
        
        
        # Define next interval
        
        filler_unit = 1
        start_train = start_train + relativedelta(**{freq: filler_unit}) #  -  this only goes one period ahead for each interval, so they overlap
        
        # start_train = end_test
        end_train = start_train + relativedelta(**{freq: train_period})  
        
        start_val = end_train + relativedelta(months=1)
        end_val = start_val + relativedelta(**{freq: val_period})
            
        start_test = end_val + relativedelta(months=1)
        end_test = start_test + relativedelta(**{freq: test_period})

    # Ensure we have the same output as sklearn sampling packages, since we will use its regressors
    index_output = [(train,val,test) for train,val,test in zip(train_indices_list,val_indices_list,test_indices_list)]
    
    return index_output

# %%
# Create the top and bottom firms by market cap:

top_symbols = (
    df_final.groupby('Symbol')['Market capitalization'].last() 
    .nlargest(500)  
    .index 
)


df_top_500 = df_final[df_final['Symbol'].isin(top_symbols)].reset_index(drop=True)



bottom_symbols = (
    df_final.groupby('Symbol')['Market capitalization'].last() 
    .nsmallest(500)  
    .index 
)


df_bottom_500 = df_final[df_final['Symbol'].isin(bottom_symbols)].reset_index(drop=True)

# %%
df_final.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Dividends', 'Stock Splits', 'Sector', 'Industry',
#        'Market capitalization', 'Revenue', 'Earnings', 'P/E ratio',
#        'P/B ratio', 'Operating Margin', 'EPS', 'Shares Outstanding',
#        'Total assets', 'Total liabilities', 'Total debt', 'Cash on Hand',
#        'Net assets', '1-month momentum', '6-month momentum',
#        '12-month momentum', '36-month momentum', 'Book-to-market', 'Size',
#        'Symbol', 'Adj Close t+1'],
#       dtype='object')

# %% [markdown]
# # NN3 algorithm for all stocks

# %%
X = df_final[['Date'] + variables]
y = df_final["Adj Close t+1"]

X['Date'] = pd.to_datetime(X['Date'])

initial_date = X['Date'].min()

predictions = []
y_test_list = []
dates = []


for split_num, (train_index, val_index, test_index) in enumerate(recursive_rolling_method(X,initial_date,date_column='Date',train_period=8,val_period=3,test_period=1,freq='years')):
    X_train = X.loc[train_index].drop('Date', axis=1)
    y_train = y.loc[train_index]

    X_val = X.loc[val_index].drop('Date', axis=1)
    y_val = y.loc[val_index]

    X_test = X.loc[test_index].drop('Date', axis=1)
    y_test = y.loc[test_index]

    
    input_shape = [X_train.shape[1]]
    
    
    mean_train = X_train.mean(axis=0)
    std_train  = X_train.std(axis=0)
    
    X_train = (X_train-mean_train) / std_train
    X_val = (X_val-mean_train) / std_train
    X_test = (X_test-mean_train) / std_train
    
    
    
    model = tf.keras.Sequential([
 
    tf.keras.layers.Flatten(input_shape=input_shape),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=8, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='linear')
    
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0, clipnorm=1.0, clipvalue=0.5), loss='mse')    
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[early_stopping])
    
    preds = model.predict(X_test)
    preds = preds.ravel()


    predictions.append(preds)
    dates.append(X.loc[y_test.index, 'Date'])
    y_test_list.append(y_test)



    del X_train, y_train, X_val, y_val, model, preds
    gc.collect()

    print(f"Completed {split_num + 1} splits")

predictions_all = np.concatenate(predictions, axis=0)
y_test_list_all = pd.concat(y_test_list, axis=0)
dates_all = pd.concat(dates, axis=0)

R2oos_NN3 = 1 - np.sum(np.power(y_test_list_all - predictions_all, 2)) / np.sum(np.power(y_test_list_all, 2))
print("R2_oos NN3:", R2oos_NN3)
# Out:
#     Train period: 1997-02-28 00:00:00 - 2005-02-28 00:00:00  || Val period: 2005-03-28 00:00:00 - 2008-03-28 00:00:00  || Test period 2008-04-28 00:00:00 - 2009-04-28 00:00:00  || Train contains 125811  || Val contains 60364  || Test contains 22228
#     Train period: 1998-02-28 00:00:00 - 2006-02-28 00:00:00  || Val period: 2006-03-28 00:00:00 - 2009-03-28 00:00:00  || Test period 2009-04-28 00:00:00 - 2010-04-28 00:00:00  || Train contains 131822  || Val contains 63246  || Test contains 22915
#     Train period: 1999-02-28 00:00:00 - 2007-02-28 00:00:00  || Val period: 2007-03-28 00:00:00 - 2010-03-28 00:00:00  || Test period 2010-04-28 00:00:00 - 2011-04-28 00:00:00  || Train contains 138129  || Val contains 66069  || Test contains 23302
#     Train period: 2000-02-28 00:00:00 - 2008-02-28 00:00:00  || Val period: 2008-03-28 00:00:00 - 2011-03-28 00:00:00  || Test period 2011-04-28 00:00:00 - 2012-04-28 00:00:00  || Train contains 145727  || Val contains 68275  || Test contains 24233
#     Train period: 2001-02-28 00:00:00 - 2009-02-28 00:00:00  || Val period: 2009-03-28 00:00:00 - 2012-03-28 00:00:00  || Test period 2012-04-28 00:00:00 - 2013-04-28 00:00:00  || Train contains 154291  || Val contains 70279  || Test contains 25026
#     Train period: 2002-02-28 00:00:00 - 2010-02-28 00:00:00  || Val period: 2010-03-28 00:00:00 - 2013-03-28 00:00:00  || Test period 2013-04-28 00:00:00 - 2014-04-28 00:00:00  || Train contains 160611  || Val contains 72378  || Test contains 25892
#     Train period: 2003-02-28 00:00:00 - 2011-02-28 00:00:00  || Val period: 2011-03-28 00:00:00 - 2014-03-28 00:00:00  || Test period 2014-04-28 00:00:00 - 2015-04-28 00:00:00  || Train contains 164593  || Val contains 74932  || Test contains 26971
#     Train period: 2004-02-28 00:00:00 - 2012-02-28 00:00:00  || Val period: 2012-03-28 00:00:00 - 2015-03-28 00:00:00  || Test period 2015-04-28 00:00:00 - 2016-04-28 00:00:00  || Train contains 169186  || Val contains 77654  || Test contains 28571
#     Train period: 2005-02-28 00:00:00 - 2013-02-28 00:00:00  || Val period: 2013-03-28 00:00:00 - 2016-03-28 00:00:00  || Test period 2016-04-28 00:00:00 - 2017-04-28 00:00:00  || Train contains 177222  || Val contains 81098  || Test contains 30144
#     Train period: 2006-02-28 00:00:00 - 2014-02-28 00:00:00  || Val period: 2014-03-28 00:00:00 - 2017-03-28 00:00:00  || Test period 2017-04-28 00:00:00 - 2018-04-28 00:00:00  || Train contains 183762  || Val contains 85324  || Test contains 31225
#     Train period: 2007-02-28 00:00:00 - 2015-02-28 00:00:00  || Val period: 2015-03-28 00:00:00 - 2018-03-28 00:00:00  || Test period 2018-04-28 00:00:00 - 2019-04-28 00:00:00  || Train contains 192835  || Val contains 89583  || Test contains 32854
#     Train period: 2008-02-28 00:00:00 - 2016-02-28 00:00:00  || Val period: 2016-03-28 00:00:00 - 2019-03-28 00:00:00  || Test period 2019-04-28 00:00:00 - 2020-04-28 00:00:00  || Train contains 197855  || Val contains 93855  || Test contains 34953
#     Train period: 2009-02-28 00:00:00 - 2017-02-28 00:00:00  || Val period: 2017-03-28 00:00:00 - 2020-03-28 00:00:00  || Test period 2020-04-28 00:00:00 - 2021-04-28 00:00:00  || Train contains 203846  || Val contains 98599  || Test contains 36696
#     Train period: 2010-02-28 00:00:00 - 2018-02-28 00:00:00  || Val period: 2018-03-28 00:00:00 - 2021-03-28 00:00:00  || Test period 2021-04-28 00:00:00 - 2022-04-28 00:00:00  || Train contains 211989  || Val contains 104036  || Test contains 38776
#     Train period: 2011-02-28 00:00:00 - 2019-02-28 00:00:00  || Val period: 2019-03-28 00:00:00 - 2022-03-28 00:00:00  || Test period 2022-04-28 00:00:00 - 2023-04-28 00:00:00  || Train contains 223231  || Val contains 109838  || Test contains 43268
#     Train period: 2012-02-28 00:00:00 - 2020-02-28 00:00:00  || Val period: 2020-03-28 00:00:00 - 2023-03-28 00:00:00  || Test period 2023-04-28 00:00:00 - 2024-04-28 00:00:00  || Train contains 233783  || Val contains 117996  || Test contains 45045
#     Train period: 2013-02-28 00:00:00 - 2021-02-28 00:00:00  || Val period: 2021-03-28 00:00:00 - 2024-03-28 00:00:00  || Test period 2024-04-28 00:00:00 - 2025-04-28 00:00:00  || Train contains 248405  || Val contains 126449  || Test contains 18811
# Epoch 1/100
# 3932/3932 [==============================] - 4s 862us/step - loss: 508.8688 - val_loss: 530.1522
# Epoch 2/100
# 3932/3932 [==============================] - 3s 818us/step - loss: 121.7818 - val_loss: 336.8624
# Epoch 3/100
# 3932/3932 [==============================] - 3s 860us/step - loss: 81.9019 - val_loss: 114.7490
# Epoch 4/100
# 3932/3932 [==============================] - 3s 849us/step - loss: 69.2820 - val_loss: 61.7622
# Epoch 5/100
# 3932/3932 [==============================] - 3s 853us/step - loss: 65.5850 - val_loss: 58.8145
# Epoch 6/100
# 3932/3932 [==============================] - 3s 855us/step - loss: 64.0786 - val_loss: 54.8518
# Epoch 7/100
# 3932/3932 [==============================] - 3s 858us/step - loss: 62.9532 - val_loss: 50.7274
# Epoch 8/100
# 3932/3932 [==============================] - 3s 853us/step - loss: 62.2776 - val_loss: 49.9656
# Epoch 9/100
# 3932/3932 [==============================] - 3s 860us/step - loss: 62.1599 - val_loss: 49.7300
# Epoch 10/100
# 3932/3932 [==============================] - 3s 861us/step - loss: 61.9444 - val_loss: 46.4130
# Epoch 11/100
# 3932/3932 [==============================] - 3s 857us/step - loss: 61.3011 - val_loss: 46.3035
# Epoch 12/100
# 3932/3932 [==============================] - 3s 865us/step - loss: 61.5700 - val_loss: 44.7431
# Epoch 13/100
# 3932/3932 [==============================] - 3s 862us/step - loss: 61.3377 - val_loss: 44.4874
# Epoch 14/100
# 3932/3932 [==============================] - 3s 864us/step - loss: 61.1943 - val_loss: 43.3131
# Epoch 15/100
# 3932/3932 [==============================] - 3s 858us/step - loss: 61.0179 - val_loss: 43.0596
# Epoch 16/100
# 3932/3932 [==============================] - 3s 855us/step - loss: 60.6246 - val_loss: 42.5989
# Epoch 17/100
# 3932/3932 [==============================] - 3s 879us/step - loss: 60.3029 - val_loss: 42.0988
# Epoch 18/100
# 3932/3932 [==============================] - 3s 849us/step - loss: 60.3453 - val_loss: 40.5031
# Epoch 19/100
# 3932/3932 [==============================] - 3s 851us/step - loss: 60.0615 - val_loss: 41.2316
# Epoch 20/100
# 3932/3932 [==============================] - 3s 857us/step - loss: 60.1879 - val_loss: 42.0842
# Epoch 21/100
# 3932/3932 [==============================] - 3s 856us/step - loss: 60.2542 - val_loss: 40.1979
# Epoch 22/100
# 3932/3932 [==============================] - 3s 850us/step - loss: 60.2838 - val_loss: 39.9892
# Epoch 23/100
# 3932/3932 [==============================] - 3s 868us/step - loss: 60.3338 - val_loss: 39.5340
# Epoch 24/100
# 3932/3932 [==============================] - 3s 852us/step - loss: 60.2831 - val_loss: 39.1962
# Epoch 25/100
# 3932/3932 [==============================] - 3s 853us/step - loss: 60.0251 - val_loss: 39.2768
# Epoch 26/100
# 3932/3932 [==============================] - 3s 859us/step - loss: 59.9078 - val_loss: 39.1246
# Epoch 27/100
# 3932/3932 [==============================] - 3s 858us/step - loss: 60.0412 - val_loss: 40.3514
# Epoch 28/100
# 3932/3932 [==============================] - 3s 854us/step - loss: 59.9434 - val_loss: 39.9901
# Epoch 29/100
# 3932/3932 [==============================] - 3s 856us/step - loss: 59.8716 - val_loss: 41.2592
# Epoch 30/100
# 3932/3932 [==============================] - 3s 857us/step - loss: 59.7309 - val_loss: 38.9698
# Epoch 31/100
# 3932/3932 [==============================] - 3s 849us/step - loss: 60.0559 - val_loss: 40.5054
# Epoch 32/100
# 3932/3932 [==============================] - 3s 860us/step - loss: 59.7314 - val_loss: 39.4366
# Epoch 33/100
# 3932/3932 [==============================] - 3s 853us/step - loss: 59.5359 - val_loss: 38.3993
# Epoch 34/100
# 3932/3932 [==============================] - 3s 845us/step - loss: 59.4768 - val_loss: 38.9881
# Epoch 35/100
# 3932/3932 [==============================] - 3s 851us/step - loss: 59.3686 - val_loss: 39.1164
# Epoch 36/100
# 3932/3932 [==============================] - 3s 860us/step - loss: 59.4618 - val_loss: 39.6288
# Epoch 37/100
# 3932/3932 [==============================] - 3s 854us/step - loss: 59.6589 - val_loss: 40.6334
# Epoch 38/100
# 3932/3932 [==============================] - 3s 860us/step - loss: 59.5819 - val_loss: 38.7763
# 695/695 [==============================] - 0s 496us/step
# Completed 1 splits
# Epoch 1/100
# 4120/4120 [==============================] - 4s 876us/step - loss: 519.2139 - val_loss: 487.3550
# Epoch 2/100
# 4120/4120 [==============================] - 4s 853us/step - loss: 114.1264 - val_loss: 381.5335
# Epoch 3/100
# 4120/4120 [==============================] - 4s 864us/step - loss: 81.0730 - val_loss: 238.6752
# Epoch 4/100
# 4120/4120 [==============================] - 4s 856us/step - loss: 71.0925 - val_loss: 107.0461
# Epoch 5/100
# 4120/4120 [==============================] - 4s 851us/step - loss: 66.8320 - val_loss: 77.7016
# Epoch 6/100
# 4120/4120 [==============================] - 3s 849us/step - loss: 64.4440 - val_loss: 70.1080
# Epoch 7/100
# 4120/4120 [==============================] - 4s 853us/step - loss: 63.1040 - val_loss: 65.4787
# Epoch 8/100
# 4120/4120 [==============================] - 4s 857us/step - loss: 62.3539 - val_loss: 61.0149
# Epoch 9/100
# 4120/4120 [==============================] - 4s 858us/step - loss: 62.0642 - val_loss: 57.0922
# Epoch 10/100
# 4120/4120 [==============================] - 4s 857us/step - loss: 61.5721 - val_loss: 59.1215
# Epoch 11/100
# 4120/4120 [==============================] - 4s 852us/step - loss: 61.1421 - val_loss: 52.5061
# Epoch 12/100
# 4120/4120 [==============================] - 4s 857us/step - loss: 60.7548 - val_loss: 50.9852
# Epoch 13/100
# 4120/4120 [==============================] - 4s 857us/step - loss: 61.0161 - val_loss: 52.4602
# Epoch 14/100
# 4120/4120 [==============================] - 4s 853us/step - loss: 61.0219 - val_loss: 53.2024
# Epoch 15/100
# 4120/4120 [==============================] - 4s 855us/step - loss: 60.4807 - val_loss: 54.5071
# Epoch 16/100
# 4120/4120 [==============================] - 4s 852us/step - loss: 60.4313 - val_loss: 49.8182
# Epoch 17/100
# 4120/4120 [==============================] - 3s 849us/step - loss: 60.2496 - val_loss: 49.9962
# Epoch 18/100
# 4120/4120 [==============================] - 4s 856us/step - loss: 60.7163 - val_loss: 49.3847
# Epoch 19/100
# 4120/4120 [==============================] - 3s 848us/step - loss: 60.4172 - val_loss: 48.6635
# Epoch 20/100
# 4120/4120 [==============================] - 4s 854us/step - loss: 60.5022 - val_loss: 50.7372
# Epoch 21/100
# 4120/4120 [==============================] - 4s 850us/step - loss: 60.5881 - val_loss: 48.7064
# Epoch 22/100
# 4120/4120 [==============================] - 3s 848us/step - loss: 60.0904 - val_loss: 44.5093
# Epoch 23/100
# 4120/4120 [==============================] - 4s 854us/step - loss: 60.3470 - val_loss: 48.5056
# Epoch 24/100
# 4120/4120 [==============================] - 4s 850us/step - loss: 59.8949 - val_loss: 47.9700
# Epoch 25/100
# 4120/4120 [==============================] - 4s 852us/step - loss: 59.7767 - val_loss: 45.0398
# Epoch 26/100
# 4120/4120 [==============================] - 4s 859us/step - loss: 59.8532 - val_loss: 47.3138
# Epoch 27/100
# 4120/4120 [==============================] - 4s 854us/step - loss: 60.0959 - val_loss: 45.6577
# 717/717 [==============================] - 0s 507us/step
# Completed 2 splits
# Epoch 1/100
# 4317/4317 [==============================] - 4s 879us/step - loss: 609.9781 - val_loss: 206.2505
# Epoch 2/100
# 4317/4317 [==============================] - 4s 854us/step - loss: 133.7725 - val_loss: 120.1437
# Epoch 3/100
# 4317/4317 [==============================] - 4s 861us/step - loss: 87.0664 - val_loss: 88.6732
# Epoch 4/100
# 4317/4317 [==============================] - 4s 857us/step - loss: 69.8444 - val_loss: 74.2273
# Epoch 5/100
# 4317/4317 [==============================] - 4s 855us/step - loss: 64.1042 - val_loss: 74.4562
# Epoch 6/100
# 4317/4317 [==============================] - 4s 851us/step - loss: 61.9407 - val_loss: 68.4729
# Epoch 7/100
# 4317/4317 [==============================] - 4s 856us/step - loss: 60.1320 - val_loss: 65.2031
# Epoch 8/100
# 4317/4317 [==============================] - 4s 853us/step - loss: 59.1957 - val_loss: 61.3163
# Epoch 9/100
# 4317/4317 [==============================] - 4s 858us/step - loss: 59.0967 - val_loss: 58.6903
# Epoch 10/100
# 4317/4317 [==============================] - 4s 851us/step - loss: 58.6344 - val_loss: 57.5674
# Epoch 11/100
# 4317/4317 [==============================] - 4s 862us/step - loss: 58.5020 - val_loss: 56.0119
# Epoch 12/100
# 4317/4317 [==============================] - 4s 858us/step - loss: 58.1673 - val_loss: 56.7041
# Epoch 13/100
# 4317/4317 [==============================] - 4s 860us/step - loss: 58.0900 - val_loss: 56.4312
# Epoch 14/100
# 4317/4317 [==============================] - 4s 851us/step - loss: 58.0530 - val_loss: 58.0439
# Epoch 15/100
# 4317/4317 [==============================] - 4s 864us/step - loss: 57.7094 - val_loss: 56.5584
# Epoch 16/100
# 4317/4317 [==============================] - 4s 851us/step - loss: 57.2981 - val_loss: 59.5421
# 729/729 [==============================] - 0s 494us/step
# Completed 3 splits
# Epoch 1/100
# 4554/4554 [==============================] - 4s 876us/step - loss: 553.8924 - val_loss: 484.1086
# Epoch 2/100
# 4554/4554 [==============================] - 4s 851us/step - loss: 100.2449 - val_loss: 125.7173
# Epoch 3/100
# 4554/4554 [==============================] - 4s 857us/step - loss: 69.9781 - val_loss: 61.3517
# Epoch 4/100
# 4554/4554 [==============================] - 4s 844us/step - loss: 62.0557 - val_loss: 50.1703
# Epoch 5/100
# 4554/4554 [==============================] - 4s 848us/step - loss: 59.9726 - val_loss: 47.6940
# Epoch 6/100
# 4554/4554 [==============================] - 4s 850us/step - loss: 58.8913 - val_loss: 47.1472
# Epoch 7/100
# 4554/4554 [==============================] - 4s 844us/step - loss: 57.9719 - val_loss: 45.8800
# Epoch 8/100
# 4554/4554 [==============================] - 4s 840us/step - loss: 57.3864 - val_loss: 45.6423
# Epoch 9/100
# 4554/4554 [==============================] - 4s 843us/step - loss: 56.7796 - val_loss: 45.8899
# Epoch 10/100
# 4554/4554 [==============================] - 4s 846us/step - loss: 56.5886 - val_loss: 45.7489
# Epoch 11/100
# 4554/4554 [==============================] - 4s 853us/step - loss: 56.3085 - val_loss: 45.6567
# Epoch 12/100
# 4554/4554 [==============================] - 4s 850us/step - loss: 55.8861 - val_loss: 45.4750
# Epoch 13/100
# 4554/4554 [==============================] - 4s 843us/step - loss: 55.9747 - val_loss: 44.9306
# Epoch 14/100
# 4554/4554 [==============================] - 4s 851us/step - loss: 55.2601 - val_loss: 45.0973
# Epoch 15/100
# 4554/4554 [==============================] - 4s 859us/step - loss: 55.7748 - val_loss: 45.0804
# Epoch 16/100
# 4554/4554 [==============================] - 4s 851us/step - loss: 55.4922 - val_loss: 44.9394
# Epoch 17/100
# 4554/4554 [==============================] - 4s 850us/step - loss: 55.7246 - val_loss: 45.7600
# Epoch 18/100
# 4554/4554 [==============================] - 4s 854us/step - loss: 55.5051 - val_loss: 45.3813
# 758/758 [==============================] - 0s 495us/step
# Completed 4 splits
# Epoch 1/100
# 4822/4822 [==============================] - 5s 863us/step - loss: 512.5374 - val_loss: 120.7867
# Epoch 2/100
# 4822/4822 [==============================] - 4s 842us/step - loss: 128.0497 - val_loss: 76.1221
# Epoch 3/100
# 4822/4822 [==============================] - 4s 849us/step - loss: 79.3136 - val_loss: 54.4426
# Epoch 4/100
# 4822/4822 [==============================] - 4s 840us/step - loss: 62.2533 - val_loss: 48.4078
# Epoch 5/100
# 4822/4822 [==============================] - 4s 841us/step - loss: 57.6305 - val_loss: 45.5957
# Epoch 6/100
# 4822/4822 [==============================] - 4s 842us/step - loss: 55.3295 - val_loss: 43.9553
# Epoch 7/100
# 4822/4822 [==============================] - 4s 842us/step - loss: 53.7433 - val_loss: 42.3695
# Epoch 8/100
# 4822/4822 [==============================] - 4s 844us/step - loss: 52.7421 - val_loss: 41.3952
# Epoch 9/100
# 4822/4822 [==============================] - 4s 848us/step - loss: 52.0216 - val_loss: 41.1061
# Epoch 10/100
# 4822/4822 [==============================] - 4s 840us/step - loss: 51.2962 - val_loss: 40.4564
# Epoch 11/100
# 4822/4822 [==============================] - 4s 843us/step - loss: 50.8631 - val_loss: 40.3518
# Epoch 12/100
# 4822/4822 [==============================] - 4s 844us/step - loss: 50.4340 - val_loss: 40.3961
# Epoch 13/100
# 4822/4822 [==============================] - 4s 845us/step - loss: 50.2950 - val_loss: 39.9482
# Epoch 14/100
# 4822/4822 [==============================] - 4s 840us/step - loss: 50.0473 - val_loss: 39.8727
# Epoch 15/100
# 4822/4822 [==============================] - 4s 849us/step - loss: 50.0462 - val_loss: 39.6739
# Epoch 16/100
# 4822/4822 [==============================] - 4s 848us/step - loss: 49.8421 - val_loss: 39.5990
# Epoch 17/100
# 4822/4822 [==============================] - 4s 843us/step - loss: 49.7137 - val_loss: 39.3908
# Epoch 18/100
# 4822/4822 [==============================] - 4s 842us/step - loss: 49.5358 - val_loss: 39.7324
# Epoch 19/100
# 4822/4822 [==============================] - 4s 851us/step - loss: 49.4578 - val_loss: 39.3737
# Epoch 20/100
# 4822/4822 [==============================] - 4s 849us/step - loss: 49.4741 - val_loss: 39.5902
# Epoch 21/100
# 4822/4822 [==============================] - 4s 841us/step - loss: 49.2245 - val_loss: 39.1991
# Epoch 22/100
# 4822/4822 [==============================] - 4s 856us/step - loss: 49.2549 - val_loss: 39.1004
# Epoch 23/100
# 4822/4822 [==============================] - 4s 843us/step - loss: 49.1170 - val_loss: 39.6696
# Epoch 24/100
# 4822/4822 [==============================] - 4s 848us/step - loss: 49.2705 - val_loss: 38.9955
# Epoch 25/100
# 4822/4822 [==============================] - 4s 856us/step - loss: 49.0281 - val_loss: 38.8845
# Epoch 26/100
# 4822/4822 [==============================] - 4s 844us/step - loss: 49.0022 - val_loss: 39.0664
# Epoch 27/100
# 4822/4822 [==============================] - 4s 845us/step - loss: 49.0604 - val_loss: 38.9353
# Epoch 28/100
# 4822/4822 [==============================] - 4s 842us/step - loss: 48.8107 - val_loss: 39.1080
# Epoch 29/100
# 4822/4822 [==============================] - 4s 842us/step - loss: 48.8807 - val_loss: 38.8823
# Epoch 30/100
# 4822/4822 [==============================] - 4s 841us/step - loss: 48.9525 - val_loss: 38.8656
# Epoch 31/100
# 4822/4822 [==============================] - 4s 834us/step - loss: 49.0717 - val_loss: 38.6891
# Epoch 32/100
# 4822/4822 [==============================] - 4s 843us/step - loss: 48.8043 - val_loss: 38.8914
# Epoch 33/100
# 4822/4822 [==============================] - 4s 852us/step - loss: 48.8813 - val_loss: 38.6292
# Epoch 34/100
# 4822/4822 [==============================] - 4s 847us/step - loss: 48.8777 - val_loss: 38.6881
# Epoch 35/100
# 4822/4822 [==============================] - 4s 853us/step - loss: 48.7873 - val_loss: 38.6494
# Epoch 36/100
# 4822/4822 [==============================] - 4s 841us/step - loss: 48.7991 - val_loss: 38.5700
# Epoch 37/100
# 4822/4822 [==============================] - 4s 843us/step - loss: 48.7515 - val_loss: 38.7390
# Epoch 38/100
# 4822/4822 [==============================] - 4s 847us/step - loss: 48.7149 - val_loss: 38.4655
# Epoch 39/100
# 4822/4822 [==============================] - 4s 848us/step - loss: 48.5789 - val_loss: 38.5759
# Epoch 40/100
# 4822/4822 [==============================] - 4s 849us/step - loss: 48.4411 - val_loss: 38.3231
# Epoch 41/100
# 4822/4822 [==============================] - 4s 839us/step - loss: 48.5288 - val_loss: 38.5334
# Epoch 42/100
# 4822/4822 [==============================] - 4s 847us/step - loss: 48.5454 - val_loss: 38.3335
# Epoch 43/100
# 4822/4822 [==============================] - 4s 844us/step - loss: 48.5055 - val_loss: 38.2475
# Epoch 44/100
# 4822/4822 [==============================] - 4s 843us/step - loss: 48.3692 - val_loss: 38.2018
# Epoch 45/100
# 4822/4822 [==============================] - 4s 856us/step - loss: 48.5969 - val_loss: 38.2283
# Epoch 46/100
# 4822/4822 [==============================] - 4s 847us/step - loss: 48.6352 - val_loss: 38.4347
# Epoch 47/100
# 4822/4822 [==============================] - 4s 848us/step - loss: 48.4256 - val_loss: 38.2807
# Epoch 48/100
# 4822/4822 [==============================] - 4s 840us/step - loss: 48.4037 - val_loss: 38.3187
# Epoch 49/100
# 4822/4822 [==============================] - 4s 842us/step - loss: 48.3929 - val_loss: 38.5266
# 783/783 [==============================] - 0s 495us/step
# Completed 5 splits
# Epoch 1/100
# 5020/5020 [==============================] - 5s 869us/step - loss: 438.2731 - val_loss: 106.1349
# Epoch 2/100
# 5020/5020 [==============================] - 4s 853us/step - loss: 87.9026 - val_loss: 61.2903
# Epoch 3/100
# 5020/5020 [==============================] - 4s 848us/step - loss: 48.6630 - val_loss: 45.7326
# Epoch 4/100
# 5020/5020 [==============================] - 4s 851us/step - loss: 42.4846 - val_loss: 40.3113
# Epoch 5/100
# 5020/5020 [==============================] - 4s 844us/step - loss: 40.4032 - val_loss: 37.6785
# Epoch 6/100
# 5020/5020 [==============================] - 4s 842us/step - loss: 39.2268 - val_loss: 35.4551
# Epoch 7/100
# 5020/5020 [==============================] - 4s 853us/step - loss: 38.5524 - val_loss: 34.1339
# Epoch 8/100
# 5020/5020 [==============================] - 4s 842us/step - loss: 37.7920 - val_loss: 33.0403
# Epoch 9/100
# 5020/5020 [==============================] - 4s 854us/step - loss: 37.1715 - val_loss: 32.5213
# Epoch 10/100
# 5020/5020 [==============================] - 4s 849us/step - loss: 36.8562 - val_loss: 31.5783
# Epoch 11/100
# 5020/5020 [==============================] - 4s 847us/step - loss: 36.7377 - val_loss: 31.2519
# Epoch 12/100
# 5020/5020 [==============================] - 4s 853us/step - loss: 36.6799 - val_loss: 30.8766
# Epoch 13/100
# 5020/5020 [==============================] - 4s 845us/step - loss: 36.2887 - val_loss: 30.6356
# Epoch 14/100
# 5020/5020 [==============================] - 4s 849us/step - loss: 36.0728 - val_loss: 30.4831
# Epoch 15/100
# 5020/5020 [==============================] - 4s 848us/step - loss: 36.1290 - val_loss: 30.5643
# Epoch 16/100
# 5020/5020 [==============================] - 4s 846us/step - loss: 36.1086 - val_loss: 30.8107
# Epoch 17/100
# 5020/5020 [==============================] - 4s 846us/step - loss: 36.1861 - val_loss: 30.5755
# Epoch 18/100
# 5020/5020 [==============================] - 4s 845us/step - loss: 36.1284 - val_loss: 30.3448
# Epoch 19/100
# 5020/5020 [==============================] - 4s 852us/step - loss: 36.0792 - val_loss: 30.3733
# Epoch 20/100
# 5020/5020 [==============================] - 5s 898us/step - loss: 35.9170 - val_loss: 30.5198
# Epoch 21/100
# 5020/5020 [==============================] - 5s 912us/step - loss: 35.7348 - val_loss: 30.1564
# Epoch 22/100
# 5020/5020 [==============================] - 5s 898us/step - loss: 35.8427 - val_loss: 30.3026
# Epoch 23/100
# 5020/5020 [==============================] - 4s 867us/step - loss: 35.8353 - val_loss: 30.4134
# Epoch 24/100
# 5020/5020 [==============================] - 4s 839us/step - loss: 35.6432 - val_loss: 30.2428
# Epoch 25/100
# 5020/5020 [==============================] - 4s 845us/step - loss: 35.5868 - val_loss: 30.1163
# Epoch 26/100
# 5020/5020 [==============================] - 5s 973us/step - loss: 35.7965 - val_loss: 30.2839
# Epoch 27/100
# 5020/5020 [==============================] - 4s 870us/step - loss: 35.5886 - val_loss: 30.1390
# Epoch 28/100
# 5020/5020 [==============================] - 4s 846us/step - loss: 35.6346 - val_loss: 30.1044
# Epoch 29/100
# 5020/5020 [==============================] - 4s 867us/step - loss: 35.4783 - val_loss: 30.2948
# Epoch 30/100
# 5020/5020 [==============================] - 4s 849us/step - loss: 35.4825 - val_loss: 30.1140
# Epoch 31/100
# 5020/5020 [==============================] - 4s 848us/step - loss: 35.6358 - val_loss: 30.0392
# Epoch 32/100
# 5020/5020 [==============================] - 4s 847us/step - loss: 35.5341 - val_loss: 30.1740
# Epoch 33/100
# 5020/5020 [==============================] - 4s 844us/step - loss: 35.5135 - val_loss: 30.0687
# Epoch 34/100
# 5020/5020 [==============================] - 4s 838us/step - loss: 35.2973 - val_loss: 30.3517
# Epoch 35/100
# 5020/5020 [==============================] - 4s 839us/step - loss: 35.6995 - val_loss: 30.1620
# Epoch 36/100
# 5020/5020 [==============================] - 4s 843us/step - loss: 35.5886 - val_loss: 30.1244
# 810/810 [==============================] - 0s 500us/step
# Completed 6 splits
# Epoch 1/100
# 5144/5144 [==============================] - 5s 870us/step - loss: 482.9358 - val_loss: 101.4513
# Epoch 2/100
# 5144/5144 [==============================] - 4s 851us/step - loss: 87.1581 - val_loss: 59.3324
# Epoch 3/100
# 5144/5144 [==============================] - 4s 854us/step - loss: 51.3850 - val_loss: 44.0743
# Epoch 4/100
# 5144/5144 [==============================] - 4s 849us/step - loss: 44.0352 - val_loss: 39.9359
# Epoch 5/100
# 5144/5144 [==============================] - 4s 854us/step - loss: 42.6186 - val_loss: 38.5150
# Epoch 6/100
# 5144/5144 [==============================] - 4s 851us/step - loss: 41.4303 - val_loss: 38.5510
# Epoch 7/100
# 5144/5144 [==============================] - 4s 858us/step - loss: 40.9904 - val_loss: 36.6493
# Epoch 8/100
# 5144/5144 [==============================] - 4s 859us/step - loss: 40.4696 - val_loss: 36.0170
# Epoch 9/100
# 5144/5144 [==============================] - 4s 849us/step - loss: 40.1386 - val_loss: 36.0921
# Epoch 10/100
# 5144/5144 [==============================] - 4s 861us/step - loss: 39.7411 - val_loss: 35.4710
# Epoch 11/100
# 5144/5144 [==============================] - 4s 848us/step - loss: 39.5172 - val_loss: 35.1775
# Epoch 12/100
# 5144/5144 [==============================] - 4s 852us/step - loss: 39.5426 - val_loss: 34.8284
# Epoch 13/100
# 5144/5144 [==============================] - 4s 845us/step - loss: 39.2835 - val_loss: 35.2303
# Epoch 14/100
# 5144/5144 [==============================] - 4s 850us/step - loss: 38.8666 - val_loss: 35.0494
# Epoch 15/100
# 5144/5144 [==============================] - 4s 855us/step - loss: 38.9607 - val_loss: 34.7539
# Epoch 16/100
# 5144/5144 [==============================] - 4s 845us/step - loss: 38.6669 - val_loss: 34.7431
# Epoch 17/100
# 5144/5144 [==============================] - 4s 851us/step - loss: 38.5043 - val_loss: 34.4070
# Epoch 18/100
# 5144/5144 [==============================] - 4s 850us/step - loss: 38.5069 - val_loss: 34.5499
# Epoch 19/100
# 5144/5144 [==============================] - 4s 857us/step - loss: 38.4779 - val_loss: 35.6718
# Epoch 20/100
# 5144/5144 [==============================] - 4s 845us/step - loss: 38.3532 - val_loss: 34.3683
# Epoch 21/100
# 5144/5144 [==============================] - 4s 848us/step - loss: 38.3329 - val_loss: 35.4666
# Epoch 22/100
# 5144/5144 [==============================] - 4s 845us/step - loss: 38.0354 - val_loss: 34.3911
# Epoch 23/100
# 5144/5144 [==============================] - 4s 848us/step - loss: 38.0542 - val_loss: 34.3146
# Epoch 24/100
# 5144/5144 [==============================] - 4s 845us/step - loss: 37.9679 - val_loss: 34.5280
# Epoch 25/100
# 5144/5144 [==============================] - 4s 839us/step - loss: 37.7467 - val_loss: 34.8247
# Epoch 26/100
# 5144/5144 [==============================] - 4s 856us/step - loss: 37.8121 - val_loss: 34.3898
# Epoch 27/100
# 5144/5144 [==============================] - 4s 846us/step - loss: 37.5860 - val_loss: 34.1598
# Epoch 28/100
# 5144/5144 [==============================] - 4s 858us/step - loss: 37.6333 - val_loss: 34.1574
# Epoch 29/100
# 5144/5144 [==============================] - 4s 845us/step - loss: 37.5368 - val_loss: 34.2922
# Epoch 30/100
# 5144/5144 [==============================] - 4s 841us/step - loss: 37.4268 - val_loss: 34.3910
# Epoch 31/100
# 5144/5144 [==============================] - 4s 845us/step - loss: 37.3803 - val_loss: 33.9227
# Epoch 32/100
# 5144/5144 [==============================] - 4s 853us/step - loss: 37.3411 - val_loss: 34.0808
# Epoch 33/100
# 5144/5144 [==============================] - 4s 850us/step - loss: 37.4776 - val_loss: 34.0453
# Epoch 34/100
# 5144/5144 [==============================] - 4s 848us/step - loss: 37.3108 - val_loss: 34.3668
# Epoch 35/100
# 5144/5144 [==============================] - 4s 854us/step - loss: 37.3734 - val_loss: 33.9493
# Epoch 36/100
# 5144/5144 [==============================] - 4s 856us/step - loss: 37.3702 - val_loss: 34.0054
# 843/843 [==============================] - 0s 503us/step
# Completed 7 splits
# Epoch 1/100
# 5288/5288 [==============================] - 5s 860us/step - loss: 484.6277 - val_loss: 130.7407
# Epoch 2/100
# 5288/5288 [==============================] - 4s 844us/step - loss: 105.7898 - val_loss: 70.5779
# Epoch 3/100
# 5288/5288 [==============================] - 4s 845us/step - loss: 70.5215 - val_loss: 49.2742
# Epoch 4/100
# 5288/5288 [==============================] - 4s 842us/step - loss: 57.8397 - val_loss: 42.3051
# Epoch 5/100
# 5288/5288 [==============================] - 5s 864us/step - loss: 49.1722 - val_loss: 39.3498
# Epoch 6/100
# 5288/5288 [==============================] - 4s 845us/step - loss: 45.9291 - val_loss: 36.7563
# Epoch 7/100
# 5288/5288 [==============================] - 5s 852us/step - loss: 43.0815 - val_loss: 35.6995
# Epoch 8/100
# 5288/5288 [==============================] - 4s 845us/step - loss: 41.3947 - val_loss: 34.8087
# Epoch 9/100
# 5288/5288 [==============================] - 4s 842us/step - loss: 40.6239 - val_loss: 34.4146
# Epoch 10/100
# 5288/5288 [==============================] - 4s 848us/step - loss: 39.6292 - val_loss: 34.5974
# Epoch 11/100
# 5288/5288 [==============================] - 4s 844us/step - loss: 39.4339 - val_loss: 34.2293
# Epoch 12/100
# 5288/5288 [==============================] - 5s 854us/step - loss: 39.0522 - val_loss: 34.2501
# Epoch 13/100
# 5288/5288 [==============================] - 4s 849us/step - loss: 38.7583 - val_loss: 33.5875
# Epoch 14/100
# 5288/5288 [==============================] - 4s 847us/step - loss: 38.5037 - val_loss: 33.4888
# Epoch 15/100
# 5288/5288 [==============================] - 5s 851us/step - loss: 38.3302 - val_loss: 33.6823
# Epoch 16/100
# 5288/5288 [==============================] - 4s 844us/step - loss: 38.2309 - val_loss: 33.4426
# Epoch 17/100
# 5288/5288 [==============================] - 4s 850us/step - loss: 38.2288 - val_loss: 33.9449
# Epoch 18/100
# 5288/5288 [==============================] - 4s 846us/step - loss: 38.0542 - val_loss: 33.9262
# Epoch 19/100
# 5288/5288 [==============================] - 5s 855us/step - loss: 38.1410 - val_loss: 33.3573
# Epoch 20/100
# 5288/5288 [==============================] - 4s 841us/step - loss: 38.1480 - val_loss: 33.5979
# Epoch 21/100
# 5288/5288 [==============================] - 4s 846us/step - loss: 38.1936 - val_loss: 33.4105
# Epoch 22/100
# 5288/5288 [==============================] - 4s 849us/step - loss: 38.1128 - val_loss: 33.4029
# Epoch 23/100
# 5288/5288 [==============================] - 4s 843us/step - loss: 38.1245 - val_loss: 33.3939
# Epoch 24/100
# 5288/5288 [==============================] - 4s 847us/step - loss: 38.2405 - val_loss: 34.2131
# 893/893 [==============================] - 0s 493us/step
# Completed 8 splits
# Epoch 1/100
# 5539/5539 [==============================] - 5s 863us/step - loss: 450.6740 - val_loss: 106.7839
# Epoch 2/100
# 5539/5539 [==============================] - 5s 843us/step - loss: 115.3963 - val_loss: 67.6764
# Epoch 3/100
# 5539/5539 [==============================] - 5s 852us/step - loss: 70.3812 - val_loss: 55.1228
# Epoch 4/100
# 5539/5539 [==============================] - 5s 862us/step - loss: 58.9029 - val_loss: 51.0687
# Epoch 5/100
# 5539/5539 [==============================] - 5s 866us/step - loss: 53.5102 - val_loss: 48.3988
# Epoch 6/100
# 5539/5539 [==============================] - 5s 854us/step - loss: 47.9642 - val_loss: 45.3609
# Epoch 7/100
# 5539/5539 [==============================] - 5s 851us/step - loss: 45.1924 - val_loss: 43.7140
# Epoch 8/100
# 5539/5539 [==============================] - 5s 846us/step - loss: 42.8806 - val_loss: 42.8547
# Epoch 9/100
# 5539/5539 [==============================] - 5s 840us/step - loss: 41.7725 - val_loss: 43.2793
# Epoch 10/100
# 5539/5539 [==============================] - 5s 841us/step - loss: 41.0233 - val_loss: 42.4827
# Epoch 11/100
# 5539/5539 [==============================] - 5s 842us/step - loss: 40.5547 - val_loss: 42.2572
# Epoch 12/100
# 5539/5539 [==============================] - 5s 844us/step - loss: 39.8988 - val_loss: 42.7690
# Epoch 13/100
# 5539/5539 [==============================] - 5s 837us/step - loss: 39.8344 - val_loss: 41.9692
# Epoch 14/100
# 5539/5539 [==============================] - 5s 841us/step - loss: 39.6560 - val_loss: 41.6695
# Epoch 15/100
# 5539/5539 [==============================] - 5s 842us/step - loss: 39.0972 - val_loss: 42.2003
# Epoch 16/100
# 5539/5539 [==============================] - 5s 840us/step - loss: 39.2708 - val_loss: 41.8510
# Epoch 17/100
# 5539/5539 [==============================] - 5s 842us/step - loss: 39.1051 - val_loss: 41.5657
# Epoch 18/100
# 5539/5539 [==============================] - 5s 845us/step - loss: 38.6990 - val_loss: 41.9121
# Epoch 19/100
# 5539/5539 [==============================] - 5s 843us/step - loss: 38.4863 - val_loss: 42.3895
# Epoch 20/100
# 5539/5539 [==============================] - 5s 843us/step - loss: 38.4834 - val_loss: 41.6380
# Epoch 21/100
# 5539/5539 [==============================] - 5s 843us/step - loss: 38.4517 - val_loss: 41.9044
# Epoch 22/100
# 5539/5539 [==============================] - 5s 848us/step - loss: 38.2033 - val_loss: 41.4757
# Epoch 23/100
# 5539/5539 [==============================] - 5s 847us/step - loss: 38.1274 - val_loss: 41.8051
# Epoch 24/100
# 5539/5539 [==============================] - 5s 838us/step - loss: 37.9189 - val_loss: 41.4923
# Epoch 25/100
# 5539/5539 [==============================] - 5s 839us/step - loss: 37.6462 - val_loss: 41.2712
# Epoch 26/100
# 5539/5539 [==============================] - 5s 844us/step - loss: 37.4568 - val_loss: 41.2242
# Epoch 27/100
# 5539/5539 [==============================] - 5s 848us/step - loss: 37.3709 - val_loss: 41.2068
# Epoch 28/100
# 5539/5539 [==============================] - 5s 843us/step - loss: 37.5051 - val_loss: 41.2246
# Epoch 29/100
# 5539/5539 [==============================] - 5s 851us/step - loss: 37.3429 - val_loss: 41.4034
# Epoch 30/100
# 5539/5539 [==============================] - 5s 850us/step - loss: 37.3477 - val_loss: 40.8347
# Epoch 31/100
# 5539/5539 [==============================] - 5s 846us/step - loss: 37.0179 - val_loss: 41.1286
# Epoch 32/100
# 5539/5539 [==============================] - 5s 842us/step - loss: 37.1138 - val_loss: 41.2287
# Epoch 33/100
# 5539/5539 [==============================] - 5s 848us/step - loss: 37.0200 - val_loss: 40.9383
# Epoch 34/100
# 5539/5539 [==============================] - 5s 843us/step - loss: 36.9883 - val_loss: 41.5341
# Epoch 35/100
# 5539/5539 [==============================] - 5s 842us/step - loss: 36.7843 - val_loss: 40.8508
# 942/942 [==============================] - 1s 492us/step
# Completed 9 splits
# Epoch 1/100
# 5743/5743 [==============================] - 5s 869us/step - loss: 454.7685 - val_loss: 82.1167
# Epoch 2/100
# 5743/5743 [==============================] - 5s 846us/step - loss: 84.6420 - val_loss: 52.4466
# Epoch 3/100
# 5743/5743 [==============================] - 5s 853us/step - loss: 45.7864 - val_loss: 42.1949
# Epoch 4/100
# 5743/5743 [==============================] - 5s 846us/step - loss: 39.5772 - val_loss: 41.6229
# Epoch 5/100
# 5743/5743 [==============================] - 5s 842us/step - loss: 38.6201 - val_loss: 40.7253
# Epoch 6/100
# 5743/5743 [==============================] - 5s 842us/step - loss: 38.3611 - val_loss: 41.8013
# Epoch 7/100
# 5743/5743 [==============================] - 5s 847us/step - loss: 38.0186 - val_loss: 40.3824
# Epoch 8/100
# 5743/5743 [==============================] - 5s 851us/step - loss: 37.8938 - val_loss: 40.6941
# Epoch 9/100
# 5743/5743 [==============================] - 5s 849us/step - loss: 37.7335 - val_loss: 40.3944
# Epoch 10/100
# 5743/5743 [==============================] - 5s 851us/step - loss: 37.7238 - val_loss: 40.0135
# Epoch 11/100
# 5743/5743 [==============================] - 5s 850us/step - loss: 37.6704 - val_loss: 40.5181
# Epoch 12/100
# 5743/5743 [==============================] - 5s 844us/step - loss: 37.3211 - val_loss: 40.5909
# Epoch 13/100
# 5743/5743 [==============================] - 5s 846us/step - loss: 37.2627 - val_loss: 40.2931
# Epoch 14/100
# 5743/5743 [==============================] - 5s 846us/step - loss: 37.3519 - val_loss: 39.7913
# Epoch 15/100
# 5743/5743 [==============================] - 5s 853us/step - loss: 37.4259 - val_loss: 40.3125
# Epoch 16/100
# 5743/5743 [==============================] - 5s 857us/step - loss: 37.3969 - val_loss: 39.7815
# Epoch 17/100
# 5743/5743 [==============================] - 5s 846us/step - loss: 37.5371 - val_loss: 40.3234
# Epoch 18/100
# 5743/5743 [==============================] - 5s 874us/step - loss: 37.3494 - val_loss: 39.7167
# Epoch 19/100
# 5743/5743 [==============================] - 5s 850us/step - loss: 37.4588 - val_loss: 39.8939
# Epoch 20/100
# 5743/5743 [==============================] - 4s 781us/step - loss: 37.3640 - val_loss: 39.6027
# Epoch 21/100
# 5743/5743 [==============================] - 4s 781us/step - loss: 37.3374 - val_loss: 39.6712
# Epoch 22/100
# 5743/5743 [==============================] - 5s 792us/step - loss: 37.2543 - val_loss: 39.7903
# Epoch 23/100
# 5743/5743 [==============================] - 5s 789us/step - loss: 37.3377 - val_loss: 40.6362
# Epoch 24/100
# 5743/5743 [==============================] - 5s 784us/step - loss: 37.2680 - val_loss: 39.6179
# Epoch 25/100
# 5743/5743 [==============================] - 4s 779us/step - loss: 37.2008 - val_loss: 39.5166
# Epoch 26/100
# 5743/5743 [==============================] - 4s 781us/step - loss: 37.0492 - val_loss: 39.5815
# Epoch 27/100
# 5743/5743 [==============================] - 5s 784us/step - loss: 37.1212 - val_loss: 39.2211
# Epoch 28/100
# 5743/5743 [==============================] - 4s 781us/step - loss: 37.0776 - val_loss: 39.8706
# Epoch 29/100
# 5743/5743 [==============================] - 4s 776us/step - loss: 37.0688 - val_loss: 39.5002
# Epoch 30/100
# 5743/5743 [==============================] - 4s 783us/step - loss: 37.2179 - val_loss: 40.3325
# Epoch 31/100
# 5743/5743 [==============================] - 5s 784us/step - loss: 37.1043 - val_loss: 39.9822
# Epoch 32/100
# 5743/5743 [==============================] - 4s 780us/step - loss: 37.1729 - val_loss: 39.8776
# 976/976 [==============================] - 0s 456us/step
# Completed 10 splits
# Epoch 1/100
# 6027/6027 [==============================] - 5s 797us/step - loss: 418.9171 - val_loss: 130.4350
# Epoch 2/100
# 6027/6027 [==============================] - 5s 787us/step - loss: 72.3781 - val_loss: 108.3573
# Epoch 3/100
# 6027/6027 [==============================] - 5s 782us/step - loss: 49.8436 - val_loss: 96.1197
# Epoch 4/100
# 6027/6027 [==============================] - 5s 793us/step - loss: 45.1278 - val_loss: 90.0433
# Epoch 5/100
# 6027/6027 [==============================] - 5s 785us/step - loss: 43.0429 - val_loss: 81.8550
# Epoch 6/100
# 6027/6027 [==============================] - 5s 786us/step - loss: 41.8055 - val_loss: 78.5227
# Epoch 7/100
# 6027/6027 [==============================] - 5s 785us/step - loss: 40.9021 - val_loss: 76.2072
# Epoch 8/100
# 6027/6027 [==============================] - 5s 780us/step - loss: 40.2611 - val_loss: 74.3269
# Epoch 9/100
# 6027/6027 [==============================] - 5s 779us/step - loss: 39.8829 - val_loss: 74.7045
# Epoch 10/100
# 6027/6027 [==============================] - 5s 784us/step - loss: 39.4952 - val_loss: 74.4152
# Epoch 11/100
# 6027/6027 [==============================] - 5s 779us/step - loss: 39.3866 - val_loss: 70.1518
# Epoch 12/100
# 6027/6027 [==============================] - 5s 787us/step - loss: 39.0607 - val_loss: 68.9254
# Epoch 13/100
# 6027/6027 [==============================] - 5s 785us/step - loss: 39.0869 - val_loss: 70.9410
# Epoch 14/100
# 6027/6027 [==============================] - 5s 815us/step - loss: 38.8138 - val_loss: 69.6179
# Epoch 15/100
# 6027/6027 [==============================] - 5s 784us/step - loss: 38.8341 - val_loss: 67.3068
# Epoch 16/100
# 6027/6027 [==============================] - 5s 789us/step - loss: 38.5038 - val_loss: 66.6997
# Epoch 17/100
# 6027/6027 [==============================] - 5s 784us/step - loss: 38.4616 - val_loss: 66.1019
# Epoch 18/100
# 6027/6027 [==============================] - 5s 782us/step - loss: 38.3411 - val_loss: 66.4625
# Epoch 19/100
# 6027/6027 [==============================] - 5s 778us/step - loss: 38.3806 - val_loss: 64.7647
# Epoch 20/100
# 6027/6027 [==============================] - 5s 785us/step - loss: 38.2917 - val_loss: 66.3605
# Epoch 21/100
# 6027/6027 [==============================] - 5s 793us/step - loss: 38.2656 - val_loss: 64.5223
# Epoch 22/100
# 6027/6027 [==============================] - 5s 791us/step - loss: 38.2094 - val_loss: 63.5676
# Epoch 23/100
# 6027/6027 [==============================] - 5s 798us/step - loss: 38.0498 - val_loss: 62.5856
# Epoch 24/100
# 6027/6027 [==============================] - 5s 812us/step - loss: 38.0707 - val_loss: 64.1353
# Epoch 25/100
# 6027/6027 [==============================] - 5s 793us/step - loss: 38.1154 - val_loss: 62.8765
# Epoch 26/100
# 6027/6027 [==============================] - 5s 794us/step - loss: 38.1190 - val_loss: 64.5126
# Epoch 27/100
# 6027/6027 [==============================] - 5s 791us/step - loss: 38.0487 - val_loss: 61.5641
# Epoch 28/100
# 6027/6027 [==============================] - 5s 798us/step - loss: 38.0031 - val_loss: 60.9634
# Epoch 29/100
# 6027/6027 [==============================] - 5s 790us/step - loss: 38.0438 - val_loss: 62.9271
# Epoch 30/100
# 6027/6027 [==============================] - 5s 791us/step - loss: 37.8775 - val_loss: 62.6568
# Epoch 31/100
# 6027/6027 [==============================] - 5s 786us/step - loss: 37.9363 - val_loss: 61.7384
# Epoch 32/100
# 6027/6027 [==============================] - 5s 789us/step - loss: 38.0283 - val_loss: 61.5264
# Epoch 33/100
# 6027/6027 [==============================] - 5s 785us/step - loss: 38.0637 - val_loss: 61.1434
# 1027/1027 [==============================] - 1s 463us/step
# Completed 11 splits
# Epoch 1/100
# 6183/6183 [==============================] - 5s 801us/step - loss: 394.8952 - val_loss: 37135.9570
# Epoch 2/100
# 6183/6183 [==============================] - 5s 788us/step - loss: 69.7115 - val_loss: 47622.5938
# Epoch 3/100
# 6183/6183 [==============================] - 5s 806us/step - loss: 52.2442 - val_loss: 65441.3789
# Epoch 4/100
# 6183/6183 [==============================] - 5s 804us/step - loss: 47.1714 - val_loss: 64865.2422
# Epoch 5/100
# 6183/6183 [==============================] - 5s 790us/step - loss: 45.9859 - val_loss: 49612.1953
# Epoch 6/100
# 6183/6183 [==============================] - 5s 789us/step - loss: 44.3477 - val_loss: 42889.1641
# 1093/1093 [==============================] - 1s 465us/step
# Completed 12 splits
# Epoch 1/100
# 6371/6371 [==============================] - 6s 817us/step - loss: 589.8964 - val_loss: 256360.8125
# Epoch 2/100
# 6371/6371 [==============================] - 5s 802us/step - loss: 69.0702 - val_loss: 48687.8398
# Epoch 3/100
# 6371/6371 [==============================] - 5s 794us/step - loss: 51.9530 - val_loss: 54416.8008
# Epoch 4/100
# 6371/6371 [==============================] - 5s 791us/step - loss: 46.3646 - val_loss: 51122.2383
# Epoch 5/100
# 6371/6371 [==============================] - 5s 797us/step - loss: 43.7278 - val_loss: 36692.6719
# Epoch 6/100
# 6371/6371 [==============================] - 5s 791us/step - loss: 41.8005 - val_loss: 27668.9121
# Epoch 7/100
# 6371/6371 [==============================] - 5s 788us/step - loss: 40.3774 - val_loss: 19986.0098
# Epoch 8/100
# 6371/6371 [==============================] - 5s 793us/step - loss: 39.4541 - val_loss: 25501.4277
# Epoch 9/100
# 6371/6371 [==============================] - 5s 793us/step - loss: 38.8387 - val_loss: 16685.2207
# Epoch 10/100
# 6371/6371 [==============================] - 5s 787us/step - loss: 38.5490 - val_loss: 16365.3564
# Epoch 11/100
# 6371/6371 [==============================] - 5s 793us/step - loss: 38.3650 - val_loss: 17910.7812
# Epoch 12/100
# 6371/6371 [==============================] - 5s 786us/step - loss: 37.9962 - val_loss: 15140.4756
# Epoch 13/100
# 6371/6371 [==============================] - 5s 796us/step - loss: 38.1862 - val_loss: 17738.0039
# Epoch 14/100
# 6371/6371 [==============================] - 5s 787us/step - loss: 38.0359 - val_loss: 17147.2441
# Epoch 15/100
# 6371/6371 [==============================] - 5s 791us/step - loss: 37.9215 - val_loss: 13800.3887
# Epoch 16/100
# 6371/6371 [==============================] - 5s 786us/step - loss: 37.8784 - val_loss: 16071.0850
# Epoch 17/100
# 6371/6371 [==============================] - 5s 795us/step - loss: 37.7977 - val_loss: 14819.9268
# Epoch 18/100
# 6371/6371 [==============================] - 5s 791us/step - loss: 37.7794 - val_loss: 14789.5215
# Epoch 19/100
# 6371/6371 [==============================] - 5s 792us/step - loss: 37.6890 - val_loss: 16749.6348
# Epoch 20/100
# 6371/6371 [==============================] - 5s 792us/step - loss: 37.8675 - val_loss: 17127.8027
# 1147/1147 [==============================] - 1s 456us/step
# Completed 13 splits
# Epoch 1/100
# 6625/6625 [==============================] - 6s 805us/step - loss: 593.8697 - val_loss: 11587.7529
# Epoch 2/100
# 6625/6625 [==============================] - 5s 791us/step - loss: 75.8202 - val_loss: 7113.4956
# Epoch 3/100
# 6625/6625 [==============================] - 5s 796us/step - loss: 60.8676 - val_loss: 41332.7500
# Epoch 4/100
# 6625/6625 [==============================] - 5s 801us/step - loss: 53.1978 - val_loss: 68720.5938
# Epoch 5/100
# 6625/6625 [==============================] - 5s 803us/step - loss: 49.0609 - val_loss: 60386.9336
# Epoch 6/100
# 6625/6625 [==============================] - 5s 788us/step - loss: 46.0596 - val_loss: 34586.4102
# Epoch 7/100
# 6625/6625 [==============================] - 5s 791us/step - loss: 44.2828 - val_loss: 43347.1055
# 1212/1212 [==============================] - 1s 454us/step
# Completed 14 splits
# Epoch 1/100
# 6976/6976 [==============================] - 6s 814us/step - loss: 590.1759 - val_loss: 1925.2977
# Epoch 2/100
# 6976/6976 [==============================] - 6s 790us/step - loss: 118.2133 - val_loss: 1816.1117
# Epoch 3/100
# 6976/6976 [==============================] - 6s 794us/step - loss: 95.9360 - val_loss: 1939.5378
# Epoch 4/100
# 6976/6976 [==============================] - 6s 801us/step - loss: 84.1075 - val_loss: 1915.8264
# Epoch 5/100
# 6976/6976 [==============================] - 6s 798us/step - loss: 77.6837 - val_loss: 1747.7932
# Epoch 6/100
# 6976/6976 [==============================] - 6s 793us/step - loss: 72.1614 - val_loss: 1567.7664
# Epoch 7/100
# 6976/6976 [==============================] - 6s 813us/step - loss: 66.8526 - val_loss: 1459.7699
# Epoch 8/100
# 6976/6976 [==============================] - 6s 794us/step - loss: 63.6723 - val_loss: 1379.5131
# Epoch 9/100
# 6976/6976 [==============================] - 6s 789us/step - loss: 60.9065 - val_loss: 1311.5210
# Epoch 10/100
# 6976/6976 [==============================] - 6s 794us/step - loss: 58.1888 - val_loss: 1260.4409
# Epoch 11/100
# 6976/6976 [==============================] - 6s 792us/step - loss: 55.6315 - val_loss: 1226.6637
# Epoch 12/100
# 6976/6976 [==============================] - 6s 795us/step - loss: 54.2158 - val_loss: 1151.2971
# Epoch 13/100
# 6976/6976 [==============================] - 6s 804us/step - loss: 52.4341 - val_loss: 1055.7571
# Epoch 14/100
# 6976/6976 [==============================] - 6s 813us/step - loss: 51.2024 - val_loss: 1023.2168
# Epoch 15/100
# 6976/6976 [==============================] - 6s 797us/step - loss: 50.4044 - val_loss: 991.5029
# Epoch 16/100
# 6976/6976 [==============================] - 6s 797us/step - loss: 49.2549 - val_loss: 938.5280
# Epoch 17/100
# 6976/6976 [==============================] - 6s 796us/step - loss: 48.7990 - val_loss: 877.7744
# Epoch 18/100
# 6976/6976 [==============================] - 6s 793us/step - loss: 48.3854 - val_loss: 862.9188
# Epoch 19/100
# 6976/6976 [==============================] - 6s 802us/step - loss: 48.0402 - val_loss: 829.2869
# Epoch 20/100
# 6976/6976 [==============================] - 6s 805us/step - loss: 48.1722 - val_loss: 811.9539
# Epoch 21/100
# 6976/6976 [==============================] - 6s 799us/step - loss: 48.0162 - val_loss: 781.7902
# Epoch 22/100
# 6976/6976 [==============================] - 6s 797us/step - loss: 48.1094 - val_loss: 763.0651
# Epoch 23/100
# 6976/6976 [==============================] - 6s 800us/step - loss: 47.9598 - val_loss: 766.9326
# Epoch 24/100
# 6976/6976 [==============================] - 6s 807us/step - loss: 47.5094 - val_loss: 780.0588
# Epoch 25/100
# 6976/6976 [==============================] - 6s 812us/step - loss: 47.9917 - val_loss: 781.2396
# Epoch 26/100
# 6976/6976 [==============================] - 6s 804us/step - loss: 47.8043 - val_loss: 787.1720
# Epoch 27/100
# 6976/6976 [==============================] - 6s 797us/step - loss: 47.8991 - val_loss: 803.3781
# 1353/1353 [==============================] - 1s 460us/step
# Completed 15 splits
# Epoch 1/100
# 7306/7306 [==============================] - 6s 810us/step - loss: 614.7151 - val_loss: 17921.9336
# Epoch 2/100
# 7306/7306 [==============================] - 6s 798us/step - loss: 119.0223 - val_loss: 9303.0996
# Epoch 3/100
# 7306/7306 [==============================] - 6s 802us/step - loss: 89.8912 - val_loss: 5767.7842
# Epoch 4/100
# 7306/7306 [==============================] - 6s 803us/step - loss: 77.7948 - val_loss: 3931.5142
# Epoch 5/100
# 7306/7306 [==============================] - 6s 801us/step - loss: 71.2349 - val_loss: 2825.5522
# Epoch 6/100
# 7306/7306 [==============================] - 6s 811us/step - loss: 67.9346 - val_loss: 2465.2839
# Epoch 7/100
# 7306/7306 [==============================] - 6s 800us/step - loss: 64.6400 - val_loss: 1893.6608
# Epoch 8/100
# 7306/7306 [==============================] - 6s 801us/step - loss: 62.4144 - val_loss: 1678.0830
# Epoch 9/100
# 7306/7306 [==============================] - 6s 802us/step - loss: 60.6372 - val_loss: 1503.0294
# Epoch 10/100
# 7306/7306 [==============================] - 6s 803us/step - loss: 58.9864 - val_loss: 1254.3687
# Epoch 11/100
# 7306/7306 [==============================] - 6s 802us/step - loss: 57.6361 - val_loss: 1080.6061
# Epoch 12/100
# 7306/7306 [==============================] - 6s 810us/step - loss: 56.9808 - val_loss: 1024.3279
# Epoch 13/100
# 7306/7306 [==============================] - 6s 796us/step - loss: 55.9418 - val_loss: 974.5508
# Epoch 14/100
# 7306/7306 [==============================] - 6s 800us/step - loss: 55.2736 - val_loss: 1044.0446
# Epoch 15/100
# 7306/7306 [==============================] - 6s 808us/step - loss: 54.9441 - val_loss: 1031.3531
# Epoch 16/100
# 7306/7306 [==============================] - 6s 802us/step - loss: 54.7287 - val_loss: 894.6658
# Epoch 17/100
# 7306/7306 [==============================] - 6s 808us/step - loss: 53.6922 - val_loss: 817.6671
# Epoch 18/100
# 7306/7306 [==============================] - 6s 811us/step - loss: 53.3246 - val_loss: 659.9680
# Epoch 19/100
# 7306/7306 [==============================] - 6s 806us/step - loss: 52.8965 - val_loss: 675.0510
# Epoch 20/100
# 7306/7306 [==============================] - 6s 808us/step - loss: 52.9342 - val_loss: 579.3064
# Epoch 21/100
# 7306/7306 [==============================] - 6s 821us/step - loss: 52.5926 - val_loss: 522.6794
# Epoch 22/100
# 7306/7306 [==============================] - 6s 804us/step - loss: 52.1726 - val_loss: 486.0819
# Epoch 23/100
# 7306/7306 [==============================] - 6s 808us/step - loss: 52.2319 - val_loss: 575.0693
# Epoch 24/100
# 7306/7306 [==============================] - 6s 801us/step - loss: 51.9025 - val_loss: 594.5467
# Epoch 25/100
# 7306/7306 [==============================] - 6s 799us/step - loss: 51.8914 - val_loss: 610.1426
# Epoch 26/100
# 7306/7306 [==============================] - 6s 799us/step - loss: 51.6701 - val_loss: 690.6660
# Epoch 27/100
# 7306/7306 [==============================] - 6s 802us/step - loss: 51.8441 - val_loss: 782.0840
# 1408/1408 [==============================] - 1s 462us/step
# Completed 16 splits
# Epoch 1/100
# 7763/7763 [==============================] - 7s 819us/step - loss: 614.7725 - val_loss: 3348.2302
# Epoch 2/100
# 7763/7763 [==============================] - 6s 809us/step - loss: 110.5600 - val_loss: 2051.6311
# Epoch 3/100
# 7763/7763 [==============================] - 6s 803us/step - loss: 95.0247 - val_loss: 1484.2419
# Epoch 4/100
# 7763/7763 [==============================] - 6s 805us/step - loss: 85.7551 - val_loss: 1077.0483
# Epoch 5/100
# 7763/7763 [==============================] - 6s 811us/step - loss: 79.1883 - val_loss: 830.2049
# Epoch 6/100
# 7763/7763 [==============================] - 6s 813us/step - loss: 74.5537 - val_loss: 643.9921
# Epoch 7/100
# 7763/7763 [==============================] - 6s 820us/step - loss: 72.1972 - val_loss: 493.9087
# Epoch 8/100
# 7763/7763 [==============================] - 6s 816us/step - loss: 70.8884 - val_loss: 411.2738
# Epoch 9/100
# 7763/7763 [==============================] - 6s 810us/step - loss: 69.9529 - val_loss: 354.2639
# Epoch 10/100
# 7763/7763 [==============================] - 6s 803us/step - loss: 69.5119 - val_loss: 320.3038
# Epoch 11/100
# 7763/7763 [==============================] - 6s 803us/step - loss: 69.1687 - val_loss: 281.5556
# Epoch 12/100
# 7763/7763 [==============================] - 6s 802us/step - loss: 68.7569 - val_loss: 265.8121
# Epoch 13/100
# 7763/7763 [==============================] - 6s 800us/step - loss: 68.7892 - val_loss: 247.2461
# Epoch 14/100
# 7763/7763 [==============================] - 6s 806us/step - loss: 68.4683 - val_loss: 227.0589
# Epoch 15/100
# 7763/7763 [==============================] - 6s 802us/step - loss: 68.0968 - val_loss: 213.4783
# Epoch 16/100
# 7763/7763 [==============================] - 6s 804us/step - loss: 68.0344 - val_loss: 206.0254
# Epoch 17/100
# 7763/7763 [==============================] - 6s 800us/step - loss: 67.6966 - val_loss: 187.2778
# Epoch 18/100
# 7763/7763 [==============================] - 6s 805us/step - loss: 67.6536 - val_loss: 183.4875
# Epoch 19/100
# 7763/7763 [==============================] - 6s 805us/step - loss: 67.7663 - val_loss: 186.0708
# Epoch 20/100
# 7763/7763 [==============================] - 6s 802us/step - loss: 67.5537 - val_loss: 178.7952
# Epoch 21/100
# 7763/7763 [==============================] - 6s 810us/step - loss: 67.4685 - val_loss: 179.9602
# Epoch 22/100
# 7763/7763 [==============================] - 6s 817us/step - loss: 67.0845 - val_loss: 167.9034
# Epoch 23/100
# 7763/7763 [==============================] - 6s 813us/step - loss: 67.0067 - val_loss: 169.8236
# Epoch 24/100
# 7763/7763 [==============================] - 6s 810us/step - loss: 67.0479 - val_loss: 163.9070
# Epoch 25/100
# 7763/7763 [==============================] - 6s 820us/step - loss: 66.8212 - val_loss: 159.1556
# Epoch 26/100
# 7763/7763 [==============================] - 6s 806us/step - loss: 66.6805 - val_loss: 161.0471
# Epoch 27/100
# 7763/7763 [==============================] - 6s 801us/step - loss: 66.7005 - val_loss: 154.2481
# Epoch 28/100
# 7763/7763 [==============================] - 6s 798us/step - loss: 66.4552 - val_loss: 153.6176
# Epoch 29/100
# 7763/7763 [==============================] - 6s 805us/step - loss: 66.3195 - val_loss: 156.1441
# Epoch 30/100
# 7763/7763 [==============================] - 6s 805us/step - loss: 66.1883 - val_loss: 151.3585
# Epoch 31/100
# 7763/7763 [==============================] - 6s 807us/step - loss: 66.1188 - val_loss: 148.1729
# Epoch 32/100
# 7763/7763 [==============================] - 6s 804us/step - loss: 65.9434 - val_loss: 143.7554
# Epoch 33/100
# 7763/7763 [==============================] - 6s 810us/step - loss: 65.9122 - val_loss: 147.1617
# Epoch 34/100
# 7763/7763 [==============================] - 6s 816us/step - loss: 65.7526 - val_loss: 142.4598
# Epoch 35/100
# 7763/7763 [==============================] - 6s 802us/step - loss: 65.5202 - val_loss: 142.6953
# Epoch 36/100
# 7763/7763 [==============================] - 6s 806us/step - loss: 65.7100 - val_loss: 141.8209
# Epoch 37/100
# 7763/7763 [==============================] - 6s 804us/step - loss: 65.6361 - val_loss: 140.0885
# Epoch 38/100
# 7763/7763 [==============================] - 6s 808us/step - loss: 65.2801 - val_loss: 138.7016
# Epoch 39/100
# 7763/7763 [==============================] - 6s 809us/step - loss: 65.3728 - val_loss: 136.0218
# Epoch 40/100
# 7763/7763 [==============================] - 6s 815us/step - loss: 65.3819 - val_loss: 136.1566
# Epoch 41/100
# 7763/7763 [==============================] - 6s 813us/step - loss: 65.3355 - val_loss: 132.2062
# Epoch 42/100
# 7763/7763 [==============================] - 6s 809us/step - loss: 65.5762 - val_loss: 136.0031
# Epoch 43/100
# 7763/7763 [==============================] - 6s 805us/step - loss: 65.2786 - val_loss: 133.0803
# Epoch 44/100
# 7763/7763 [==============================] - 6s 804us/step - loss: 65.4040 - val_loss: 130.4768
# Epoch 45/100
# 7763/7763 [==============================] - 6s 805us/step - loss: 65.2460 - val_loss: 130.9319
# Epoch 46/100
# 7763/7763 [==============================] - 6s 810us/step - loss: 65.3426 - val_loss: 130.2337
# Epoch 47/100
# 7763/7763 [==============================] - 6s 812us/step - loss: 65.2468 - val_loss: 127.1403
# Epoch 48/100
# 7763/7763 [==============================] - 6s 815us/step - loss: 65.1115 - val_loss: 124.1548
# Epoch 49/100
# 7763/7763 [==============================] - 6s 820us/step - loss: 65.1208 - val_loss: 123.1759
# Epoch 50/100
# 7763/7763 [==============================] - 6s 807us/step - loss: 65.1381 - val_loss: 123.6139
# Epoch 51/100
# 7763/7763 [==============================] - 6s 804us/step - loss: 64.9846 - val_loss: 123.2911
# Epoch 52/100
# 7763/7763 [==============================] - 6s 808us/step - loss: 64.8277 - val_loss: 119.4990
# Epoch 53/100
# 7763/7763 [==============================] - 6s 799us/step - loss: 65.1017 - val_loss: 123.4013
# Epoch 54/100
# 7763/7763 [==============================] - 6s 808us/step - loss: 65.1554 - val_loss: 124.9773
# Epoch 55/100
# 7763/7763 [==============================] - 6s 815us/step - loss: 64.8686 - val_loss: 125.7436
# Epoch 56/100
# 7763/7763 [==============================] - 6s 819us/step - loss: 64.8397 - val_loss: 125.8170
# Epoch 57/100
# 7763/7763 [==============================] - 6s 813us/step - loss: 65.0687 - val_loss: 124.7238
# 588/588 [==============================] - 0s 483us/step
# Completed 17 splits
# R2_oos NN3: -191.86017841935322

# %% [markdown]
# # NN3 algorithm for top 500 stocks

# %%
X = df_top_500[['Date'] + variables]
y = df_top_500['Adj Close t+1']

X['Date'] = pd.to_datetime(X['Date'])

initial_date = X['Date'].min()

predictions = []
y_test_list = []
dates = []


for split_num, (train_index, val_index, test_index) in enumerate(recursive_rolling_method(X,initial_date,date_column='Date',train_period=8,val_period=3,test_period=1,freq='years')):
    X_train = X.loc[train_index].drop('Date', axis=1)
    y_train = y.loc[train_index]

    X_val = X.loc[val_index].drop('Date', axis=1)
    y_val = y.loc[val_index]

    X_test = X.loc[test_index].drop('Date', axis=1)
    y_test = y.loc[test_index]

    
    input_shape = [X_train.shape[1]]
    
    
    mean_train = X_train.mean(axis=0)
    std_train  = X_train.std(axis=0)
    
    X_train = (X_train-mean_train) / std_train
    X_val = (X_val-mean_train) / std_train
    X_test = (X_test-mean_train) / std_train
    
    
    
    model = tf.keras.Sequential([
 
    tf.keras.layers.Flatten(input_shape=input_shape),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=8, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='linear')
    
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0, clipnorm=1.0, clipvalue=0.5), loss='mse')    
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[early_stopping])
    
    preds = model.predict(X_test)
    preds = preds.ravel()


    predictions.append(preds)
    dates.append(X.loc[y_test.index, 'Date'])
    y_test_list.append(y_test)



    del X_train, y_train, X_val, y_val, model, preds
    gc.collect()

    print(f"Completed {split_num + 1} splits")

predictions_all = np.concatenate(predictions, axis=0)
y_test_list_all = pd.concat(y_test_list, axis=0)
dates_all = pd.concat(dates, axis=0)


R2oos_NN3_top = 1 - np.sum(np.power(y_test_list_all - predictions_all, 2)) / np.sum(np.power(y_test_list_all, 2))
print("R2_oos NN3 Top 500: ", R2oos_NN3_top)
# Out:
#     Train period: 1997-02-28 00:00:00 - 2005-02-28 00:00:00  || Val period: 2005-03-28 00:00:00 - 2008-03-28 00:00:00  || Test period 2008-04-28 00:00:00 - 2009-04-28 00:00:00  || Train contains 29361  || Val contains 13204  || Test contains 4636
#     Train period: 1998-02-28 00:00:00 - 2006-02-28 00:00:00  || Val period: 2006-03-28 00:00:00 - 2009-03-28 00:00:00  || Test period 2009-04-28 00:00:00 - 2010-04-28 00:00:00  || Train contains 30401  || Val contains 13524  || Test contains 4741
#     Train period: 1999-02-28 00:00:00 - 2007-02-28 00:00:00  || Val period: 2007-03-28 00:00:00 - 2010-03-28 00:00:00  || Test period 2010-04-28 00:00:00 - 2011-04-28 00:00:00  || Train contains 31579  || Val contains 13863  || Test contains 4803
#     Train period: 2000-02-28 00:00:00 - 2008-02-28 00:00:00  || Val period: 2008-03-28 00:00:00 - 2011-03-28 00:00:00  || Test period 2011-04-28 00:00:00 - 2012-04-28 00:00:00  || Train contains 32931  || Val contains 14151  || Test contains 4951
#     Train period: 2001-02-28 00:00:00 - 2009-02-28 00:00:00  || Val period: 2009-03-28 00:00:00 - 2012-03-28 00:00:00  || Test period 2012-04-28 00:00:00 - 2013-04-28 00:00:00  || Train contains 34349  || Val contains 14468  || Test contains 5046
#     Train period: 2002-02-28 00:00:00 - 2010-02-28 00:00:00  || Val period: 2010-03-28 00:00:00 - 2013-03-28 00:00:00  || Test period 2013-04-28 00:00:00 - 2014-04-28 00:00:00  || Train contains 35303  || Val contains 14776  || Test contains 5126
#     Train period: 2003-02-28 00:00:00 - 2011-02-28 00:00:00  || Val period: 2011-03-28 00:00:00 - 2014-03-28 00:00:00  || Test period 2014-04-28 00:00:00 - 2015-04-28 00:00:00  || Train contains 35691  || Val contains 15097  || Test contains 5205
#     Train period: 2004-02-28 00:00:00 - 2012-02-28 00:00:00  || Val period: 2012-03-28 00:00:00 - 2015-03-28 00:00:00  || Test period 2015-04-28 00:00:00 - 2016-04-28 00:00:00  || Train contains 36109  || Val contains 15359  || Test contains 5271
#     Train period: 2005-02-28 00:00:00 - 2013-02-28 00:00:00  || Val period: 2013-03-28 00:00:00 - 2016-03-28 00:00:00  || Test period 2016-04-28 00:00:00 - 2017-04-28 00:00:00  || Train contains 37271  || Val contains 15579  || Test contains 5360
#     Train period: 2006-02-28 00:00:00 - 2014-02-28 00:00:00  || Val period: 2014-03-28 00:00:00 - 2017-03-28 00:00:00  || Test period 2017-04-28 00:00:00 - 2018-04-28 00:00:00  || Train contains 38082  || Val contains 15818  || Test contains 5431
#     Train period: 2007-02-28 00:00:00 - 2015-02-28 00:00:00  || Val period: 2015-03-28 00:00:00 - 2018-03-28 00:00:00  || Test period 2018-04-28 00:00:00 - 2019-04-28 00:00:00  || Train contains 39328  || Val contains 16041  || Test contains 5519
#     Train period: 2008-02-28 00:00:00 - 2016-02-28 00:00:00  || Val period: 2016-03-28 00:00:00 - 2019-03-28 00:00:00  || Test period 2019-04-28 00:00:00 - 2020-04-28 00:00:00  || Train contains 39645  || Val contains 16290  || Test contains 5580
#     Train period: 2009-02-28 00:00:00 - 2017-02-28 00:00:00  || Val period: 2017-03-28 00:00:00 - 2020-03-28 00:00:00  || Test period 2020-04-28 00:00:00 - 2021-04-28 00:00:00  || Train contains 39994  || Val contains 16516  || Test contains 5636
#     Train period: 2010-02-28 00:00:00 - 2018-02-28 00:00:00  || Val period: 2018-03-28 00:00:00 - 2021-03-28 00:00:00  || Test period 2021-04-28 00:00:00 - 2022-04-28 00:00:00  || Train contains 40679  || Val contains 16721  || Test contains 5657
#     Train period: 2011-02-28 00:00:00 - 2019-02-28 00:00:00  || Val period: 2019-03-28 00:00:00 - 2022-03-28 00:00:00  || Test period 2022-04-28 00:00:00 - 2023-04-28 00:00:00  || Train contains 41792  || Val contains 16855  || Test contains 5821
#     Train period: 2012-02-28 00:00:00 - 2020-02-28 00:00:00  || Val period: 2020-03-28 00:00:00 - 2023-03-28 00:00:00  || Test period 2023-04-28 00:00:00 - 2024-04-28 00:00:00  || Train contains 42440  || Val contains 17091  || Test contains 5757
#     Train period: 2013-02-28 00:00:00 - 2021-02-28 00:00:00  || Val period: 2021-03-28 00:00:00 - 2024-03-28 00:00:00  || Test period 2024-04-28 00:00:00 - 2025-04-28 00:00:00  || Train contains 43500  || Val contains 17229  || Test contains 2359
# Epoch 1/100
# 918/918 [==============================] - 1s 951us/step - loss: 581.7256 - val_loss: 526.8773
# Epoch 2/100
# 918/918 [==============================] - 1s 904us/step - loss: 145.8361 - val_loss: 193.9254
# Epoch 3/100
# 918/918 [==============================] - 1s 792us/step - loss: 63.8364 - val_loss: 103.1309
# Epoch 4/100
# 918/918 [==============================] - 1s 801us/step - loss: 48.3707 - val_loss: 65.2578
# Epoch 5/100
# 918/918 [==============================] - 1s 787us/step - loss: 40.0273 - val_loss: 46.0588
# Epoch 6/100
# 918/918 [==============================] - 1s 787us/step - loss: 33.6695 - val_loss: 34.3496
# Epoch 7/100
# 918/918 [==============================] - 1s 784us/step - loss: 29.2488 - val_loss: 31.2744
# Epoch 8/100
# 918/918 [==============================] - 1s 778us/step - loss: 25.9383 - val_loss: 26.2555
# Epoch 9/100
# 918/918 [==============================] - 1s 782us/step - loss: 23.4370 - val_loss: 24.2281
# Epoch 10/100
# 918/918 [==============================] - 1s 801us/step - loss: 21.9507 - val_loss: 19.8198
# Epoch 11/100
# 918/918 [==============================] - 1s 781us/step - loss: 20.4742 - val_loss: 16.1450
# Epoch 12/100
# 918/918 [==============================] - 1s 779us/step - loss: 19.7758 - val_loss: 14.7205
# Epoch 13/100
# 918/918 [==============================] - 1s 781us/step - loss: 18.8509 - val_loss: 11.7470
# Epoch 14/100
# 918/918 [==============================] - 1s 782us/step - loss: 18.5613 - val_loss: 11.7073
# Epoch 15/100
# 918/918 [==============================] - 1s 796us/step - loss: 18.0414 - val_loss: 10.1138
# Epoch 16/100
# 918/918 [==============================] - 1s 776us/step - loss: 17.9305 - val_loss: 9.6112
# Epoch 17/100
# 918/918 [==============================] - 1s 804us/step - loss: 17.7096 - val_loss: 10.7446
# Epoch 18/100
# 918/918 [==============================] - 1s 822us/step - loss: 17.4432 - val_loss: 9.8405
# Epoch 19/100
# 918/918 [==============================] - 1s 788us/step - loss: 17.4300 - val_loss: 9.1532
# Epoch 20/100
# 918/918 [==============================] - 1s 809us/step - loss: 17.3287 - val_loss: 8.6712
# Epoch 21/100
# 918/918 [==============================] - 1s 828us/step - loss: 17.0513 - val_loss: 8.3240
# Epoch 22/100
# 918/918 [==============================] - 1s 798us/step - loss: 16.8004 - val_loss: 8.1444
# Epoch 23/100
# 918/918 [==============================] - 1s 805us/step - loss: 16.9184 - val_loss: 7.9580
# Epoch 24/100
# 918/918 [==============================] - 1s 785us/step - loss: 16.7164 - val_loss: 7.8506
# Epoch 25/100
# 918/918 [==============================] - 1s 777us/step - loss: 16.6534 - val_loss: 7.5807
# Epoch 26/100
# 918/918 [==============================] - 1s 768us/step - loss: 16.7222 - val_loss: 7.6515
# Epoch 27/100
# 918/918 [==============================] - 1s 773us/step - loss: 16.4716 - val_loss: 7.5800
# Epoch 28/100
# 918/918 [==============================] - 1s 783us/step - loss: 16.3618 - val_loss: 7.5249
# Epoch 29/100
# 918/918 [==============================] - 1s 794us/step - loss: 16.3663 - val_loss: 7.6167
# Epoch 30/100
# 918/918 [==============================] - 1s 811us/step - loss: 16.3772 - val_loss: 7.3419
# Epoch 31/100
# 918/918 [==============================] - 1s 834us/step - loss: 16.1337 - val_loss: 7.2786
# Epoch 32/100
# 918/918 [==============================] - 1s 835us/step - loss: 16.0688 - val_loss: 7.1677
# Epoch 33/100
# 918/918 [==============================] - 1s 830us/step - loss: 16.0981 - val_loss: 7.4540
# Epoch 34/100
# 918/918 [==============================] - 1s 834us/step - loss: 15.8441 - val_loss: 7.2929
# Epoch 35/100
# 918/918 [==============================] - 1s 867us/step - loss: 15.7481 - val_loss: 7.2056
# Epoch 36/100
# 918/918 [==============================] - 1s 830us/step - loss: 15.8459 - val_loss: 7.3594
# Epoch 37/100
# 918/918 [==============================] - 1s 840us/step - loss: 15.7809 - val_loss: 7.1710
# 145/145 [==============================] - 0s 503us/step
# Completed 1 splits
# Epoch 1/100
# 951/951 [==============================] - 1s 930us/step - loss: 454.3580 - val_loss: 552.2748
# Epoch 2/100
# 951/951 [==============================] - 1s 833us/step - loss: 78.0103 - val_loss: 198.9689
# Epoch 3/100
# 951/951 [==============================] - 1s 830us/step - loss: 46.4031 - val_loss: 102.7706
# Epoch 4/100
# 951/951 [==============================] - 1s 834us/step - loss: 36.5372 - val_loss: 69.1545
# Epoch 5/100
# 951/951 [==============================] - 1s 844us/step - loss: 30.6524 - val_loss: 53.0099
# Epoch 6/100
# 951/951 [==============================] - 1s 839us/step - loss: 25.6647 - val_loss: 44.8584
# Epoch 7/100
# 951/951 [==============================] - 1s 834us/step - loss: 22.6222 - val_loss: 36.9451
# Epoch 8/100
# 951/951 [==============================] - 1s 837us/step - loss: 20.2118 - val_loss: 32.4611
# Epoch 9/100
# 951/951 [==============================] - 1s 829us/step - loss: 18.4111 - val_loss: 30.4946
# Epoch 10/100
# 951/951 [==============================] - 1s 827us/step - loss: 17.2509 - val_loss: 29.0467
# Epoch 11/100
# 951/951 [==============================] - 1s 831us/step - loss: 16.4014 - val_loss: 25.8338
# Epoch 12/100
# 951/951 [==============================] - 1s 832us/step - loss: 16.0720 - val_loss: 24.1674
# Epoch 13/100
# 951/951 [==============================] - 1s 826us/step - loss: 15.8099 - val_loss: 21.0028
# Epoch 14/100
# 951/951 [==============================] - 1s 828us/step - loss: 15.3418 - val_loss: 20.6876
# Epoch 15/100
# 951/951 [==============================] - 1s 830us/step - loss: 15.1510 - val_loss: 20.2140
# Epoch 16/100
# 951/951 [==============================] - 1s 831us/step - loss: 15.2891 - val_loss: 19.3911
# Epoch 17/100
# 951/951 [==============================] - 1s 828us/step - loss: 14.9663 - val_loss: 18.5279
# Epoch 18/100
# 951/951 [==============================] - 1s 869us/step - loss: 15.1051 - val_loss: 18.7231
# Epoch 19/100
# 951/951 [==============================] - 1s 839us/step - loss: 14.9737 - val_loss: 17.5249
# Epoch 20/100
# 951/951 [==============================] - 1s 829us/step - loss: 14.8327 - val_loss: 17.2855
# Epoch 21/100
# 951/951 [==============================] - 1s 833us/step - loss: 14.9247 - val_loss: 16.9737
# Epoch 22/100
# 951/951 [==============================] - 1s 840us/step - loss: 14.8255 - val_loss: 16.5373
# Epoch 23/100
# 951/951 [==============================] - 1s 828us/step - loss: 14.6381 - val_loss: 15.9494
# Epoch 24/100
# 951/951 [==============================] - 1s 835us/step - loss: 14.7352 - val_loss: 15.7358
# Epoch 25/100
# 951/951 [==============================] - 1s 834us/step - loss: 14.4422 - val_loss: 15.9964
# Epoch 26/100
# 951/951 [==============================] - 1s 843us/step - loss: 14.7535 - val_loss: 15.7769
# Epoch 27/100
# 951/951 [==============================] - 1s 829us/step - loss: 14.3884 - val_loss: 14.8544
# Epoch 28/100
# 951/951 [==============================] - 1s 887us/step - loss: 14.4645 - val_loss: 15.1711
# Epoch 29/100
# 951/951 [==============================] - 1s 965us/step - loss: 14.4663 - val_loss: 15.4273
# Epoch 30/100
# 951/951 [==============================] - 1s 907us/step - loss: 14.4394 - val_loss: 15.0553
# Epoch 31/100
# 951/951 [==============================] - 1s 950us/step - loss: 14.4618 - val_loss: 14.6832
# Epoch 32/100
# 951/951 [==============================] - 1s 908us/step - loss: 14.4307 - val_loss: 14.6826
# Epoch 33/100
# 951/951 [==============================] - 1s 877us/step - loss: 14.3947 - val_loss: 14.5038
# Epoch 34/100
# 951/951 [==============================] - 1s 889us/step - loss: 14.3357 - val_loss: 14.4079
# Epoch 35/100
# 951/951 [==============================] - 1s 879us/step - loss: 14.2266 - val_loss: 14.7880
# Epoch 36/100
# 951/951 [==============================] - 1s 867us/step - loss: 14.3418 - val_loss: 14.6300
# Epoch 37/100
# 951/951 [==============================] - 1s 879us/step - loss: 14.2093 - val_loss: 14.2753
# Epoch 38/100
# 951/951 [==============================] - 1s 853us/step - loss: 14.2914 - val_loss: 14.4461
# Epoch 39/100
# 951/951 [==============================] - 1s 858us/step - loss: 14.1568 - val_loss: 14.1093
# Epoch 40/100
# 951/951 [==============================] - 1s 843us/step - loss: 14.1810 - val_loss: 14.6251
# Epoch 41/100
# 951/951 [==============================] - 1s 867us/step - loss: 14.1562 - val_loss: 14.4751
# Epoch 42/100
# 951/951 [==============================] - 1s 943us/step - loss: 14.1311 - val_loss: 14.1596
# Epoch 43/100
# 951/951 [==============================] - 1s 955us/step - loss: 14.1600 - val_loss: 14.2410
# Epoch 44/100
# 951/951 [==============================] - 1s 907us/step - loss: 14.1387 - val_loss: 13.9675
# Epoch 45/100
# 951/951 [==============================] - 1s 966us/step - loss: 13.9316 - val_loss: 13.9329
# Epoch 46/100
# 951/951 [==============================] - 1s 942us/step - loss: 14.1585 - val_loss: 14.1481
# Epoch 47/100
# 951/951 [==============================] - 1s 904us/step - loss: 13.9703 - val_loss: 13.9569
# Epoch 48/100
# 951/951 [==============================] - 1s 1ms/step - loss: 14.0839 - val_loss: 14.0450
# Epoch 49/100
# 951/951 [==============================] - 1s 867us/step - loss: 13.9280 - val_loss: 13.7357
# Epoch 50/100
# 951/951 [==============================] - 1s 887us/step - loss: 13.8600 - val_loss: 13.9005
# Epoch 51/100
# 951/951 [==============================] - 1s 883us/step - loss: 13.8568 - val_loss: 13.9309
# Epoch 52/100
# 951/951 [==============================] - 1s 858us/step - loss: 13.8457 - val_loss: 13.9833
# Epoch 53/100
# 951/951 [==============================] - 1s 859us/step - loss: 13.8515 - val_loss: 14.1692
# Epoch 54/100
# 951/951 [==============================] - 1s 854us/step - loss: 13.8705 - val_loss: 13.8682
# 149/149 [==============================] - 0s 519us/step
# Completed 2 splits
# Epoch 1/100
# 987/987 [==============================] - 1s 977us/step - loss: 595.4516 - val_loss: 818.6265
# Epoch 2/100
# 987/987 [==============================] - 1s 895us/step - loss: 99.6125 - val_loss: 298.8888
# Epoch 3/100
# 987/987 [==============================] - 1s 848us/step - loss: 48.4381 - val_loss: 174.7848
# Epoch 4/100
# 987/987 [==============================] - 1s 844us/step - loss: 38.9545 - val_loss: 114.4237
# Epoch 5/100
# 987/987 [==============================] - 1s 863us/step - loss: 31.5792 - val_loss: 80.3487
# Epoch 6/100
# 987/987 [==============================] - 1s 865us/step - loss: 26.3170 - val_loss: 62.8444
# Epoch 7/100
# 987/987 [==============================] - 1s 835us/step - loss: 22.6861 - val_loss: 57.5988
# Epoch 8/100
# 987/987 [==============================] - 1s 849us/step - loss: 20.0078 - val_loss: 60.4457
# Epoch 9/100
# 987/987 [==============================] - 1s 839us/step - loss: 17.8596 - val_loss: 94.1976
# Epoch 10/100
# 987/987 [==============================] - 1s 854us/step - loss: 16.1589 - val_loss: 132.5801
# Epoch 11/100
# 987/987 [==============================] - 1s 838us/step - loss: 15.0557 - val_loss: 154.7113
# Epoch 12/100
# 987/987 [==============================] - 1s 845us/step - loss: 14.2016 - val_loss: 158.0665
# 151/151 [==============================] - 0s 529us/step
# Completed 3 splits
# Epoch 1/100
# 1030/1030 [==============================] - 1s 1ms/step - loss: 634.8179 - val_loss: 61672.2930
# Epoch 2/100
# 1030/1030 [==============================] - 1s 960us/step - loss: 93.7473 - val_loss: 17026.3281
# Epoch 3/100
# 1030/1030 [==============================] - 1s 1ms/step - loss: 42.5329 - val_loss: 2155.7822
# Epoch 4/100
# 1030/1030 [==============================] - 2s 2ms/step - loss: 32.5813 - val_loss: 642.5750
# Epoch 5/100
# 1030/1030 [==============================] - 2s 2ms/step - loss: 26.6673 - val_loss: 300.3087
# Epoch 6/100
# 1030/1030 [==============================] - 1s 1ms/step - loss: 22.5706 - val_loss: 221.5207
# Epoch 7/100
# 1030/1030 [==============================] - 1s 1ms/step - loss: 19.1150 - val_loss: 210.7005
# Epoch 8/100
# 1030/1030 [==============================] - 1s 1ms/step - loss: 16.6231 - val_loss: 244.8911
# Epoch 9/100
# 1030/1030 [==============================] - 1s 996us/step - loss: 14.5883 - val_loss: 706.3472
# Epoch 10/100
# 1030/1030 [==============================] - 1s 860us/step - loss: 12.8915 - val_loss: 911.0406
# Epoch 11/100
# 1030/1030 [==============================] - 1s 869us/step - loss: 11.9346 - val_loss: 1365.3002
# Epoch 12/100
# 1030/1030 [==============================] - 1s 886us/step - loss: 10.9897 - val_loss: 1572.2451
# 155/155 [==============================] - 0s 525us/step
# Completed 4 splits
# Epoch 1/100
# 1074/1074 [==============================] - 1s 938us/step - loss: 629.6700 - val_loss: 94204.2812
# Epoch 2/100
# 1074/1074 [==============================] - 1s 854us/step - loss: 101.2233 - val_loss: 41318.8359
# Epoch 3/100
# 1074/1074 [==============================] - 1s 858us/step - loss: 36.5640 - val_loss: 3268.9111
# Epoch 4/100
# 1074/1074 [==============================] - 1s 875us/step - loss: 28.0757 - val_loss: 1069.0337
# Epoch 5/100
# 1074/1074 [==============================] - 1s 871us/step - loss: 23.2780 - val_loss: 691.6163
# Epoch 6/100
# 1074/1074 [==============================] - 1s 865us/step - loss: 19.8805 - val_loss: 480.2815
# Epoch 7/100
# 1074/1074 [==============================] - 1s 862us/step - loss: 17.3276 - val_loss: 366.1863
# Epoch 8/100
# 1074/1074 [==============================] - 1s 869us/step - loss: 15.3371 - val_loss: 411.2895
# Epoch 9/100
# 1074/1074 [==============================] - 1s 893us/step - loss: 13.9008 - val_loss: 509.8785
# Epoch 10/100
# 1074/1074 [==============================] - 1s 861us/step - loss: 12.5570 - val_loss: 608.7831
# Epoch 11/100
# 1074/1074 [==============================] - 1s 866us/step - loss: 11.6542 - val_loss: 649.3389
# Epoch 12/100
# 1074/1074 [==============================] - 1s 925us/step - loss: 10.9076 - val_loss: 614.7700
# 158/158 [==============================] - 0s 549us/step
# Completed 5 splits
# Epoch 1/100
# 1104/1104 [==============================] - 1s 927us/step - loss: 628.0593 - val_loss: 1179.4414
# Epoch 2/100
# 1104/1104 [==============================] - 1s 859us/step - loss: 80.9689 - val_loss: 857.2678
# Epoch 3/100
# 1104/1104 [==============================] - 1s 853us/step - loss: 42.8110 - val_loss: 470.1943
# Epoch 4/100
# 1104/1104 [==============================] - 1s 869us/step - loss: 31.2753 - val_loss: 334.2981
# Epoch 5/100
# 1104/1104 [==============================] - 1s 855us/step - loss: 24.5402 - val_loss: 243.0639
# Epoch 6/100
# 1104/1104 [==============================] - 1s 850us/step - loss: 19.5717 - val_loss: 179.7214
# Epoch 7/100
# 1104/1104 [==============================] - 1s 854us/step - loss: 16.0048 - val_loss: 137.3530
# Epoch 8/100
# 1104/1104 [==============================] - 1s 849us/step - loss: 13.8032 - val_loss: 83.4347
# Epoch 9/100
# 1104/1104 [==============================] - 1s 848us/step - loss: 12.4558 - val_loss: 65.2950
# Epoch 10/100
# 1104/1104 [==============================] - 1s 868us/step - loss: 11.8356 - val_loss: 47.9653
# Epoch 11/100
# 1104/1104 [==============================] - 1s 863us/step - loss: 11.4320 - val_loss: 41.4170
# Epoch 12/100
# 1104/1104 [==============================] - 1s 874us/step - loss: 10.9752 - val_loss: 28.9075
# Epoch 13/100
# 1104/1104 [==============================] - 1s 863us/step - loss: 10.8945 - val_loss: 27.3000
# Epoch 14/100
# 1104/1104 [==============================] - 1s 853us/step - loss: 10.5699 - val_loss: 21.1047
# Epoch 15/100
# 1104/1104 [==============================] - 1s 851us/step - loss: 10.3806 - val_loss: 20.3059
# Epoch 16/100
# 1104/1104 [==============================] - 1s 867us/step - loss: 10.2778 - val_loss: 18.4740
# Epoch 17/100
# 1104/1104 [==============================] - 1s 852us/step - loss: 9.9480 - val_loss: 16.0301
# Epoch 18/100
# 1104/1104 [==============================] - 1s 850us/step - loss: 9.8714 - val_loss: 16.7683
# Epoch 19/100
# 1104/1104 [==============================] - 1s 855us/step - loss: 9.8057 - val_loss: 15.8328
# Epoch 20/100
# 1104/1104 [==============================] - 1s 845us/step - loss: 9.7300 - val_loss: 14.1272
# Epoch 21/100
# 1104/1104 [==============================] - 1s 855us/step - loss: 9.5529 - val_loss: 14.7598
# Epoch 22/100
# 1104/1104 [==============================] - 1s 866us/step - loss: 9.4632 - val_loss: 14.3499
# Epoch 23/100
# 1104/1104 [==============================] - 1s 871us/step - loss: 9.3186 - val_loss: 13.0014
# Epoch 24/100
# 1104/1104 [==============================] - 1s 890us/step - loss: 9.4199 - val_loss: 13.2352
# Epoch 25/100
# 1104/1104 [==============================] - 1s 869us/step - loss: 9.2094 - val_loss: 12.1736
# Epoch 26/100
# 1104/1104 [==============================] - 1s 856us/step - loss: 9.1332 - val_loss: 13.5831
# Epoch 27/100
# 1104/1104 [==============================] - 1s 852us/step - loss: 8.9967 - val_loss: 12.0500
# Epoch 28/100
# 1104/1104 [==============================] - 1s 860us/step - loss: 8.8647 - val_loss: 11.4544
# Epoch 29/100
# 1104/1104 [==============================] - 1s 946us/step - loss: 8.8962 - val_loss: 12.1690
# Epoch 30/100
# 1104/1104 [==============================] - 1s 853us/step - loss: 8.8727 - val_loss: 11.7117
# Epoch 31/100
# 1104/1104 [==============================] - 1s 845us/step - loss: 8.8198 - val_loss: 12.3703
# Epoch 32/100
# 1104/1104 [==============================] - 1s 847us/step - loss: 8.7304 - val_loss: 11.2396
# Epoch 33/100
# 1104/1104 [==============================] - 1s 875us/step - loss: 8.7380 - val_loss: 11.1017
# Epoch 34/100
# 1104/1104 [==============================] - 1s 864us/step - loss: 8.6239 - val_loss: 10.1370
# Epoch 35/100
# 1104/1104 [==============================] - 1s 851us/step - loss: 8.4992 - val_loss: 11.5973
# Epoch 36/100
# 1104/1104 [==============================] - 1s 868us/step - loss: 8.5290 - val_loss: 10.5338
# Epoch 37/100
# 1104/1104 [==============================] - 1s 860us/step - loss: 8.5486 - val_loss: 10.7102
# Epoch 38/100
# 1104/1104 [==============================] - 1s 885us/step - loss: 8.5107 - val_loss: 11.3211
# Epoch 39/100
# 1104/1104 [==============================] - 1s 845us/step - loss: 8.4252 - val_loss: 10.7275
# 161/161 [==============================] - 0s 513us/step
# Completed 6 splits
# Epoch 1/100
# 1116/1116 [==============================] - 1s 921us/step - loss: 741.8989 - val_loss: 2864.6436
# Epoch 2/100
# 1116/1116 [==============================] - 1s 854us/step - loss: 127.1732 - val_loss: 3182.0483
# Epoch 3/100
# 1116/1116 [==============================] - 1s 851us/step - loss: 54.7578 - val_loss: 2464.5674
# Epoch 4/100
# 1116/1116 [==============================] - 1s 871us/step - loss: 41.6666 - val_loss: 1993.0791
# Epoch 5/100
# 1116/1116 [==============================] - 1s 872us/step - loss: 33.1361 - val_loss: 1558.0741
# Epoch 6/100
# 1116/1116 [==============================] - 1s 855us/step - loss: 26.9567 - val_loss: 1222.1793
# Epoch 7/100
# 1116/1116 [==============================] - 1s 850us/step - loss: 22.6781 - val_loss: 829.8947
# Epoch 8/100
# 1116/1116 [==============================] - 1s 851us/step - loss: 19.6812 - val_loss: 663.3242
# Epoch 9/100
# 1116/1116 [==============================] - 1s 879us/step - loss: 17.5310 - val_loss: 561.3699
# Epoch 10/100
# 1116/1116 [==============================] - 1s 851us/step - loss: 16.1640 - val_loss: 401.8630
# Epoch 11/100
# 1116/1116 [==============================] - 1s 851us/step - loss: 15.4044 - val_loss: 380.4821
# Epoch 12/100
# 1116/1116 [==============================] - 1s 848us/step - loss: 14.6572 - val_loss: 333.8830
# Epoch 13/100
# 1116/1116 [==============================] - 1s 851us/step - loss: 14.1573 - val_loss: 313.5581
# Epoch 14/100
# 1116/1116 [==============================] - 1s 852us/step - loss: 13.8445 - val_loss: 274.6561
# Epoch 15/100
# 1116/1116 [==============================] - 1s 888us/step - loss: 13.5611 - val_loss: 245.2200
# Epoch 16/100
# 1116/1116 [==============================] - 1s 862us/step - loss: 13.1338 - val_loss: 196.3984
# Epoch 17/100
# 1116/1116 [==============================] - 1s 853us/step - loss: 12.9626 - val_loss: 192.2150
# Epoch 18/100
# 1116/1116 [==============================] - 1s 866us/step - loss: 12.7617 - val_loss: 176.9850
# Epoch 19/100
# 1116/1116 [==============================] - 1s 880us/step - loss: 12.6760 - val_loss: 139.2221
# Epoch 20/100
# 1116/1116 [==============================] - 1s 878us/step - loss: 12.5987 - val_loss: 147.4675
# Epoch 21/100
# 1116/1116 [==============================] - 1s 847us/step - loss: 12.4460 - val_loss: 147.6955
# Epoch 22/100
# 1116/1116 [==============================] - 1s 850us/step - loss: 12.4780 - val_loss: 122.6540
# Epoch 23/100
# 1116/1116 [==============================] - 1s 854us/step - loss: 12.3163 - val_loss: 105.9742
# Epoch 24/100
# 1116/1116 [==============================] - 1s 848us/step - loss: 12.2295 - val_loss: 101.7902
# Epoch 25/100
# 1116/1116 [==============================] - 1s 864us/step - loss: 11.9642 - val_loss: 82.6980
# Epoch 26/100
# 1116/1116 [==============================] - 1s 865us/step - loss: 11.9404 - val_loss: 86.5735
# Epoch 27/100
# 1116/1116 [==============================] - 1s 857us/step - loss: 11.9887 - val_loss: 78.5636
# Epoch 28/100
# 1116/1116 [==============================] - 1s 856us/step - loss: 12.0101 - val_loss: 78.2534
# Epoch 29/100
# 1116/1116 [==============================] - 1s 858us/step - loss: 11.7653 - val_loss: 72.0498
# Epoch 30/100
# 1116/1116 [==============================] - 1s 877us/step - loss: 11.8428 - val_loss: 73.6169
# Epoch 31/100
# 1116/1116 [==============================] - 1s 862us/step - loss: 11.8218 - val_loss: 72.8149
# Epoch 32/100
# 1116/1116 [==============================] - 1s 893us/step - loss: 11.7787 - val_loss: 56.7513
# Epoch 33/100
# 1116/1116 [==============================] - 1s 877us/step - loss: 11.8197 - val_loss: 57.2450
# Epoch 34/100
# 1116/1116 [==============================] - 1s 873us/step - loss: 11.7704 - val_loss: 58.2541
# Epoch 35/100
# 1116/1116 [==============================] - 1s 857us/step - loss: 11.7595 - val_loss: 56.7824
# Epoch 36/100
# 1116/1116 [==============================] - 1s 864us/step - loss: 11.5832 - val_loss: 44.1164
# Epoch 37/100
# 1116/1116 [==============================] - 1s 861us/step - loss: 11.6159 - val_loss: 53.4425
# Epoch 38/100
# 1116/1116 [==============================] - 1s 877us/step - loss: 11.5606 - val_loss: 44.0393
# Epoch 39/100
# 1116/1116 [==============================] - 1s 873us/step - loss: 11.6404 - val_loss: 51.5828
# Epoch 40/100
# 1116/1116 [==============================] - 1s 865us/step - loss: 11.6121 - val_loss: 48.4212
# Epoch 41/100
# 1116/1116 [==============================] - 1s 848us/step - loss: 11.5144 - val_loss: 40.4479
# Epoch 42/100
# 1116/1116 [==============================] - 1s 864us/step - loss: 11.4409 - val_loss: 44.0339
# Epoch 43/100
# 1116/1116 [==============================] - 1s 870us/step - loss: 11.3621 - val_loss: 46.4406
# Epoch 44/100
# 1116/1116 [==============================] - 1s 851us/step - loss: 11.2828 - val_loss: 40.9371
# Epoch 45/100
# 1116/1116 [==============================] - 1s 853us/step - loss: 11.2618 - val_loss: 32.8873
# Epoch 46/100
# 1116/1116 [==============================] - 1s 867us/step - loss: 11.1173 - val_loss: 31.0239
# Epoch 47/100
# 1116/1116 [==============================] - 1s 895us/step - loss: 11.2096 - val_loss: 36.7213
# Epoch 48/100
# 1116/1116 [==============================] - 1s 881us/step - loss: 11.1890 - val_loss: 41.1717
# Epoch 49/100
# 1116/1116 [==============================] - 1s 872us/step - loss: 10.9879 - val_loss: 36.8643
# Epoch 50/100
# 1116/1116 [==============================] - 1s 877us/step - loss: 11.0850 - val_loss: 31.9109
# Epoch 51/100
# 1116/1116 [==============================] - 1s 855us/step - loss: 11.0629 - val_loss: 43.8188
# 163/163 [==============================] - 0s 523us/step
# Completed 7 splits
# Epoch 1/100
# 1129/1129 [==============================] - 1s 919us/step - loss: 1022.8243 - val_loss: 1955.3683
# Epoch 2/100
# 1129/1129 [==============================] - 1s 853us/step - loss: 228.9890 - val_loss: 340.7190
# Epoch 3/100
# 1129/1129 [==============================] - 1s 883us/step - loss: 60.3481 - val_loss: 260.6198
# Epoch 4/100
# 1129/1129 [==============================] - 1s 854us/step - loss: 47.2536 - val_loss: 235.6007
# Epoch 5/100
# 1129/1129 [==============================] - 1s 877us/step - loss: 40.3120 - val_loss: 214.8976
# Epoch 6/100
# 1129/1129 [==============================] - 1s 871us/step - loss: 35.3845 - val_loss: 195.4886
# Epoch 7/100
# 1129/1129 [==============================] - 1s 862us/step - loss: 30.4144 - val_loss: 169.5753
# Epoch 8/100
# 1129/1129 [==============================] - 1s 885us/step - loss: 26.4667 - val_loss: 146.8918
# Epoch 9/100
# 1129/1129 [==============================] - 1s 862us/step - loss: 22.6991 - val_loss: 119.6085
# Epoch 10/100
# 1129/1129 [==============================] - 1s 872us/step - loss: 19.8266 - val_loss: 98.6822
# Epoch 11/100
# 1129/1129 [==============================] - 1s 857us/step - loss: 18.1742 - val_loss: 81.5216
# Epoch 12/100
# 1129/1129 [==============================] - 1s 856us/step - loss: 17.0418 - val_loss: 67.7919
# Epoch 13/100
# 1129/1129 [==============================] - 1s 854us/step - loss: 15.7918 - val_loss: 57.1358
# Epoch 14/100
# 1129/1129 [==============================] - 1s 891us/step - loss: 15.0485 - val_loss: 50.8909
# Epoch 15/100
# 1129/1129 [==============================] - 1s 867us/step - loss: 14.6637 - val_loss: 45.9659
# Epoch 16/100
# 1129/1129 [==============================] - 1s 886us/step - loss: 14.1976 - val_loss: 42.9577
# Epoch 17/100
# 1129/1129 [==============================] - 1s 889us/step - loss: 13.9051 - val_loss: 40.0777
# Epoch 18/100
# 1129/1129 [==============================] - 1s 860us/step - loss: 13.5911 - val_loss: 38.6614
# Epoch 19/100
# 1129/1129 [==============================] - 1s 861us/step - loss: 13.4404 - val_loss: 34.9501
# Epoch 20/100
# 1129/1129 [==============================] - 1s 849us/step - loss: 13.0328 - val_loss: 33.6560
# Epoch 21/100
# 1129/1129 [==============================] - 1s 865us/step - loss: 12.9408 - val_loss: 33.0734
# Epoch 22/100
# 1129/1129 [==============================] - 1s 845us/step - loss: 12.8878 - val_loss: 31.6548
# Epoch 23/100
# 1129/1129 [==============================] - 1s 853us/step - loss: 12.6111 - val_loss: 31.4037
# Epoch 24/100
# 1129/1129 [==============================] - 1s 887us/step - loss: 12.3781 - val_loss: 30.4458
# Epoch 25/100
# 1129/1129 [==============================] - 1s 856us/step - loss: 12.3983 - val_loss: 29.9545
# Epoch 26/100
# 1129/1129 [==============================] - 1s 870us/step - loss: 12.1718 - val_loss: 28.7840
# Epoch 27/100
# 1129/1129 [==============================] - 1s 856us/step - loss: 12.0380 - val_loss: 27.0245
# Epoch 28/100
# 1129/1129 [==============================] - 1s 888us/step - loss: 11.7588 - val_loss: 26.3424
# Epoch 29/100
# 1129/1129 [==============================] - 1s 894us/step - loss: 11.7344 - val_loss: 26.6873
# Epoch 30/100
# 1129/1129 [==============================] - 1s 857us/step - loss: 11.7635 - val_loss: 24.9757
# Epoch 31/100
# 1129/1129 [==============================] - 1s 870us/step - loss: 11.4954 - val_loss: 24.6135
# Epoch 32/100
# 1129/1129 [==============================] - 1s 853us/step - loss: 11.4737 - val_loss: 24.1063
# Epoch 33/100
# 1129/1129 [==============================] - 1s 850us/step - loss: 11.2907 - val_loss: 23.2375
# Epoch 34/100
# 1129/1129 [==============================] - 1s 865us/step - loss: 11.2358 - val_loss: 22.7371
# Epoch 35/100
# 1129/1129 [==============================] - 1s 902us/step - loss: 11.1687 - val_loss: 22.3577
# Epoch 36/100
# 1129/1129 [==============================] - 1s 865us/step - loss: 11.0486 - val_loss: 21.8761
# Epoch 37/100
# 1129/1129 [==============================] - 1s 856us/step - loss: 11.0010 - val_loss: 21.7924
# Epoch 38/100
# 1129/1129 [==============================] - 1s 905us/step - loss: 10.8450 - val_loss: 21.2667
# Epoch 39/100
# 1129/1129 [==============================] - 1s 860us/step - loss: 10.8412 - val_loss: 21.2170
# Epoch 40/100
# 1129/1129 [==============================] - 1s 857us/step - loss: 10.6979 - val_loss: 20.4675
# Epoch 41/100
# 1129/1129 [==============================] - 1s 857us/step - loss: 10.7101 - val_loss: 20.9564
# Epoch 42/100
# 1129/1129 [==============================] - 1s 852us/step - loss: 10.5564 - val_loss: 21.0065
# Epoch 43/100
# 1129/1129 [==============================] - 1s 864us/step - loss: 10.6296 - val_loss: 20.6697
# Epoch 44/100
# 1129/1129 [==============================] - 1s 849us/step - loss: 10.5095 - val_loss: 19.9557
# Epoch 45/100
# 1129/1129 [==============================] - 1s 878us/step - loss: 10.4132 - val_loss: 19.6553
# Epoch 46/100
# 1129/1129 [==============================] - 1s 862us/step - loss: 10.4413 - val_loss: 19.6403
# Epoch 47/100
# 1129/1129 [==============================] - 1s 852us/step - loss: 10.3260 - val_loss: 19.1420
# Epoch 48/100
# 1129/1129 [==============================] - 1s 868us/step - loss: 10.3089 - val_loss: 18.8736
# Epoch 49/100
# 1129/1129 [==============================] - 1s 871us/step - loss: 10.2296 - val_loss: 19.1110
# Epoch 50/100
# 1129/1129 [==============================] - 1s 864us/step - loss: 10.2226 - val_loss: 18.7192
# Epoch 51/100
# 1129/1129 [==============================] - 1s 864us/step - loss: 10.2104 - val_loss: 18.6813
# Epoch 52/100
# 1129/1129 [==============================] - 1s 851us/step - loss: 10.1150 - val_loss: 18.7732
# Epoch 53/100
# 1129/1129 [==============================] - 1s 858us/step - loss: 10.0663 - val_loss: 18.8714
# Epoch 54/100
# 1129/1129 [==============================] - 1s 851us/step - loss: 10.0775 - val_loss: 18.4812
# Epoch 55/100
# 1129/1129 [==============================] - 1s 862us/step - loss: 9.9737 - val_loss: 18.0336
# Epoch 56/100
# 1129/1129 [==============================] - 1s 871us/step - loss: 9.8913 - val_loss: 17.9613
# Epoch 57/100
# 1129/1129 [==============================] - 1s 878us/step - loss: 9.8330 - val_loss: 17.4032
# Epoch 58/100
# 1129/1129 [==============================] - 1s 868us/step - loss: 9.7862 - val_loss: 16.2786
# Epoch 59/100
# 1129/1129 [==============================] - 1s 852us/step - loss: 9.7518 - val_loss: 16.1767
# Epoch 60/100
# 1129/1129 [==============================] - 1s 854us/step - loss: 9.7071 - val_loss: 16.2748
# Epoch 61/100
# 1129/1129 [==============================] - 1s 867us/step - loss: 9.6543 - val_loss: 15.5364
# Epoch 62/100
# 1129/1129 [==============================] - 1s 848us/step - loss: 9.6857 - val_loss: 15.5425
# Epoch 63/100
# 1129/1129 [==============================] - 1s 906us/step - loss: 9.5384 - val_loss: 15.8083
# Epoch 64/100
# 1129/1129 [==============================] - 1s 885us/step - loss: 9.4917 - val_loss: 14.9042
# Epoch 65/100
# 1129/1129 [==============================] - 1s 847us/step - loss: 9.4457 - val_loss: 14.9334
# Epoch 66/100
# 1129/1129 [==============================] - 1s 872us/step - loss: 9.4103 - val_loss: 15.5668
# Epoch 67/100
# 1129/1129 [==============================] - 1s 879us/step - loss: 9.3540 - val_loss: 14.1834
# Epoch 68/100
# 1129/1129 [==============================] - 1s 858us/step - loss: 9.2890 - val_loss: 14.1674
# Epoch 69/100
# 1129/1129 [==============================] - 1s 858us/step - loss: 9.2999 - val_loss: 13.7907
# Epoch 70/100
# 1129/1129 [==============================] - 1s 869us/step - loss: 9.2918 - val_loss: 13.4300
# Epoch 71/100
# 1129/1129 [==============================] - 1s 856us/step - loss: 9.2292 - val_loss: 14.1650
# Epoch 72/100
# 1129/1129 [==============================] - 1s 850us/step - loss: 9.2659 - val_loss: 13.5613
# Epoch 73/100
# 1129/1129 [==============================] - 1s 870us/step - loss: 9.1969 - val_loss: 13.3390
# Epoch 74/100
# 1129/1129 [==============================] - 1s 862us/step - loss: 9.2312 - val_loss: 13.2205
# Epoch 75/100
# 1129/1129 [==============================] - 1s 859us/step - loss: 9.2536 - val_loss: 13.6103
# Epoch 76/100
# 1129/1129 [==============================] - 1s 884us/step - loss: 9.1797 - val_loss: 13.1864
# Epoch 77/100
# 1129/1129 [==============================] - 1s 863us/step - loss: 9.2328 - val_loss: 13.0103
# Epoch 78/100
# 1129/1129 [==============================] - 1s 854us/step - loss: 9.1249 - val_loss: 12.9242
# Epoch 79/100
# 1129/1129 [==============================] - 1s 862us/step - loss: 9.2508 - val_loss: 12.5298
# Epoch 80/100
# 1129/1129 [==============================] - 1s 857us/step - loss: 9.1735 - val_loss: 12.1121
# Epoch 81/100
# 1129/1129 [==============================] - 1s 857us/step - loss: 9.0725 - val_loss: 12.1135
# Epoch 82/100
# 1129/1129 [==============================] - 1s 851us/step - loss: 9.0966 - val_loss: 12.1473
# Epoch 83/100
# 1129/1129 [==============================] - 1s 859us/step - loss: 9.0274 - val_loss: 12.0076
# Epoch 84/100
# 1129/1129 [==============================] - 1s 849us/step - loss: 9.1013 - val_loss: 12.0762
# Epoch 85/100
# 1129/1129 [==============================] - 1s 853us/step - loss: 9.0303 - val_loss: 11.8525
# Epoch 86/100
# 1129/1129 [==============================] - 1s 880us/step - loss: 9.0592 - val_loss: 11.6741
# Epoch 87/100
# 1129/1129 [==============================] - 1s 860us/step - loss: 8.9952 - val_loss: 11.8159
# Epoch 88/100
# 1129/1129 [==============================] - 1s 918us/step - loss: 9.0479 - val_loss: 11.6314
# Epoch 89/100
# 1129/1129 [==============================] - 1s 857us/step - loss: 8.9858 - val_loss: 11.6047
# Epoch 90/100
# 1129/1129 [==============================] - 1s 881us/step - loss: 9.0489 - val_loss: 11.4402
# Epoch 91/100
# 1129/1129 [==============================] - 1s 871us/step - loss: 8.9995 - val_loss: 11.3429
# Epoch 92/100
# 1129/1129 [==============================] - 1s 870us/step - loss: 8.8869 - val_loss: 11.4599
# Epoch 93/100
# 1129/1129 [==============================] - 1s 859us/step - loss: 8.9653 - val_loss: 11.1827
# Epoch 94/100
# 1129/1129 [==============================] - 1s 860us/step - loss: 8.9012 - val_loss: 11.2721
# Epoch 95/100
# 1129/1129 [==============================] - 1s 849us/step - loss: 8.9059 - val_loss: 11.2689
# Epoch 96/100
# 1129/1129 [==============================] - 1s 868us/step - loss: 8.7999 - val_loss: 10.6991
# Epoch 97/100
# 1129/1129 [==============================] - 1s 893us/step - loss: 8.8110 - val_loss: 11.3752
# Epoch 98/100
# 1129/1129 [==============================] - 1s 875us/step - loss: 8.7893 - val_loss: 11.0750
# Epoch 99/100
# 1129/1129 [==============================] - 1s 854us/step - loss: 8.9113 - val_loss: 11.0045
# Epoch 100/100
# 1129/1129 [==============================] - 1s 870us/step - loss: 8.8672 - val_loss: 11.1749
# 165/165 [==============================] - 0s 517us/step
# Completed 8 splits
# Epoch 1/100
# 1165/1165 [==============================] - 1s 923us/step - loss: 829.0768 - val_loss: 642.9695
# Epoch 2/100
# 1165/1165 [==============================] - 1s 856us/step - loss: 89.1071 - val_loss: 94.0497
# Epoch 3/100
# 1165/1165 [==============================] - 1s 852us/step - loss: 51.7864 - val_loss: 76.8456
# Epoch 4/100
# 1165/1165 [==============================] - 1s 846us/step - loss: 39.9556 - val_loss: 53.0143
# Epoch 5/100
# 1165/1165 [==============================] - 1s 877us/step - loss: 31.6554 - val_loss: 39.4616
# Epoch 6/100
# 1165/1165 [==============================] - 1s 853us/step - loss: 25.7882 - val_loss: 27.3072
# Epoch 7/100
# 1165/1165 [==============================] - 1s 853us/step - loss: 22.3141 - val_loss: 22.1511
# Epoch 8/100
# 1165/1165 [==============================] - 1s 856us/step - loss: 20.3602 - val_loss: 20.4502
# Epoch 9/100
# 1165/1165 [==============================] - 1s 863us/step - loss: 19.0986 - val_loss: 18.1922
# Epoch 10/100
# 1165/1165 [==============================] - 1s 874us/step - loss: 17.8095 - val_loss: 17.9505
# Epoch 11/100
# 1165/1165 [==============================] - 1s 853us/step - loss: 16.9026 - val_loss: 17.3223
# Epoch 12/100
# 1165/1165 [==============================] - 1s 845us/step - loss: 15.9950 - val_loss: 17.8577
# Epoch 13/100
# 1165/1165 [==============================] - 1s 902us/step - loss: 15.1903 - val_loss: 17.1678
# Epoch 14/100
# 1165/1165 [==============================] - 1s 842us/step - loss: 14.2714 - val_loss: 17.1005
# Epoch 15/100
# 1165/1165 [==============================] - 1s 855us/step - loss: 13.7020 - val_loss: 16.8915
# Epoch 16/100
# 1165/1165 [==============================] - 1s 854us/step - loss: 13.1041 - val_loss: 17.1937
# Epoch 17/100
# 1165/1165 [==============================] - 1s 861us/step - loss: 12.3707 - val_loss: 17.0766
# Epoch 18/100
# 1165/1165 [==============================] - 1s 846us/step - loss: 12.0251 - val_loss: 16.7202
# Epoch 19/100
# 1165/1165 [==============================] - 1s 854us/step - loss: 11.5524 - val_loss: 16.8128
# Epoch 20/100
# 1165/1165 [==============================] - 1s 841us/step - loss: 11.2647 - val_loss: 16.8830
# Epoch 21/100
# 1165/1165 [==============================] - 1s 860us/step - loss: 10.9939 - val_loss: 16.5284
# Epoch 22/100
# 1165/1165 [==============================] - 1s 850us/step - loss: 10.8059 - val_loss: 16.5125
# Epoch 23/100
# 1165/1165 [==============================] - 1s 852us/step - loss: 10.6481 - val_loss: 17.1992
# Epoch 24/100
# 1165/1165 [==============================] - 1s 877us/step - loss: 10.4767 - val_loss: 16.8568
# Epoch 25/100
# 1165/1165 [==============================] - 1s 852us/step - loss: 10.3266 - val_loss: 16.6162
# Epoch 26/100
# 1165/1165 [==============================] - 1s 845us/step - loss: 10.2904 - val_loss: 16.9107
# Epoch 27/100
# 1165/1165 [==============================] - 1s 854us/step - loss: 10.1637 - val_loss: 16.4826
# Epoch 28/100
# 1165/1165 [==============================] - 1s 846us/step - loss: 10.0849 - val_loss: 17.4513
# Epoch 29/100
# 1165/1165 [==============================] - 1s 878us/step - loss: 9.9405 - val_loss: 16.4053
# Epoch 30/100
# 1165/1165 [==============================] - 1s 867us/step - loss: 9.9777 - val_loss: 16.4344
# Epoch 31/100
# 1165/1165 [==============================] - 1s 884us/step - loss: 9.7128 - val_loss: 17.5778
# Epoch 32/100
# 1165/1165 [==============================] - 1s 869us/step - loss: 9.7168 - val_loss: 16.6681
# Epoch 33/100
# 1165/1165 [==============================] - 1s 846us/step - loss: 9.7695 - val_loss: 16.2611
# Epoch 34/100
# 1165/1165 [==============================] - 1s 874us/step - loss: 9.7699 - val_loss: 16.5718
# Epoch 35/100
# 1165/1165 [==============================] - 1s 873us/step - loss: 9.6856 - val_loss: 16.4105
# Epoch 36/100
# 1165/1165 [==============================] - 1s 844us/step - loss: 9.6938 - val_loss: 16.9049
# Epoch 37/100
# 1165/1165 [==============================] - 1s 860us/step - loss: 9.7224 - val_loss: 16.2644
# Epoch 38/100
# 1165/1165 [==============================] - 1s 852us/step - loss: 9.6206 - val_loss: 16.2981
# 168/168 [==============================] - 0s 529us/step
# Completed 9 splits
# Epoch 1/100
# 1191/1191 [==============================] - 1s 934us/step - loss: 1084.2288 - val_loss: 1146.1508
# Epoch 2/100
# 1191/1191 [==============================] - 1s 842us/step - loss: 97.3551 - val_loss: 96.7324
# Epoch 3/100
# 1191/1191 [==============================] - 1s 837us/step - loss: 50.3830 - val_loss: 84.2076
# Epoch 4/100
# 1191/1191 [==============================] - 1s 859us/step - loss: 39.3052 - val_loss: 74.1114
# Epoch 5/100
# 1191/1191 [==============================] - 1s 848us/step - loss: 32.0477 - val_loss: 64.1427
# Epoch 6/100
# 1191/1191 [==============================] - 1s 840us/step - loss: 26.7264 - val_loss: 55.5520
# Epoch 7/100
# 1191/1191 [==============================] - 1s 835us/step - loss: 22.2272 - val_loss: 42.1835
# Epoch 8/100
# 1191/1191 [==============================] - 1s 852us/step - loss: 18.5858 - val_loss: 34.8727
# Epoch 9/100
# 1191/1191 [==============================] - 1s 854us/step - loss: 15.6353 - val_loss: 27.2417
# Epoch 10/100
# 1191/1191 [==============================] - 1s 851us/step - loss: 13.6911 - val_loss: 28.0497
# Epoch 11/100
# 1191/1191 [==============================] - 1s 866us/step - loss: 12.4372 - val_loss: 22.2150
# Epoch 12/100
# 1191/1191 [==============================] - 1s 843us/step - loss: 11.6552 - val_loss: 21.4464
# Epoch 13/100
# 1191/1191 [==============================] - 1s 841us/step - loss: 11.2455 - val_loss: 20.6527
# Epoch 14/100
# 1191/1191 [==============================] - 1s 889us/step - loss: 10.9371 - val_loss: 21.3393
# Epoch 15/100
# 1191/1191 [==============================] - 1s 838us/step - loss: 10.7477 - val_loss: 20.9209
# Epoch 16/100
# 1191/1191 [==============================] - 1s 851us/step - loss: 10.6399 - val_loss: 20.0454
# Epoch 17/100
# 1191/1191 [==============================] - 1s 874us/step - loss: 10.4488 - val_loss: 20.6928
# Epoch 18/100
# 1191/1191 [==============================] - 1s 852us/step - loss: 10.3505 - val_loss: 20.0815
# Epoch 19/100
# 1191/1191 [==============================] - 1s 841us/step - loss: 10.3075 - val_loss: 20.4651
# Epoch 20/100
# 1191/1191 [==============================] - 1s 840us/step - loss: 10.2554 - val_loss: 21.0835
# Epoch 21/100
# 1191/1191 [==============================] - 1s 857us/step - loss: 10.1594 - val_loss: 21.6261
# 170/170 [==============================] - 0s 518us/step
# Completed 10 splits
# Epoch 1/100
# 1229/1229 [==============================] - 1s 887us/step - loss: 1417.8751 - val_loss: 1885.2673
# Epoch 2/100
# 1229/1229 [==============================] - 1s 861us/step - loss: 149.5245 - val_loss: 139.8982
# Epoch 3/100
# 1229/1229 [==============================] - 1s 818us/step - loss: 69.8733 - val_loss: 113.9095
# Epoch 4/100
# 1229/1229 [==============================] - 1s 831us/step - loss: 55.1977 - val_loss: 100.9271
# Epoch 5/100
# 1229/1229 [==============================] - 1s 817us/step - loss: 45.6783 - val_loss: 87.9466
# Epoch 6/100
# 1229/1229 [==============================] - 1s 832us/step - loss: 38.5601 - val_loss: 72.2679
# Epoch 7/100
# 1229/1229 [==============================] - 1s 821us/step - loss: 32.5116 - val_loss: 61.5052
# Epoch 8/100
# 1229/1229 [==============================] - 1s 854us/step - loss: 27.3159 - val_loss: 55.7279
# Epoch 9/100
# 1229/1229 [==============================] - 1s 840us/step - loss: 22.7839 - val_loss: 45.6384
# Epoch 10/100
# 1229/1229 [==============================] - 1s 814us/step - loss: 19.2358 - val_loss: 39.5175
# Epoch 11/100
# 1229/1229 [==============================] - 1s 846us/step - loss: 16.6167 - val_loss: 31.2480
# Epoch 12/100
# 1229/1229 [==============================] - 1s 814us/step - loss: 15.0766 - val_loss: 29.5445
# Epoch 13/100
# 1229/1229 [==============================] - 1s 836us/step - loss: 14.1394 - val_loss: 27.9039
# Epoch 14/100
# 1229/1229 [==============================] - 1s 822us/step - loss: 13.6898 - val_loss: 27.5281
# Epoch 15/100
# 1229/1229 [==============================] - 1s 897us/step - loss: 13.2318 - val_loss: 26.8989
# Epoch 16/100
# 1229/1229 [==============================] - 1s 815us/step - loss: 13.0872 - val_loss: 26.0680
# Epoch 17/100
# 1229/1229 [==============================] - 1s 828us/step - loss: 12.7840 - val_loss: 26.3306
# Epoch 18/100
# 1229/1229 [==============================] - 1s 814us/step - loss: 12.7346 - val_loss: 25.7030
# Epoch 19/100
# 1229/1229 [==============================] - 1s 815us/step - loss: 12.7808 - val_loss: 25.3483
# Epoch 20/100
# 1229/1229 [==============================] - 1s 865us/step - loss: 12.5244 - val_loss: 25.1738
# Epoch 21/100
# 1229/1229 [==============================] - 1s 817us/step - loss: 12.5222 - val_loss: 25.1661
# Epoch 22/100
# 1229/1229 [==============================] - 1s 825us/step - loss: 12.4183 - val_loss: 25.5928
# Epoch 23/100
# 1229/1229 [==============================] - 1s 809us/step - loss: 12.5596 - val_loss: 24.8010
# Epoch 24/100
# 1229/1229 [==============================] - 1s 827us/step - loss: 12.3486 - val_loss: 24.8393
# Epoch 25/100
# 1229/1229 [==============================] - 1s 810us/step - loss: 12.3145 - val_loss: 25.1443
# Epoch 26/100
# ...
# Epoch 64/100
# 1250/1250 [==============================] - 1s 844us/step - loss: 13.7400 - val_loss: 68.0451
# Epoch 65/100
# 1250/1250 [==============================] - 1s 876us/step - loss: 13.6880 - val_loss: 67.3083
# Epoch 66/100
# 1250/1250 [==============================] - 1s 844us/step - loss: 13.6205 - val_loss: 67.2161
# Epoch 67/100
# 1250/1250 [==============================] - 1s 855us/step - loss: 13.5827 - val_loss: 67.4653
# Epoch 68/100
# 1250/1250 [==============================] - 1s 842us/step - loss: 13.4363 - val_loss: 69.1940
# Epoch 69/100
# 1250/1250 [==============================] - 1s 849us/step - loss: 13.3187 - val_loss: 68.8035
# Epoch 70/100
# 1250/1250 [==============================] - 1s 854us/step - loss: 13.3816 - val_loss: 66.9417
# Epoch 71/100
# 1250/1250 [==============================] - 1s 843us/step - loss: 13.2526 - val_loss: 66.8417
# Epoch 72/100
# 1250/1250 [==============================] - 1s 883us/step - loss: 13.1803 - val_loss: 66.8420
# Epoch 73/100
# 1250/1250 [==============================] - 1s 891us/step - loss: 13.0964 - val_loss: 67.4247
# Epoch 74/100
# 1250/1250 [==============================] - 1s 935us/step - loss: 13.0583 - val_loss: 66.5454
# Epoch 75/100
# 1250/1250 [==============================] - 1s 864us/step - loss: 13.0559 - val_loss: 66.9412
# Epoch 76/100
# 1250/1250 [==============================] - 1s 846us/step - loss: 13.0237 - val_loss: 68.9186
# Epoch 77/100
# 1250/1250 [==============================] - 1s 860us/step - loss: 12.9239 - val_loss: 66.8558
# Epoch 78/100
# 1250/1250 [==============================] - 1s 841us/step - loss: 12.9194 - val_loss: 68.4098
# Epoch 79/100
# 1250/1250 [==============================] - 1s 854us/step - loss: 12.8710 - val_loss: 67.1728
# 177/177 [==============================] - 0s 505us/step
# Completed 13 splits
# Epoch 1/100
# 1272/1272 [==============================] - 2s 977us/step - loss: 2243.7234 - val_loss: 8131.0459
# Epoch 2/100
# 1272/1272 [==============================] - 1s 830us/step - loss: 185.1622 - val_loss: 6080.4580
# Epoch 3/100
# 1272/1272 [==============================] - 1s 858us/step - loss: 96.8521 - val_loss: 4153.8970
# Epoch 4/100
# 1272/1272 [==============================] - 1s 857us/step - loss: 73.7815 - val_loss: 3060.6372
# Epoch 5/100
# 1272/1272 [==============================] - 1s 841us/step - loss: 62.2788 - val_loss: 2376.5044
# Epoch 6/100
# 1272/1272 [==============================] - 1s 857us/step - loss: 54.6225 - val_loss: 1925.5978
# Epoch 7/100
# 1272/1272 [==============================] - 1s 864us/step - loss: 48.4050 - val_loss: 1580.8074
# Epoch 8/100
# 1272/1272 [==============================] - 1s 853us/step - loss: 43.7579 - val_loss: 1363.0283
# Epoch 9/100
# 1272/1272 [==============================] - 1s 849us/step - loss: 39.3332 - val_loss: 1185.6396
# Epoch 10/100
# 1272/1272 [==============================] - 1s 845us/step - loss: 35.7912 - val_loss: 1014.2951
# Epoch 11/100
# 1272/1272 [==============================] - 1s 860us/step - loss: 32.4426 - val_loss: 926.8580
# Epoch 12/100
# 1272/1272 [==============================] - 1s 850us/step - loss: 29.7063 - val_loss: 828.1837
# Epoch 13/100
# 1272/1272 [==============================] - 1s 857us/step - loss: 27.1716 - val_loss: 738.5010
# Epoch 14/100
# 1272/1272 [==============================] - 1s 861us/step - loss: 25.1884 - val_loss: 669.2287
# Epoch 15/100
# 1272/1272 [==============================] - 1s 866us/step - loss: 23.4339 - val_loss: 620.4771
# Epoch 16/100
# 1272/1272 [==============================] - 1s 868us/step - loss: 22.2391 - val_loss: 586.7610
# Epoch 17/100
# 1272/1272 [==============================] - 1s 857us/step - loss: 21.0904 - val_loss: 544.6091
# Epoch 18/100
# 1272/1272 [==============================] - 1s 876us/step - loss: 20.2310 - val_loss: 516.3002
# Epoch 19/100
# 1272/1272 [==============================] - 1s 856us/step - loss: 19.3583 - val_loss: 499.7389
# Epoch 20/100
# 1272/1272 [==============================] - 1s 833us/step - loss: 18.7561 - val_loss: 469.4745
# Epoch 21/100
# 1272/1272 [==============================] - 1s 849us/step - loss: 18.3635 - val_loss: 443.3611
# Epoch 22/100
# 1272/1272 [==============================] - 1s 874us/step - loss: 17.7795 - val_loss: 423.4903
# Epoch 23/100
# 1272/1272 [==============================] - 1s 854us/step - loss: 17.4526 - val_loss: 405.2685
# Epoch 24/100
# 1272/1272 [==============================] - 1s 857us/step - loss: 17.2005 - val_loss: 404.1207
# Epoch 25/100
# 1272/1272 [==============================] - 1s 853us/step - loss: 17.0183 - val_loss: 372.5403
# Epoch 26/100
# 1272/1272 [==============================] - 1s 851us/step - loss: 16.8553 - val_loss: 372.9409
# Epoch 27/100
# 1272/1272 [==============================] - 1s 850us/step - loss: 16.8531 - val_loss: 386.1617
# Epoch 28/100
# 1272/1272 [==============================] - 1s 847us/step - loss: 16.6551 - val_loss: 335.1771
# Epoch 29/100
# 1272/1272 [==============================] - 1s 884us/step - loss: 16.5335 - val_loss: 318.5277
# Epoch 30/100
# 1272/1272 [==============================] - 1s 853us/step - loss: 16.5771 - val_loss: 323.8454
# Epoch 31/100
# 1272/1272 [==============================] - 1s 851us/step - loss: 16.5075 - val_loss: 296.9609
# Epoch 32/100
# 1272/1272 [==============================] - 1s 857us/step - loss: 16.5593 - val_loss: 284.8998
# Epoch 33/100
# 1272/1272 [==============================] - 1s 849us/step - loss: 16.4074 - val_loss: 273.9093
# Epoch 34/100
# 1272/1272 [==============================] - 1s 853us/step - loss: 16.3131 - val_loss: 261.1210
# Epoch 35/100
# 1272/1272 [==============================] - 1s 869us/step - loss: 16.4090 - val_loss: 257.1845
# Epoch 36/100
# 1272/1272 [==============================] - 1s 857us/step - loss: 16.3152 - val_loss: 255.0924
# Epoch 37/100
# 1272/1272 [==============================] - 1s 898us/step - loss: 16.2393 - val_loss: 246.3395
# Epoch 38/100
# 1272/1272 [==============================] - 1s 873us/step - loss: 16.1188 - val_loss: 231.0872
# Epoch 39/100
# 1272/1272 [==============================] - 1s 852us/step - loss: 16.1484 - val_loss: 226.3258
# Epoch 40/100
# 1272/1272 [==============================] - 1s 870us/step - loss: 16.2276 - val_loss: 218.4455
# Epoch 41/100
# 1272/1272 [==============================] - 1s 848us/step - loss: 16.0032 - val_loss: 210.5070
# Epoch 42/100
# 1272/1272 [==============================] - 1s 858us/step - loss: 16.0474 - val_loss: 201.7596
# Epoch 43/100
# 1272/1272 [==============================] - 1s 845us/step - loss: 15.9777 - val_loss: 191.7431
# Epoch 44/100
# 1272/1272 [==============================] - 1s 893us/step - loss: 15.9675 - val_loss: 190.7744
# Epoch 45/100
# 1272/1272 [==============================] - 1s 855us/step - loss: 15.8073 - val_loss: 190.8112
# Epoch 46/100
# 1272/1272 [==============================] - 1s 842us/step - loss: 15.9332 - val_loss: 178.2299
# Epoch 47/100
# 1272/1272 [==============================] - 1s 883us/step - loss: 15.7926 - val_loss: 185.5139
# Epoch 48/100
# 1272/1272 [==============================] - 1s 867us/step - loss: 15.8224 - val_loss: 180.5476
# Epoch 49/100
# 1272/1272 [==============================] - 1s 846us/step - loss: 15.7107 - val_loss: 170.0211
# Epoch 50/100
# 1272/1272 [==============================] - 1s 886us/step - loss: 15.7699 - val_loss: 167.6091
# Epoch 51/100
# 1272/1272 [==============================] - 1s 862us/step - loss: 15.6783 - val_loss: 180.2354
# Epoch 52/100
# 1272/1272 [==============================] - 1s 845us/step - loss: 15.6514 - val_loss: 185.1703
# Epoch 53/100
# 1272/1272 [==============================] - 1s 858us/step - loss: 15.6350 - val_loss: 174.6616
# Epoch 54/100
# 1272/1272 [==============================] - 1s 845us/step - loss: 15.6241 - val_loss: 175.7664
# Epoch 55/100
# 1272/1272 [==============================] - 1s 851us/step - loss: 15.6352 - val_loss: 169.3916
# 177/177 [==============================] - 0s 510us/step
# Completed 14 splits
# Epoch 1/100
# 1306/1306 [==============================] - 1s 892us/step - loss: 4211.4912 - val_loss: 11226.3359
# Epoch 2/100
# 1306/1306 [==============================] - 1s 845us/step - loss: 514.6926 - val_loss: 7892.4282
# Epoch 3/100
# 1306/1306 [==============================] - 1s 823us/step - loss: 115.7821 - val_loss: 7725.5923
# Epoch 4/100
# 1306/1306 [==============================] - 1s 867us/step - loss: 88.1124 - val_loss: 13102.2129
# Epoch 5/100
# 1306/1306 [==============================] - 1s 840us/step - loss: 77.3605 - val_loss: 14952.4932
# Epoch 6/100
# 1306/1306 [==============================] - 1s 835us/step - loss: 71.0907 - val_loss: 13403.0947
# Epoch 7/100
# 1306/1306 [==============================] - 1s 837us/step - loss: 66.0449 - val_loss: 12232.0801
# Epoch 8/100
# 1306/1306 [==============================] - 1s 833us/step - loss: 61.9075 - val_loss: 10536.2500
# 182/182 [==============================] - 0s 508us/step
# Completed 15 splits
# Epoch 1/100
# 1327/1327 [==============================] - 2s 941us/step - loss: 4836.2456 - val_loss: 6741.0815
# Epoch 2/100
# 1327/1327 [==============================] - 1s 853us/step - loss: 434.5412 - val_loss: 10175.5693
# Epoch 3/100
# 1327/1327 [==============================] - 1s 850us/step - loss: 162.0644 - val_loss: 13214.0098
# Epoch 4/100
# 1327/1327 [==============================] - 1s 854us/step - loss: 110.1931 - val_loss: 13121.6514
# Epoch 5/100
# 1327/1327 [==============================] - 1s 834us/step - loss: 89.6860 - val_loss: 11276.4863
# Epoch 6/100
# 1327/1327 [==============================] - 1s 848us/step - loss: 79.3730 - val_loss: 10421.5312
# 180/180 [==============================] - 0s 512us/step
# Completed 16 splits
# Epoch 1/100
# 1360/1360 [==============================] - 2s 927us/step - loss: 7105.4917 - val_loss: 10737.7051
# Epoch 2/100
# 1360/1360 [==============================] - 1s 857us/step - loss: 847.5271 - val_loss: 767.1827
# Epoch 3/100
# 1360/1360 [==============================] - 1s 828us/step - loss: 206.9488 - val_loss: 430.8468
# Epoch 4/100
# 1360/1360 [==============================] - 1s 842us/step - loss: 148.9565 - val_loss: 384.6524
# Epoch 5/100
# 1360/1360 [==============================] - 1s 851us/step - loss: 132.9690 - val_loss: 373.1918
# Epoch 6/100
# 1360/1360 [==============================] - 1s 836us/step - loss: 123.4208 - val_loss: 360.4180
# Epoch 7/100
# 1360/1360 [==============================] - 1s 864us/step - loss: 116.3336 - val_loss: 337.4289
# Epoch 8/100
# 1360/1360 [==============================] - 1s 874us/step - loss: 110.7112 - val_loss: 334.3267
# Epoch 9/100
# 1360/1360 [==============================] - 1s 835us/step - loss: 105.7827 - val_loss: 318.5676
# Epoch 10/100
# 1360/1360 [==============================] - 1s 843us/step - loss: 101.1416 - val_loss: 304.1869
# Epoch 11/100
# 1360/1360 [==============================] - 1s 859us/step - loss: 97.0812 - val_loss: 308.1618
# Epoch 12/100
# 1360/1360 [==============================] - 1s 871us/step - loss: 93.6153 - val_loss: 287.5274
# Epoch 13/100
# 1360/1360 [==============================] - 1s 889us/step - loss: 90.7539 - val_loss: 291.8366
# Epoch 14/100
# 1360/1360 [==============================] - 1s 906us/step - loss: 87.8292 - val_loss: 277.2524
# Epoch 15/100
# 1360/1360 [==============================] - 1s 934us/step - loss: 85.3218 - val_loss: 265.3795
# Epoch 16/100
# 1360/1360 [==============================] - 1s 967us/step - loss: 83.0198 - val_loss: 268.2827
# Epoch 17/100
# 1360/1360 [==============================] - 1s 846us/step - loss: 80.3983 - val_loss: 259.0208
# Epoch 18/100
# 1360/1360 [==============================] - 1s 843us/step - loss: 78.4911 - val_loss: 255.6083
# Epoch 19/100
# 1360/1360 [==============================] - 1s 848us/step - loss: 76.3719 - val_loss: 250.6982
# Epoch 20/100
# 1360/1360 [==============================] - 1s 839us/step - loss: 74.5141 - val_loss: 245.2187
# Epoch 21/100
# 1360/1360 [==============================] - 1s 842us/step - loss: 72.9473 - val_loss: 244.4461
# Epoch 22/100
# 1360/1360 [==============================] - 1s 852us/step - loss: 70.8724 - val_loss: 239.3384
# Epoch 23/100
# 1360/1360 [==============================] - 1s 871us/step - loss: 69.6472 - val_loss: 234.7390
# Epoch 24/100
# 1360/1360 [==============================] - 1s 883us/step - loss: 68.3542 - val_loss: 234.6142
# Epoch 25/100
# 1360/1360 [==============================] - 1s 835us/step - loss: 66.8638 - val_loss: 232.9335
# Epoch 26/100
# 1360/1360 [==============================] - 1s 865us/step - loss: 65.6236 - val_loss: 230.7917
# Epoch 27/100
# 1360/1360 [==============================] - 1s 884us/step - loss: 64.5468 - val_loss: 222.6351
# Epoch 28/100
# 1360/1360 [==============================] - 1s 852us/step - loss: 63.5077 - val_loss: 223.4935
# Epoch 29/100
# 1360/1360 [==============================] - 1s 861us/step - loss: 62.6112 - val_loss: 216.9745
# Epoch 30/100
# 1360/1360 [==============================] - 1s 873us/step - loss: 61.7353 - val_loss: 216.0135
# Epoch 31/100
# 1360/1360 [==============================] - 1s 871us/step - loss: 61.0836 - val_loss: 213.7686
# Epoch 32/100
# 1360/1360 [==============================] - 1s 851us/step - loss: 60.1334 - val_loss: 212.6347
# Epoch 33/100
# 1360/1360 [==============================] - 1s 853us/step - loss: 59.5109 - val_loss: 209.9047
# Epoch 34/100
# 1360/1360 [==============================] - 1s 849us/step - loss: 58.7125 - val_loss: 210.2974
# Epoch 35/100
# 1360/1360 [==============================] - 1s 846us/step - loss: 58.2149 - val_loss: 205.4656
# Epoch 36/100
# 1360/1360 [==============================] - 1s 841us/step - loss: 57.8511 - val_loss: 203.4853
# Epoch 37/100
# 1360/1360 [==============================] - 1s 875us/step - loss: 57.1031 - val_loss: 202.7193
# Epoch 38/100
# 1360/1360 [==============================] - 1s 839us/step - loss: 56.6396 - val_loss: 201.0911
# Epoch 39/100
# 1360/1360 [==============================] - 1s 861us/step - loss: 56.1213 - val_loss: 201.7345
# Epoch 40/100
# 1360/1360 [==============================] - 1s 835us/step - loss: 55.7368 - val_loss: 198.4409
# Epoch 41/100
# 1360/1360 [==============================] - 1s 882us/step - loss: 55.2752 - val_loss: 197.2065
# Epoch 42/100
# 1360/1360 [==============================] - 1s 888us/step - loss: 54.9183 - val_loss: 195.2329
# Epoch 43/100
# 1360/1360 [==============================] - 1s 866us/step - loss: 54.7041 - val_loss: 194.1195
# Epoch 44/100
# 1360/1360 [==============================] - 1s 845us/step - loss: 54.1318 - val_loss: 192.4603
# Epoch 45/100
# 1360/1360 [==============================] - 1s 896us/step - loss: 53.8864 - val_loss: 191.8665
# Epoch 46/100
# 1360/1360 [==============================] - 1s 845us/step - loss: 53.6729 - val_loss: 190.9211
# Epoch 47/100
# 1360/1360 [==============================] - 1s 865us/step - loss: 53.2316 - val_loss: 189.2186
# Epoch 48/100
# 1360/1360 [==============================] - 1s 839us/step - loss: 53.0983 - val_loss: 189.5263
# Epoch 49/100
# 1360/1360 [==============================] - 1s 829us/step - loss: 52.7591 - val_loss: 187.5283
# Epoch 50/100
# 1360/1360 [==============================] - 1s 856us/step - loss: 52.5321 - val_loss: 186.1366
# Epoch 51/100
# 1360/1360 [==============================] - 1s 879us/step - loss: 52.1418 - val_loss: 187.0497
# Epoch 52/100
# 1360/1360 [==============================] - 1s 871us/step - loss: 52.0281 - val_loss: 183.7741
# Epoch 53/100
# 1360/1360 [==============================] - 1s 832us/step - loss: 51.8121 - val_loss: 184.1249
# Epoch 54/100
# 1360/1360 [==============================] - 1s 844us/step - loss: 51.5699 - val_loss: 184.9875
# Epoch 55/100
# 1360/1360 [==============================] - 1s 836us/step - loss: 51.5651 - val_loss: 186.0404
# Epoch 56/100
# 1360/1360 [==============================] - 1s 845us/step - loss: 51.3039 - val_loss: 184.5311
# Epoch 57/100
# 1360/1360 [==============================] - 1s 852us/step - loss: 51.1978 - val_loss: 188.0396
# 74/74 [==============================] - 0s 555us/step
# Completed 17 splits
# R2_oos NN3 Top 500:  0.9364020077294148

# %% [markdown]
# # NN3 algorithm for bottom 500 stocks

# %%
X = df_bottom_500[['Date'] + variables]
y = df_bottom_500['Adj Close t+1']

X['Date'] = pd.to_datetime(X['Date'])

initial_date = X['Date'].min()

predictions = []
y_test_list = []
dates = []


for split_num, (train_index, val_index, test_index) in enumerate(recursive_rolling_method(X,initial_date,date_column='Date',train_period=8,val_period=3,test_period=1,freq='years')):
    X_train = X.loc[train_index].drop('Date', axis=1)
    y_train = y.loc[train_index]

    X_val = X.loc[val_index].drop('Date', axis=1)
    y_val = y.loc[val_index]

    X_test = X.loc[test_index].drop('Date', axis=1)
    y_test = y.loc[test_index]

    
    input_shape = [X_train.shape[1]]
    
    
    mean_train = X_train.mean(axis=0)
    std_train  = X_train.std(axis=0)
    
    X_train = (X_train-mean_train) / std_train
    X_val = (X_val-mean_train) / std_train
    X_test = (X_test-mean_train) / std_train
    
    
    
    model = tf.keras.Sequential([
 
    tf.keras.layers.Flatten(input_shape=input_shape),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=8, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='linear')
    
    ])

    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0, clipnorm=1.0, clipvalue=0.5), loss='mse')    
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[early_stopping])
    
    preds = model.predict(X_test)
    preds = preds.ravel()


    predictions.append(preds)
    dates.append(X.loc[y_test.index, 'Date'])
    y_test_list.append(y_test)



    del X_train, y_train, X_val, y_val, model, preds
    gc.collect()

    print(f"Completed {split_num + 1} splits")

predictions_all = np.concatenate(predictions, axis=0)
y_test_list_all = pd.concat(y_test_list, axis=0)
dates_all = pd.concat(dates, axis=0)


R2oos_NN3_bottom = 1 - np.sum(np.power(y_test_list_all - predictions_all, 2)) / np.sum(np.power(y_test_list_all, 2))
print("R2_oos NN3 bottom 500: ", R2oos_NN3_bottom)
# Out:
#     Train period: 1997-02-28 00:00:00 - 2005-02-28 00:00:00  || Val period: 2005-03-28 00:00:00 - 2008-03-28 00:00:00  || Test period 2008-04-28 00:00:00 - 2009-04-28 00:00:00  || Train contains 6974  || Val contains 3935  || Test contains 1557
#     Train period: 1998-02-28 00:00:00 - 2006-02-28 00:00:00  || Val period: 2006-03-28 00:00:00 - 2009-03-28 00:00:00  || Test period 2009-04-28 00:00:00 - 2010-04-28 00:00:00  || Train contains 7561  || Val contains 4256  || Test contains 1633
#     Train period: 1999-02-28 00:00:00 - 2007-02-28 00:00:00  || Val period: 2007-03-28 00:00:00 - 2010-03-28 00:00:00  || Test period 2010-04-28 00:00:00 - 2011-04-28 00:00:00  || Train contains 8150  || Val contains 4597  || Test contains 1704
#     Train period: 2000-02-28 00:00:00 - 2008-02-28 00:00:00  || Val period: 2008-03-28 00:00:00 - 2011-03-28 00:00:00  || Test period 2011-04-28 00:00:00 - 2012-04-28 00:00:00  || Train contains 8887  || Val contains 4876  || Test contains 1778
#     Train period: 2001-02-28 00:00:00 - 2009-02-28 00:00:00  || Val period: 2009-03-28 00:00:00 - 2012-03-28 00:00:00  || Test period 2012-04-28 00:00:00 - 2013-04-28 00:00:00  || Train contains 9767  || Val contains 5094  || Test contains 1888
#     Train period: 2002-02-28 00:00:00 - 2010-02-28 00:00:00  || Val period: 2010-03-28 00:00:00 - 2013-03-28 00:00:00  || Test period 2013-04-28 00:00:00 - 2014-04-28 00:00:00  || Train contains 10466  || Val contains 5349  || Test contains 1973
#     Train period: 2003-02-28 00:00:00 - 2011-02-28 00:00:00  || Val period: 2011-03-28 00:00:00 - 2014-03-28 00:00:00  || Test period 2014-04-28 00:00:00 - 2015-04-28 00:00:00  || Train contains 11013  || Val contains 5617  || Test contains 2064
#     Train period: 2004-02-28 00:00:00 - 2012-02-28 00:00:00  || Val period: 2012-03-28 00:00:00 - 2015-03-28 00:00:00  || Test period 2015-04-28 00:00:00 - 2016-04-28 00:00:00  || Train contains 11578  || Val contains 5905  || Test contains 2278
#     Train period: 2005-02-28 00:00:00 - 2013-02-28 00:00:00  || Val period: 2013-03-28 00:00:00 - 2016-03-28 00:00:00  || Test period 2016-04-28 00:00:00 - 2017-04-28 00:00:00  || Train contains 12396  || Val contains 6278  || Test contains 2551
#     Train period: 2006-02-28 00:00:00 - 2014-02-28 00:00:00  || Val period: 2014-03-28 00:00:00 - 2017-03-28 00:00:00  || Test period 2017-04-28 00:00:00 - 2018-04-28 00:00:00  || Train contains 13142  || Val contains 6837  || Test contains 2743
#     Train period: 2007-02-28 00:00:00 - 2015-02-28 00:00:00  || Val period: 2015-03-28 00:00:00 - 2018-03-28 00:00:00  || Test period 2018-04-28 00:00:00 - 2019-04-28 00:00:00  || Train contains 14080  || Val contains 7509  || Test contains 3057
#     Train period: 2008-02-28 00:00:00 - 2016-02-28 00:00:00  || Val period: 2016-03-28 00:00:00 - 2019-03-28 00:00:00  || Test period 2019-04-28 00:00:00 - 2020-04-28 00:00:00  || Train contains 14727  || Val contains 8276  || Test contains 3551
#     Train period: 2009-02-28 00:00:00 - 2017-02-28 00:00:00  || Val period: 2017-03-28 00:00:00 - 2020-03-28 00:00:00  || Test period 2020-04-28 00:00:00 - 2021-04-28 00:00:00  || Train contains 15564  || Val contains 9256  || Test contains 3902
#     Train period: 2010-02-28 00:00:00 - 2018-02-28 00:00:00  || Val period: 2018-03-28 00:00:00 - 2021-03-28 00:00:00  || Test period 2021-04-28 00:00:00 - 2022-04-28 00:00:00  || Train contains 16638  || Val contains 10412  || Test contains 4286
#     Train period: 2011-02-28 00:00:00 - 2019-02-28 00:00:00  || Val period: 2019-03-28 00:00:00 - 2022-03-28 00:00:00  || Test period 2022-04-28 00:00:00 - 2023-04-28 00:00:00  || Train contains 18073  || Val contains 11621  || Test contains 5119
#     Train period: 2012-02-28 00:00:00 - 2020-02-28 00:00:00  || Val period: 2020-03-28 00:00:00 - 2023-03-28 00:00:00  || Test period 2023-04-28 00:00:00 - 2024-04-28 00:00:00  || Train contains 19789  || Val contains 13164  || Test contains 5673
#     Train period: 2013-02-28 00:00:00 - 2021-02-28 00:00:00  || Val period: 2021-03-28 00:00:00 - 2024-03-28 00:00:00  || Test period 2024-04-28 00:00:00 - 2025-04-28 00:00:00  || Train contains 22102  || Val contains 14938  || Test contains 2398
# Epoch 1/100
# 218/218 [==============================] - 1s 1ms/step - loss: 5676.3623 - val_loss: 9678.9033
# Epoch 2/100
# 218/218 [==============================] - 0s 1ms/step - loss: 5589.7637 - val_loss: 9465.0137
# Epoch 3/100
# 218/218 [==============================] - 0s 986us/step - loss: 5424.0137 - val_loss: 9051.2822
# Epoch 4/100
# 218/218 [==============================] - 0s 1ms/step - loss: 5121.9019 - val_loss: 8348.0117
# Epoch 5/100
# 218/218 [==============================] - 0s 981us/step - loss: 4642.5376 - val_loss: 7282.8906
# Epoch 6/100
# 218/218 [==============================] - 0s 1ms/step - loss: 3940.3433 - val_loss: 5879.6772
# Epoch 7/100
# 218/218 [==============================] - 0s 943us/step - loss: 3034.5554 - val_loss: 4259.6558
# Epoch 8/100
# 218/218 [==============================] - 0s 983us/step - loss: 2072.0872 - val_loss: 2831.9993
# Epoch 9/100
# 218/218 [==============================] - 0s 956us/step - loss: 1271.5569 - val_loss: 1983.7432
# Epoch 10/100
# 218/218 [==============================] - 0s 937us/step - loss: 847.8837 - val_loss: 1687.6666
# Epoch 11/100
# 218/218 [==============================] - 0s 1ms/step - loss: 664.7916 - val_loss: 1563.5137
# Epoch 12/100
# 218/218 [==============================] - 0s 974us/step - loss: 575.0229 - val_loss: 1441.1401
# Epoch 13/100
# 218/218 [==============================] - 0s 960us/step - loss: 522.4549 - val_loss: 1363.2258
# Epoch 14/100
# 218/218 [==============================] - 0s 1ms/step - loss: 490.7303 - val_loss: 1295.7131
# Epoch 15/100
# 218/218 [==============================] - 0s 926us/step - loss: 469.4755 - val_loss: 1270.3905
# Epoch 16/100
# 218/218 [==============================] - 0s 929us/step - loss: 452.8666 - val_loss: 1215.0243
# Epoch 17/100
# 218/218 [==============================] - 0s 928us/step - loss: 433.8850 - val_loss: 1197.1309
# Epoch 18/100
# 218/218 [==============================] - 0s 922us/step - loss: 422.9762 - val_loss: 1193.6267
# Epoch 19/100
# 218/218 [==============================] - 0s 965us/step - loss: 412.6359 - val_loss: 1158.8877
# Epoch 20/100
# 218/218 [==============================] - 0s 939us/step - loss: 402.3940 - val_loss: 1176.1560
# Epoch 21/100
# 218/218 [==============================] - 0s 982us/step - loss: 393.8043 - val_loss: 1148.2802
# Epoch 22/100
# 218/218 [==============================] - 0s 924us/step - loss: 388.3161 - val_loss: 1178.7554
# Epoch 23/100
# 218/218 [==============================] - 0s 927us/step - loss: 381.3237 - val_loss: 1175.4481
# Epoch 24/100
# 218/218 [==============================] - 0s 921us/step - loss: 376.8503 - val_loss: 1161.0558
# Epoch 25/100
# 218/218 [==============================] - 0s 906us/step - loss: 372.3461 - val_loss: 1190.0890
# Epoch 26/100
# 218/218 [==============================] - 0s 924us/step - loss: 370.4011 - val_loss: 1147.8243
# Epoch 27/100
# 218/218 [==============================] - 0s 993us/step - loss: 362.4363 - val_loss: 1138.0145
# Epoch 28/100
# 218/218 [==============================] - 0s 912us/step - loss: 364.8571 - val_loss: 1167.0063
# Epoch 29/100
# 218/218 [==============================] - 0s 1ms/step - loss: 358.6276 - val_loss: 1139.7991
# Epoch 30/100
# 218/218 [==============================] - 0s 928us/step - loss: 354.7198 - val_loss: 1118.4021
# Epoch 31/100
# 218/218 [==============================] - 0s 923us/step - loss: 353.1609 - val_loss: 1155.7067
# Epoch 32/100
# 218/218 [==============================] - 0s 919us/step - loss: 353.9719 - val_loss: 1146.5081
# Epoch 33/100
# 218/218 [==============================] - 0s 910us/step - loss: 349.1155 - val_loss: 1132.3049
# Epoch 34/100
# 218/218 [==============================] - 0s 919us/step - loss: 344.6283 - val_loss: 1144.5852
# Epoch 35/100
# 218/218 [==============================] - 0s 942us/step - loss: 342.0747 - val_loss: 1107.2803
# Epoch 36/100
# 218/218 [==============================] - 0s 976us/step - loss: 341.9796 - val_loss: 1106.8665
# Epoch 37/100
# 218/218 [==============================] - 0s 973us/step - loss: 338.1627 - val_loss: 1127.4244
# Epoch 38/100
# 218/218 [==============================] - 0s 955us/step - loss: 341.9831 - val_loss: 1130.7920
# Epoch 39/100
# 218/218 [==============================] - 0s 969us/step - loss: 337.8298 - val_loss: 1104.5858
# Epoch 40/100
# 218/218 [==============================] - 0s 955us/step - loss: 334.5667 - val_loss: 1118.4182
# Epoch 41/100
# 218/218 [==============================] - 0s 1ms/step - loss: 336.3146 - val_loss: 1098.3978
# Epoch 42/100
# 218/218 [==============================] - 0s 978us/step - loss: 334.2301 - val_loss: 1095.0790
# Epoch 43/100
# 218/218 [==============================] - 0s 968us/step - loss: 334.7229 - val_loss: 1084.4221
# Epoch 44/100
# 218/218 [==============================] - 0s 983us/step - loss: 331.7790 - val_loss: 1110.3030
# Epoch 45/100
# 218/218 [==============================] - 0s 994us/step - loss: 332.3810 - val_loss: 1054.9495
# Epoch 46/100
# 218/218 [==============================] - 0s 970us/step - loss: 330.3069 - val_loss: 1061.8690
# Epoch 47/100
# 218/218 [==============================] - 0s 976us/step - loss: 330.0218 - val_loss: 1079.1218
# Epoch 48/100
# 218/218 [==============================] - 0s 965us/step - loss: 329.4299 - val_loss: 1052.2009
# Epoch 49/100
# 218/218 [==============================] - 0s 965us/step - loss: 330.5195 - val_loss: 1048.1785
# Epoch 50/100
# 218/218 [==============================] - 0s 968us/step - loss: 325.1792 - val_loss: 1070.8690
# Epoch 51/100
# 218/218 [==============================] - 0s 958us/step - loss: 329.0249 - val_loss: 1059.9323
# Epoch 52/100
# 218/218 [==============================] - 0s 1ms/step - loss: 327.2930 - val_loss: 1038.9729
# Epoch 53/100
# 218/218 [==============================] - 0s 965us/step - loss: 328.0682 - val_loss: 1035.3851
# Epoch 54/100
# 218/218 [==============================] - 0s 970us/step - loss: 325.6002 - val_loss: 1025.1973
# Epoch 55/100
# 218/218 [==============================] - 0s 962us/step - loss: 322.6816 - val_loss: 1003.8316
# Epoch 56/100
# 218/218 [==============================] - 0s 969us/step - loss: 323.3760 - val_loss: 1008.7000
# Epoch 57/100
# 218/218 [==============================] - 0s 963us/step - loss: 326.5776 - val_loss: 1030.5344
# Epoch 58/100
# 218/218 [==============================] - 0s 966us/step - loss: 324.3252 - val_loss: 1002.7335
# Epoch 59/100
# 218/218 [==============================] - 0s 964us/step - loss: 322.0734 - val_loss: 1005.2115
# Epoch 60/100
# 218/218 [==============================] - 0s 958us/step - loss: 319.6971 - val_loss: 1066.0958
# Epoch 61/100
# 218/218 [==============================] - 0s 971us/step - loss: 319.4439 - val_loss: 1008.1697
# Epoch 62/100
# 218/218 [==============================] - 0s 952us/step - loss: 317.1915 - val_loss: 1034.5627
# Epoch 63/100
# 218/218 [==============================] - 0s 957us/step - loss: 319.7572 - val_loss: 993.2139
# Epoch 64/100
# 218/218 [==============================] - 0s 962us/step - loss: 315.1087 - val_loss: 976.0529
# Epoch 65/100
# 218/218 [==============================] - 0s 955us/step - loss: 316.4791 - val_loss: 1016.9510
# Epoch 66/100
# 218/218 [==============================] - 0s 1ms/step - loss: 320.3327 - val_loss: 997.5401
# Epoch 67/100
# 218/218 [==============================] - 0s 1ms/step - loss: 317.5966 - val_loss: 1008.7861
# Epoch 68/100
# 218/218 [==============================] - 0s 975us/step - loss: 317.5467 - val_loss: 1014.5092
# Epoch 69/100
# 218/218 [==============================] - 0s 987us/step - loss: 315.0745 - val_loss: 1019.8734
# 49/49 [==============================] - 0s 552us/step
# Completed 1 splits
# Epoch 1/100
# 237/237 [==============================] - 1s 1ms/step - loss: 6390.4038 - val_loss: 8023.2339
# Epoch 2/100
# 237/237 [==============================] - 0s 954us/step - loss: 6242.1167 - val_loss: 7755.7217
# Epoch 3/100
# 237/237 [==============================] - 0s 957us/step - loss: 5929.1816 - val_loss: 7242.1045
# Epoch 4/100
# 237/237 [==============================] - 0s 957us/step - loss: 5400.1846 - val_loss: 6400.9717
# Epoch 5/100
# 237/237 [==============================] - 0s 956us/step - loss: 4582.7373 - val_loss: 5206.4932
# Epoch 6/100
# 237/237 [==============================] - 0s 946us/step - loss: 3488.7896 - val_loss: 3788.4375
# Epoch 7/100
# 237/237 [==============================] - 0s 958us/step - loss: 2340.3625 - val_loss: 2522.6218
# Epoch 8/100
# 237/237 [==============================] - 0s 941us/step - loss: 1432.1027 - val_loss: 1740.6687
# Epoch 9/100
# 237/237 [==============================] - 0s 942us/step - loss: 976.7584 - val_loss: 1436.6179
# Epoch 10/100
# 237/237 [==============================] - 0s 945us/step - loss: 811.1360 - val_loss: 1256.0919
# Epoch 11/100
# 237/237 [==============================] - 0s 955us/step - loss: 721.8537 - val_loss: 1127.2847
# Epoch 12/100
# 237/237 [==============================] - 0s 943us/step - loss: 672.3947 - val_loss: 1024.1469
# Epoch 13/100
# 237/237 [==============================] - 0s 944us/step - loss: 626.9207 - val_loss: 938.0147
# Epoch 14/100
# 237/237 [==============================] - 0s 946us/step - loss: 598.3059 - val_loss: 872.9064
# Epoch 15/100
# 237/237 [==============================] - 0s 992us/step - loss: 576.6295 - val_loss: 829.2219
# Epoch 16/100
# 237/237 [==============================] - 0s 961us/step - loss: 557.9802 - val_loss: 795.0513
# Epoch 17/100
# 237/237 [==============================] - 0s 945us/step - loss: 543.8497 - val_loss: 759.8440
# Epoch 18/100
# 237/237 [==============================] - 0s 954us/step - loss: 531.4601 - val_loss: 723.9249
# Epoch 19/100
# 237/237 [==============================] - 0s 973us/step - loss: 517.4460 - val_loss: 707.9288
# Epoch 20/100
# 237/237 [==============================] - 0s 957us/step - loss: 512.6519 - val_loss: 695.6336
# Epoch 21/100
# 237/237 [==============================] - 0s 967us/step - loss: 502.8607 - val_loss: 682.2606
# Epoch 22/100
# 237/237 [==============================] - 0s 956us/step - loss: 504.4936 - val_loss: 663.8018
# Epoch 23/100
# 237/237 [==============================] - 0s 959us/step - loss: 495.9739 - val_loss: 642.0688
# Epoch 24/100
# 237/237 [==============================] - 0s 953us/step - loss: 484.6252 - val_loss: 640.8463
# Epoch 25/100
# 237/237 [==============================] - 0s 961us/step - loss: 481.2976 - val_loss: 625.8071
# Epoch 26/100
# 237/237 [==============================] - 0s 954us/step - loss: 475.1613 - val_loss: 621.1771
# Epoch 27/100
# 237/237 [==============================] - 0s 948us/step - loss: 473.0435 - val_loss: 613.7820
# Epoch 28/100
# 237/237 [==============================] - 0s 956us/step - loss: 469.8529 - val_loss: 616.2347
# Epoch 29/100
# 237/237 [==============================] - 0s 1ms/step - loss: 466.4919 - val_loss: 600.6668
# Epoch 30/100
# 237/237 [==============================] - 0s 947us/step - loss: 457.1512 - val_loss: 589.3393
# Epoch 31/100
# 237/237 [==============================] - 0s 964us/step - loss: 455.6466 - val_loss: 595.4716
# Epoch 32/100
# 237/237 [==============================] - 0s 980us/step - loss: 456.3808 - val_loss: 584.3174
# Epoch 33/100
# 237/237 [==============================] - 0s 950us/step - loss: 456.5237 - val_loss: 577.2764
# Epoch 34/100
# 237/237 [==============================] - 0s 1ms/step - loss: 451.8819 - val_loss: 574.6661
# Epoch 35/100
# 237/237 [==============================] - 0s 954us/step - loss: 450.9188 - val_loss: 576.5931
# Epoch 36/100
# 237/237 [==============================] - 0s 955us/step - loss: 449.6184 - val_loss: 577.1390
# Epoch 37/100
# 237/237 [==============================] - 0s 948us/step - loss: 453.7202 - val_loss: 573.6658
# Epoch 38/100
# 237/237 [==============================] - 0s 945us/step - loss: 448.3553 - val_loss: 557.4091
# Epoch 39/100
# 237/237 [==============================] - 0s 1ms/step - loss: 439.8287 - val_loss: 563.8235
# Epoch 40/100
# 237/237 [==============================] - 0s 949us/step - loss: 440.6051 - val_loss: 555.7469
# Epoch 41/100
# 237/237 [==============================] - 0s 958us/step - loss: 436.6744 - val_loss: 547.9639
# Epoch 42/100
# 237/237 [==============================] - 0s 968us/step - loss: 430.6729 - val_loss: 551.1047
# Epoch 43/100
# 237/237 [==============================] - 0s 963us/step - loss: 439.3061 - val_loss: 547.3494
# Epoch 44/100
# 237/237 [==============================] - 0s 963us/step - loss: 430.8324 - val_loss: 541.1444
# Epoch 45/100
# 237/237 [==============================] - 0s 958us/step - loss: 425.9897 - val_loss: 541.6308
# Epoch 46/100
# 237/237 [==============================] - 0s 969us/step - loss: 422.6515 - val_loss: 539.7500
# Epoch 47/100
# 237/237 [==============================] - 0s 979us/step - loss: 428.9825 - val_loss: 538.6489
# Epoch 48/100
# 237/237 [==============================] - 0s 959us/step - loss: 423.5938 - val_loss: 536.7852
# Epoch 49/100
# 237/237 [==============================] - 0s 943us/step - loss: 425.2487 - val_loss: 539.1442
# Epoch 50/100
# 237/237 [==============================] - 0s 955us/step - loss: 428.1850 - val_loss: 529.0492
# Epoch 51/100
# 237/237 [==============================] - 0s 963us/step - loss: 421.1721 - val_loss: 516.6057
# Epoch 52/100
# 237/237 [==============================] - 0s 958us/step - loss: 415.9003 - val_loss: 522.7262
# Epoch 53/100
# 237/237 [==============================] - 0s 960us/step - loss: 414.8377 - val_loss: 514.3718
# Epoch 54/100
# 237/237 [==============================] - 0s 957us/step - loss: 412.4833 - val_loss: 509.6414
# Epoch 55/100
# 237/237 [==============================] - 0s 954us/step - loss: 411.8503 - val_loss: 505.0571
# Epoch 56/100
# 237/237 [==============================] - 0s 952us/step - loss: 411.6125 - val_loss: 502.5959
# Epoch 57/100
# 237/237 [==============================] - 0s 942us/step - loss: 407.8092 - val_loss: 496.8259
# Epoch 58/100
# 237/237 [==============================] - 0s 956us/step - loss: 406.6080 - val_loss: 500.3274
# Epoch 59/100
# 237/237 [==============================] - 0s 995us/step - loss: 402.5955 - val_loss: 494.8369
# Epoch 60/100
# 237/237 [==============================] - 0s 946us/step - loss: 397.0857 - val_loss: 501.7637
# Epoch 61/100
# 237/237 [==============================] - 0s 958us/step - loss: 404.2228 - val_loss: 495.0826
# Epoch 62/100
# 237/237 [==============================] - 0s 956us/step - loss: 403.8599 - val_loss: 492.5384
# Epoch 63/100
# 237/237 [==============================] - 0s 942us/step - loss: 404.3894 - val_loss: 488.9933
# Epoch 64/100
# 237/237 [==============================] - 0s 949us/step - loss: 403.1795 - val_loss: 485.1728
# Epoch 65/100
# 237/237 [==============================] - 0s 972us/step - loss: 392.7627 - val_loss: 474.7858
# Epoch 66/100
# 237/237 [==============================] - 0s 951us/step - loss: 390.5885 - val_loss: 478.3982
# Epoch 67/100
# 237/237 [==============================] - 0s 940us/step - loss: 395.6869 - val_loss: 476.1880
# Epoch 68/100
# 237/237 [==============================] - 0s 946us/step - loss: 396.3527 - val_loss: 481.1381
# Epoch 69/100
# 237/237 [==============================] - 0s 948us/step - loss: 395.5564 - val_loss: 470.7493
# Epoch 70/100
# 237/237 [==============================] - 0s 1ms/step - loss: 391.7182 - val_loss: 473.6285
# Epoch 71/100
# 237/237 [==============================] - 0s 954us/step - loss: 391.5862 - val_loss: 468.6257
# Epoch 72/100
# 237/237 [==============================] - 0s 953us/step - loss: 388.9962 - val_loss: 459.7748
# Epoch 73/100
# 237/237 [==============================] - 0s 1ms/step - loss: 383.9732 - val_loss: 457.1732
# Epoch 74/100
# 237/237 [==============================] - 0s 1ms/step - loss: 380.3264 - val_loss: 463.3123
# Epoch 75/100
# 237/237 [==============================] - 0s 1ms/step - loss: 388.7252 - val_loss: 456.6713
# Epoch 76/100
# 237/237 [==============================] - 0s 965us/step - loss: 384.1528 - val_loss: 450.2254
# Epoch 77/100
# 237/237 [==============================] - 0s 949us/step - loss: 376.7896 - val_loss: 453.5796
# Epoch 78/100
# 237/237 [==============================] - 0s 953us/step - loss: 378.7208 - val_loss: 449.3266
# Epoch 79/100
# 237/237 [==============================] - 0s 947us/step - loss: 374.4700 - val_loss: 443.7350
# Epoch 80/100
# 237/237 [==============================] - 0s 1ms/step - loss: 375.6532 - val_loss: 449.3383
# Epoch 81/100
# 237/237 [==============================] - 0s 1ms/step - loss: 374.1434 - val_loss: 445.0858
# Epoch 82/100
# 237/237 [==============================] - 0s 1ms/step - loss: 372.8850 - val_loss: 434.8957
# Epoch 83/100
# 237/237 [==============================] - 0s 997us/step - loss: 367.6563 - val_loss: 432.7389
# Epoch 84/100
# 237/237 [==============================] - 0s 956us/step - loss: 369.6523 - val_loss: 430.8749
# Epoch 85/100
# 237/237 [==============================] - 0s 948us/step - loss: 368.2663 - val_loss: 426.9440
# Epoch 86/100
# 237/237 [==============================] - 0s 962us/step - loss: 364.4140 - val_loss: 432.6759
# Epoch 87/100
# 237/237 [==============================] - 0s 1ms/step - loss: 364.6853 - val_loss: 423.3241
# Epoch 88/100
# 237/237 [==============================] - 0s 959us/step - loss: 362.4100 - val_loss: 424.3378
# Epoch 89/100
# 237/237 [==============================] - 0s 1ms/step - loss: 361.8148 - val_loss: 421.7820
# Epoch 90/100
# 237/237 [==============================] - 0s 939us/step - loss: 357.3940 - val_loss: 420.9167
# Epoch 91/100
# 237/237 [==============================] - 0s 957us/step - loss: 357.6544 - val_loss: 420.4822
# Epoch 92/100
# 237/237 [==============================] - 0s 944us/step - loss: 355.5407 - val_loss: 408.5351
# Epoch 93/100
# 237/237 [==============================] - 0s 938us/step - loss: 353.7560 - val_loss: 414.3369
# Epoch 94/100
# 237/237 [==============================] - 0s 944us/step - loss: 353.4002 - val_loss: 410.2053
# Epoch 95/100
# 237/237 [==============================] - 0s 951us/step - loss: 352.5974 - val_loss: 405.5692
# Epoch 96/100
# 237/237 [==============================] - 0s 946us/step - loss: 351.3404 - val_loss: 400.2963
# Epoch 97/100
# 237/237 [==============================] - 0s 933us/step - loss: 350.4704 - val_loss: 400.9624
# Epoch 98/100
# 237/237 [==============================] - 0s 943us/step - loss: 350.9246 - val_loss: 403.1015
# Epoch 99/100
# 237/237 [==============================] - 0s 943us/step - loss: 347.1540 - val_loss: 398.2120
# Epoch 100/100
# 237/237 [==============================] - 0s 948us/step - loss: 346.3576 - val_loss: 392.1843
# 52/52 [==============================] - 0s 540us/step
# Completed 2 splits
# Epoch 1/100
# 255/255 [==============================] - 1s 1ms/step - loss: 7142.6787 - val_loss: 7518.6206
# Epoch 2/100
# 255/255 [==============================] - 0s 963us/step - loss: 6859.2446 - val_loss: 7141.6724
# Epoch 3/100
# 255/255 [==============================] - 0s 968us/step - loss: 6363.1812 - val_loss: 6487.5391
# Epoch 4/100
# 255/255 [==============================] - 0s 970us/step - loss: 5552.4717 - val_loss: 5503.7866
# Epoch 5/100
# 255/255 [==============================] - 0s 972us/step - loss: 4384.5200 - val_loss: 4277.9751
# Epoch 6/100
# 255/255 [==============================] - 0s 977us/step - loss: 3018.5649 - val_loss: 3047.5378
# Epoch 7/100
# 255/255 [==============================] - 0s 956us/step - loss: 1758.1488 - val_loss: 2207.5640
# Epoch 8/100
# 255/255 [==============================] - 0s 1ms/step - loss: 1082.6733 - val_loss: 1834.7861
# Epoch 9/100
# 255/255 [==============================] - 0s 953us/step - loss: 800.5051 - val_loss: 1604.0903
# Epoch 10/100
# 255/255 [==============================] - 0s 954us/step - loss: 675.8026 - val_loss: 1426.7650
# Epoch 11/100
# 255/255 [==============================] - 0s 950us/step - loss: 609.3676 - val_loss: 1268.4814
# Epoch 12/100
# 255/255 [==============================] - 0s 976us/step - loss: 578.9076 - val_loss: 1156.3927
# Epoch 13/100
# 255/255 [==============================] - 0s 956us/step - loss: 554.3795 - val_loss: 1052.5780
# Epoch 14/100
# 255/255 [==============================] - 0s 1ms/step - loss: 545.5104 - val_loss: 961.3134
# Epoch 15/100
# 255/255 [==============================] - 0s 962us/step - loss: 529.3224 - val_loss: 893.2972
# Epoch 16/100
# 255/255 [==============================] - 0s 960us/step - loss: 512.8878 - val_loss: 827.1798
# Epoch 17/100
# 255/255 [==============================] - 0s 961us/step - loss: 505.2173 - val_loss: 789.8199
# Epoch 18/100
# 255/255 [==============================] - 0s 964us/step - loss: 500.5815 - val_loss: 752.1737
# Epoch 19/100
# 255/255 [==============================] - 0s 960us/step - loss: 500.2552 - val_loss: 704.7639
# Epoch 20/100
# 255/255 [==============================] - 0s 960us/step - loss: 487.8700 - val_loss: 678.8190
# Epoch 21/100
# 255/255 [==============================] - 0s 965us/step - loss: 484.1325 - val_loss: 652.5892
# Epoch 22/100
# 255/255 [==============================] - 0s 958us/step - loss: 480.0283 - val_loss: 626.8538
# Epoch 23/100
# 255/255 [==============================] - 0s 956us/step - loss: 473.5421 - val_loss: 602.9240
# Epoch 24/100
# 255/255 [==============================] - 0s 962us/step - loss: 474.1339 - val_loss: 586.8580
# Epoch 25/100
# 255/255 [==============================] - 0s 965us/step - loss: 463.0359 - val_loss: 567.8954
# Epoch 26/100
# 255/255 [==============================] - 0s 976us/step - loss: 458.2943 - val_loss: 555.5730
# Epoch 27/100
# 255/255 [==============================] - 0s 1ms/step - loss: 454.9174 - val_loss: 540.6584
# Epoch 28/100
# 255/255 [==============================] - 0s 964us/step - loss: 454.0727 - val_loss: 527.6936
# Epoch 29/100
# 255/255 [==============================] - 0s 957us/step - loss: 449.4756 - val_loss: 516.0517
# Epoch 30/100
# 255/255 [==============================] - 0s 980us/step - loss: 446.2408 - val_loss: 508.2649
# Epoch 31/100
# 255/255 [==============================] - 0s 1ms/step - loss: 445.5236 - val_loss: 497.0059
# Epoch 32/100
# 255/255 [==============================] - 0s 997us/step - loss: 439.6180 - val_loss: 492.1682
# Epoch 33/100
# 255/255 [==============================] - 0s 1ms/step - loss: 434.2366 - val_loss: 488.0817
# Epoch 34/100
# 255/255 [==============================] - 0s 1ms/step - loss: 429.0087 - val_loss: 480.6810
# Epoch 35/100
# 255/255 [==============================] - 0s 1ms/step - loss: 427.1215 - val_loss: 476.6231
# Epoch 36/100
# 255/255 [==============================] - 0s 1ms/step - loss: 420.2102 - val_loss: 471.3988
# Epoch 37/100
# 255/255 [==============================] - 0s 1ms/step - loss: 424.2251 - val_loss: 463.9036
# Epoch 38/100
# 255/255 [==============================] - 0s 995us/step - loss: 415.4973 - val_loss: 459.4843
# Epoch 39/100
# 255/255 [==============================] - 0s 975us/step - loss: 415.3277 - val_loss: 455.1221
# Epoch 40/100
# 255/255 [==============================] - 0s 965us/step - loss: 410.5853 - val_loss: 452.4310
# Epoch 41/100
# 255/255 [==============================] - 0s 988us/step - loss: 407.8389 - val_loss: 451.7088
# Epoch 42/100
# 255/255 [==============================] - 0s 999us/step - loss: 401.7531 - val_loss: 444.7386
# Epoch 43/100
# 255/255 [==============================] - 0s 1ms/step - loss: 405.9005 - val_loss: 440.4301
# Epoch 44/100
# 255/255 [==============================] - 0s 1ms/step - loss: 403.0015 - val_loss: 437.5784
# Epoch 45/100
# 255/255 [==============================] - 0s 1ms/step - loss: 402.6801 - val_loss: 433.6503
# Epoch 46/100
# 255/255 [==============================] - 0s 1ms/step - loss: 395.1238 - val_loss: 434.2915
# Epoch 47/100
# 255/255 [==============================] - 0s 1ms/step - loss: 396.9169 - val_loss: 432.7671
# Epoch 48/100
# 255/255 [==============================] - 0s 963us/step - loss: 392.6542 - val_loss: 431.0850
# Epoch 49/100
# 255/255 [==============================] - 0s 1ms/step - loss: 384.4706 - val_loss: 426.3205
# Epoch 50/100
# 255/255 [==============================] - 0s 983us/step - loss: 383.3326 - val_loss: 423.3217
# Epoch 51/100
# 255/255 [==============================] - 0s 991us/step - loss: 383.6789 - val_loss: 422.6350
# Epoch 52/100
# 255/255 [==============================] - 0s 980us/step - loss: 379.6704 - val_loss: 420.6347
# Epoch 53/100
# 255/255 [==============================] - 0s 987us/step - loss: 376.7598 - val_loss: 417.1393
# Epoch 54/100
# 255/255 [==============================] - 0s 970us/step - loss: 376.2185 - val_loss: 417.9775
# Epoch 55/100
# 255/255 [==============================] - 0s 974us/step - loss: 372.4465 - val_loss: 413.5550
# Epoch 56/100
# 255/255 [==============================] - 0s 919us/step - loss: 371.8636 - val_loss: 411.9328
# Epoch 57/100
# 255/255 [==============================] - 0s 931us/step - loss: 369.8976 - val_loss: 411.2266
# Epoch 58/100
# 255/255 [==============================] - 0s 903us/step - loss: 364.7518 - val_loss: 412.8895
# Epoch 59/100
# 255/255 [==============================] - 0s 916us/step - loss: 360.5046 - val_loss: 407.7057
# Epoch 60/100
# 255/255 [==============================] - 0s 978us/step - loss: 360.9014 - val_loss: 406.5354
# Epoch 61/100
# 255/255 [==============================] - 0s 937us/step - loss: 359.9661 - val_loss: 405.4789
# Epoch 62/100
# 255/255 [==============================] - 0s 919us/step - loss: 351.4482 - val_loss: 405.0150
# Epoch 63/100
# 255/255 [==============================] - 0s 921us/step - loss: 353.9830 - val_loss: 403.9241
# Epoch 64/100
# 255/255 [==============================] - 0s 928us/step - loss: 353.5156 - val_loss: 399.1511
# Epoch 65/100
# 255/255 [==============================] - 0s 971us/step - loss: 351.2381 - val_loss: 398.8956
# Epoch 66/100
# 255/255 [==============================] - 0s 927us/step - loss: 347.5439 - val_loss: 396.5600
# Epoch 67/100
# 255/255 [==============================] - 0s 934us/step - loss: 347.0573 - val_loss: 393.5158
# Epoch 68/100
# 255/255 [==============================] - 0s 1ms/step - loss: 343.0302 - val_loss: 393.0930
# Epoch 69/100
# 255/255 [==============================] - 0s 923us/step - loss: 342.7879 - val_loss: 394.4493
# Epoch 70/100
# 255/255 [==============================] - 0s 941us/step - loss: 335.4955 - val_loss: 391.8427
# Epoch 71/100
# 255/255 [==============================] - 0s 942us/step - loss: 336.6730 - val_loss: 391.3878
# Epoch 72/100
# 255/255 [==============================] - 0s 936us/step - loss: 334.4561 - val_loss: 390.6574
# Epoch 73/100
# 255/255 [==============================] - 0s 905us/step - loss: 333.1154 - val_loss: 385.1488
# Epoch 74/100
# 255/255 [==============================] - 0s 984us/step - loss: 332.6172 - val_loss: 389.9789
# Epoch 75/100
# 255/255 [==============================] - 0s 913us/step - loss: 330.7865 - val_loss: 386.7443
# Epoch 76/100
# 255/255 [==============================] - 0s 909us/step - loss: 326.0378 - val_loss: 382.6821
# Epoch 77/100
# 255/255 [==============================] - 0s 921us/step - loss: 326.6175 - val_loss: 384.3478
# Epoch 78/100
# 255/255 [==============================] - 0s 937us/step - loss: 324.4502 - val_loss: 378.9948
# Epoch 79/100
# 255/255 [==============================] - 0s 936us/step - loss: 325.6997 - val_loss: 378.8627
# Epoch 80/100
# 255/255 [==============================] - 0s 943us/step - loss: 321.9537 - val_loss: 376.9682
# Epoch 81/100
# 255/255 [==============================] - 0s 909us/step - loss: 319.8457 - val_loss: 376.9038
# Epoch 82/100
# 255/255 [==============================] - 0s 927us/step - loss: 318.5298 - val_loss: 376.4568
# Epoch 83/100
# 255/255 [==============================] - 0s 912us/step - loss: 314.8741 - val_loss: 375.5905
# Epoch 84/100
# 255/255 [==============================] - 0s 911us/step - loss: 314.1508 - val_loss: 374.4302
# Epoch 85/100
# 255/255 [==============================] - 0s 916us/step - loss: 313.3711 - val_loss: 373.5955
# Epoch 86/100
# 255/255 [==============================] - 0s 1ms/step - loss: 311.5562 - val_loss: 372.3501
# Epoch 87/100
# 255/255 [==============================] - 0s 914us/step - loss: 308.9963 - val_loss: 370.5029
# Epoch 88/100
# 255/255 [==============================] - 0s 910us/step - loss: 309.2901 - val_loss: 369.4420
# Epoch 89/100
# 255/255 [==============================] - 0s 945us/step - loss: 304.6624 - val_loss: 370.2574
# Epoch 90/100
# 255/255 [==============================] - 0s 1ms/step - loss: 304.0537 - val_loss: 365.2842
# Epoch 91/100
# 255/255 [==============================] - 0s 914us/step - loss: 303.7906 - val_loss: 366.0293
# Epoch 92/100
# 255/255 [==============================] - 0s 948us/step - loss: 301.2407 - val_loss: 362.5824
# Epoch 93/100
# 255/255 [==============================] - 0s 926us/step - loss: 299.9199 - val_loss: 362.1019
# Epoch 94/100
# 255/255 [==============================] - 0s 937us/step - loss: 298.7856 - val_loss: 363.0037
# Epoch 95/100
# 255/255 [==============================] - 0s 918us/step - loss: 295.7535 - val_loss: 361.6284
# Epoch 96/100
# 255/255 [==============================] - 0s 904us/step - loss: 295.2422 - val_loss: 358.4233
# Epoch 97/100
# 255/255 [==============================] - 0s 903us/step - loss: 294.6861 - val_loss: 362.0702
# Epoch 98/100
# 255/255 [==============================] - 0s 904us/step - loss: 292.7239 - val_loss: 359.9372
# Epoch 99/100
# 255/255 [==============================] - 0s 935us/step - loss: 291.0240 - val_loss: 356.7507
# Epoch 100/100
# 255/255 [==============================] - 0s 928us/step - loss: 289.6245 - val_loss: 354.7820
# 54/54 [==============================] - 0s 530us/step
# Completed 3 splits
# Epoch 1/100
# 278/278 [==============================] - 1s 1ms/step - loss: 7805.1699 - val_loss: 8639.0176
# Epoch 2/100
# 278/278 [==============================] - 0s 942us/step - loss: 7524.5215 - val_loss: 10098.3271
# Epoch 3/100
# 278/278 [==============================] - 0s 889us/step - loss: 6936.5752 - val_loss: 15127.6279
# Epoch 4/100
# 278/278 [==============================] - 0s 964us/step - loss: 5969.8584 - val_loss: 29200.4355
# Epoch 5/100
# 278/278 [==============================] - 0s 901us/step - loss: 4428.2012 - val_loss: 59866.8828
# Epoch 6/100
# 278/278 [==============================] - 0s 893us/step - loss: 2733.7427 - val_loss: 114792.4375
# 56/56 [==============================] - 0s 493us/step
# Completed 4 splits
# Epoch 1/100
# 306/306 [==============================] - 1s 1ms/step - loss: 7433.2212 - val_loss: 8557.2051
# Epoch 2/100
# 306/306 [==============================] - 0s 868us/step - loss: 6977.7358 - val_loss: 8236.8047
# Epoch 3/100
# 306/306 [==============================] - 0s 878us/step - loss: 6071.6289 - val_loss: 8949.0361
# Epoch 4/100
# 306/306 [==============================] - 0s 873us/step - loss: 4624.4478 - val_loss: 12760.8477
# Epoch 5/100
# 306/306 [==============================] - 0s 881us/step - loss: 2850.1824 - val_loss: 22302.4590
# Epoch 6/100
# 306/306 [==============================] - 0s 873us/step - loss: 1436.3280 - val_loss: 33647.2383
# Epoch 7/100
# 306/306 [==============================] - 0s 945us/step - loss: 908.4470 - val_loss: 36425.3984
# 59/59 [==============================] - 0s 500us/step
# Completed 5 splits
# Epoch 1/100
# 328/328 [==============================] - 1s 1ms/step - loss: 7626.3857 - val_loss: 10917.4883
# Epoch 2/100
# 328/328 [==============================] - 0s 868us/step - loss: 6823.3960 - val_loss: 26375.7793
# Epoch 3/100
# 328/328 [==============================] - 0s 863us/step - loss: 5430.0063 - val_loss: 71211.6250
# Epoch 4/100
# 328/328 [==============================] - 0s 948us/step - loss: 3534.5454 - val_loss: 165642.9219
# Epoch 5/100
# 328/328 [==============================] - 0s 850us/step - loss: 1866.0602 - val_loss: 263064.1562
# Epoch 6/100
# 328/328 [==============================] - 0s 870us/step - loss: 1127.7192 - val_loss: 288183.8438
# 62/62 [==============================] - 0s 493us/step
# Completed 6 splits
# Epoch 1/100
# 345/345 [==============================] - 1s 1ms/step - loss: 8696.0254 - val_loss: 7345.1558
# Epoch 2/100
# 345/345 [==============================] - 0s 907us/step - loss: 8437.2705 - val_loss: 6987.1470
# Epoch 3/100
# 345/345 [==============================] - 0s 850us/step - loss: 7749.0049 - val_loss: 6188.9541
# Epoch 4/100
# 345/345 [==============================] - 0s 859us/step - loss: 6399.6201 - val_loss: 4869.8345
# Epoch 5/100
# 345/345 [==============================] - 0s 851us/step - loss: 4396.2290 - val_loss: 3313.0996
# Epoch 6/100
# 345/345 [==============================] - 0s 851us/step - loss: 2343.1411 - val_loss: 2231.0095
# Epoch 7/100
# 345/345 [==============================] - 0s 851us/step - loss: 1190.7467 - val_loss: 1746.2714
# Epoch 8/100
# 345/345 [==============================] - 0s 870us/step - loss: 812.1075 - val_loss: 1383.5721
# Epoch 9/100
# 345/345 [==============================] - 0s 873us/step - loss: 667.2125 - val_loss: 1088.0643
# Epoch 10/100
# 345/345 [==============================] - 0s 854us/step - loss: 598.1982 - val_loss: 878.4542
# Epoch 11/100
# 345/345 [==============================] - 0s 853us/step - loss: 572.2947 - val_loss: 766.8049
# Epoch 12/100
# 345/345 [==============================] - 0s 854us/step - loss: 546.2150 - val_loss: 685.3150
# Epoch 13/100
# 345/345 [==============================] - 0s 891us/step - loss: 527.4836 - val_loss: 640.4206
# Epoch 14/100
# 345/345 [==============================] - 0s 848us/step - loss: 533.0090 - val_loss: 602.3952
# Epoch 15/100
# 345/345 [==============================] - 0s 859us/step - loss: 514.4251 - val_loss: 562.8452
# Epoch 16/100
# 345/345 [==============================] - 0s 852us/step - loss: 502.4915 - val_loss: 532.6906
# Epoch 17/100
# 345/345 [==============================] - 0s 913us/step - loss: 494.9596 - val_loss: 514.9067
# Epoch 18/100
# 345/345 [==============================] - 0s 855us/step - loss: 497.3281 - val_loss: 498.6546
# Epoch 19/100
# 345/345 [==============================] - 0s 862us/step - loss: 487.7641 - val_loss: 481.3994
# Epoch 20/100
# 345/345 [==============================] - 0s 872us/step - loss: 485.2583 - val_loss: 469.9228
# Epoch 21/100
# 345/345 [==============================] - 0s 854us/step - loss: 479.6566 - val_loss: 460.0979
# Epoch 22/100
# 345/345 [==============================] - 0s 848us/step - loss: 470.5762 - val_loss: 446.5042
# Epoch 23/100
# 345/345 [==============================] - 0s 916us/step - loss: 459.4297 - val_loss: 438.4395
# Epoch 24/100
# 345/345 [==============================] - 0s 849us/step - loss: 459.1157 - val_loss: 433.8335
# Epoch 25/100
# 345/345 [==============================] - 0s 851us/step - loss: 461.7013 - val_loss: 422.9075
# Epoch 26/100
# 345/345 [==============================] - 0s 849us/step - loss: 451.9313 - val_loss: 418.3727
# Epoch 27/100
# 345/345 [==============================] - 0s 842us/step - loss: 455.8669 - val_loss: 412.0479
# Epoch 28/100
# 345/345 [==============================] - 0s 911us/step - loss: 448.3436 - val_loss: 408.0729
# Epoch 29/100
# 345/345 [==============================] - 0s 849us/step - loss: 443.4929 - val_loss: 403.7078
# Epoch 30/100
# 345/345 [==============================] - 0s 858us/step - loss: 435.1524 - val_loss: 400.4391
# Epoch 31/100
# 345/345 [==============================] - 0s 863us/step - loss: 434.7969 - val_loss: 397.1803
# Epoch 32/100
# 345/345 [==============================] - 0s 871us/step - loss: 427.0723 - val_loss: 394.3866
# Epoch 33/100
# 345/345 [==============================] - 0s 904us/step - loss: 428.6164 - val_loss: 390.5535
# Epoch 34/100
# 345/345 [==============================] - 0s 910us/step - loss: 421.7717 - val_loss: 388.4815
# Epoch 35/100
# 345/345 [==============================] - 0s 875us/step - loss: 424.7952 - val_loss: 384.8047
# Epoch 36/100
# 345/345 [==============================] - 0s 858us/step - loss: 419.8266 - val_loss: 381.3016
# Epoch 37/100
# 345/345 [==============================] - 0s 865us/step - loss: 418.9920 - val_loss: 379.3535
# Epoch 38/100
# 345/345 [==============================] - 0s 857us/step - loss: 410.9883 - val_loss: 375.2251
# Epoch 39/100
# 345/345 [==============================] - 0s 858us/step - loss: 406.6816 - val_loss: 372.4702
# Epoch 40/100
# 345/345 [==============================] - 0s 853us/step - loss: 401.7193 - val_loss: 369.9330
# Epoch 41/100
# 345/345 [==============================] - 0s 840us/step - loss: 399.6761 - val_loss: 364.9865
# Epoch 42/100
# 345/345 [==============================] - 0s 895us/step - loss: 400.4057 - val_loss: 362.9035
# Epoch 43/100
# 345/345 [==============================] - 0s 861us/step - loss: 394.0393 - val_loss: 362.7690
# Epoch 44/100
# 345/345 [==============================] - 0s 847us/step - loss: 389.9572 - val_loss: 358.6393
# Epoch 45/100
# 345/345 [==============================] - 0s 854us/step - loss: 389.6389 - val_loss: 357.1942
# Epoch 46/100
# 345/345 [==============================] - 0s 856us/step - loss: 383.4021 - val_loss: 354.7228
# Epoch 47/100
# 345/345 [==============================] - 0s 849us/step - loss: 380.2210 - val_loss: 353.7089
# Epoch 48/100
# 345/345 [==============================] - 0s 855us/step - loss: 377.2726 - val_loss: 352.2880
# Epoch 49/100
# 345/345 [==============================] - 0s 846us/step - loss: 379.7050 - val_loss: 351.3768
# Epoch 50/100
# 345/345 [==============================] - 0s 854us/step - loss: 376.6042 - val_loss: 350.7957
# Epoch 51/100
# 345/345 [==============================] - 0s 866us/step - loss: 373.4822 - val_loss: 348.2609
# Epoch 52/100
# 345/345 [==============================] - 0s 936us/step - loss: 370.8629 - val_loss: 345.6001
# Epoch 53/100
# 345/345 [==============================] - 0s 876us/step - loss: 365.8740 - val_loss: 344.2070
# Epoch 54/100
# 345/345 [==============================] - 0s 851us/step - loss: 363.8349 - val_loss: 343.2532
# Epoch 55/100
# 345/345 [==============================] - 0s 862us/step - loss: 359.9699 - val_loss: 342.0661
# Epoch 56/100
# 345/345 [==============================] - 0s 866us/step - loss: 357.8287 - val_loss: 341.0120
# Epoch 57/100
# 345/345 [==============================] - 0s 958us/step - loss: 354.4070 - val_loss: 338.5958
# Epoch 58/100
# 345/345 [==============================] - 0s 864us/step - loss: 354.2379 - val_loss: 337.1606
# Epoch 59/100
# 345/345 [==============================] - 0s 853us/step - loss: 355.6359 - val_loss: 337.8764
# Epoch 60/100
# 345/345 [==============================] - 0s 855us/step - loss: 348.9896 - val_loss: 335.8484
# Epoch 61/100
# 345/345 [==============================] - 0s 891us/step - loss: 348.5247 - val_loss: 336.0784
# Epoch 62/100
# 345/345 [==============================] - 0s 853us/step - loss: 344.3154 - val_loss: 334.2493
# Epoch 63/100
# 345/345 [==============================] - 0s 864us/step - loss: 344.5030 - val_loss: 332.0985
# Epoch 64/100
# 345/345 [==============================] - 0s 860us/step - loss: 340.0267 - val_loss: 331.2241
# Epoch 65/100
# 345/345 [==============================] - 0s 865us/step - loss: 339.0155 - val_loss: 329.6873
# Epoch 66/100
# 345/345 [==============================] - 0s 869us/step - loss: 337.5270 - val_loss: 328.1803
# Epoch 67/100
# 345/345 [==============================] - 0s 870us/step - loss: 336.3173 - val_loss: 327.2535
# Epoch 68/100
# 345/345 [==============================] - 0s 865us/step - loss: 333.6024 - val_loss: 326.4710
# Epoch 69/100
# 345/345 [==============================] - 0s 919us/step - loss: 331.5419 - val_loss: 325.5222
# Epoch 70/100
# 345/345 [==============================] - 0s 882us/step - loss: 329.6265 - val_loss: 325.1382
# Epoch 71/100
# 345/345 [==============================] - 0s 851us/step - loss: 326.9481 - val_loss: 324.7958
# Epoch 72/100
# 345/345 [==============================] - 0s 842us/step - loss: 325.1013 - val_loss: 327.1687
# Epoch 73/100
# 345/345 [==============================] - 0s 844us/step - loss: 321.7296 - val_loss: 325.0704
# Epoch 74/100
# 345/345 [==============================] - 0s 847us/step - loss: 322.9442 - val_loss: 322.3565
# Epoch 75/100
# 345/345 [==============================] - 0s 843us/step - loss: 320.5707 - val_loss: 322.6154
# Epoch 76/100
# 345/345 [==============================] - 0s 860us/step - loss: 316.3445 - val_loss: 320.0276
# Epoch 77/100
# 345/345 [==============================] - 0s 845us/step - loss: 315.1158 - val_loss: 319.0097
# Epoch 78/100
# 345/345 [==============================] - 0s 926us/step - loss: 312.0675 - val_loss: 319.3386
# Epoch 79/100
# 345/345 [==============================] - 0s 871us/step - loss: 312.9219 - val_loss: 318.0199
# Epoch 80/100
# 345/345 [==============================] - 0s 854us/step - loss: 312.9672 - val_loss: 318.5623
# Epoch 81/100
# 345/345 [==============================] - 0s 856us/step - loss: 308.6319 - val_loss: 318.0029
# Epoch 82/100
# 345/345 [==============================] - 0s 850us/step - loss: 307.7087 - val_loss: 317.7993
# Epoch 83/100
# 345/345 [==============================] - 0s 850us/step - loss: 305.3405 - val_loss: 314.3181
# Epoch 84/100
# 345/345 [==============================] - 0s 849us/step - loss: 304.1407 - val_loss: 316.1817
# Epoch 85/100
# 345/345 [==============================] - 0s 868us/step - loss: 302.9168 - val_loss: 315.6401
# Epoch 86/100
# 345/345 [==============================] - 0s 940us/step - loss: 301.6367 - val_loss: 313.5752
# Epoch 87/100
# 345/345 [==============================] - 0s 877us/step - loss: 301.7863 - val_loss: 312.7116
# Epoch 88/100
# 345/345 [==============================] - 0s 855us/step - loss: 298.1928 - val_loss: 312.5256
# Epoch 89/100
# 345/345 [==============================] - 0s 849us/step - loss: 297.1868 - val_loss: 314.5032
# Epoch 90/100
# 345/345 [==============================] - 0s 899us/step - loss: 295.1104 - val_loss: 309.8937
# Epoch 91/100
# 345/345 [==============================] - 0s 853us/step - loss: 295.4494 - val_loss: 311.5044
# Epoch 92/100
# 345/345 [==============================] - 0s 855us/step - loss: 293.8847 - val_loss: 310.5376
# Epoch 93/100
# 345/345 [==============================] - 0s 854us/step - loss: 292.2675 - val_loss: 310.0427
# Epoch 94/100
# 345/345 [==============================] - 0s 849us/step - loss: 288.4481 - val_loss: 308.9487
# Epoch 95/100
# 345/345 [==============================] - 0s 897us/step - loss: 292.0050 - val_loss: 308.1631
# Epoch 96/100
# 345/345 [==============================] - 0s 859us/step - loss: 288.9449 - val_loss: 307.6701
# Epoch 97/100
# 345/345 [==============================] - 0s 847us/step - loss: 287.3011 - val_loss: 307.4543
# Epoch 98/100
# 345/345 [==============================] - 0s 850us/step - loss: 287.2674 - val_loss: 306.1304
# Epoch 99/100
# 345/345 [==============================] - 0s 853us/step - loss: 285.7597 - val_loss: 305.1272
# Epoch 100/100
# 345/345 [==============================] - 0s 858us/step - loss: 283.6266 - val_loss: 305.9078
# 65/65 [==============================] - 0s 502us/step
# Completed 7 splits
# Epoch 1/100
# 362/362 [==============================] - 1s 1ms/step - loss: 8602.8252 - val_loss: 8088.0693
# Epoch 2/100
# 362/362 [==============================] - 0s 918us/step - loss: 8124.5591 - val_loss: 7450.9155
# Epoch 3/100
# 362/362 [==============================] - 0s 854us/step - loss: 7050.9849 - val_loss: 6163.7207
# Epoch 4/100
# 362/362 [==============================] - 0s 881us/step - loss: 5073.9644 - val_loss: 4187.0029
# Epoch 5/100
# 362/362 [==============================] - 0s 859us/step - loss: 2751.4368 - val_loss: 2316.7327
# Epoch 6/100
# 362/362 [==============================] - 0s 872us/step - loss: 1235.4331 - val_loss: 1550.3462
# Epoch 7/100
# 362/362 [==============================] - 0s 866us/step - loss: 867.2823 - val_loss: 1256.8851
# Epoch 8/100
# 362/362 [==============================] - 0s 849us/step - loss: 738.9968 - val_loss: 1064.7484
# Epoch 9/100
# 362/362 [==============================] - 0s 900us/step - loss: 658.3475 - val_loss: 922.2838
# Epoch 10/100
# 362/362 [==============================] - 0s 867us/step - loss: 618.9144 - val_loss: 827.4908
# Epoch 11/100
# 362/362 [==============================] - 0s 925us/step - loss: 582.7664 - val_loss: 743.5974
# Epoch 12/100
# 362/362 [==============================] - 0s 852us/step - loss: 558.7686 - val_loss: 683.0212
# Epoch 13/100
# ...
# Epoch 32/100
# 411/411 [==============================] - 0s 857us/step - loss: 354.6930 - val_loss: 358.9522
# Epoch 33/100
# 411/411 [==============================] - 0s 850us/step - loss: 353.6466 - val_loss: 359.7649
# Epoch 34/100
# 411/411 [==============================] - 0s 899us/step - loss: 354.7242 - val_loss: 355.8878
# Epoch 35/100
# 411/411 [==============================] - 0s 853us/step - loss: 350.3478 - val_loss: 354.8008
# Epoch 36/100
# 411/411 [==============================] - 0s 868us/step - loss: 352.9266 - val_loss: 351.9572
# Epoch 37/100
# 411/411 [==============================] - 0s 957us/step - loss: 344.5579 - val_loss: 352.6965
# Epoch 38/100
# 411/411 [==============================] - 0s 863us/step - loss: 343.5740 - val_loss: 349.6511
# Epoch 39/100
# 411/411 [==============================] - 0s 914us/step - loss: 342.3083 - val_loss: 348.8585
# Epoch 40/100
# 411/411 [==============================] - 0s 851us/step - loss: 344.6637 - val_loss: 354.2584
# Epoch 41/100
# 411/411 [==============================] - 0s 851us/step - loss: 339.9827 - val_loss: 348.8966
# Epoch 42/100
# 411/411 [==============================] - 0s 855us/step - loss: 339.1242 - val_loss: 345.8304
# Epoch 43/100
# 411/411 [==============================] - 0s 851us/step - loss: 337.1736 - val_loss: 346.7744
# Epoch 44/100
# 411/411 [==============================] - 0s 905us/step - loss: 333.5620 - val_loss: 342.9996
# Epoch 45/100
# 411/411 [==============================] - 0s 893us/step - loss: 333.8762 - val_loss: 347.3526
# Epoch 46/100
# 411/411 [==============================] - 0s 853us/step - loss: 331.8841 - val_loss: 340.1348
# Epoch 47/100
# 411/411 [==============================] - 0s 863us/step - loss: 329.1410 - val_loss: 338.1585
# Epoch 48/100
# 411/411 [==============================] - 0s 856us/step - loss: 331.6272 - val_loss: 337.6879
# Epoch 49/100
# 411/411 [==============================] - 0s 901us/step - loss: 325.9806 - val_loss: 336.9077
# Epoch 50/100
# 411/411 [==============================] - 0s 861us/step - loss: 328.9623 - val_loss: 336.1907
# Epoch 51/100
# 411/411 [==============================] - 0s 876us/step - loss: 325.9609 - val_loss: 334.3271
# Epoch 52/100
# 411/411 [==============================] - 0s 893us/step - loss: 325.8698 - val_loss: 333.8522
# Epoch 53/100
# 411/411 [==============================] - 0s 866us/step - loss: 321.3383 - val_loss: 333.7852
# Epoch 54/100
# 411/411 [==============================] - 0s 881us/step - loss: 321.4471 - val_loss: 332.6030
# Epoch 55/100
# 411/411 [==============================] - 0s 851us/step - loss: 318.6321 - val_loss: 332.0305
# Epoch 56/100
# 411/411 [==============================] - 0s 861us/step - loss: 317.4580 - val_loss: 329.6079
# Epoch 57/100
# 411/411 [==============================] - 0s 916us/step - loss: 316.3141 - val_loss: 327.7910
# Epoch 58/100
# 411/411 [==============================] - 0s 842us/step - loss: 315.9879 - val_loss: 329.3441
# Epoch 59/100
# 411/411 [==============================] - 0s 887us/step - loss: 312.6070 - val_loss: 327.1769
# Epoch 60/100
# 411/411 [==============================] - 0s 856us/step - loss: 312.5486 - val_loss: 326.6525
# Epoch 61/100
# 411/411 [==============================] - 0s 854us/step - loss: 311.1266 - val_loss: 323.2221
# Epoch 62/100
# 411/411 [==============================] - 0s 857us/step - loss: 309.5052 - val_loss: 321.9347
# Epoch 63/100
# 411/411 [==============================] - 0s 889us/step - loss: 309.7336 - val_loss: 321.4854
# Epoch 64/100
# 411/411 [==============================] - 0s 843us/step - loss: 309.9613 - val_loss: 320.8733
# Epoch 65/100
# 411/411 [==============================] - 0s 885us/step - loss: 307.6497 - val_loss: 319.0316
# Epoch 66/100
# 411/411 [==============================] - 0s 894us/step - loss: 305.5556 - val_loss: 317.9940
# Epoch 67/100
# 411/411 [==============================] - 0s 854us/step - loss: 302.6277 - val_loss: 315.6727
# Epoch 68/100
# 411/411 [==============================] - 0s 888us/step - loss: 302.5054 - val_loss: 314.5186
# Epoch 69/100
# 411/411 [==============================] - 0s 861us/step - loss: 301.3384 - val_loss: 313.5036
# Epoch 70/100
# 411/411 [==============================] - 0s 851us/step - loss: 299.9948 - val_loss: 314.0661
# Epoch 71/100
# 411/411 [==============================] - 0s 846us/step - loss: 296.8549 - val_loss: 310.9296
# Epoch 72/100
# 411/411 [==============================] - 0s 857us/step - loss: 297.5866 - val_loss: 311.9461
# Epoch 73/100
# 411/411 [==============================] - 0s 896us/step - loss: 297.7650 - val_loss: 309.1572
# Epoch 74/100
# 411/411 [==============================] - 0s 875us/step - loss: 296.4569 - val_loss: 307.0328
# Epoch 75/100
# 411/411 [==============================] - 0s 858us/step - loss: 296.7353 - val_loss: 306.1858
# Epoch 76/100
# 411/411 [==============================] - 0s 905us/step - loss: 294.0955 - val_loss: 305.3326
# Epoch 77/100
# 411/411 [==============================] - 0s 892us/step - loss: 292.3123 - val_loss: 304.2000
# Epoch 78/100
# 411/411 [==============================] - 0s 852us/step - loss: 292.2787 - val_loss: 304.0610
# Epoch 79/100
# 411/411 [==============================] - 0s 915us/step - loss: 290.7245 - val_loss: 303.6405
# Epoch 80/100
# 411/411 [==============================] - 0s 1ms/step - loss: 289.9498 - val_loss: 304.3722
# Epoch 81/100
# 411/411 [==============================] - 0s 880us/step - loss: 288.6276 - val_loss: 303.4936
# Epoch 82/100
# 411/411 [==============================] - 0s 881us/step - loss: 289.1351 - val_loss: 300.3654
# Epoch 83/100
# 411/411 [==============================] - 0s 927us/step - loss: 287.3534 - val_loss: 299.7801
# Epoch 84/100
# 411/411 [==============================] - 0s 861us/step - loss: 287.5357 - val_loss: 298.1751
# Epoch 85/100
# 411/411 [==============================] - 0s 852us/step - loss: 284.9998 - val_loss: 296.7058
# Epoch 86/100
# 411/411 [==============================] - 0s 893us/step - loss: 285.7681 - val_loss: 298.9447
# Epoch 87/100
# 411/411 [==============================] - 0s 839us/step - loss: 283.0744 - val_loss: 294.8925
# Epoch 88/100
# 411/411 [==============================] - 0s 844us/step - loss: 282.9775 - val_loss: 294.8313
# Epoch 89/100
# 411/411 [==============================] - 0s 905us/step - loss: 281.2408 - val_loss: 293.7955
# Epoch 90/100
# 411/411 [==============================] - 0s 893us/step - loss: 280.1346 - val_loss: 293.5440
# Epoch 91/100
# 411/411 [==============================] - 0s 858us/step - loss: 280.8317 - val_loss: 292.2207
# Epoch 92/100
# 411/411 [==============================] - 0s 859us/step - loss: 279.6634 - val_loss: 290.4425
# Epoch 93/100
# 411/411 [==============================] - 0s 844us/step - loss: 278.2219 - val_loss: 289.5751
# Epoch 94/100
# 411/411 [==============================] - 0s 937us/step - loss: 275.7161 - val_loss: 287.8571
# Epoch 95/100
# 411/411 [==============================] - 0s 903us/step - loss: 275.9326 - val_loss: 287.4759
# Epoch 96/100
# 411/411 [==============================] - 0s 863us/step - loss: 275.7084 - val_loss: 285.6873
# Epoch 97/100
# 411/411 [==============================] - 0s 848us/step - loss: 274.7438 - val_loss: 285.7954
# Epoch 98/100
# 411/411 [==============================] - 0s 850us/step - loss: 274.9089 - val_loss: 284.4733
# Epoch 99/100
# 411/411 [==============================] - 0s 857us/step - loss: 272.3739 - val_loss: 284.2354
# Epoch 100/100
# 411/411 [==============================] - 0s 890us/step - loss: 271.9151 - val_loss: 283.0617
# 86/86 [==============================] - 0s 550us/step
# Completed 10 splits
# Epoch 1/100
# 440/440 [==============================] - 1s 995us/step - loss: 8140.8862 - val_loss: 8430.6074
# Epoch 2/100
# 440/440 [==============================] - 0s 840us/step - loss: 7365.7041 - val_loss: 7121.9619
# Epoch 3/100
# 440/440 [==============================] - 0s 893us/step - loss: 5466.3047 - val_loss: 4570.7241
# Epoch 4/100
# 440/440 [==============================] - 0s 847us/step - loss: 2747.9084 - val_loss: 1732.1349
# Epoch 5/100
# 440/440 [==============================] - 0s 849us/step - loss: 903.9955 - val_loss: 780.8612
# Epoch 6/100
# 440/440 [==============================] - 0s 844us/step - loss: 583.5089 - val_loss: 604.9097
# Epoch 7/100
# 440/440 [==============================] - 0s 908us/step - loss: 516.3464 - val_loss: 544.0385
# Epoch 8/100
# 440/440 [==============================] - 0s 853us/step - loss: 483.8971 - val_loss: 510.1714
# Epoch 9/100
# 440/440 [==============================] - 0s 864us/step - loss: 463.1114 - val_loss: 487.9548
# Epoch 10/100
# 440/440 [==============================] - 0s 852us/step - loss: 446.4543 - val_loss: 475.0737
# Epoch 11/100
# 440/440 [==============================] - 0s 874us/step - loss: 429.3321 - val_loss: 464.3350
# Epoch 12/100
# 440/440 [==============================] - 0s 888us/step - loss: 418.8223 - val_loss: 457.4748
# Epoch 13/100
# 440/440 [==============================] - 0s 905us/step - loss: 406.5266 - val_loss: 451.1420
# Epoch 14/100
# 440/440 [==============================] - 0s 843us/step - loss: 398.9846 - val_loss: 450.2120
# Epoch 15/100
# 440/440 [==============================] - 0s 842us/step - loss: 394.4002 - val_loss: 447.3979
# Epoch 16/100
# 440/440 [==============================] - 0s 893us/step - loss: 384.4422 - val_loss: 445.0714
# Epoch 17/100
# 440/440 [==============================] - 0s 848us/step - loss: 383.1295 - val_loss: 440.4226
# Epoch 18/100
# 440/440 [==============================] - 0s 845us/step - loss: 376.8906 - val_loss: 442.9447
# Epoch 19/100
# 440/440 [==============================] - 0s 845us/step - loss: 374.7089 - val_loss: 437.3472
# Epoch 20/100
# 440/440 [==============================] - 0s 911us/step - loss: 366.5387 - val_loss: 436.5585
# Epoch 21/100
# 440/440 [==============================] - 0s 865us/step - loss: 367.4887 - val_loss: 435.0945
# Epoch 22/100
# 440/440 [==============================] - 0s 851us/step - loss: 361.8864 - val_loss: 435.5011
# Epoch 23/100
# 440/440 [==============================] - 0s 862us/step - loss: 359.2596 - val_loss: 437.6379
# Epoch 24/100
# 440/440 [==============================] - 0s 888us/step - loss: 357.1033 - val_loss: 434.5330
# Epoch 25/100
# 440/440 [==============================] - 0s 873us/step - loss: 351.7261 - val_loss: 436.2361
# Epoch 26/100
# 440/440 [==============================] - 0s 839us/step - loss: 352.8121 - val_loss: 434.8091
# Epoch 27/100
# 440/440 [==============================] - 0s 843us/step - loss: 347.0839 - val_loss: 433.9590
# Epoch 28/100
# 440/440 [==============================] - 0s 887us/step - loss: 346.3379 - val_loss: 435.5992
# Epoch 29/100
# 440/440 [==============================] - 0s 868us/step - loss: 340.8428 - val_loss: 434.1314
# Epoch 30/100
# 440/440 [==============================] - 0s 907us/step - loss: 340.6465 - val_loss: 432.5242
# Epoch 31/100
# 440/440 [==============================] - 0s 886us/step - loss: 340.5992 - val_loss: 435.6732
# Epoch 32/100
# 440/440 [==============================] - 0s 887us/step - loss: 340.6589 - val_loss: 436.0945
# Epoch 33/100
# 440/440 [==============================] - 0s 857us/step - loss: 335.9778 - val_loss: 438.1821
# Epoch 34/100
# 440/440 [==============================] - 0s 872us/step - loss: 335.6332 - val_loss: 438.5615
# Epoch 35/100
# 440/440 [==============================] - 0s 863us/step - loss: 332.0844 - val_loss: 437.8814
# 96/96 [==============================] - 0s 575us/step
# Completed 11 splits
# Epoch 1/100
# 461/461 [==============================] - 1s 1ms/step - loss: 8122.9272 - val_loss: 197886.6875
# Epoch 2/100
# 461/461 [==============================] - 0s 884us/step - loss: 7467.3813 - val_loss: 1905481.8750
# Epoch 3/100
# 461/461 [==============================] - 0s 885us/step - loss: 5790.2026 - val_loss: 10258999.0000
# Epoch 4/100
# 461/461 [==============================] - 0s 913us/step - loss: 3076.8218 - val_loss: 33401414.0000
# Epoch 5/100
# 461/461 [==============================] - 0s 879us/step - loss: 1068.0764 - val_loss: 51575632.0000
# Epoch 6/100
# 461/461 [==============================] - 0s 883us/step - loss: 574.1803 - val_loss: 46223960.0000
# 111/111 [==============================] - 0s 509us/step
# Completed 12 splits
# Epoch 1/100
# 487/487 [==============================] - 1s 1ms/step - loss: 8434.7324 - val_loss: 175960.3594
# Epoch 2/100
# 487/487 [==============================] - 0s 944us/step - loss: 7378.3130 - val_loss: 3043424.0000
# Epoch 3/100
# 487/487 [==============================] - 0s 941us/step - loss: 4977.0698 - val_loss: 18257464.0000
# Epoch 4/100
# 487/487 [==============================] - 0s 1ms/step - loss: 2049.4277 - val_loss: 51819692.0000
# Epoch 5/100
# 487/487 [==============================] - 0s 904us/step - loss: 873.2603 - val_loss: 53818740.0000
# Epoch 6/100
# 487/487 [==============================] - 0s 912us/step - loss: 623.4788 - val_loss: 42556376.0000
# 122/122 [==============================] - 0s 516us/step
# Completed 13 splits
# Epoch 1/100
# 520/520 [==============================] - 1s 1ms/step - loss: 8426.3555 - val_loss: 45596.8633
# Epoch 2/100
# 520/520 [==============================] - 0s 912us/step - loss: 6936.7500 - val_loss: 1277885.8750
# Epoch 3/100
# 520/520 [==============================] - 0s 910us/step - loss: 3909.3269 - val_loss: 11381862.0000
# Epoch 4/100
# 520/520 [==============================] - 0s 951us/step - loss: 1192.5085 - val_loss: 21556686.0000
# Epoch 5/100
# 520/520 [==============================] - 0s 933us/step - loss: 635.5048 - val_loss: 15163707.0000
# Epoch 6/100
# 520/520 [==============================] - 0s 922us/step - loss: 525.0201 - val_loss: 10285469.0000
# 134/134 [==============================] - 0s 518us/step
# Completed 14 splits
# Epoch 1/100
# 565/565 [==============================] - 1s 1ms/step - loss: 8324.7793 - val_loss: 4648.4766
# Epoch 2/100
# 565/565 [==============================] - 1s 914us/step - loss: 7569.2422 - val_loss: 4601.7183
# Epoch 3/100
# 565/565 [==============================] - 1s 903us/step - loss: 5221.7500 - val_loss: 7842.8516
# Epoch 4/100
# 565/565 [==============================] - 1s 933us/step - loss: 1903.6700 - val_loss: 19098.3945
# Epoch 5/100
# 565/565 [==============================] - 1s 902us/step - loss: 807.5832 - val_loss: 19298.9629
# Epoch 6/100
# 565/565 [==============================] - 1s 960us/step - loss: 682.2386 - val_loss: 16216.5059
# Epoch 7/100
# 565/565 [==============================] - 1s 926us/step - loss: 615.5558 - val_loss: 14617.4023
# 160/160 [==============================] - 0s 503us/step
# Completed 15 splits
# Epoch 1/100
# 619/619 [==============================] - 1s 1ms/step - loss: 7458.3052 - val_loss: 3513.2507
# Epoch 2/100
# 619/619 [==============================] - 1s 935us/step - loss: 5731.2773 - val_loss: 5671.1562
# Epoch 3/100
# 619/619 [==============================] - 1s 907us/step - loss: 2365.0723 - val_loss: 14703.9297
# Epoch 4/100
# 619/619 [==============================] - 1s 902us/step - loss: 767.3955 - val_loss: 11709.8545
# Epoch 5/100
# 619/619 [==============================] - 1s 928us/step - loss: 625.9570 - val_loss: 6753.7036
# Epoch 6/100
# 619/619 [==============================] - 1s 912us/step - loss: 563.5408 - val_loss: 3809.6804
# 178/178 [==============================] - 0s 486us/step
# Completed 16 splits
# Epoch 1/100
# 691/691 [==============================] - 1s 1ms/step - loss: 7201.5410 - val_loss: 1652.9438
# Epoch 2/100
# 691/691 [==============================] - 1s 925us/step - loss: 5123.2314 - val_loss: 4134.1646
# Epoch 3/100
# 691/691 [==============================] - 1s 933us/step - loss: 1568.0173 - val_loss: 9859.9395
# Epoch 4/100
# 691/691 [==============================] - 1s 931us/step - loss: 600.6673 - val_loss: 6259.2065
# Epoch 5/100
# 691/691 [==============================] - 1s 906us/step - loss: 536.1723 - val_loss: 4669.0288
# Epoch 6/100
# 691/691 [==============================] - 1s 922us/step - loss: 506.5931 - val_loss: 3648.3203
# 75/75 [==============================] - 0s 518us/step
# Completed 17 splits
# R2_oos NN3 bottom 500:  -572.7430471783252

# %%
R2oos_OLS_df = pd.DataFrame({
    "NN3" : [R2oos_NN3,
                R2oos_NN3_top,
                R2oos_NN3_bottom
                ]
})

R2oos_OLS_df.index = ['Alle', "Øverste 500", "Nederste 500"]

# %%
R2oos_OLS_df
# Out:
#                      NN3
# Alle         -191.860178
# Øverste 500     0.936402
# Nederste 500 -572.743047

# %%
R2oos_OLS_df.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/R2-værdier/R2oos_NN3.csv", index=False)

# %% [markdown]
# # Variable importance

# %%
X_train = df_final[variables].loc[(df_final["Date"] >= '2012-02-28') & (df_final["Date"] < '2020-02-28')]
y_train = df_final["Adj Close t+1"].loc[(df_final["Date"]>='2012-02-28') & (df_final["Date"] < '2020-02-28')]

X_val = df_final[variables].loc[(df_final["Date"] >= '2020-03-28') & (df_final["Date"] < '2023-03-28')]
y_val = df_final["Adj Close t+1"].loc[(df_final["Date"] >= '2020-03-28') & (df_final["Date"] < '2023-03-28')]

X_test = df_final[variables].loc[(df_final["Date"] >= '2023-04-28') & (df_final["Date"] < '2024-04-28')]
y_test = df_final["Adj Close t+1"].loc[(df_final["Date"] >= '2023-04-28') & (df_final["Date"] < '2024-04-28')]


input_shape = [X_train.shape[1]]


mean_train = X_train.mean(axis=0)
std_train  = X_train.std(axis=0)

X_train = (X_train-mean_train) / std_train
X_val = (X_val-mean_train) / std_train
X_test = (X_test-mean_train) / std_train



model = tf.keras.Sequential([

tf.keras.layers.Flatten(input_shape=input_shape),
tf.keras.layers.Dense(units=32, activation='relu'),
tf.keras.layers.Dense(units=16, activation='relu'),
tf.keras.layers.Dense(units=8, activation='relu'),
tf.keras.layers.Dense(units=1, activation='linear')

])

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0, clipnorm=1.0, clipvalue=0.5), loss='mse')    

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[early_stopping])
preds = model.predict(X_test)
preds = preds.ravel()



R2oos_varimp = 1 - np.sum(np.power(y_test - preds, 2)) / np.sum(np.power(y_test, 2))
    
R2oos_varimp
# Out:
# Epoch 1/100
# 7306/7306 [==============================] - 6s 832us/step - loss: 527.8047 - val_loss: 6281.6567
# Epoch 2/100
# 7306/7306 [==============================] - 6s 836us/step - loss: 100.4792 - val_loss: 2213.5215
# Epoch 3/100
# 7306/7306 [==============================] - 6s 845us/step - loss: 81.0209 - val_loss: 830.2207
# Epoch 4/100
# 7306/7306 [==============================] - 6s 847us/step - loss: 72.4468 - val_loss: 410.6859
# Epoch 5/100
# 7306/7306 [==============================] - 6s 843us/step - loss: 67.3066 - val_loss: 284.5768
# Epoch 6/100
# 7306/7306 [==============================] - 6s 859us/step - loss: 63.1279 - val_loss: 207.8758
# Epoch 7/100
# 7306/7306 [==============================] - 6s 849us/step - loss: 60.9476 - val_loss: 185.5062
# Epoch 8/100
# 7306/7306 [==============================] - 6s 844us/step - loss: 59.0894 - val_loss: 157.6321
# Epoch 9/100
# 7306/7306 [==============================] - 6s 852us/step - loss: 57.8630 - val_loss: 134.8590
# Epoch 10/100
# 7306/7306 [==============================] - 6s 857us/step - loss: 56.9083 - val_loss: 131.0789
# Epoch 11/100
# 7306/7306 [==============================] - 7s 946us/step - loss: 56.1214 - val_loss: 125.1825
# Epoch 12/100
# 7306/7306 [==============================] - 6s 804us/step - loss: 55.4216 - val_loss: 121.4726
# Epoch 13/100
# 7306/7306 [==============================] - 6s 801us/step - loss: 54.7111 - val_loss: 119.7804
# Epoch 14/100
# 7306/7306 [==============================] - 6s 800us/step - loss: 54.4772 - val_loss: 119.1667
# Epoch 15/100
# 7306/7306 [==============================] - 6s 806us/step - loss: 53.8498 - val_loss: 120.7491
# Epoch 16/100
# 7306/7306 [==============================] - 6s 804us/step - loss: 53.5760 - val_loss: 118.8256
# Epoch 17/100
# 7306/7306 [==============================] - 6s 807us/step - loss: 53.4607 - val_loss: 119.5804
# Epoch 18/100
# 7306/7306 [==============================] - 6s 803us/step - loss: 53.0759 - val_loss: 117.6637
# Epoch 19/100
# 7306/7306 [==============================] - 6s 807us/step - loss: 52.8244 - val_loss: 118.5593
# Epoch 20/100
# 7306/7306 [==============================] - 6s 800us/step - loss: 52.8376 - val_loss: 117.6151
# Epoch 21/100
# 7306/7306 [==============================] - 6s 827us/step - loss: 53.0472 - val_loss: 121.0298
# Epoch 22/100
# 7306/7306 [==============================] - 6s 808us/step - loss: 53.0859 - val_loss: 121.2044
# Epoch 23/100
# 7306/7306 [==============================] - 6s 807us/step - loss: 52.8231 - val_loss: 119.9755
# Epoch 24/100
# 7306/7306 [==============================] - 6s 807us/step - loss: 52.7010 - val_loss: 119.3409
# Epoch 25/100
# 7306/7306 [==============================] - 6s 808us/step - loss: 52.4976 - val_loss: 121.5509
# 1408/1408 [==============================] - 1s 471us/step
# 0.9890597556586261

# %%
R2_dic = {}

for variable in variables:
    X_test_copy = X_test.copy()
    
    X_test_copy[variable] = 0
    
    preds = model.predict(X_test_copy)
    preds = preds.ravel()

    
    R2oos_varimp_each_var = 1 - np.sum(np.power(y_test - preds, 2)) / np.sum(np.power(y_test, 2))
    
    R2_dic[variable] = R2oos_varimp_each_var
# Out:
# 1408/1408 [==============================] - 1s 500us/step
# 1408/1408 [==============================] - 1s 493us/step
# 1408/1408 [==============================] - 1s 453us/step
# 1408/1408 [==============================] - 1s 444us/step
# 1408/1408 [==============================] - 1s 448us/step
# 1408/1408 [==============================] - 1s 470us/step
# 1408/1408 [==============================] - 1s 447us/step
# 1408/1408 [==============================] - 1s 449us/step
# 1408/1408 [==============================] - 1s 445us/step
# 1408/1408 [==============================] - 1s 446us/step
# 1408/1408 [==============================] - 1s 444us/step
# 1408/1408 [==============================] - 1s 446us/step
# 1408/1408 [==============================] - 1s 456us/step
# 1408/1408 [==============================] - 1s 446us/step
# 1408/1408 [==============================] - 1s 447us/step
# 1408/1408 [==============================] - 1s 446us/step
# 1408/1408 [==============================] - 1s 444us/step
# 1408/1408 [==============================] - 1s 441us/step
# 1408/1408 [==============================] - 1s 441us/step
# 1408/1408 [==============================] - 1s 441us/step
# 1408/1408 [==============================] - 1s 446us/step
# 1408/1408 [==============================] - 1s 443us/step
# 1408/1408 [==============================] - 1s 464us/step
# 1408/1408 [==============================] - 1s 444us/step
# 1408/1408 [==============================] - 1s 442us/step
# 1408/1408 [==============================] - 1s 456us/step
# 1408/1408 [==============================] - 1s 536us/step

# %%
R2_dic
# Out:
# {'Open': 0.9885718355599763,
#  'High': 0.9882491714931443,
#  'Low': 0.9874610087340692,
#  'Close': 0.9880669061599113,
#  'Adj Close': 0.31388983905692713,
#  'Volume': 0.9890990565165454,
#  'Dividends': 0.9890582611626652,
#  'Stock Splits': 0.9891426979735328,
#  'Market capitalization': 0.9887848246684651,
#  'Revenue': 0.9891120189924462,
#  'Earnings': 0.9890952719515654,
#  'P/E ratio': 0.98909544460759,
#  'P/B ratio': 0.9890633749177719,
#  'Operating Margin': 0.9890826215005899,
#  'EPS': 0.9890557521870252,
#  'Shares Outstanding': 0.9890768528907493,
#  'Total assets': 0.9889823456604059,
#  'Total liabilities': 0.988937062690369,
#  'Total debt': 0.9889825722085469,
#  'Cash on Hand': 0.9889925170807939,
#  'Net assets': 0.9888479809121408,
#  '1-month momentum': 0.9892514033628038,
#  '6-month momentum': 0.9879981584605029,
#  '12-month momentum': 0.9890746836228564,
#  '36-month momentum': 0.989027283422118,
#  'Book-to-market': 0.9900737023220497,
#  'Size': 0.9889688778344192}

# %%
varimp = pd.DataFrame.from_dict(R2_dic, orient='index', columns=['R2oos']).reset_index()
varimp.rename(columns={'index': 'Variable'}, inplace=True)

varimp['reduc_R2oos'] = R2oos_varimp - varimp['R2oos']

total_reduction = varimp['reduc_R2oos'].sum()
varimp['var_imp'] = varimp['reduc_R2oos'] / total_reduction

varimp = varimp.sort_values(by='var_imp', ascending=False).reset_index(drop=True)

imp = varimp.sort_values('var_imp', ascending=False).head(20)

# %%
varimp
# Out:
#                  Variable     R2oos  reduc_R2oos   var_imp
# 0               Adj Close  0.313890     0.675170  0.993522
# 1                     Low  0.987461     0.001599  0.002353
# 2        6-month momentum  0.987998     0.001062  0.001562
# 3                   Close  0.988067     0.000993  0.001461
# 4                    High  0.988249     0.000811  0.001193
# 5                    Open  0.988572     0.000488  0.000718
# 6   Market capitalization  0.988785     0.000275  0.000405
# 7              Net assets  0.988848     0.000212  0.000312
# 8       Total liabilities  0.988937     0.000123  0.000181
# 9                    Size  0.988969     0.000091  0.000134
# 10           Total assets  0.988982     0.000077  0.000114
# 11             Total debt  0.988983     0.000077  0.000114
# 12           Cash on Hand  0.988993     0.000067  0.000099
# 13      36-month momentum  0.989027     0.000032  0.000048
# 14                    EPS  0.989056     0.000004  0.000006
# 15              Dividends  0.989058     0.000001  0.000002
# 16              P/B ratio  0.989063    -0.000004 -0.000005
# 17      12-month momentum  0.989075    -0.000015 -0.000022
# 18     Shares Outstanding  0.989077    -0.000017 -0.000025
# 19       Operating Margin  0.989083    -0.000023 -0.000034
# 20               Earnings  0.989095    -0.000036 -0.000052
# 21              P/E ratio  0.989095    -0.000036 -0.000053
# 22                 Volume  0.989099    -0.000039 -0.000058
# 23                Revenue  0.989112    -0.000052 -0.000077
# 24           Stock Splits  0.989143    -0.000083 -0.000122
# 25       1-month momentum  0.989251    -0.000192 -0.000282
# 26         Book-to-market  0.990074    -0.001014 -0.001492

# %%
imp = varimp.sort_values('var_imp', ascending=False).head(20)

df_plot = pd.DataFrame({
    'Variable': imp['Variable'],
    'Importance': imp['var_imp']
})

plt.figure(figsize=(12, 8))
plt.barh(df_plot['Variable'], df_plot['Importance'], color='steelblue')
plt.gca().invert_yaxis()



plt.axvline(0.2, color='black', linestyle='--', linewidth=0.5)
plt.axvline(0.4, color='black', linestyle='--', linewidth=0.5)
plt.axvline(0.6, color='black', linestyle='--', linewidth=0.5)
plt.axvline(0.8, color='black', linestyle='--', linewidth=0.5)



plt.xlabel('Variable Importance')
plt.ylabel('Variables')
plt.title('NN3')

plt.show()

# %%
varimp=varimp[["Variable", "var_imp"]]
varimp.to_csv(r'C:/Users/CMert/Documents/Data bachelorprojekt/variable-comparison/varimp NN3.csv', index = False)

# %% [markdown]
# # Preparations for machine learning portfolios

# %%
# The following is a table comparing the estimiates to the true values of each stock for every day in the test set.

# Remember to rerun df_final for all stock!

symbols = df_final.loc[dates_all.index, 'Symbol']  


comparison = pd.DataFrame({
    'Date': dates_all,  
    'y_hat': predictions_all.tolist(),
    'y_true': y_test_list_all.tolist(),
    'Symbol': symbols  
})


comparison['MonthYear'] = comparison['Date'].dt.to_period('M')

comparison = comparison.sort_values(by=['Date', 'Symbol'], ascending=True)
comparison = comparison.set_index(['MonthYear', 'Symbol'])

comparison
# Out:
#                        Date      y_hat     y_true
# MonthYear Symbol
# 2008-04   A      2008-04-30  19.089781  23.992857
#           AAL    2008-04-30   8.525998   3.733256
#           AAON   2008-04-30   3.147741   3.544210
#           AAP    2008-04-30  30.985559  35.527317
#           AAPL   2008-04-30   7.803210   5.692668
# ...                     ...        ...        ...
# 2024-08   ZVIA   2024-08-30   1.301421   1.020000
#           ZVRA   2024-08-30   7.746873   7.390000
#           ZWS    2024-08-30  33.080330  32.099998
#           ZYME   2024-08-30  11.876691  12.100000
#           ZYXI   2024-08-30   8.968077   7.960000
#
# [510910 rows x 3 columns]

# %%
# Save the df for the Diebold-Mariano test

ols= comparison.reset_index()
ols.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/Estimater/NN3 Estimates", index = False)

# %%
ols = pd.read_csv("C:/Users/CMert/Documents/Data bachelorprojekt/Estimater/NN3 Estimates")

# %% [markdown]
# Lad Adj Close være betegnet som P. Afkastraten udregnes ved:
#
# $$ r_{t+1} = \frac{P_{t+1}}{P_t} -1 $$
# Og
#
# $$ \hat{r}_{t+1} = \frac{\hat{P}_{t+1}}{P_t} -1 $$

# %% [markdown]
# Merafkastsraten udregnes ved:
#
# $$ er_{t+1} = r_{t+1} - r_{f,t+1}  $$
# Og
#
# $$ \hat{er}_{t+1} = \hat{r}_{t+1} - r_{f,t+1}  $$
#
#
# Her er $R_{f,t}$ notation for den risikofrie rate i periode t. Fordi vi arbejder med amerikanske aktier, har vi fundet data for obligationsraten i USA, og benytter dette som den risikofrie rate.
# Dataen er fundet her: https://fred.stlouisfed.org/series/DGS20

# %%
#Calculate estimiated future return, where distance between each period is one month. Notice that for the return estimate, then for P_t we use the actual adj close price, since at time t it is known: 

comparison = ols

comparison['Date'] = pd.to_datetime(comparison['Date'])


comparison = comparison.sort_values(by=['Symbol', 'Date']).reset_index(drop=True)


comparison["ret_t+1_hat"] = comparison["y_hat"] / comparison.groupby("Symbol")["y_true"].shift(1) - 1
comparison["ret_t+1_true"] = comparison["y_true"] / comparison.groupby("Symbol")["y_true"].shift(1) - 1


comparison_ret_1m = comparison.sort_values(by=['Date', 'Symbol'], ascending=True)


comparison_ret_1m
# Out:
#        MonthYear Symbol       Date      y_hat     y_true  ret_t+1_hat  \
# 0        2008-04      A 2008-04-30  19.089781  23.992857          NaN
# 549      2008-04    AAL 2008-04-30   8.525998   3.733256          NaN
# 898      2008-04   AAON 2008-04-30   3.147741   3.544210          NaN
# 1095     2008-04    AAP 2008-04-30  30.985559  35.527317          NaN
# 1292     2008-04   AAPL 2008-04-30   7.803210   5.692668          NaN
# ...          ...    ...        ...        ...        ...          ...
# 510411   2024-08   ZVIA 2024-08-30   1.301421   1.020000     0.288536
# 510510   2024-08   ZVRA 2024-08-30   7.746873   7.390000     0.012663
# 510647   2024-08    ZWS 2024-08-30  33.080330  32.099998     0.020053
# 510723   2024-08   ZYME 2024-08-30  11.876691  12.100000     0.012506
# 510909   2024-08   ZYXI 2024-08-30   8.968077   7.960000     0.140977
#
#         ret_t+1_true
# 0                NaN
# 549              NaN
# 898              NaN
# 1095             NaN
# 1292             NaN
# ...              ...
# 510411      0.009901
# 510510     -0.033987
# 510647     -0.010176
# 510723      0.031543
# 510909      0.012723
#
# [510910 rows x 7 columns]

# %%
# Drop rows where either 'ret_t-(y_hat)	' or 'ret_t-(y_true)' is NaN
comparison_ret_1m = comparison_ret_1m.dropna(subset=['ret_t+1_hat', 'ret_t+1_true']).reset_index(drop=False)

# %%
treasury_securities = pd.read_excel("C:/Users/CMert/Documents/Data bachelorprojekt/Treasury securities.xlsx")

# %%
treasury_securities['Date'] = pd.to_datetime(treasury_securities['Date'])
comparison_ret_1m['Date'] = pd.to_datetime(comparison_ret_1m['Date'])

new_comparison = pd.merge(comparison_ret_1m, treasury_securities, on='Date', how='inner')

new_comparison = new_comparison[new_comparison['Treasury Securities'] != 0]

new_comparison['Treasury Securities'] = new_comparison['Treasury Securities'] / (12*100)

new_comparison['exc_ret_t+1_hat'] = new_comparison['ret_t+1_hat']-new_comparison['Treasury Securities']

new_comparison['exc_ret_t+1_true'] = new_comparison['ret_t+1_true']-new_comparison['Treasury Securities']

new_comparison = new_comparison.sort_values(by=['Date', 'Symbol'], ascending=True)

new_comparison = new_comparison.drop("index", axis = 1)

new_comparison
# Out:
#        MonthYear Symbol       Date      y_hat     y_true  ret_t+1_hat  \
# 0        2008-05      A 2008-05-30  23.022150  22.805721    -0.040458
# 1        2008-05    AAL 2008-05-30   4.895541   2.356854     0.311333
# 2        2008-05   AAON 2008-05-30   3.535120   3.271587    -0.002565
# 3        2008-05    AAP 2008-05-30  35.030479  34.281311    -0.013985
# 4        2008-05   AAPL 2008-05-30   7.504087   5.049963     0.318202
# ...          ...    ...        ...        ...        ...          ...
# 507062   2024-08   ZVIA 2024-08-30   1.301421   1.020000     0.288536
# 507063   2024-08   ZVRA 2024-08-30   7.746873   7.390000     0.012663
# 507064   2024-08    ZWS 2024-08-30  33.080330  32.099998     0.020053
# 507065   2024-08   ZYME 2024-08-30  11.876691  12.100000     0.012506
# 507066   2024-08   ZYXI 2024-08-30   8.968077   7.960000     0.140977
#
#         ret_t+1_true  Treasury Securities  exc_ret_t+1_hat  exc_ret_t+1_true
# 0          -0.049479             0.003950        -0.044408         -0.053429
# 1          -0.368687             0.003950         0.307383         -0.372637
# 2          -0.076921             0.003950        -0.006515         -0.080871
# 3          -0.035072             0.003950        -0.017935         -0.039022
# 4          -0.112901             0.003950         0.314252         -0.116851
# ...              ...                  ...              ...               ...
# 507062      0.009901             0.003567         0.284969          0.006334
# 507063     -0.033987             0.003567         0.009097         -0.037554
# 507064     -0.010176             0.003567         0.016487         -0.013742
# 507065      0.031543             0.003567         0.008939          0.027976
# 507066      0.012723             0.003567         0.137410          0.009156
#
# [507067 rows x 10 columns]

# %%
# Remember to rerun df_final, when adding 'Market cap' since it is standardized:

new_comparison['Date'] = pd.to_datetime(new_comparison['Date'])
df_final['Date'] = pd.to_datetime(df_final['Date'])

final_comparison = pd.merge(new_comparison, df_final[["Date", "Symbol", "Market capitalization"]], on=["Date", "Symbol"], how="inner")


final_comparison = final_comparison.sort_values(by=['Date', 'Symbol'], ascending=True)

# %%
final_comparison = final_comparison.rename(columns={'Treasury Securities' : 'Risk free rate'})

# %%
# We now limit the df to the following decade 2014-01 and 2023-12
final_comparison = final_comparison[
    (final_comparison["MonthYear"] >= "2014-01") &
    (final_comparison["MonthYear"] <= "2023-12")
]

# %%
final_comparison
# Out:
#        MonthYear Symbol       Date       y_hat      y_true  ret_t+1_hat  \
# 134848   2014-01      A 2014-01-31   38.298138   37.276997     0.005839
# 134849   2014-01   AACG 2014-01-31    0.573848    0.375884     0.641161
# 134850   2014-01    AAL 2014-01-31   33.702595   34.815441     0.065561
# 134851   2014-01   AAON 2014-01-31   13.141682   12.327587     0.073946
# 134852   2014-01    AAP 2014-01-31  107.035255  115.128609     0.031328
# ...          ...    ...        ...         ...         ...          ...
# 477000   2023-12   ZVIA 2023-12-29    1.720011    1.700000    -0.144273
# 477001   2023-12   ZVRA 2023-12-29    6.291210    5.790000    -0.039510
# 477002   2023-12    ZWS 2023-12-29   29.743008   29.427322     0.018976
# 477003   2023-12   ZYME 2023-12-29   10.358926   10.840000    -0.002991
# 477004   2023-12   ZYXI 2023-12-29   11.380206   11.840000     0.045014
#
#         ret_t+1_true  Risk free rate  exc_ret_t+1_hat  exc_ret_t+1_true  \
# 134848     -0.020980        0.002792         0.003047         -0.023772
# 134849      0.075000        0.002792         0.638369          0.072208
# 134850      0.100745        0.002792         0.062769          0.097953
# 134851      0.007418        0.002792         0.071154          0.004626
# 134852      0.109311        0.002792         0.028537          0.106519
# ...              ...             ...              ...               ...
# 477000     -0.154229        0.003500        -0.147773         -0.157729
# 477001     -0.116031        0.003500        -0.043010         -0.119531
# 477002      0.008160        0.003500         0.015476          0.004660
# 477003      0.043311        0.003500        -0.006491          0.039811
# 477004      0.087236        0.003500         0.041514          0.083736
#
#         Market capitalization
# 134848           1.904000e+10
# 134849           9.062000e+07
# 134850           6.590000e+09
# 134851           1.170000e+09
# 134852           8.060000e+09
# ...                       ...
# 477000           2.600000e+08
# 477001           1.583091e+08
# 477002           3.760000e+09
# 477003           4.900000e+08
# 477004           5.300000e+08
#
# [342157 rows x 11 columns]

# %%
# Index every month in order

unique_months = final_comparison['MonthYear'].unique()
unique_months.sort()

month_indices = list(range(1, len(unique_months) + 1))

df_month_merge = pd.DataFrame({
    'MonthYear': unique_months,
    'MonthIndex': month_indices
})

final_comparison = final_comparison.merge(df_month_merge, on='MonthYear', how='left')

# %%
final_comparison
# Out:
#        MonthYear Symbol       Date       y_hat      y_true  ret_t+1_hat  \
# 0        2014-01      A 2014-01-31   38.298138   37.276997     0.005839
# 1        2014-01   AACG 2014-01-31    0.573848    0.375884     0.641161
# 2        2014-01    AAL 2014-01-31   33.702595   34.815441     0.065561
# 3        2014-01   AAON 2014-01-31   13.141682   12.327587     0.073946
# 4        2014-01    AAP 2014-01-31  107.035255  115.128609     0.031328
# ...          ...    ...        ...         ...         ...          ...
# 342152   2023-12   ZVIA 2023-12-29    1.720011    1.700000    -0.144273
# 342153   2023-12   ZVRA 2023-12-29    6.291210    5.790000    -0.039510
# 342154   2023-12    ZWS 2023-12-29   29.743008   29.427322     0.018976
# 342155   2023-12   ZYME 2023-12-29   10.358926   10.840000    -0.002991
# 342156   2023-12   ZYXI 2023-12-29   11.380206   11.840000     0.045014
#
#         ret_t+1_true  Risk free rate  exc_ret_t+1_hat  exc_ret_t+1_true  \
# 0          -0.020980        0.002792         0.003047         -0.023772
# 1           0.075000        0.002792         0.638369          0.072208
# 2           0.100745        0.002792         0.062769          0.097953
# 3           0.007418        0.002792         0.071154          0.004626
# 4           0.109311        0.002792         0.028537          0.106519
# ...              ...             ...              ...               ...
# 342152     -0.154229        0.003500        -0.147773         -0.157729
# 342153     -0.116031        0.003500        -0.043010         -0.119531
# 342154      0.008160        0.003500         0.015476          0.004660
# 342155      0.043311        0.003500        -0.006491          0.039811
# 342156      0.087236        0.003500         0.041514          0.083736
#
#         Market capitalization  MonthIndex
# 0                1.904000e+10           1
# 1                9.062000e+07           1
# 2                6.590000e+09           1
# 3                1.170000e+09           1
# 4                8.060000e+09           1
# ...                       ...         ...
# 342152           2.600000e+08         120
# 342153           1.583091e+08         120
# 342154           3.760000e+09         120
# 342155           4.900000e+08         120
# 342156           5.300000e+08         120
#
# [342157 rows x 12 columns]

# %%
# Function to add the decile rank of each stock in each month

def decile_ranks(df):
    df = df.sort_values(by='exc_ret_t+1_hat', ascending=True)
    
    df['Decile rank'] = pd.qcut(df['exc_ret_t+1_hat'], 10, labels=False, duplicates='drop')
    return df


final_comparison = final_comparison.groupby('MonthYear', group_keys=False).apply(decile_ranks)

# %%
# A dictionray of the stock history of each decile:

decile_dataframes = {}

# Loop through each decile rank
for decile in range(10):
    
    decile_df = final_comparison[final_comparison['Decile rank'] == decile].copy()
    
    decile_df.reset_index(drop=True, inplace=True)
    
    decile_dataframes[f'decile_rank_{decile}'] = decile_df

# %%
decile_dataframes['decile_rank_9']
# Out:
#       MonthYear Symbol       Date       y_hat     y_true  ret_t+1_hat  \
# 0       2014-01    LUV 2014-01-31   20.252554  20.205492     0.073617
# 1       2014-01   AAON 2014-01-31   13.141682  12.327587     0.073946
# 2       2014-01   FORM 2014-01-31    6.917790   7.130000     0.074191
# 3       2014-01   AXTI 2014-01-31    2.621503   2.290000     0.074386
# 4       2014-01   STCN 2014-01-31   51.665237  42.653332     0.074866
# ...         ...    ...        ...         ...        ...          ...
# 34253   2023-12   EAST 2023-12-29   57.639446   1.110000    43.681743
# 34254   2023-12   OTRK 2023-12-29   19.383881   0.220000    47.459701
# 34255   2023-12   ONFO 2023-12-29   67.596001   0.540000   131.541180
# 34256   2023-12   ASNS 2023-12-29  175.734222   1.130000   155.905555
# 34257   2023-12   VERB 2023-12-29   47.549976   0.158000   275.453341
#
#        ret_t+1_true  Risk free rate  exc_ret_t+1_hat  exc_ret_t+1_true  \
# 0          0.071122        0.002792         0.070825          0.068330
# 1          0.007418        0.002792         0.071154          0.004626
# 2          0.107143        0.002792         0.071399          0.104351
# 3         -0.061475        0.002792         0.071595         -0.064267
# 4         -0.112621        0.002792         0.072075         -0.115413
# ...             ...             ...              ...               ...
# 34253     -0.139535        0.003500        43.678243         -0.143035
# 34254     -0.450000        0.003500        47.456201         -0.453500
# 34255      0.058824        0.003500       131.537680          0.055324
# 34256      0.008929        0.003500       155.902055          0.005429
# 34257     -0.081395        0.003500       275.449841         -0.084895
#
#        Market capitalization  MonthIndex  Decile rank
# 0               1.319000e+10           1            9
# 1               1.170000e+09           1            9
# 2               3.200000e+08           1            9
# 3               8.509000e+07           1            9
# 4               2.900000e+08           1            9
# ...                      ...         ...          ...
# 34253           3.600000e+06         120            9
# 34254           9.930000e+06         120            9
# 34255           7.760000e+06         120            9
# 34256           8.260000e+06         120            9
# 34257           1.906000e+07         120            9
#
# [34258 rows x 13 columns]

# %% [markdown]
# # Machine learning portfolios

# %% [markdown]
# For hvert decildatasæt og derfra for hver måned tilføjer vi to vægte for hver aktie. Vægtene er henholdsvis 'equal weights' og 'market capitalization weights' som udregnes ved:
#
# $$w^{eq} = \frac{1}{N}, $$
# hvor N er antallet af aktier for den respektive måned. Vægten baseret på aktiens markedsværdi udregnes ved:
#
# $$w^{mc}_{i} = \frac{mc_i}{\sum_{j = 1}^N mc_j}, $$
# hvor $i$ og $j$ er en indexering af aktierne for den respektive måned.

# %%
for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Calculate eq weights:
    decile_dfs_value['eq_weights'] = 1 / decile_dfs_value.groupby('MonthYear')['Symbol'].transform('count')
    
    # Calculate mc weights
    decile_dfs_value['mc_weights'] = decile_dfs_value['Market capitalization'] / decile_dfs_value.groupby('MonthYear')['Market capitalization'].transform('sum')
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %% [markdown]
# I artiklen S. 2261 (PDF S. 39) er porteføljens merafkastsrate givet ved:
#
# $$\hat{er}^P_{t+1} = \sum_{i = 1}^N w^P_{i,t} \cdot \hat{er}_{i,t+1} , $$
# hvor P angiver den enkelte portefølje, specificeret ved variablerne Decile rank og MonthYear.

# %%
# Weighted true excess return at t+1 for each stock:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    # Calculate the product of equal weights and excess return, to find the equal weighted excess return of each stock:
    decile_dfs_value['exc_ret_t+1_true_eq'] = decile_dfs_value['exc_ret_t+1_true'] * decile_dfs_value['eq_weights']
    
    
    # Calculate the product of mc weights and excess return, to find the mc weighted excess return of each stock:
    decile_dfs_value['exc_ret_t+1_true_mc'] = decile_dfs_value['exc_ret_t+1_true'] * decile_dfs_value['mc_weights']
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted true portfolio excess return at t+1:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Calculate true eq portfolio excess return:
    decile_dfs_value['portfolio_true_exc_ret_eq'] = decile_dfs_value.groupby('MonthYear')['exc_ret_t+1_true_eq'].transform('sum')
    
    # Calculate true mc portfolio excess return:
    decile_dfs_value['portfolio_true_exc_ret_mc'] = decile_dfs_value.groupby('MonthYear')['exc_ret_t+1_true_mc'].transform('sum')
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted predicted excess return at t+1 for each stock:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    # Calculate the product of equal weights and excess return, to find the equal weighted excess return of each stock:
    decile_dfs_value['exc_ret_t+1_hat_eq'] = decile_dfs_value['exc_ret_t+1_hat'] * decile_dfs_value['eq_weights']
    
    
    # Calculate the product of mc weights and excess return, to find the mc weighted excess return of each stock:
    decile_dfs_value['exc_ret_t+1_hat_mc'] = decile_dfs_value['exc_ret_t+1_hat'] * decile_dfs_value['mc_weights']
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted predicted portfolio excess return at t+1:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Calculate true eq portfolio excess return:
    decile_dfs_value['portfolio_hat_exc_ret_eq'] = decile_dfs_value.groupby('MonthYear')['exc_ret_t+1_hat_eq'].transform('sum')
    
    # Calculate true mc portfolio excess return:
    decile_dfs_value['portfolio_hat_exc_ret_mc'] = decile_dfs_value.groupby('MonthYear')['exc_ret_t+1_hat_mc'].transform('sum')
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted true return at t+1 for each stock:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    # Calculate the product of equal weights and return, to find the equal weighted return of each stock:
    decile_dfs_value['ret_t+1_true_eq'] = decile_dfs_value['ret_t+1_true'] * decile_dfs_value['eq_weights']
    
    
    # Calculate the product of mc weights and return, to find the mc weighted return of each stock:
    decile_dfs_value['ret_t+1_true_mc'] = decile_dfs_value['ret_t+1_true'] * decile_dfs_value['mc_weights']
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
# Weighted true portfolio return at t+1:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Calculate true eq portfolio return:
    decile_dfs_value['portfolio_true_ret_eq'] = decile_dfs_value.groupby('MonthYear')['ret_t+1_true_eq'].transform('sum')
    
    # Calculate true mc portfolio return:
    decile_dfs_value['portfolio_true_ret_mc'] = decile_dfs_value.groupby('MonthYear')['ret_t+1_true_mc'].transform('sum')
    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
decile_dataframes['decile_rank_5'].columns
# Out:
# Index(['MonthYear', 'Symbol', 'Date', 'y_hat', 'y_true', 'ret_t+1_hat',
#        'ret_t+1_true', 'Risk free rate', 'exc_ret_t+1_hat', 'exc_ret_t+1_true',
#        'Market capitalization', 'MonthIndex', 'Decile rank', 'eq_weights',
#        'mc_weights', 'exc_ret_t+1_true_eq', 'exc_ret_t+1_true_mc',
#        'portfolio_true_exc_ret_eq', 'portfolio_true_exc_ret_mc',
#        'exc_ret_t+1_hat_eq', 'exc_ret_t+1_hat_mc', 'portfolio_hat_exc_ret_eq',
#        'portfolio_hat_exc_ret_mc', 'ret_t+1_true_eq', 'ret_t+1_true_mc',
#        'portfolio_true_ret_eq', 'portfolio_true_ret_mc'],
#       dtype='object')

# %%
portfolio_returns2 = {}

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():

    portfolio_variables = decile_dfs_value[['MonthYear',
                                   
                                   'portfolio_true_exc_ret_eq',
                                   'portfolio_true_exc_ret_mc',
                                   
                                   'portfolio_hat_exc_ret_eq',
                                   'portfolio_hat_exc_ret_mc',
                                   
                                   'portfolio_true_ret_eq',
                                   'portfolio_true_ret_mc',
                                   
                                   'Decile rank',
                                   'MonthIndex',
                                   
                                   ]].copy()
    
    portfolio_variables = portfolio_variables.drop_duplicates()
    
    portfolio_variables.reset_index(drop=True, inplace=True)
    
    portfolio_returns2[decile_dfs_key] = portfolio_variables

# %%
portfolio_returns2['decile_rank_9']
# Out:
#     MonthYear  portfolio_true_exc_ret_eq  portfolio_true_exc_ret_mc  \
# 0     2014-01                   0.111446                   0.049415
# 1     2014-02                   0.078511                   0.037615
# 2     2014-03                   0.035479                   0.044579
# 3     2014-04                   0.048686                   0.031231
# 4     2014-05                   0.097416                   0.027132
# ..        ...                        ...                        ...
# 115   2023-08                  -0.031596                  -0.058661
# 116   2023-09                  -0.087925                   0.012960
# 117   2023-10                   0.234364                   0.143280
# 118   2023-11                   0.190769                   0.040917
# 119   2023-12                   0.056446                  -0.013535
#
#      portfolio_hat_exc_ret_eq  portfolio_hat_exc_ret_mc  \
# 0                    0.208712                  0.284720
# 1                    0.183555                  0.273595
# 2                    0.171996                  0.261907
# 3                    0.170279                  0.326850
# 4                    0.213621                  0.302187
# ..                        ...                       ...
# 115                  1.413526                  0.206204
# 116                  1.573411                  0.190103
# 117                  2.377115                  0.285813
# 118                  2.544843                  0.194033
# 119                  2.951134                  0.169657
#
#      portfolio_true_ret_eq  portfolio_true_ret_mc  Decile rank  MonthIndex
# 0                 0.114237               0.052206            9           1
# 1                 0.081270               0.040374            9           2
# 2                 0.038237               0.047338            9           3
# 3                 0.051369               0.033915            9           4
# 4                 0.099958               0.029674            9           5
# ..                     ...                    ...          ...         ...
# 115              -0.027937              -0.055003            9         116
# 116              -0.083825               0.017060            9         117
# 117               0.238706               0.147622            9         118
# 118               0.194702               0.044850            9         119
# 119               0.059946              -0.010035            9         120
#
# [120 rows x 9 columns]

# %% [markdown]
# Pr. vores finansieringsbog, så gælder: "For any portfolio, P, we define the Sharpe-ratio as excess return relative to standard deviation", jf. S. 57, "Finance 1 and Beyond":
#
# $$Sharpe-ratio^P = \frac{er^P_{t+1}}{\sigma_R^P}$$

# %%
#Find Sharpe-ratio of each decile rank dataframe:

for decile_key, portfolio_df in portfolio_returns2.items():
    
    # Calculate average of the true portfolio excess return
    mean_ER_true_eq = portfolio_df['portfolio_true_exc_ret_eq'].mean()
    mean_ER_true_mc = portfolio_df['portfolio_true_exc_ret_mc'].mean()
    
    # Calculate average of the predicted portfolio excess return
    mean_ER_pred_eq = portfolio_df['portfolio_hat_exc_ret_eq'].mean()
    mean_ER_pred_mc = portfolio_df['portfolio_hat_exc_ret_mc'].mean()
    
    # Calculate standard deviation of the true portfolio excess returns
    std_R_true_eq = portfolio_df['portfolio_true_ret_eq'].std()
    std_R_true_mc = portfolio_df['portfolio_true_ret_mc'].std()
    
    # Calculate annualized Sharpe ratio of the true excess returns
    sharpe_ratio_eq = (mean_ER_true_eq / std_R_true_eq) * np.sqrt(12)
    sharpe_ratio_mc = (mean_ER_true_mc / std_R_true_mc) * np.sqrt(12)
    
   
    portfolio_df['Mean_true_ER_eq'] = mean_ER_true_eq
    portfolio_df['Mean_true_ER_mc'] = mean_ER_true_mc
    portfolio_df['Mean_pred_ER_eq'] = mean_ER_pred_eq
    portfolio_df['Mean_pred_ER_mc'] = mean_ER_pred_mc
    portfolio_df['Std_true_ER_eq'] = std_R_true_eq
    portfolio_df['Std_true_ER_mc'] = std_R_true_mc
    portfolio_df['Sharpe_ratio_eq'] = sharpe_ratio_eq
    portfolio_df['Sharpe_ratio_mc'] = sharpe_ratio_mc
    

    portfolio_returns2[decile_key] = portfolio_df

# %% [markdown]
# # Zero-net-investment long-short portfolios

# %% [markdown]
# At shorte en aktie betyder at du låner aktier, som du vælger at sælge, fordi du forudsiger at de vil falde i pris og dermed kan du købe dem billiger og tjene differencen. At longe en aktie betyder at du køber en aktie, fordi du forventer den stiger i pris og dermed kan tjene differencen. Derfor vil man ifølge zero-net-investment teorien bruge alle ens penge på long-investment, hvor pengene kommer af de aktier man lige har shortet. Dvs. til tid 0 skal ens portefølje have følgende værdi:
#
# $$\sum_{i = 1}^N w_i \cdot P^{long}_{i,0} - \sum_{j = 1}^M w_j \cdot P^{short}_{j,0} = 0$$
# Her vælges vægtene for både short- og long-aktierne som før, hvor summen af alle vægte skal være 1. Afkastet for zero-net-investment er dermed til tid t givet ved:
#
# $$\sum_{i = 1}^N w_i \cdot P^{long}_{i,t} - \sum_{j = 1}^M w_j \cdot P^{short}_{j,t} = profit$$

# %%
# Create the tables that show the performance of the machine learning portfolios

long_df = portfolio_returns2['decile_rank_9'].copy()
short_df = portfolio_returns2['decile_rank_0'].copy()

long_df['Investment type'] = 'long'
short_df['Investment type'] = 'short'


calc_df = pd.merge(long_df, short_df, on='MonthIndex', suffixes=('_long', '_short'))

# %%
# Calculate zero-net investment excess returns
calc_df['true_ER_zni_eq'] = calc_df['portfolio_true_exc_ret_eq_long'] - calc_df['portfolio_true_exc_ret_eq_short']
calc_df['true_ER_zni_mc'] = calc_df['portfolio_true_exc_ret_mc_long'] - calc_df['portfolio_true_exc_ret_mc_short']
calc_df['pred_ER_zni_eq'] = calc_df['portfolio_hat_exc_ret_eq_long'] - calc_df['portfolio_hat_exc_ret_eq_short']
calc_df['pred_ER_zni_mc'] = calc_df['portfolio_hat_exc_ret_mc_long'] - calc_df['portfolio_hat_exc_ret_mc_short']

# Calculate the means
mean_true_ER_zni_eq = calc_df['true_ER_zni_eq'].mean()
mean_true_ER_zni_mc = calc_df['true_ER_zni_mc'].mean()

mean_pred_ER_zni_eq = calc_df['pred_ER_zni_eq'].mean()
mean_pred_ER_zni_mc = calc_df['pred_ER_zni_mc'].mean()

# # Calculate zero-net investment returns that we need for Sharpe ratio
calc_df['true_R_zni_eq'] = calc_df['portfolio_true_ret_eq_long'] - calc_df['portfolio_true_ret_eq_short']
calc_df['true_R_zni_mc'] = calc_df['portfolio_true_ret_mc_long'] - calc_df['portfolio_true_ret_mc_short']


std_true_R_zni_eq = calc_df['true_R_zni_eq'].std()
std_true_R_zni_mc = calc_df['true_R_zni_mc'].std()

# Sharpe ratio
sharpe_ratio_eq_zni = (mean_true_ER_zni_eq / std_true_R_zni_eq) * np.sqrt(12)
sharpe_ratio_mc_zni = (mean_true_ER_zni_mc / std_true_R_zni_mc) * np.sqrt(12)

# %%
calc_df
# Out:
#     MonthYear_long  portfolio_true_exc_ret_eq_long  \
# 0          2014-01                        0.111446
# 1          2014-02                        0.078511
# 2          2014-03                        0.035479
# 3          2014-04                        0.048686
# 4          2014-05                        0.097416
# ..             ...                             ...
# 115        2023-08                       -0.031596
# 116        2023-09                       -0.087925
# 117        2023-10                        0.234364
# 118        2023-11                        0.190769
# 119        2023-12                        0.056446
#
#      portfolio_true_exc_ret_mc_long  portfolio_hat_exc_ret_eq_long  \
# 0                          0.049415                       0.208712
# 1                          0.037615                       0.183555
# 2                          0.044579                       0.171996
# 3                          0.031231                       0.170279
# 4                          0.027132                       0.213621
# ..                              ...                            ...
# 115                       -0.058661                       1.413526
# 116                        0.012960                       1.573411
# 117                        0.143280                       2.377115
# 118                        0.040917                       2.544843
# 119                       -0.013535                       2.951134
#
#      portfolio_hat_exc_ret_mc_long  portfolio_true_ret_eq_long  \
# 0                         0.284720                    0.114237
# 1                         0.273595                    0.081270
# 2                         0.261907                    0.038237
# 3                         0.326850                    0.051369
# 4                         0.302187                    0.099958
# ..                             ...                         ...
# 115                       0.206204                   -0.027937
# 116                       0.190103                   -0.083825
# 117                       0.285813                    0.238706
# 118                       0.194033                    0.194702
# 119                       0.169657                    0.059946
#
#      portfolio_true_ret_mc_long  Decile rank_long  MonthIndex  \
# 0                      0.052206                 9           1
# 1                      0.040374                 9           2
# 2                      0.047338                 9           3
# 3                      0.033915                 9           4
# 4                      0.029674                 9           5
# ..                          ...               ...         ...
# 115                   -0.055003                 9         116
# 116                    0.017060                 9         117
# 117                    0.147622                 9         118
# 118                    0.044850                 9         119
# 119                   -0.010035                 9         120
#
#      Mean_true_ER_eq_long  ...  Std_true_ER_mc_short  Sharpe_ratio_eq_short  \
# 0                 0.14733  ...              0.054127              -2.045614
# 1                 0.14733  ...              0.054127              -2.045614
# 2                 0.14733  ...              0.054127              -2.045614
# 3                 0.14733  ...              0.054127              -2.045614
# 4                 0.14733  ...              0.054127              -2.045614
# ..                    ...  ...                   ...                    ...
# 115               0.14733  ...              0.054127              -2.045614
# 116               0.14733  ...              0.054127              -2.045614
# 117               0.14733  ...              0.054127              -2.045614
# 118               0.14733  ...              0.054127              -2.045614
# 119               0.14733  ...              0.054127              -2.045614
#
#      Sharpe_ratio_mc_short  Investment type_short  true_ER_zni_eq  \
# 0                -0.727667                  short        0.074109
# 1                -0.727667                  short        0.140910
# 2                -0.727667                  short        0.125736
# 3                -0.727667                  short        0.088676
# 4                -0.727667                  short        0.075056
# ..                     ...                    ...             ...
# 115              -0.727667                  short        0.058508
# 116              -0.727667                  short        0.050548
# 117              -0.727667                  short        0.193232
# 118              -0.727667                  short        0.074663
# 119              -0.727667                  short        0.156751
#
#      true_ER_zni_mc  pred_ER_zni_eq pred_ER_zni_mc true_R_zni_eq  \
# 0          0.019362        0.275261       0.374338      0.074109
# 1          0.040602        0.264219       0.374064      0.140910
# 2          0.056143        0.243689       0.359970      0.125736
# 3          0.030631        0.240052       0.435455      0.088676
# 4          0.010879        0.294004       0.418127      0.075056
# ..              ...             ...            ...           ...
# 115       -0.039921        1.646808       0.350743      0.058508
# 116        0.079132        1.829298       0.371145      0.050548
# 117        0.074351        2.657592       0.499204      0.193232
# 118       -0.003253        2.852511       0.422136      0.074663
# 119       -0.010602        3.261129       0.405903      0.156751
#
#      true_R_zni_mc
# 0         0.019362
# 1         0.040602
# 2         0.056143
# 3         0.030631
# 4         0.010879
# ..             ...
# 115      -0.039921
# 116       0.079132
# 117       0.074351
# 118      -0.003253
# 119      -0.010602
#
# [120 rows x 41 columns]

# %%
performance_data = []

for i in range(10):
    decile_key = f'decile_rank_{i}'
    decile_df = portfolio_returns2[decile_key]
    
    mean_pred_ER_eq = decile_df['Mean_pred_ER_eq'].iloc[0]
    mean_true_ER_eq = decile_df['Mean_true_ER_eq'].iloc[0]
    std_true_ER_eq = decile_df['Std_true_ER_eq'].iloc[0]
    sharpe_ratio_eq = decile_df['Sharpe_ratio_eq'].iloc[0]
    
    performance_data.append([mean_pred_ER_eq, mean_true_ER_eq, std_true_ER_eq, sharpe_ratio_eq])

# The zero-net-investments caluclations will be used as H-L row
performance_data.append([mean_pred_ER_zni_eq, mean_true_ER_zni_eq, std_true_R_zni_eq, sharpe_ratio_eq_zni])


columns = ['Pred Avg', 'True Avg', 'SD', 'SR']
index = ['Low(L)', '1', '2', '3', '4', '5', '6', '7', '8', 'High(H)', 'H-L']

ML_performance_eq_table = pd.DataFrame(performance_data, columns=columns, index=index)

# %%
ML_performance_eq_table
# Out:
#          Pred Avg  True Avg        SD        SR
# Low(L)  -0.143110 -0.044601  0.075529 -2.045614
# 1       -0.065145 -0.027112  0.062221 -1.509441
# 2       -0.042751 -0.016181  0.056508 -0.991938
# 3       -0.027362 -0.006935  0.053134 -0.452150
# 4       -0.014654  0.000600  0.050813  0.040916
# 5       -0.002945  0.009405  0.051318  0.634878
# 6        0.009192  0.017193  0.052482  1.134832
# 7        0.024542  0.027857  0.055790  1.729709
# 8        0.053620  0.041286  0.066479  2.151356
# High(H)  6.091875  0.147330  0.423589  1.204865
# H-L      6.234985  0.191932  0.408753  1.626584

# %%
performance_data = []

for i in range(10):
    decile_key = f'decile_rank_{i}'
    decile_df = portfolio_returns2[decile_key]
    
    mean_pred_ER_mc = decile_df['Mean_pred_ER_mc'].iloc[0]
    mean_true_ER_mc = decile_df['Mean_true_ER_mc'].iloc[0]
    std_true_ER_mc = decile_df['Std_true_ER_mc'].iloc[0]
    sharpe_ratio_mc = decile_df['Sharpe_ratio_mc'].iloc[0]
    
    performance_data.append([mean_pred_ER_mc, mean_true_ER_mc, std_true_ER_mc, sharpe_ratio_mc])

# The zero-net-investments caluclations will be used as H-L row
performance_data.append([mean_pred_ER_zni_mc, mean_true_ER_zni_mc, std_true_R_zni_mc, sharpe_ratio_mc_zni])

columns = ['Pred Avg', 'True Avg', 'SD', 'SR']
index = ['Low(L)', '1', '2', '3', '4', '5', '6', '7', '8', 'High(H)', 'H-L']

ML_performance_mc_table = pd.DataFrame(performance_data, columns=columns, index=index)

# %%
ML_performance_mc_table
# Out:
#          Pred Avg  True Avg        SD        SR
# Low(L)  -0.155101 -0.011370  0.054127 -0.727667
# 1       -0.065156 -0.013296  0.052862 -0.871302
# 2       -0.042751 -0.009084  0.047913 -0.656804
# 3       -0.027291 -0.003001  0.047400 -0.219358
# 4       -0.014570  0.003517  0.044585  0.273272
# 5       -0.003034  0.012535  0.045988  0.944185
# 6        0.009094  0.017998  0.046574  1.338659
# 7        0.024373  0.028669  0.049892  1.990581
# 8        0.053080  0.039507  0.060088  2.277614
# High(H)  0.405522  0.038348  0.076364  1.739555
# H-L      0.560623  0.049718  0.046713  3.686876

# %%
ML_performance_eq_table.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/ML_Sharpe_results/NN3_eq.csv")
ML_performance_mc_table.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/ML_Sharpe_results/NN3_mc.csv")

# %% [markdown]
# # The second table of the machine learning portfolios performance

# %% [markdown]
# Maximum drawdown er i artiklen defineret ved:
#
# $$MaxDD = \max _{0 \leq t_{1} \leq t_{2} \leq T}\left(Y_{t_{1}}-Y_{t_{2}}\right),  $$
# hvor $Y_t$ er den akkumulerede log afkast givet ved:
#
# $$ r = \log\left(\prod_{i = 1}^{n}(1+r_i) \right)$$
#
# $$ = \sum_{i = 1}^{n} \log \left( 1+r_i \right), $$
# hvor n er antallet af porteføljer

# %%
# Calculate the maximum drawdown
def max_dd(returns):
    
    draw_downs = []
    exc_ret = returns.copy()
    
    # Calculate cumulative log excess returns
    exc_ret = np.log(1 + exc_ret).cumsum()
    
    
    peak = exc_ret.iloc[0]
    
    for i in range(1, len(exc_ret)):
        current = exc_ret.iloc[i]
        
        if current > peak:
            peak = current  
        else:
            drawdown = peak - current  
            draw_downs.append(drawdown)
    
    if draw_downs:
        max_drawdown = max(draw_downs)
    else:
        max_drawdown = 0  # In the off chance the stock is ever increasing
    
    return max_drawdown

maxdd_eq = max_dd(calc_df['true_ER_zni_eq'])
maxdd_mc = max_dd(calc_df['true_ER_zni_mc'])


maxdd_eq_pct = maxdd_eq * 100
maxdd_mc_pct = maxdd_mc * 100

print("MaxDD EQ: ", maxdd_eq_pct)
print("MaxDD MC: ", maxdd_mc_pct)
# Out:
# MaxDD EQ:  0
# MaxDD MC:  4.0739934522135535

# %% [markdown]
# # Max 1M loss
# I artiklen defineret som den mest extreme, negative månedlige afkast.

# %%
max_1m_loss_eq_pct = calc_df['true_ER_zni_eq'].min()*(-100)
max_1m_loss_mc_pct = calc_df['true_ER_zni_mc'].min()*(-100)

print("Max 1M EQ: ", max_1m_loss_eq_pct)
print("Max 1M MC: ", max_1m_loss_mc_pct)
# Out:
# Max 1M EQ:  -1.9175846345798977
# Max 1M MC:  3.992121916947211

# %% [markdown]
# # Turnover
#
# I artiklen er turnover defineret ved:
#
# $$ \frac{1}{T} \sum_{t = 1}^T \left(\sum_{i = 1}^n   \bigg| w_{i,t+1} - \frac{w_{i,t}(1+r_{i,t+1})}{1+ \sum_{j = 1}^n  w_{j,t} \cdot r_{j,t+1}}  \bigg|  \right)  $$

# %%
# Get the t+1 weights for both eq and mc weights:

for decile_dfs_key, decile_dfs_value in decile_dataframes.items():
    
    decile_dfs_value.sort_values(['Symbol', 'MonthYear'], inplace=True)
    decile_dfs_value.reset_index(drop=True, inplace=True)
    
    # Create next month's weights for eq_weights and mc_weights, and if they dont exist set to 0
    decile_dfs_value['eq_weights_t+1'] = decile_dfs_value.groupby('Symbol')['eq_weights'].shift(-1).fillna(0)
    decile_dfs_value['mc_weights_t+1'] = decile_dfs_value.groupby('Symbol')['mc_weights'].shift(-1).fillna(0)

    
    decile_dataframes[decile_dfs_key] = decile_dfs_value

# %%
def turnover(long_df, short_df, weight_t0, weight_t1, exc_ret_t1):
    turnover_each_month = []
    
    # Combine long and short portfolios into one portfolio
    zero_net = pd.concat([long_df, short_df], ignore_index=True)
    
    zero_net.sort_values(['MonthYear'], inplace=True)
    zero_net.reset_index(drop=True, inplace=True)
    
    months = zero_net['MonthYear'].unique()
    
    for t in months[:-1]:  # Exclude the last month since it has no t+1 weights
        
        current_month = zero_net[zero_net['MonthYear'] == t]
        
        # Calculate the denominator for month t
        denominator = 1 + (current_month[weight_t0] * current_month[exc_ret_t1]).sum()
        
        # Calculate the turnover for each stock
        current_month['fraction'] = (
            current_month[weight_t0] * (1 + current_month[exc_ret_t1]) / denominator
        )
        current_month['abs_diff'] = abs(
            current_month[weight_t1] - current_month['fraction']
        )
        
        # Sum the absolute differences for month t
        turnover_each_month.append(current_month['abs_diff'].sum())
    
    # Calculate the average turnover across all months
    turnover = sum(turnover_each_month) / len(turnover_each_month)
    return turnover

# %%
long_df = decile_dataframes['decile_rank_9']
short_df = decile_dataframes['decile_rank_0']


weight_eq = 'eq_weights'
weight_t1_eq = 'eq_weights_t+1'
exc_ret_t1 = 'exc_ret_t+1_true'

turnover_eq = turnover(long_df, short_df, weight_eq, weight_t1_eq, exc_ret_t1)


weight_mc = 'mc_weights'
weight_t1_mc = 'mc_weights_t+1'
exc_ret_t1 = 'exc_ret_t+1_true'

turnover_mc = turnover(long_df, short_df, weight_mc, weight_t1_mc, exc_ret_t1)


turnover_eq_pct = turnover_eq*100
turnover_mc_pct = turnover_mc*100

print("Turnover EQ: ", turnover_eq_pct)
print("Turnover MC: ", turnover_mc_pct)
# Out:
# Turnover EQ:  47.64852488298628
# Turnover MC:  63.1626693584542

# %%
eq_table_OLS = pd.DataFrame({
    "NN3" : [maxdd_eq_pct,
                max_1m_loss_eq_pct,
                turnover_eq_pct
                ]
})


eq_table_OLS.index = ['Max DD(%)', "Max 1M loss(%)", "Turnover(%)"]

# %%
eq_table_OLS
# Out:
#                       NN3
# Max DD(%)        0.000000
# Max 1M loss(%)  -1.917585
# Turnover(%)     47.648525

# %%
mc_table_OLS = pd.DataFrame({
    "NN3" : [maxdd_mc_pct,
                max_1m_loss_mc_pct,
                turnover_mc_pct
                ]
})


mc_table_OLS.index = ['Max DD(%)', "Max 1M loss(%)", "Turnover(%)"]

# %%
mc_table_OLS
# Out:
#                       NN3
# Max DD(%)        4.073993
# Max 1M loss(%)   3.992122
# Turnover(%)     63.162669

# %%
eq_table_OLS.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/ML Performance tables/NN3_eq.csv")
mc_table_OLS.to_csv(r"C:/Users/CMert/Documents/Data bachelorprojekt/ML Performance tables/NN3_mc.csv")

# %% [markdown]
# # Cumulative log returns of portfolio rank 0 and 9

# %%
calc_df
# Out:
#     MonthYear_long  portfolio_true_exc_ret_eq_long  \
# 0          2014-01                        0.111446
# 1          2014-02                        0.078511
# 2          2014-03                        0.035479
# 3          2014-04                        0.048686
# 4          2014-05                        0.097416
# ..             ...                             ...
# 115        2023-08                       -0.031596
# 116        2023-09                       -0.087925
# 117        2023-10                        0.234364
# 118        2023-11                        0.190769
# 119        2023-12                        0.056446
#
#      portfolio_true_exc_ret_mc_long  portfolio_hat_exc_ret_eq_long  \
# 0                          0.049415                       0.208712
# 1                          0.037615                       0.183555
# 2                          0.044579                       0.171996
# 3                          0.031231                       0.170279
# 4                          0.027132                       0.213621
# ..                              ...                            ...
# 115                       -0.058661                       1.413526
# 116                        0.012960                       1.573411
# 117                        0.143280                       2.377115
# 118                        0.040917                       2.544843
# 119                       -0.013535                       2.951134
#
#      portfolio_hat_exc_ret_mc_long  portfolio_true_ret_eq_long  \
# 0                         0.284720                    0.114237
# 1                         0.273595                    0.081270
# 2                         0.261907                    0.038237
# 3                         0.326850                    0.051369
# 4                         0.302187                    0.099958
# ..                             ...                         ...
# 115                       0.206204                   -0.027937
# 116                       0.190103                   -0.083825
# 117                       0.285813                    0.238706
# 118                       0.194033                    0.194702
# 119                       0.169657                    0.059946
#
#      portfolio_true_ret_mc_long  Decile rank_long  MonthIndex  \
# 0                      0.052206                 9           1
# 1                      0.040374                 9           2
# 2                      0.047338                 9           3
# 3                      0.033915                 9           4
# 4                      0.029674                 9           5
# ..                          ...               ...         ...
# 115                   -0.055003                 9         116
# 116                    0.017060                 9         117
# 117                    0.147622                 9         118
# 118                    0.044850                 9         119
# 119                   -0.010035                 9         120
#
#      Mean_true_ER_eq_long  ...  Std_true_ER_mc_short  Sharpe_ratio_eq_short  \
# 0                 0.14733  ...              0.054127              -2.045614
# 1                 0.14733  ...              0.054127              -2.045614
# 2                 0.14733  ...              0.054127              -2.045614
# 3                 0.14733  ...              0.054127              -2.045614
# 4                 0.14733  ...              0.054127              -2.045614
# ..                    ...  ...                   ...                    ...
# 115               0.14733  ...              0.054127              -2.045614
# 116               0.14733  ...              0.054127              -2.045614
# 117               0.14733  ...              0.054127              -2.045614
# 118               0.14733  ...              0.054127              -2.045614
# 119               0.14733  ...              0.054127              -2.045614
#
#      Sharpe_ratio_mc_short  Investment type_short  true_ER_zni_eq  \
# 0                -0.727667                  short        0.074109
# 1                -0.727667                  short        0.140910
# 2                -0.727667                  short        0.125736
# 3                -0.727667                  short        0.088676
# 4                -0.727667                  short        0.075056
# ..                     ...                    ...             ...
# 115              -0.727667                  short        0.058508
# 116              -0.727667                  short        0.050548
# 117              -0.727667                  short        0.193232
# 118              -0.727667                  short        0.074663
# 119              -0.727667                  short        0.156751
#
#      true_ER_zni_mc  pred_ER_zni_eq pred_ER_zni_mc true_R_zni_eq  \
# 0          0.019362        0.275261       0.374338      0.074109
# 1          0.040602        0.264219       0.374064      0.140910
# 2          0.056143        0.243689       0.359970      0.125736
# 3          0.030631        0.240052       0.435455      0.088676
# 4          0.010879        0.294004       0.418127      0.075056
# ..              ...             ...            ...           ...
# 115       -0.039921        1.646808       0.350743      0.058508
# 116        0.079132        1.829298       0.371145      0.050548
# 117        0.074351        2.657592       0.499204      0.193232
# 118       -0.003253        2.852511       0.422136      0.074663
# 119       -0.010602        3.261129       0.405903      0.156751
#
#      true_R_zni_mc
# 0         0.019362
# 1         0.040602
# 2         0.056143
# 3         0.030631
# 4         0.010879
# ..             ...
# 115      -0.039921
# 116       0.079132
# 117       0.074351
# 118      -0.003253
# 119      -0.010602
#
# [120 rows x 41 columns]

# %%
long_df = calc_df.copy()


long_df = long_df.set_index("MonthYear_long")
long_df.sort_values(['MonthYear_long'], inplace = True)


long_df['true_exc_ret_eq_t'] = long_df['portfolio_true_exc_ret_eq_long'].shift(1)


long_df['cum_log_exc_ret_eq_long'] =(np.log(1 + long_df['true_exc_ret_eq_t'])).cumsum()

long_df['cum_log_exc_ret_eq_long'].iloc[0] = 0


long_df[['cum_log_exc_ret_eq_long']].plot(grid=True, figsize=(12, 7))
# Out:
# <Axes: xlabel='MonthYear_long'>

# %%
long_df = calc_df.copy()


long_df = long_df.set_index("MonthYear_long")
long_df.sort_values(['MonthYear_long'], inplace = True)


long_df['true_exc_ret_mc_t'] = long_df['portfolio_true_exc_ret_mc_long'].shift(1)


long_df['cum_log_exc_ret_mc_long'] =(np.log(1 + long_df['true_exc_ret_mc_t'])).cumsum()

long_df['cum_log_exc_ret_mc_long'].iloc[0] = 0

long_df[['cum_log_exc_ret_mc_long']].plot(grid=True, figsize=(12, 7))
# Out:
# <Axes: xlabel='MonthYear_long'>

# %%
short_df = calc_df.copy()


short_df = long_df.set_index("MonthYear_short")
short_df.sort_values(['MonthYear_short'], inplace = True)


short_df['true_exc_ret_eq_t'] = short_df['portfolio_true_exc_ret_eq_short'].shift(1)


short_df['cum_log_exc_ret_eq_short'] = (np.log(1 + short_df['true_exc_ret_eq_t'])).cumsum()

short_df['cum_log_exc_ret_eq_short'].iloc[0] = 0


short_df[['cum_log_exc_ret_eq_short']].plot(grid=True, figsize=(12, 7))
# Out:
# <Axes: xlabel='MonthYear_short'>

# %%
short_df = calc_df.copy()


short_df = long_df.set_index("MonthYear_short")
short_df.sort_values(['MonthYear_short'], inplace = True)


short_df['true_exc_ret_mc_t'] = short_df['portfolio_true_exc_ret_mc_short'].shift(1)


short_df['cum_log_exc_ret_mc_short'] = (np.log(1 + short_df['true_exc_ret_mc_t'])).cumsum()

short_df['cum_log_exc_ret_mc_short'].iloc[0] = 0


short_df[['cum_log_exc_ret_mc_short']].plot(grid=True, figsize=(12, 7))
# Out:
# <Axes: xlabel='MonthYear_short'>

# %%
long_short_OLS_eq = pd.merge(long_df[['cum_log_exc_ret_eq_long']], short_df[['cum_log_exc_ret_eq_short']],left_index=True, right_index=True)


long_short_OLS_eq[["cum_log_exc_ret_eq_long", "cum_log_exc_ret_eq_short"]].plot(grid=True,figsize=(12, 5))
# Out:
# <Axes: xlabel='MonthYear_long'>

# %%
long_short_OLS_eq.to_csv(r'C:/Users/CMert/Documents/Data bachelorprojekt/ML grafer/NN3 eq.csv')

# %%
long_short_OLS_mc = pd.merge(long_df[['cum_log_exc_ret_mc_long']], short_df[['cum_log_exc_ret_mc_short']],left_index=True, right_index=True)


long_short_OLS_mc[["cum_log_exc_ret_mc_long", "cum_log_exc_ret_mc_short"]].plot(grid=True,figsize=(12, 5))
# Out:
# <Axes: xlabel='MonthYear_long'>

# %%
long_short_OLS_mc.to_csv(r'C:/Users/CMert/Documents/Data bachelorprojekt/ML grafer/NN3 mc.csv')

# %% [markdown]
# # Graveyard
